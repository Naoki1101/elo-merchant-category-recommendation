# %%
import numpy as np
import pandas as pd
import datetime
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold, Kfold
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')
np.random.seed(4590)

# %%
df_train = pd.read_csv('./input/train.csv')
df_test = pd.read_csv('./input/test.csv')
df_hist_trans = pd.read_csv('./input/historical_transactions.csv')
df_new_merchant_trans = pd.read_csv('./input/new_merchant_transactions.csv')

# %%
df_hist_trans['purchase_amount'] = np.exp(df_hist_trans['purchase_amount'])
df_new_merchant_trans['purchase_amount'] = np.exp(df_new_merchant_trans['purchase_amount'])

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['category_2'].fillna(1.0,inplace=True)
    df['category_3'].fillna('A',inplace=True)
    df['merchant_id'].fillna('M_ID_00a6ca8a8a',inplace=True)

# %%
def get_new_columns(name,aggs):
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    df['year'] = df['purchase_date'].dt.year
    df['weekofyear'] = df['purchase_date'].dt.weekofyear
    df['month'] = df['purchase_date'].dt.month
    df['dayofweek'] = df['purchase_date'].dt.dayofweek
    df['weekend'] = (df.purchase_date.dt.weekday >=5).astype(int)
    df['hour'] = df['purchase_date'].dt.hour
    df['authorized_flag'] = df['authorized_flag'].map({'Y':1, 'N':0})
    df['category_1'] = df['category_1'].map({'Y':1, 'N':0}) 
    #https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/73244
    df['month_diff'] = ((datetime.datetime.today() - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']

aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['authorized_flag'] = ['sum', 'mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_hist_trans[col+'_mean'] = df_hist_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']    

new_columns = get_new_columns('hist',aggs)
df_hist_trans_group = df_hist_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['hist_purchase_date_diff'] = (df_hist_trans_group['hist_purchase_date_max'] - df_hist_trans_group['hist_purchase_date_min']).dt.days
df_hist_trans_group['hist_purchase_date_average'] = df_hist_trans_group['hist_purchase_date_diff']/df_hist_trans_group['hist_card_id_size']
df_hist_trans_group['hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 175

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']
aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_new_merchant_trans[col+'_mean'] = df_new_merchant_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']
    
new_columns = get_new_columns('new_hist',aggs)
df_hist_trans_group = df_new_merchant_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['new_hist_purchase_date_diff'] = (df_hist_trans_group['new_hist_purchase_date_max'] - df_hist_trans_group['new_hist_purchase_date_min']).dt.days
df_hist_trans_group['new_hist_purchase_date_average'] = df_hist_trans_group['new_hist_purchase_date_diff']/df_hist_trans_group['new_hist_card_id_size']
df_hist_trans_group['new_hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['new_hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 28

# %%
del df_hist_trans;gc.collect()
del df_new_merchant_trans;gc.collect()
df_train.head(5)
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
# 3            2017-09  C_ID_186d6a6901          4          3          0
# 4            2017-11  C_ID_cdbd2c0db2          1          3          0
#
#      target  hist_month_nunique  hist_hour_nunique  hist_weekofyear_nunique  \
# 0 -0.820283                   9                 23                       35
# 1  0.392913                  12                 24                       50
# 2  0.688056                  10                 14                       22
# 3  0.142495                   6                 16                       20
# 4 -0.159749                   4                 22                       17
#
#    hist_dayofweek_nunique               ...                \
# 0                       7               ...
# 1                       7               ...
# 2                       7               ...
# 3                       7               ...
# 4                       7               ...
#
#    new_hist_weekend_sum  new_hist_weekend_mean  new_hist_category_1_sum  \
# 0                   6.0               0.260870                      0.0
# 1                   0.0               0.000000                      0.0
# 2                   1.0               1.000000                      0.0
# 3                   3.0               0.428571                      1.0
# 4                  12.0               0.333333                      2.0
#
#    new_hist_category_1_mean  new_hist_card_id_size  \
# 0                  0.000000                   23.0
# 1                  0.000000                    6.0
# 2                  0.000000                    1.0
# 3                  0.142857                    7.0
# 4                  0.055556                   36.0
#
#    new_hist_category_2_mean_mean  new_hist_category_3_mean_mean  \
# 0                  1.658319e+108                   1.381361e+36
# 1                  1.658319e+108                   3.557623e+25
# 2                   7.789907e+26                   1.381361e+36
# 3                  2.369028e+107                   1.973373e+35
# 4                  1.842577e+107                  3.624714e+107
#
#    new_hist_purchase_date_diff  new_hist_purchase_date_average  \
# 0                         54.0                        2.347826
# 1                         56.0                        9.333333
# 2                          0.0                        0.000000
# 3                         41.0                        5.857143
# 4                         57.0                        1.583333
#
#    new_hist_purchase_date_uptonow
# 0                           229.0
# 1                           259.0
# 2                           230.0
# 3                           240.0
# 4                           230.0
#
# [5 rows x 78 columns]

# %%
df_train['outliers'] = 0
df_train.loc[df_train['target'] < -30, 'outliers'] = 1
df_train['outliers'].value_counts()
# Out:
# 0    199710
# 1      2207
# Name: outliers, dtype: int64

# %%
list_outlier_idx = df_train[df_train.outliers == 1].index.tolist()

# %%
for df in [df_train,df_test]:
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['dayofweek'] = df['first_active_month'].dt.dayofweek
    df['weekofyear'] = df['first_active_month'].dt.weekofyear
    df['month'] = df['first_active_month'].dt.month
    df['elapsed_time'] = (datetime.datetime.today() - df['first_active_month']).dt.days
    df['hist_first_buy'] = (df['hist_purchase_date_min'] - df['first_active_month']).dt.days
    df['new_hist_first_buy'] = (df['new_hist_purchase_date_min'] - df['first_active_month']).dt.days
    for f in ['hist_purchase_date_max','hist_purchase_date_min','new_hist_purchase_date_max',\
                     'new_hist_purchase_date_min']:
        df[f] = df[f].astype(np.int64) * 1e-9
    df['card_id_total'] = df['new_hist_card_id_size']+df['hist_card_id_size']
    df['purchase_amount_total'] = df['new_hist_purchase_amount_sum']+df['hist_purchase_amount_sum']

for f in ['feature_1','feature_2','feature_3']:
    order_label = df_train.groupby([f])['outliers'].mean()
    df_train[f] = df_train[f].map(order_label)
    df_test[f] = df_test[f].map(order_label)

# %%
high_importance_features = [
    "hist_month_diff_mean", 
    "hist_authorized_flag_mean", 
    "hist_category_1_sum", 
    "hist_month_lag_mean", 
    "new_hist_purchase_amount_sum", 
    "new_hist_purchase_date_uptonow"
]

#smoothing
for col in high_importance_features:
    df_train[col] = np.where(df_train[col].values==0, 0.001, df_train[col].values)
    df_test[col] = np.where(df_test[col].values==0, 0.001, df_test[col].values)


for i in range(len(high_importance_features)):
    for j in range(len((high_importance_features)))[i+1:]:
        col1 = high_importance_features[i]
        col2 = high_importance_features[j]
        new_col_name = "{c1}__div__{c2}".format(c1=col1, c2=col2)
        
        df_train[new_col_name] = df_train[col1] / df_train[col2]
        df_test[new_col_name] = df_test[col1] / df_test[col2]

# %%
def merge_new_feature(path):
    df_new_feature = pd.read_csv(path)
    
    df_tr = pd.merge(df_train, df_new_feature, on="card_id", how="left")
    df_te = pd.merge(df_test, df_new_feature, on="card_id", how="left")
    
    return df_tr, df_te

# %%
df_train, df_test = merge_new_feature("./input/merchants_nmf.csv")
df_train, df_test = merge_new_feature("./input/new_merchants_nmf.csv")
df_train, df_test = merge_new_feature("./input/prosperity_merchants_latest.csv")
df_train, df_test = merge_new_feature("./input/merchants_numerical_features.csv")
df_train, df_test = merge_new_feature("./input/merchants_item_scale_feature.csv")

# %%
df_train_columns = [c for c in df_train.columns if c not in ['card_id', 'first_active_month','target','outliers']]
target = df_train['target']
del df_train['target']

# %%
#original
param = {'num_leaves': 31,
         'min_data_in_leaf': 30, 
         'objective':'regression',
         'max_depth': -1,
         'learning_rate': 0.004,
         "min_child_samples": 20,
         "boosting": "gbdt",
         "feature_fraction": 0.9,
         "bagging_freq": 1,
         "bagging_fraction": 0.9 ,
         "bagging_seed": 11,
         "metric": 'rmse',
         "lambda_l1": 0.1,
         "verbosity": -1,
         "nthread": 4,
         "random_state": 4590}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=4590)
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74134	valid_1's rmse: 3.77821
# [200]	training's rmse: 3.67354	valid_1's rmse: 3.73436
# [300]	training's rmse: 3.62625	valid_1's rmse: 3.71004
# [400]	training's rmse: 3.58941	valid_1's rmse: 3.69486
# [500]	training's rmse: 3.56019	valid_1's rmse: 3.68401
# [600]	training's rmse: 3.53681	valid_1's rmse: 3.67716
# [700]	training's rmse: 3.51646	valid_1's rmse: 3.67197
# [800]	training's rmse: 3.49851	valid_1's rmse: 3.66763
# [900]	training's rmse: 3.48207	valid_1's rmse: 3.66463
# [1000]	training's rmse: 3.467	valid_1's rmse: 3.66177
# [1100]	training's rmse: 3.45274	valid_1's rmse: 3.65982
# [1200]	training's rmse: 3.43921	valid_1's rmse: 3.65828
# [1300]	training's rmse: 3.42693	valid_1's rmse: 3.65667
# [1400]	training's rmse: 3.41496	valid_1's rmse: 3.65564
# [1500]	training's rmse: 3.40399	valid_1's rmse: 3.65435
# [1600]	training's rmse: 3.39343	valid_1's rmse: 3.65342
# [1700]	training's rmse: 3.38316	valid_1's rmse: 3.65241
# [1800]	training's rmse: 3.37347	valid_1's rmse: 3.65174
# [1900]	training's rmse: 3.36376	valid_1's rmse: 3.65102
# [2000]	training's rmse: 3.35424	valid_1's rmse: 3.65055
# [2100]	training's rmse: 3.3454	valid_1's rmse: 3.65027
# [2200]	training's rmse: 3.33725	valid_1's rmse: 3.64996
# [2300]	training's rmse: 3.32857	valid_1's rmse: 3.64971
# [2400]	training's rmse: 3.3204	valid_1's rmse: 3.64963
# [2500]	training's rmse: 3.31258	valid_1's rmse: 3.64949
# [2600]	training's rmse: 3.30498	valid_1's rmse: 3.64941
# [2700]	training's rmse: 3.2976	valid_1's rmse: 3.64914
# [2800]	training's rmse: 3.29037	valid_1's rmse: 3.64902
# [2900]	training's rmse: 3.28284	valid_1's rmse: 3.64891
# [3000]	training's rmse: 3.27558	valid_1's rmse: 3.64876
# [3100]	training's rmse: 3.26838	valid_1's rmse: 3.64875
# [3200]	training's rmse: 3.26116	valid_1's rmse: 3.6486
# [3300]	training's rmse: 3.25434	valid_1's rmse: 3.64859
# [3400]	training's rmse: 3.24774	valid_1's rmse: 3.64863
# [3500]	training's rmse: 3.24121	valid_1's rmse: 3.64844
# [3600]	training's rmse: 3.23457	valid_1's rmse: 3.64835
# [3700]	training's rmse: 3.22836	valid_1's rmse: 3.64823
# [3800]	training's rmse: 3.22165	valid_1's rmse: 3.64798
# [3900]	training's rmse: 3.21539	valid_1's rmse: 3.648
# [4000]	training's rmse: 3.20884	valid_1's rmse: 3.64799
# [4100]	training's rmse: 3.2023	valid_1's rmse: 3.64801
# [4200]	training's rmse: 3.19612	valid_1's rmse: 3.64804
# [4300]	training's rmse: 3.19031	valid_1's rmse: 3.64826
# Early stopping, best iteration is:
# [3943]	training's rmse: 3.2125	valid_1's rmse: 3.64792
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74201	valid_1's rmse: 3.76737
# [200]	training's rmse: 3.67433	valid_1's rmse: 3.72547
# [300]	training's rmse: 3.62612	valid_1's rmse: 3.70238
# [400]	training's rmse: 3.58903	valid_1's rmse: 3.68855
# [500]	training's rmse: 3.55948	valid_1's rmse: 3.67975
# [600]	training's rmse: 3.53551	valid_1's rmse: 3.67408
# [700]	training's rmse: 3.51509	valid_1's rmse: 3.67031
# [800]	training's rmse: 3.49675	valid_1's rmse: 3.66682
# [900]	training's rmse: 3.47982	valid_1's rmse: 3.66412
# [1000]	training's rmse: 3.46472	valid_1's rmse: 3.66217
# [1100]	training's rmse: 3.45111	valid_1's rmse: 3.66026
# [1200]	training's rmse: 3.43793	valid_1's rmse: 3.65878
# [1300]	training's rmse: 3.42509	valid_1's rmse: 3.65757
# [1400]	training's rmse: 3.41291	valid_1's rmse: 3.65666
# [1500]	training's rmse: 3.40153	valid_1's rmse: 3.65569
# [1600]	training's rmse: 3.39092	valid_1's rmse: 3.65495
# [1700]	training's rmse: 3.38056	valid_1's rmse: 3.65466
# [1800]	training's rmse: 3.37046	valid_1's rmse: 3.65435
# [1900]	training's rmse: 3.36092	valid_1's rmse: 3.65387
# [2000]	training's rmse: 3.35154	valid_1's rmse: 3.6537
# [2100]	training's rmse: 3.34258	valid_1's rmse: 3.65342
# [2200]	training's rmse: 3.33398	valid_1's rmse: 3.65337
# [2300]	training's rmse: 3.32519	valid_1's rmse: 3.65341
# [2400]	training's rmse: 3.31693	valid_1's rmse: 3.65306
# [2500]	training's rmse: 3.30858	valid_1's rmse: 3.65285
# [2600]	training's rmse: 3.30053	valid_1's rmse: 3.65267
# [2700]	training's rmse: 3.2925	valid_1's rmse: 3.65246
# [2800]	training's rmse: 3.28489	valid_1's rmse: 3.65245
# [2900]	training's rmse: 3.27728	valid_1's rmse: 3.65249
# [3000]	training's rmse: 3.27051	valid_1's rmse: 3.65248
# [3100]	training's rmse: 3.26335	valid_1's rmse: 3.65235
# [3200]	training's rmse: 3.2567	valid_1's rmse: 3.65234
# [3300]	training's rmse: 3.24934	valid_1's rmse: 3.65219
# [3400]	training's rmse: 3.24276	valid_1's rmse: 3.65208
# [3500]	training's rmse: 3.23595	valid_1's rmse: 3.65192
# [3600]	training's rmse: 3.22912	valid_1's rmse: 3.65186
# [3700]	training's rmse: 3.22265	valid_1's rmse: 3.65172
# [3800]	training's rmse: 3.21578	valid_1's rmse: 3.65167
# [3900]	training's rmse: 3.20909	valid_1's rmse: 3.65139
# [4000]	training's rmse: 3.20209	valid_1's rmse: 3.65114
# [4100]	training's rmse: 3.19583	valid_1's rmse: 3.65113
# [4200]	training's rmse: 3.18911	valid_1's rmse: 3.65102
# [4300]	training's rmse: 3.18284	valid_1's rmse: 3.65088
# [4400]	training's rmse: 3.17668	valid_1's rmse: 3.65097
# [4500]	training's rmse: 3.17042	valid_1's rmse: 3.65097
# [4600]	training's rmse: 3.16473	valid_1's rmse: 3.65103
# Early stopping, best iteration is:
# [4255]	training's rmse: 3.18581	valid_1's rmse: 3.65085
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74011	valid_1's rmse: 3.77418
# [200]	training's rmse: 3.67197	valid_1's rmse: 3.73077
# [300]	training's rmse: 3.62389	valid_1's rmse: 3.70669
# [400]	training's rmse: 3.58588	valid_1's rmse: 3.6927
# [500]	training's rmse: 3.55611	valid_1's rmse: 3.68288
# [600]	training's rmse: 3.53236	valid_1's rmse: 3.67659
# [700]	training's rmse: 3.51183	valid_1's rmse: 3.67179
# [800]	training's rmse: 3.49318	valid_1's rmse: 3.6682
# [900]	training's rmse: 3.47714	valid_1's rmse: 3.66518
# [1000]	training's rmse: 3.46203	valid_1's rmse: 3.66261
# [1100]	training's rmse: 3.44722	valid_1's rmse: 3.66065
# [1200]	training's rmse: 3.43369	valid_1's rmse: 3.65879
# [1300]	training's rmse: 3.42116	valid_1's rmse: 3.65725
# [1400]	training's rmse: 3.40918	valid_1's rmse: 3.65598
# [1500]	training's rmse: 3.3975	valid_1's rmse: 3.65477
# [1600]	training's rmse: 3.38663	valid_1's rmse: 3.65378
# [1700]	training's rmse: 3.37625	valid_1's rmse: 3.65276
# [1800]	training's rmse: 3.36609	valid_1's rmse: 3.65191
# [1900]	training's rmse: 3.35654	valid_1's rmse: 3.6514
# [2000]	training's rmse: 3.3469	valid_1's rmse: 3.65095
# [2100]	training's rmse: 3.33828	valid_1's rmse: 3.65029
# [2200]	training's rmse: 3.32969	valid_1's rmse: 3.64976
# [2300]	training's rmse: 3.32107	valid_1's rmse: 3.64937
# [2400]	training's rmse: 3.31256	valid_1's rmse: 3.64898
# [2500]	training's rmse: 3.30432	valid_1's rmse: 3.64867
# [2600]	training's rmse: 3.29648	valid_1's rmse: 3.64852
# [2700]	training's rmse: 3.28907	valid_1's rmse: 3.64816
# [2800]	training's rmse: 3.28157	valid_1's rmse: 3.64807
# [2900]	training's rmse: 3.27429	valid_1's rmse: 3.64788
# [3000]	training's rmse: 3.26692	valid_1's rmse: 3.64784
# [3100]	training's rmse: 3.25973	valid_1's rmse: 3.64782
# [3200]	training's rmse: 3.25253	valid_1's rmse: 3.64772
# [3300]	training's rmse: 3.24541	valid_1's rmse: 3.64759
# [3400]	training's rmse: 3.23902	valid_1's rmse: 3.64744
# [3500]	training's rmse: 3.23217	valid_1's rmse: 3.64748
# [3600]	training's rmse: 3.22554	valid_1's rmse: 3.64728
# [3700]	training's rmse: 3.21899	valid_1's rmse: 3.64728
# [3800]	training's rmse: 3.21223	valid_1's rmse: 3.64712
# [3900]	training's rmse: 3.20594	valid_1's rmse: 3.64708
# [4000]	training's rmse: 3.1995	valid_1's rmse: 3.64689
# [4100]	training's rmse: 3.19345	valid_1's rmse: 3.64679
# [4200]	training's rmse: 3.18717	valid_1's rmse: 3.64683
# [4300]	training's rmse: 3.18098	valid_1's rmse: 3.64705
# [4400]	training's rmse: 3.17488	valid_1's rmse: 3.64701
# [4500]	training's rmse: 3.1687	valid_1's rmse: 3.64714
# Early stopping, best iteration is:
# [4181]	training's rmse: 3.18823	valid_1's rmse: 3.64672
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74239	valid_1's rmse: 3.77033
# [200]	training's rmse: 3.67408	valid_1's rmse: 3.72911
# [300]	training's rmse: 3.62579	valid_1's rmse: 3.70627
# [400]	training's rmse: 3.58808	valid_1's rmse: 3.693
# [500]	training's rmse: 3.5577	valid_1's rmse: 3.68417
# [600]	training's rmse: 3.5326	valid_1's rmse: 3.67842
# [700]	training's rmse: 3.51096	valid_1's rmse: 3.67411
# [800]	training's rmse: 3.49235	valid_1's rmse: 3.67045
# [900]	training's rmse: 3.47578	valid_1's rmse: 3.66781
# [1000]	training's rmse: 3.46098	valid_1's rmse: 3.66526
# [1100]	training's rmse: 3.44695	valid_1's rmse: 3.66262
# [1200]	training's rmse: 3.43426	valid_1's rmse: 3.66061
# [1300]	training's rmse: 3.42187	valid_1's rmse: 3.65898
# [1400]	training's rmse: 3.40981	valid_1's rmse: 3.65758
# [1500]	training's rmse: 3.39839	valid_1's rmse: 3.65651
# [1600]	training's rmse: 3.38708	valid_1's rmse: 3.65549
# [1700]	training's rmse: 3.37644	valid_1's rmse: 3.65457
# [1800]	training's rmse: 3.36656	valid_1's rmse: 3.6538
# [1900]	training's rmse: 3.35685	valid_1's rmse: 3.65333
# [2000]	training's rmse: 3.34741	valid_1's rmse: 3.65297
# [2100]	training's rmse: 3.3383	valid_1's rmse: 3.65235
# [2200]	training's rmse: 3.32934	valid_1's rmse: 3.6519
# [2300]	training's rmse: 3.32082	valid_1's rmse: 3.65165
# [2400]	training's rmse: 3.31243	valid_1's rmse: 3.65132
# [2500]	training's rmse: 3.3044	valid_1's rmse: 3.65116
# [2600]	training's rmse: 3.29669	valid_1's rmse: 3.65085
# [2700]	training's rmse: 3.28882	valid_1's rmse: 3.6506
# [2800]	training's rmse: 3.28117	valid_1's rmse: 3.65044
# [2900]	training's rmse: 3.274	valid_1's rmse: 3.65012
# [3000]	training's rmse: 3.26658	valid_1's rmse: 3.64975
# [3100]	training's rmse: 3.25949	valid_1's rmse: 3.64967
# [3200]	training's rmse: 3.25279	valid_1's rmse: 3.64944
# [3300]	training's rmse: 3.24579	valid_1's rmse: 3.64933
# [3400]	training's rmse: 3.23889	valid_1's rmse: 3.64935
# [3500]	training's rmse: 3.232	valid_1's rmse: 3.64921
# [3600]	training's rmse: 3.22511	valid_1's rmse: 3.64915
# [3700]	training's rmse: 3.21888	valid_1's rmse: 3.64904
# [3800]	training's rmse: 3.21245	valid_1's rmse: 3.64896
# [3900]	training's rmse: 3.20557	valid_1's rmse: 3.64882
# [4000]	training's rmse: 3.1995	valid_1's rmse: 3.64878
# [4100]	training's rmse: 3.19294	valid_1's rmse: 3.64877
# [4200]	training's rmse: 3.18673	valid_1's rmse: 3.64865
# [4300]	training's rmse: 3.18015	valid_1's rmse: 3.64866
# [4400]	training's rmse: 3.17415	valid_1's rmse: 3.64858
# [4500]	training's rmse: 3.16789	valid_1's rmse: 3.64861
# [4600]	training's rmse: 3.16215	valid_1's rmse: 3.64868
# [4700]	training's rmse: 3.15594	valid_1's rmse: 3.64887
# [4800]	training's rmse: 3.15016	valid_1's rmse: 3.64893
# Early stopping, best iteration is:
# [4403]	training's rmse: 3.17391	valid_1's rmse: 3.64851
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74362	valid_1's rmse: 3.75641
# [200]	training's rmse: 3.67478	valid_1's rmse: 3.71598
# [300]	training's rmse: 3.62622	valid_1's rmse: 3.69436
# [400]	training's rmse: 3.58877	valid_1's rmse: 3.68009
# [500]	training's rmse: 3.5589	valid_1's rmse: 3.67106
# [600]	training's rmse: 3.53487	valid_1's rmse: 3.66478
# [700]	training's rmse: 3.51345	valid_1's rmse: 3.65981
# [800]	training's rmse: 3.49531	valid_1's rmse: 3.65626
# [900]	training's rmse: 3.47843	valid_1's rmse: 3.65362
# [1000]	training's rmse: 3.46315	valid_1's rmse: 3.65188
# [1100]	training's rmse: 3.44898	valid_1's rmse: 3.65039
# [1200]	training's rmse: 3.43581	valid_1's rmse: 3.64931
# [1300]	training's rmse: 3.42386	valid_1's rmse: 3.64779
# [1400]	training's rmse: 3.41184	valid_1's rmse: 3.6463
# [1500]	training's rmse: 3.40005	valid_1's rmse: 3.6456
# [1600]	training's rmse: 3.38881	valid_1's rmse: 3.64476
# [1700]	training's rmse: 3.37858	valid_1's rmse: 3.64405
# [1800]	training's rmse: 3.36839	valid_1's rmse: 3.64346
# [1900]	training's rmse: 3.35886	valid_1's rmse: 3.64295
# [2000]	training's rmse: 3.34956	valid_1's rmse: 3.64265
# [2100]	training's rmse: 3.34055	valid_1's rmse: 3.64231
# [2200]	training's rmse: 3.33141	valid_1's rmse: 3.64202
# [2300]	training's rmse: 3.32298	valid_1's rmse: 3.64177
# [2400]	training's rmse: 3.31448	valid_1's rmse: 3.64165
# [2500]	training's rmse: 3.30654	valid_1's rmse: 3.64166
# [2600]	training's rmse: 3.29831	valid_1's rmse: 3.64174
# [2700]	training's rmse: 3.29011	valid_1's rmse: 3.64186
# [2800]	training's rmse: 3.28244	valid_1's rmse: 3.64178
# Early stopping, best iteration is:
# [2481]	training's rmse: 3.30807	valid_1's rmse: 3.6416
# 3.6471213133496283

# %%
# score:  3.6458692529031196

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
# plt.savefig('lgbm_importances.png')

# %%
df_train2 = df_train.drop(list_outlier_idx, axis=0).reset_index(drop=True)
target = target.drop(list_outlier_idx, axis=0).reset_index(drop=True)

folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=4590)
oof = np.zeros(len(df_train2))
predictions2 = np.zeros(len(df_test))
feature_importance_df2 = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train2, df_train2['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train2.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train2.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train2.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df2 = pd.DataFrame()
    fold_importance_df2["Feature"] = df_train_columns
    fold_importance_df2["importance"] = clf.feature_importance()
    fold_importance_df2["fold"] = fold_ + 1
    feature_importance_df2 = pd.concat([feature_importance_df2, fold_importance_df2], axis=0)
    
    predictions2 += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.64715	valid_1's rmse: 1.67529
# [200]	training's rmse: 1.61211	valid_1's rmse: 1.64286
# [300]	training's rmse: 1.59154	valid_1's rmse: 1.62448
# [400]	training's rmse: 1.5784	valid_1's rmse: 1.61335
# [500]	training's rmse: 1.56904	valid_1's rmse: 1.60594
# [600]	training's rmse: 1.56197	valid_1's rmse: 1.60081
# [700]	training's rmse: 1.55623	valid_1's rmse: 1.59694
# [800]	training's rmse: 1.55141	valid_1's rmse: 1.59401
# [900]	training's rmse: 1.54722	valid_1's rmse: 1.59169
# [1000]	training's rmse: 1.54343	valid_1's rmse: 1.5898
# [1100]	training's rmse: 1.54001	valid_1's rmse: 1.58833
# [1200]	training's rmse: 1.53679	valid_1's rmse: 1.58701
# [1300]	training's rmse: 1.53381	valid_1's rmse: 1.58597
# [1400]	training's rmse: 1.53093	valid_1's rmse: 1.585
# [1500]	training's rmse: 1.52826	valid_1's rmse: 1.5842
# [1600]	training's rmse: 1.52575	valid_1's rmse: 1.58361
# [1700]	training's rmse: 1.52328	valid_1's rmse: 1.58307
# [1800]	training's rmse: 1.52096	valid_1's rmse: 1.58263
# [1900]	training's rmse: 1.51871	valid_1's rmse: 1.58224
# [2000]	training's rmse: 1.51651	valid_1's rmse: 1.58193
# [2100]	training's rmse: 1.51444	valid_1's rmse: 1.58165
# [2200]	training's rmse: 1.51239	valid_1's rmse: 1.58143
# [2300]	training's rmse: 1.51038	valid_1's rmse: 1.58122
# [2400]	training's rmse: 1.50842	valid_1's rmse: 1.58103
# [2500]	training's rmse: 1.50652	valid_1's rmse: 1.58088
# [2600]	training's rmse: 1.50461	valid_1's rmse: 1.58072
# [2700]	training's rmse: 1.50279	valid_1's rmse: 1.58055
# [2800]	training's rmse: 1.50104	valid_1's rmse: 1.58045
# [2900]	training's rmse: 1.49927	valid_1's rmse: 1.58035
# [3000]	training's rmse: 1.49746	valid_1's rmse: 1.58026
# [3100]	training's rmse: 1.49573	valid_1's rmse: 1.58014
# [3200]	training's rmse: 1.49396	valid_1's rmse: 1.58001
# [3300]	training's rmse: 1.49232	valid_1's rmse: 1.57992
# [3400]	training's rmse: 1.49061	valid_1's rmse: 1.57983
# [3500]	training's rmse: 1.4889	valid_1's rmse: 1.57976
# [3600]	training's rmse: 1.48724	valid_1's rmse: 1.57968
# [3700]	training's rmse: 1.48562	valid_1's rmse: 1.57961
# [3800]	training's rmse: 1.484	valid_1's rmse: 1.57954
# [3900]	training's rmse: 1.4824	valid_1's rmse: 1.5795
# [4000]	training's rmse: 1.48079	valid_1's rmse: 1.57945
# [4100]	training's rmse: 1.47919	valid_1's rmse: 1.57939
# [4200]	training's rmse: 1.47762	valid_1's rmse: 1.57935
# [4300]	training's rmse: 1.47605	valid_1's rmse: 1.57932
# [4400]	training's rmse: 1.47448	valid_1's rmse: 1.57931
# [4500]	training's rmse: 1.47292	valid_1's rmse: 1.57927
# [4600]	training's rmse: 1.47144	valid_1's rmse: 1.57924
# [4700]	training's rmse: 1.4699	valid_1's rmse: 1.57923
# [4800]	training's rmse: 1.46835	valid_1's rmse: 1.57921
# [4900]	training's rmse: 1.46683	valid_1's rmse: 1.57924
# [5000]	training's rmse: 1.46534	valid_1's rmse: 1.57921
# [5100]	training's rmse: 1.46385	valid_1's rmse: 1.57922
# [5200]	training's rmse: 1.46233	valid_1's rmse: 1.57918
# [5300]	training's rmse: 1.46086	valid_1's rmse: 1.57916
# [5400]	training's rmse: 1.4594	valid_1's rmse: 1.57911
# [5500]	training's rmse: 1.45793	valid_1's rmse: 1.57913
# [5600]	training's rmse: 1.45643	valid_1's rmse: 1.57913
# [5700]	training's rmse: 1.45489	valid_1's rmse: 1.57912
# [5800]	training's rmse: 1.45345	valid_1's rmse: 1.57911
# [5900]	training's rmse: 1.45201	valid_1's rmse: 1.57906
# [6000]	training's rmse: 1.45058	valid_1's rmse: 1.57905
# [6100]	training's rmse: 1.44917	valid_1's rmse: 1.579
# [6200]	training's rmse: 1.44772	valid_1's rmse: 1.57898
# [6300]	training's rmse: 1.44632	valid_1's rmse: 1.579
# [6400]	training's rmse: 1.44492	valid_1's rmse: 1.57896
# [6500]	training's rmse: 1.44356	valid_1's rmse: 1.57898
# [6600]	training's rmse: 1.44213	valid_1's rmse: 1.57896
# [6700]	training's rmse: 1.44072	valid_1's rmse: 1.57891
# [6800]	training's rmse: 1.43927	valid_1's rmse: 1.57892
# [6900]	training's rmse: 1.43786	valid_1's rmse: 1.57892
# [7000]	training's rmse: 1.43649	valid_1's rmse: 1.5789
# [7100]	training's rmse: 1.43513	valid_1's rmse: 1.57891
# [7200]	training's rmse: 1.43375	valid_1's rmse: 1.5789
# [7300]	training's rmse: 1.43236	valid_1's rmse: 1.57892
# [7400]	training's rmse: 1.43101	valid_1's rmse: 1.5789
# [7500]	training's rmse: 1.42961	valid_1's rmse: 1.5789
# [7600]	training's rmse: 1.42825	valid_1's rmse: 1.57892
# [7700]	training's rmse: 1.42687	valid_1's rmse: 1.57889
# [7800]	training's rmse: 1.42551	valid_1's rmse: 1.57889
# [7900]	training's rmse: 1.42413	valid_1's rmse: 1.57888
# [8000]	training's rmse: 1.42273	valid_1's rmse: 1.57884
# [8100]	training's rmse: 1.42142	valid_1's rmse: 1.57886
# [8200]	training's rmse: 1.42008	valid_1's rmse: 1.57889
# [8300]	training's rmse: 1.41876	valid_1's rmse: 1.57889
# [8400]	training's rmse: 1.41744	valid_1's rmse: 1.57889
# Early stopping, best iteration is:
# [8033]	training's rmse: 1.4223	valid_1's rmse: 1.57884
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65425	valid_1's rmse: 1.64684
# [200]	training's rmse: 1.61917	valid_1's rmse: 1.6144
# [300]	training's rmse: 1.59854	valid_1's rmse: 1.59612
# [400]	training's rmse: 1.58516	valid_1's rmse: 1.58501
# [500]	training's rmse: 1.57561	valid_1's rmse: 1.57769
# [600]	training's rmse: 1.56843	valid_1's rmse: 1.5727
# [700]	training's rmse: 1.56267	valid_1's rmse: 1.56909
# [800]	training's rmse: 1.55776	valid_1's rmse: 1.56631
# [900]	training's rmse: 1.55351	valid_1's rmse: 1.5641
# [1000]	training's rmse: 1.54966	valid_1's rmse: 1.56235
# [1100]	training's rmse: 1.54614	valid_1's rmse: 1.56099
# [1200]	training's rmse: 1.54289	valid_1's rmse: 1.55985
# [1300]	training's rmse: 1.5398	valid_1's rmse: 1.55884
# [1400]	training's rmse: 1.53695	valid_1's rmse: 1.55797
# [1500]	training's rmse: 1.53427	valid_1's rmse: 1.55734
# [1600]	training's rmse: 1.53169	valid_1's rmse: 1.55681
# [1700]	training's rmse: 1.52923	valid_1's rmse: 1.55629
# [1800]	training's rmse: 1.52688	valid_1's rmse: 1.55585
# [1900]	training's rmse: 1.52464	valid_1's rmse: 1.55547
# [2000]	training's rmse: 1.52243	valid_1's rmse: 1.55519
# [2100]	training's rmse: 1.5203	valid_1's rmse: 1.55492
# [2200]	training's rmse: 1.51831	valid_1's rmse: 1.5547
# [2300]	training's rmse: 1.51628	valid_1's rmse: 1.5545
# [2400]	training's rmse: 1.5143	valid_1's rmse: 1.55432
# [2500]	training's rmse: 1.5124	valid_1's rmse: 1.55416
# [2600]	training's rmse: 1.51052	valid_1's rmse: 1.55401
# [2700]	training's rmse: 1.50867	valid_1's rmse: 1.55392
# [2800]	training's rmse: 1.50685	valid_1's rmse: 1.55378
# [2900]	training's rmse: 1.50508	valid_1's rmse: 1.55369
# [3000]	training's rmse: 1.5033	valid_1's rmse: 1.5536
# [3100]	training's rmse: 1.50158	valid_1's rmse: 1.55351
# [3200]	training's rmse: 1.49982	valid_1's rmse: 1.55342
# [3300]	training's rmse: 1.49809	valid_1's rmse: 1.55334
# [3400]	training's rmse: 1.49641	valid_1's rmse: 1.55326
# [3500]	training's rmse: 1.49475	valid_1's rmse: 1.55321
# [3600]	training's rmse: 1.49311	valid_1's rmse: 1.55315
# [3700]	training's rmse: 1.4915	valid_1's rmse: 1.55311
# [3800]	training's rmse: 1.48984	valid_1's rmse: 1.55308
# [3900]	training's rmse: 1.48821	valid_1's rmse: 1.55306
# [4000]	training's rmse: 1.48663	valid_1's rmse: 1.55301
# [4100]	training's rmse: 1.48509	valid_1's rmse: 1.55296
# [4200]	training's rmse: 1.48345	valid_1's rmse: 1.55288
# [4300]	training's rmse: 1.48187	valid_1's rmse: 1.55285
# [4400]	training's rmse: 1.48036	valid_1's rmse: 1.55285
# [4500]	training's rmse: 1.47884	valid_1's rmse: 1.5528
# [4600]	training's rmse: 1.47733	valid_1's rmse: 1.55276
# [4700]	training's rmse: 1.47577	valid_1's rmse: 1.55274
# [4800]	training's rmse: 1.47423	valid_1's rmse: 1.55273
# [4900]	training's rmse: 1.47275	valid_1's rmse: 1.5527
# [5000]	training's rmse: 1.47125	valid_1's rmse: 1.55268
# [5100]	training's rmse: 1.46977	valid_1's rmse: 1.55264
# [5200]	training's rmse: 1.46828	valid_1's rmse: 1.55262
# [5300]	training's rmse: 1.46681	valid_1's rmse: 1.55265
# [5400]	training's rmse: 1.46534	valid_1's rmse: 1.55262
# [5500]	training's rmse: 1.46386	valid_1's rmse: 1.55261
# [5600]	training's rmse: 1.46241	valid_1's rmse: 1.5526
# [5700]	training's rmse: 1.46093	valid_1's rmse: 1.5526
# [5800]	training's rmse: 1.4595	valid_1's rmse: 1.55257
# [5900]	training's rmse: 1.45802	valid_1's rmse: 1.55255
# [6000]	training's rmse: 1.45657	valid_1's rmse: 1.55254
# [6100]	training's rmse: 1.45512	valid_1's rmse: 1.55251
# [6200]	training's rmse: 1.45372	valid_1's rmse: 1.55244
# [6300]	training's rmse: 1.45228	valid_1's rmse: 1.55241
# [6400]	training's rmse: 1.4509	valid_1's rmse: 1.55239
# [6500]	training's rmse: 1.44948	valid_1's rmse: 1.55233
# [6600]	training's rmse: 1.44812	valid_1's rmse: 1.55233
# [6700]	training's rmse: 1.44674	valid_1's rmse: 1.55232
# [6800]	training's rmse: 1.44535	valid_1's rmse: 1.55234
# [6900]	training's rmse: 1.44399	valid_1's rmse: 1.55233
# [7000]	training's rmse: 1.44257	valid_1's rmse: 1.55235
# [7100]	training's rmse: 1.44121	valid_1's rmse: 1.55234
# Early stopping, best iteration is:
# [6731]	training's rmse: 1.44629	valid_1's rmse: 1.55231
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.64815	valid_1's rmse: 1.67265
# [200]	training's rmse: 1.61309	valid_1's rmse: 1.63967
# [300]	training's rmse: 1.59267	valid_1's rmse: 1.62109
# [400]	training's rmse: 1.57957	valid_1's rmse: 1.60973
# [500]	training's rmse: 1.57023	valid_1's rmse: 1.60208
# [600]	training's rmse: 1.5632	valid_1's rmse: 1.59676
# [700]	training's rmse: 1.55751	valid_1's rmse: 1.5929
# [800]	training's rmse: 1.55274	valid_1's rmse: 1.58989
# [900]	training's rmse: 1.54853	valid_1's rmse: 1.58753
# [1000]	training's rmse: 1.54477	valid_1's rmse: 1.58563
# [1100]	training's rmse: 1.54133	valid_1's rmse: 1.58404
# [1200]	training's rmse: 1.53811	valid_1's rmse: 1.58267
# [1300]	training's rmse: 1.53508	valid_1's rmse: 1.58153
# [1400]	training's rmse: 1.53224	valid_1's rmse: 1.58063
# [1500]	training's rmse: 1.52958	valid_1's rmse: 1.57984
# [1600]	training's rmse: 1.52704	valid_1's rmse: 1.57922
# [1700]	training's rmse: 1.5246	valid_1's rmse: 1.57867
# [1800]	training's rmse: 1.52229	valid_1's rmse: 1.57831
# [1900]	training's rmse: 1.52007	valid_1's rmse: 1.57796
# [2000]	training's rmse: 1.51791	valid_1's rmse: 1.5777
# [2100]	training's rmse: 1.51581	valid_1's rmse: 1.57745
# [2200]	training's rmse: 1.51376	valid_1's rmse: 1.57718
# [2300]	training's rmse: 1.5118	valid_1's rmse: 1.57697
# [2400]	training's rmse: 1.50986	valid_1's rmse: 1.57681
# [2500]	training's rmse: 1.50797	valid_1's rmse: 1.57665
# [2600]	training's rmse: 1.50613	valid_1's rmse: 1.57647
# [2700]	training's rmse: 1.50426	valid_1's rmse: 1.57627
# [2800]	training's rmse: 1.50248	valid_1's rmse: 1.57616
# [2900]	training's rmse: 1.50071	valid_1's rmse: 1.57606
# [3000]	training's rmse: 1.49897	valid_1's rmse: 1.57595
# [3100]	training's rmse: 1.49723	valid_1's rmse: 1.57585
# [3200]	training's rmse: 1.4955	valid_1's rmse: 1.57576
# [3300]	training's rmse: 1.49386	valid_1's rmse: 1.57568
# [3400]	training's rmse: 1.49223	valid_1's rmse: 1.57564
# [3500]	training's rmse: 1.49058	valid_1's rmse: 1.57554
# [3600]	training's rmse: 1.48895	valid_1's rmse: 1.57547
# [3700]	training's rmse: 1.48729	valid_1's rmse: 1.57537
# [3800]	training's rmse: 1.48569	valid_1's rmse: 1.57529
# [3900]	training's rmse: 1.48407	valid_1's rmse: 1.57528
# [4000]	training's rmse: 1.48248	valid_1's rmse: 1.57527
# [4100]	training's rmse: 1.48091	valid_1's rmse: 1.57525
# [4200]	training's rmse: 1.47934	valid_1's rmse: 1.57521
# [4300]	training's rmse: 1.4778	valid_1's rmse: 1.57514
# [4400]	training's rmse: 1.47626	valid_1's rmse: 1.57506
# [4500]	training's rmse: 1.47474	valid_1's rmse: 1.57506
# [4600]	training's rmse: 1.47322	valid_1's rmse: 1.575
# [4700]	training's rmse: 1.47167	valid_1's rmse: 1.57495
# [4800]	training's rmse: 1.47016	valid_1's rmse: 1.57491
# [4900]	training's rmse: 1.46866	valid_1's rmse: 1.57487
# [5000]	training's rmse: 1.46713	valid_1's rmse: 1.57486
# [5100]	training's rmse: 1.46566	valid_1's rmse: 1.57486
# [5200]	training's rmse: 1.46418	valid_1's rmse: 1.57481
# [5300]	training's rmse: 1.46268	valid_1's rmse: 1.57476
# [5400]	training's rmse: 1.46125	valid_1's rmse: 1.57477
# [5500]	training's rmse: 1.45981	valid_1's rmse: 1.57475
# [5600]	training's rmse: 1.45833	valid_1's rmse: 1.57472
# [5700]	training's rmse: 1.45684	valid_1's rmse: 1.57467
# [5800]	training's rmse: 1.4554	valid_1's rmse: 1.57463
# [5900]	training's rmse: 1.45398	valid_1's rmse: 1.57461
# [6000]	training's rmse: 1.45259	valid_1's rmse: 1.57457
# [6100]	training's rmse: 1.45115	valid_1's rmse: 1.57452
# [6200]	training's rmse: 1.44969	valid_1's rmse: 1.57452
# [6300]	training's rmse: 1.44829	valid_1's rmse: 1.57451
# [6400]	training's rmse: 1.44688	valid_1's rmse: 1.57447
# [6500]	training's rmse: 1.44547	valid_1's rmse: 1.57444
# [6600]	training's rmse: 1.44404	valid_1's rmse: 1.5744
# [6700]	training's rmse: 1.44269	valid_1's rmse: 1.57437
# [6800]	training's rmse: 1.4413	valid_1's rmse: 1.57435
# [6900]	training's rmse: 1.43991	valid_1's rmse: 1.57435
# [7000]	training's rmse: 1.43857	valid_1's rmse: 1.57434
# [7100]	training's rmse: 1.43723	valid_1's rmse: 1.57433
# [7200]	training's rmse: 1.43588	valid_1's rmse: 1.57428
# [7300]	training's rmse: 1.43451	valid_1's rmse: 1.57429
# [7400]	training's rmse: 1.43318	valid_1's rmse: 1.57431
# [7500]	training's rmse: 1.43178	valid_1's rmse: 1.57431
# [7600]	training's rmse: 1.43045	valid_1's rmse: 1.57432
# Early stopping, best iteration is:
# [7203]	training's rmse: 1.43583	valid_1's rmse: 1.57428
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65258	valid_1's rmse: 1.65436
# [200]	training's rmse: 1.61787	valid_1's rmse: 1.62071
# [300]	training's rmse: 1.59764	valid_1's rmse: 1.60185
# [400]	training's rmse: 1.58454	valid_1's rmse: 1.59027
# [500]	training's rmse: 1.57531	valid_1's rmse: 1.58265
# [600]	training's rmse: 1.56829	valid_1's rmse: 1.57736
# [700]	training's rmse: 1.56264	valid_1's rmse: 1.57343
# [800]	training's rmse: 1.55782	valid_1's rmse: 1.57036
# [900]	training's rmse: 1.55363	valid_1's rmse: 1.56782
# [1000]	training's rmse: 1.54986	valid_1's rmse: 1.5658
# [1100]	training's rmse: 1.54637	valid_1's rmse: 1.56412
# [1200]	training's rmse: 1.54315	valid_1's rmse: 1.56269
# [1300]	training's rmse: 1.54015	valid_1's rmse: 1.56144
# [1400]	training's rmse: 1.5373	valid_1's rmse: 1.56041
# [1500]	training's rmse: 1.53457	valid_1's rmse: 1.55948
# [1600]	training's rmse: 1.53204	valid_1's rmse: 1.55875
# [1700]	training's rmse: 1.52958	valid_1's rmse: 1.55818
# [1800]	training's rmse: 1.52725	valid_1's rmse: 1.55769
# [1900]	training's rmse: 1.52502	valid_1's rmse: 1.55727
# [2000]	training's rmse: 1.5228	valid_1's rmse: 1.55687
# [2100]	training's rmse: 1.52068	valid_1's rmse: 1.55653
# [2200]	training's rmse: 1.5186	valid_1's rmse: 1.55622
# [2300]	training's rmse: 1.51663	valid_1's rmse: 1.55601
# [2400]	training's rmse: 1.51467	valid_1's rmse: 1.55577
# [2500]	training's rmse: 1.51272	valid_1's rmse: 1.55558
# [2600]	training's rmse: 1.51081	valid_1's rmse: 1.55541
# [2700]	training's rmse: 1.50892	valid_1's rmse: 1.55524
# [2800]	training's rmse: 1.50711	valid_1's rmse: 1.55512
# [2900]	training's rmse: 1.50531	valid_1's rmse: 1.55496
# [3000]	training's rmse: 1.50354	valid_1's rmse: 1.55487
# [3100]	training's rmse: 1.50178	valid_1's rmse: 1.55481
# [3200]	training's rmse: 1.50004	valid_1's rmse: 1.55472
# [3300]	training's rmse: 1.49833	valid_1's rmse: 1.55466
# [3400]	training's rmse: 1.49667	valid_1's rmse: 1.55459
# [3500]	training's rmse: 1.49497	valid_1's rmse: 1.55454
# [3600]	training's rmse: 1.49331	valid_1's rmse: 1.5545
# [3700]	training's rmse: 1.49169	valid_1's rmse: 1.5544
# [3800]	training's rmse: 1.49004	valid_1's rmse: 1.55436
# [3900]	training's rmse: 1.48845	valid_1's rmse: 1.55428
# [4000]	training's rmse: 1.48683	valid_1's rmse: 1.55424
# [4100]	training's rmse: 1.48527	valid_1's rmse: 1.55419
# [4200]	training's rmse: 1.48365	valid_1's rmse: 1.55414
# [4300]	training's rmse: 1.48212	valid_1's rmse: 1.55412
# [4400]	training's rmse: 1.48059	valid_1's rmse: 1.55411
# [4500]	training's rmse: 1.47901	valid_1's rmse: 1.55408
# [4600]	training's rmse: 1.47746	valid_1's rmse: 1.55403
# [4700]	training's rmse: 1.47591	valid_1's rmse: 1.55403
# [4800]	training's rmse: 1.47439	valid_1's rmse: 1.554
# [4900]	training's rmse: 1.47288	valid_1's rmse: 1.554
# [5000]	training's rmse: 1.47136	valid_1's rmse: 1.55394
# [5100]	training's rmse: 1.46984	valid_1's rmse: 1.55392
# [5200]	training's rmse: 1.46839	valid_1's rmse: 1.55387
# [5300]	training's rmse: 1.46687	valid_1's rmse: 1.55384
# [5400]	training's rmse: 1.46538	valid_1's rmse: 1.5538
# [5500]	training's rmse: 1.46388	valid_1's rmse: 1.55381
# [5600]	training's rmse: 1.46243	valid_1's rmse: 1.55382
# [5700]	training's rmse: 1.46097	valid_1's rmse: 1.55376
# [5800]	training's rmse: 1.45952	valid_1's rmse: 1.55377
# [5900]	training's rmse: 1.45808	valid_1's rmse: 1.55377
# [6000]	training's rmse: 1.45661	valid_1's rmse: 1.55372
# [6100]	training's rmse: 1.45517	valid_1's rmse: 1.5537
# [6200]	training's rmse: 1.45372	valid_1's rmse: 1.55372
# [6300]	training's rmse: 1.45227	valid_1's rmse: 1.55374
# [6400]	training's rmse: 1.45079	valid_1's rmse: 1.55376
# Early stopping, best iteration is:
# [6086]	training's rmse: 1.45535	valid_1's rmse: 1.55369
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.66033	valid_1's rmse: 1.62223
# [200]	training's rmse: 1.62535	valid_1's rmse: 1.58876
# [300]	training's rmse: 1.60495	valid_1's rmse: 1.57019
# [400]	training's rmse: 1.59168	valid_1's rmse: 1.55878
# [500]	training's rmse: 1.58226	valid_1's rmse: 1.55132
# [600]	training's rmse: 1.57509	valid_1's rmse: 1.546
# [700]	training's rmse: 1.56931	valid_1's rmse: 1.54216
# [800]	training's rmse: 1.56447	valid_1's rmse: 1.53923
# [900]	training's rmse: 1.56021	valid_1's rmse: 1.53686
# [1000]	training's rmse: 1.55638	valid_1's rmse: 1.53508
# [1100]	training's rmse: 1.55288	valid_1's rmse: 1.5336
# [1200]	training's rmse: 1.54966	valid_1's rmse: 1.53241
# [1300]	training's rmse: 1.54666	valid_1's rmse: 1.53141
# [1400]	training's rmse: 1.54381	valid_1's rmse: 1.53055
# [1500]	training's rmse: 1.54111	valid_1's rmse: 1.52983
# [1600]	training's rmse: 1.53855	valid_1's rmse: 1.52922
# [1700]	training's rmse: 1.53611	valid_1's rmse: 1.52863
# [1800]	training's rmse: 1.53377	valid_1's rmse: 1.52816
# [1900]	training's rmse: 1.53149	valid_1's rmse: 1.52775
# [2000]	training's rmse: 1.52932	valid_1's rmse: 1.52743
# [2100]	training's rmse: 1.5272	valid_1's rmse: 1.52716
# [2200]	training's rmse: 1.52515	valid_1's rmse: 1.5269
# [2300]	training's rmse: 1.52314	valid_1's rmse: 1.52669
# [2400]	training's rmse: 1.52118	valid_1's rmse: 1.52651
# [2500]	training's rmse: 1.51923	valid_1's rmse: 1.52631
# [2600]	training's rmse: 1.51735	valid_1's rmse: 1.52617
# [2700]	training's rmse: 1.51553	valid_1's rmse: 1.52603
# [2800]	training's rmse: 1.51371	valid_1's rmse: 1.52586
# [2900]	training's rmse: 1.51193	valid_1's rmse: 1.52574
# [3000]	training's rmse: 1.51017	valid_1's rmse: 1.52559
# [3100]	training's rmse: 1.50847	valid_1's rmse: 1.52551
# [3200]	training's rmse: 1.50673	valid_1's rmse: 1.5254
# [3300]	training's rmse: 1.50504	valid_1's rmse: 1.52531
# [3400]	training's rmse: 1.50338	valid_1's rmse: 1.52526
# [3500]	training's rmse: 1.50167	valid_1's rmse: 1.52517
# [3600]	training's rmse: 1.50001	valid_1's rmse: 1.52504
# [3700]	training's rmse: 1.49839	valid_1's rmse: 1.52501
# [3800]	training's rmse: 1.49678	valid_1's rmse: 1.52496
# [3900]	training's rmse: 1.49521	valid_1's rmse: 1.52492
# [4000]	training's rmse: 1.49359	valid_1's rmse: 1.52485
# [4100]	training's rmse: 1.492	valid_1's rmse: 1.52483
# [4200]	training's rmse: 1.49044	valid_1's rmse: 1.52477
# [4300]	training's rmse: 1.48888	valid_1's rmse: 1.52474
# [4400]	training's rmse: 1.48735	valid_1's rmse: 1.52468
# [4500]	training's rmse: 1.48575	valid_1's rmse: 1.52459
# [4600]	training's rmse: 1.48415	valid_1's rmse: 1.52453
# [4700]	training's rmse: 1.48261	valid_1's rmse: 1.5245
# [4800]	training's rmse: 1.48106	valid_1's rmse: 1.52449
# [4900]	training's rmse: 1.47959	valid_1's rmse: 1.52447
# [5000]	training's rmse: 1.47806	valid_1's rmse: 1.52444
# [5100]	training's rmse: 1.47659	valid_1's rmse: 1.5244
# [5200]	training's rmse: 1.47515	valid_1's rmse: 1.52436
# [5300]	training's rmse: 1.47372	valid_1's rmse: 1.52433
# [5400]	training's rmse: 1.47223	valid_1's rmse: 1.52431
# [5500]	training's rmse: 1.47079	valid_1's rmse: 1.52429
# [5600]	training's rmse: 1.46933	valid_1's rmse: 1.52428
# [5700]	training's rmse: 1.46787	valid_1's rmse: 1.52427
# [5800]	training's rmse: 1.4664	valid_1's rmse: 1.52425
# [5900]	training's rmse: 1.46493	valid_1's rmse: 1.52428
# [6000]	training's rmse: 1.46347	valid_1's rmse: 1.52427
# [6100]	training's rmse: 1.46207	valid_1's rmse: 1.52427
# [6200]	training's rmse: 1.46062	valid_1's rmse: 1.52423
# [6300]	training's rmse: 1.45919	valid_1's rmse: 1.5242
# [6400]	training's rmse: 1.45778	valid_1's rmse: 1.52417
# [6500]	training's rmse: 1.45637	valid_1's rmse: 1.52419
# [6600]	training's rmse: 1.45491	valid_1's rmse: 1.52417
# [6700]	training's rmse: 1.4535	valid_1's rmse: 1.52415
# [6800]	training's rmse: 1.45208	valid_1's rmse: 1.52412
# [6900]	training's rmse: 1.45067	valid_1's rmse: 1.52408
# [7000]	training's rmse: 1.44935	valid_1's rmse: 1.5241
# [7100]	training's rmse: 1.44797	valid_1's rmse: 1.52406
# [7200]	training's rmse: 1.44661	valid_1's rmse: 1.52405
# [7300]	training's rmse: 1.44522	valid_1's rmse: 1.52403
# [7400]	training's rmse: 1.44385	valid_1's rmse: 1.52402
# [7500]	training's rmse: 1.44246	valid_1's rmse: 1.52403
# [7600]	training's rmse: 1.44109	valid_1's rmse: 1.52403
# [7700]	training's rmse: 1.43967	valid_1's rmse: 1.52401
# [7800]	training's rmse: 1.43828	valid_1's rmse: 1.52398
# [7900]	training's rmse: 1.43688	valid_1's rmse: 1.52396
# [8000]	training's rmse: 1.43556	valid_1's rmse: 1.52397
# [8100]	training's rmse: 1.43418	valid_1's rmse: 1.52395
# [8200]	training's rmse: 1.43283	valid_1's rmse: 1.52392
# [8300]	training's rmse: 1.43146	valid_1's rmse: 1.5239
# [8400]	training's rmse: 1.43008	valid_1's rmse: 1.52389
# [8500]	training's rmse: 1.42877	valid_1's rmse: 1.52387
# [8600]	training's rmse: 1.42748	valid_1's rmse: 1.52385
# [8700]	training's rmse: 1.42617	valid_1's rmse: 1.52387
# [8800]	training's rmse: 1.42483	valid_1's rmse: 1.52386
# [8900]	training's rmse: 1.42349	valid_1's rmse: 1.52388
# [9000]	training's rmse: 1.42215	valid_1's rmse: 1.52389
# Early stopping, best iteration is:
# [8602]	training's rmse: 1.42745	valid_1's rmse: 1.52384
# 1.556712748947121

# %%
# score:  1.556712748947121

# %%
cols = (feature_importance_df2[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df2.loc[feature_importance_df2.Feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
# plt.savefig('lgbm_importances.png')

# %%
predictions
# Out:
# array([-2.13323427, -0.23448163, -1.00621903, ...,  0.9306894 ,
#        -3.12432883,  0.09343256])

# %%
predictions2
# Out:
# array([-0.54371103, -0.24292679, -0.41665706, ...,  1.15778824,
#        -0.87487808,  0.04397952])

# %%
final_prediction = 1.25 * predictions - 0. * predictions2

# %%
# import optuna

# def objective(trial):
#     train_x, test_x, train_y, test_y = train_test_split(df_train[df_train_columns], target, test_size=0.25, random_state=4590)
#     dtrain = lgb.Dataset(train_x, label=train_y)

#     num_round = trial.suggest_int('num_round', 1, 1000)
#     param = {'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'bagging_seed':11, 'random_state':4590,
#              'boosting_type': trial.suggest_categorical('boosting', ['gbdt']),
#              'num_leaves': trial.suggest_int('num_leaves', 10, 100),
#              'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1e-1),
#              'min_data_in_leaf': 30,
#              'min_child_samples': trial.suggest_loguniform('min_child_samples', 10, 1000),
#              'feature_fraction': trial.suggest_loguniform('feature_fraction', 0.8, 1.0),
#              'bagging_fraction': trial.suggest_loguniform('bagging_fraction', 0.8, 1.0),
#              }

#     gbm = lgb.train(param, dtrain, num_round)
#     preds = gbm.predict(test_x)
#     pred_labels = np.rint(preds)
#     rmse = np.sqrt(mean_squared_error(test_y, pred_labels))
#     return rmse

# study = optuna.create_study()
# study.optimize(objective, n_trials=20)

# print('Number of finished trials: {}'.format(len(study.trials)))

# print('Best trial:')
# trial = study.best_trial

# print('  Value: {}'.format(trial.value))

# print('  Params: ')
# for key, value in trial.params.items():
#     print('    {}: {}'.format(key, value))

# %%
sub_df = pd.DataFrame({"card_id":df_test["card_id"].values})
sub_df["target"] = final_prediction
sub_df.to_csv("./output/submission_model20181214.csv", index=False)
