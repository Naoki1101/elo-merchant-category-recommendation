# %%
import numpy as np
import pandas as pd
import datetime
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')
np.random.seed(4590)

# %%
df_train = pd.read_csv('./input/train.csv')
df_test = pd.read_csv('./input/test.csv')
df_hist_trans = pd.read_csv('./input/historical_transactions.csv')
df_new_merchant_trans = pd.read_csv('./input/new_merchant_transactions.csv')

# %%
df_hist_trans['purchase_amount'] = np.exp(df_hist_trans['purchase_amount'])
df_new_merchant_trans['purchase_amount'] = np.exp(df_new_merchant_trans['purchase_amount'])

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['category_2'].fillna(1.0,inplace=True)
    df['category_3'].fillna('A',inplace=True)
    df['merchant_id'].fillna('M_ID_00a6ca8a8a',inplace=True)

# %%
def get_new_columns(name,aggs):
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    df['year'] = df['purchase_date'].dt.year
    df['weekofyear'] = df['purchase_date'].dt.weekofyear
    df['month'] = df['purchase_date'].dt.month
    df['dayofweek'] = df['purchase_date'].dt.dayofweek
    df['weekend'] = (df.purchase_date.dt.weekday >=5).astype(int)
    df['hour'] = df['purchase_date'].dt.hour
    df['authorized_flag'] = df['authorized_flag'].map({'Y':1, 'N':0})
    df['category_1'] = df['category_1'].map({'Y':1, 'N':0}) 
    #https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/73244
    df['month_diff'] = ((datetime.datetime.today() - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']

aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['authorized_flag'] = ['sum', 'mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_hist_trans[col+'_mean'] = df_hist_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']    

new_columns = get_new_columns('hist',aggs)
df_hist_trans_group = df_hist_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['hist_purchase_date_diff'] = (df_hist_trans_group['hist_purchase_date_max'] - df_hist_trans_group['hist_purchase_date_min']).dt.days
df_hist_trans_group['hist_purchase_date_average'] = df_hist_trans_group['hist_purchase_date_diff']/df_hist_trans_group['hist_card_id_size']
df_hist_trans_group['hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 175

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']
aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_new_merchant_trans[col+'_mean'] = df_new_merchant_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']
    
new_columns = get_new_columns('new_hist',aggs)
df_hist_trans_group = df_new_merchant_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['new_hist_purchase_date_diff'] = (df_hist_trans_group['new_hist_purchase_date_max'] - df_hist_trans_group['new_hist_purchase_date_min']).dt.days
df_hist_trans_group['new_hist_purchase_date_average'] = df_hist_trans_group['new_hist_purchase_date_diff']/df_hist_trans_group['new_hist_card_id_size']
df_hist_trans_group['new_hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['new_hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 28

# %%
del df_hist_trans;gc.collect()
del df_new_merchant_trans;gc.collect()
df_train.head(5)
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
# 3            2017-09  C_ID_186d6a6901          4          3          0
# 4            2017-11  C_ID_cdbd2c0db2          1          3          0
#
#      target  hist_month_nunique  hist_hour_nunique  hist_weekofyear_nunique  \
# 0 -0.820283                   9                 23                       35
# 1  0.392913                  12                 24                       50
# 2  0.688056                  10                 14                       22
# 3  0.142495                   6                 16                       20
# 4 -0.159749                   4                 22                       17
#
#    hist_dayofweek_nunique               ...                \
# 0                       7               ...
# 1                       7               ...
# 2                       7               ...
# 3                       7               ...
# 4                       7               ...
#
#    new_hist_weekend_sum  new_hist_weekend_mean  new_hist_category_1_sum  \
# 0                   6.0               0.260870                      0.0
# 1                   0.0               0.000000                      0.0
# 2                   1.0               1.000000                      0.0
# 3                   3.0               0.428571                      1.0
# 4                  12.0               0.333333                      2.0
#
#    new_hist_category_1_mean  new_hist_card_id_size  \
# 0                  0.000000                   23.0
# 1                  0.000000                    6.0
# 2                  0.000000                    1.0
# 3                  0.142857                    7.0
# 4                  0.055556                   36.0
#
#    new_hist_category_2_mean_mean  new_hist_category_3_mean_mean  \
# 0                  1.658319e+108                   1.381361e+36
# 1                  1.658319e+108                   3.557623e+25
# 2                   7.789907e+26                   1.381361e+36
# 3                  2.369028e+107                   1.973373e+35
# 4                  1.842577e+107                  3.624714e+107
#
#    new_hist_purchase_date_diff  new_hist_purchase_date_average  \
# 0                         54.0                        2.347826
# 1                         56.0                        9.333333
# 2                          0.0                        0.000000
# 3                         41.0                        5.857143
# 4                         57.0                        1.583333
#
#    new_hist_purchase_date_uptonow
# 0                           226.0
# 1                           256.0
# 2                           227.0
# 3                           237.0
# 4                           227.0
#
# [5 rows x 78 columns]

# %%
df_train['outliers'] = 0
df_train.loc[df_train['target'] < -30, 'outliers'] = 1
df_train['outliers'].value_counts()
# Out:
# 0    199710
# 1      2207
# Name: outliers, dtype: int64

# %%
for df in [df_train,df_test]:
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['dayofweek'] = df['first_active_month'].dt.dayofweek
    df['weekofyear'] = df['first_active_month'].dt.weekofyear
    df['month'] = df['first_active_month'].dt.month
    df['elapsed_time'] = (datetime.datetime.today() - df['first_active_month']).dt.days
    df['hist_first_buy'] = (df['hist_purchase_date_min'] - df['first_active_month']).dt.days
    df['new_hist_first_buy'] = (df['new_hist_purchase_date_min'] - df['first_active_month']).dt.days
    for f in ['hist_purchase_date_max','hist_purchase_date_min','new_hist_purchase_date_max',\
                     'new_hist_purchase_date_min']:
        df[f] = df[f].astype(np.int64) * 1e-9
    df['card_id_total'] = df['new_hist_card_id_size']+df['hist_card_id_size']
    df['purchase_amount_total'] = df['new_hist_purchase_amount_sum']+df['hist_purchase_amount_sum']

for f in ['feature_1','feature_2','feature_3']:
    order_label = df_train.groupby([f])['outliers'].mean()
    df_train[f] = df_train[f].map(order_label)
    df_test[f] = df_test[f].map(order_label)

# %%
high_importance_features = [
    "hist_month_diff_mean", 
    "hist_authorized_flag_mean", 
    "hist_category_1_sum", 
    "hist_month_lag_mean", 
    "new_hist_purchase_amount_sum", 
    "new_hist_purchase_date_uptonow"
]

#smoothing
for col in high_importance_features:
    df_train[col] = np.where(df_train[col].values==0, 0.001, df_train[col].values)
    df_test[col] = np.where(df_test[col].values==0, 0.001, df_test[col].values)


for i in range(len(high_importance_features)):
    for j in range(len((high_importance_features)))[i+1:]:
        col1 = high_importance_features[i]
        col2 = high_importance_features[j]
        new_col_name = "{c1}__div__{c2}".format(c1=col1, c2=col2)
        
        df_train[new_col_name] = df_train[col1] / df_train[col2]
        df_test[new_col_name] = df_test[col1] / df_test[col2]

# %%
merchant_feature = pd.read_csv("./input/merchants_nmf.csv")

df_train = pd.merge(df_train, merchant_feature, on="card_id", how="left")
df_test = pd.merge(df_test, merchant_feature, on="card_id", how="left")

# %%
new_merchant_feature = pd.read_csv("./input/new_merchants_nmf.csv")

df_train = pd.merge(df_train, new_merchant_feature, on="card_id", how="left")
df_test = pd.merge(df_test, new_merchant_feature, on="card_id", how="left")

# %%
prosperity_count = pd.read_csv("./input/prosperity_merchants_count.csv")

df_train = pd.merge(df_train, prosperity_count, on="card_id", how="left")
df_test = pd.merge(df_test, prosperity_count, on="card_id", how="left")

# %%
df_train_columns = [c for c in df_train.columns if c not in ['card_id', 'first_active_month','target','outliers']]
target = df_train['target']
del df_train['target']

# %%
#original
param = {'num_leaves': 31,
         'min_data_in_leaf': 30, 
         'objective':'regression',
         'max_depth': -1,
         'learning_rate': 0.004,
         "min_child_samples": 20,
         "boosting": "gbdt",
         "feature_fraction": 0.9,
         "bagging_freq": 1,
         "bagging_fraction": 0.9 ,
         "bagging_seed": 11,
         "metric": 'rmse',
         "lambda_l1": 0.1,
         "verbosity": -1,
         "nthread": 4,
         "random_state": 4590}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=4590)
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74359	valid_1's rmse: 3.77714
# [200]	training's rmse: 3.67823	valid_1's rmse: 3.7312
# [300]	training's rmse: 3.63305	valid_1's rmse: 3.70654
# [400]	training's rmse: 3.59875	valid_1's rmse: 3.6914
# [500]	training's rmse: 3.57144	valid_1's rmse: 3.68099
# [600]	training's rmse: 3.54926	valid_1's rmse: 3.67336
# [700]	training's rmse: 3.53066	valid_1's rmse: 3.66842
# [800]	training's rmse: 3.51367	valid_1's rmse: 3.66465
# [900]	training's rmse: 3.49808	valid_1's rmse: 3.66164
# [1000]	training's rmse: 3.48396	valid_1's rmse: 3.65908
# [1100]	training's rmse: 3.47131	valid_1's rmse: 3.65703
# [1200]	training's rmse: 3.45922	valid_1's rmse: 3.65538
# [1300]	training's rmse: 3.44788	valid_1's rmse: 3.65375
# [1400]	training's rmse: 3.43683	valid_1's rmse: 3.65266
# [1500]	training's rmse: 3.42652	valid_1's rmse: 3.65162
# [1600]	training's rmse: 3.41671	valid_1's rmse: 3.65077
# [1700]	training's rmse: 3.40739	valid_1's rmse: 3.65028
# [1800]	training's rmse: 3.39811	valid_1's rmse: 3.64957
# [1900]	training's rmse: 3.38907	valid_1's rmse: 3.64899
# [2000]	training's rmse: 3.38018	valid_1's rmse: 3.64859
# [2100]	training's rmse: 3.37194	valid_1's rmse: 3.64819
# [2200]	training's rmse: 3.36415	valid_1's rmse: 3.64813
# [2300]	training's rmse: 3.35626	valid_1's rmse: 3.64808
# [2400]	training's rmse: 3.34825	valid_1's rmse: 3.64796
# [2500]	training's rmse: 3.34088	valid_1's rmse: 3.64775
# [2600]	training's rmse: 3.33353	valid_1's rmse: 3.64759
# [2700]	training's rmse: 3.32637	valid_1's rmse: 3.64725
# [2800]	training's rmse: 3.31941	valid_1's rmse: 3.64717
# [2900]	training's rmse: 3.31239	valid_1's rmse: 3.647
# [3000]	training's rmse: 3.30575	valid_1's rmse: 3.64672
# [3100]	training's rmse: 3.299	valid_1's rmse: 3.64679
# [3200]	training's rmse: 3.29231	valid_1's rmse: 3.6467
# [3300]	training's rmse: 3.28583	valid_1's rmse: 3.64676
# [3400]	training's rmse: 3.27956	valid_1's rmse: 3.64664
# [3500]	training's rmse: 3.27323	valid_1's rmse: 3.64654
# [3600]	training's rmse: 3.26653	valid_1's rmse: 3.64669
# [3700]	training's rmse: 3.26042	valid_1's rmse: 3.64689
# [3800]	training's rmse: 3.25481	valid_1's rmse: 3.64683
# [3900]	training's rmse: 3.24844	valid_1's rmse: 3.64674
# Early stopping, best iteration is:
# [3516]	training's rmse: 3.2722	valid_1's rmse: 3.64654
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74349	valid_1's rmse: 3.76677
# [200]	training's rmse: 3.67731	valid_1's rmse: 3.72468
# [300]	training's rmse: 3.63122	valid_1's rmse: 3.70055
# [400]	training's rmse: 3.59617	valid_1's rmse: 3.68749
# [500]	training's rmse: 3.56875	valid_1's rmse: 3.67939
# [600]	training's rmse: 3.54591	valid_1's rmse: 3.67364
# [700]	training's rmse: 3.52652	valid_1's rmse: 3.66976
# [800]	training's rmse: 3.5094	valid_1's rmse: 3.66652
# [900]	training's rmse: 3.49391	valid_1's rmse: 3.66385
# [1000]	training's rmse: 3.48035	valid_1's rmse: 3.66181
# [1100]	training's rmse: 3.46778	valid_1's rmse: 3.66028
# [1200]	training's rmse: 3.45558	valid_1's rmse: 3.65896
# [1300]	training's rmse: 3.44422	valid_1's rmse: 3.65804
# [1400]	training's rmse: 3.43302	valid_1's rmse: 3.65711
# [1500]	training's rmse: 3.42212	valid_1's rmse: 3.65602
# [1600]	training's rmse: 3.41204	valid_1's rmse: 3.65535
# [1700]	training's rmse: 3.40219	valid_1's rmse: 3.65482
# [1800]	training's rmse: 3.39277	valid_1's rmse: 3.65431
# [1900]	training's rmse: 3.38363	valid_1's rmse: 3.65377
# [2000]	training's rmse: 3.37496	valid_1's rmse: 3.65347
# [2100]	training's rmse: 3.36665	valid_1's rmse: 3.65307
# [2200]	training's rmse: 3.35847	valid_1's rmse: 3.65283
# [2300]	training's rmse: 3.35021	valid_1's rmse: 3.65264
# [2400]	training's rmse: 3.34225	valid_1's rmse: 3.65237
# [2500]	training's rmse: 3.33472	valid_1's rmse: 3.65211
# [2600]	training's rmse: 3.32715	valid_1's rmse: 3.65191
# [2700]	training's rmse: 3.31963	valid_1's rmse: 3.65176
# [2800]	training's rmse: 3.31255	valid_1's rmse: 3.65182
# [2900]	training's rmse: 3.30555	valid_1's rmse: 3.6518
# [3000]	training's rmse: 3.29868	valid_1's rmse: 3.65173
# [3100]	training's rmse: 3.29186	valid_1's rmse: 3.65165
# [3200]	training's rmse: 3.28473	valid_1's rmse: 3.65174
# [3300]	training's rmse: 3.27781	valid_1's rmse: 3.6516
# [3400]	training's rmse: 3.27123	valid_1's rmse: 3.6515
# [3500]	training's rmse: 3.26449	valid_1's rmse: 3.65165
# [3600]	training's rmse: 3.25776	valid_1's rmse: 3.65155
# [3700]	training's rmse: 3.25127	valid_1's rmse: 3.6514
# [3800]	training's rmse: 3.24509	valid_1's rmse: 3.65126
# [3900]	training's rmse: 3.23896	valid_1's rmse: 3.65113
# [4000]	training's rmse: 3.23266	valid_1's rmse: 3.65108
# [4100]	training's rmse: 3.22645	valid_1's rmse: 3.6512
# [4200]	training's rmse: 3.22018	valid_1's rmse: 3.65109
# [4300]	training's rmse: 3.21426	valid_1's rmse: 3.65112
# [4400]	training's rmse: 3.20792	valid_1's rmse: 3.65126
# [4500]	training's rmse: 3.20196	valid_1's rmse: 3.6512
# [4600]	training's rmse: 3.19636	valid_1's rmse: 3.65125
# Early stopping, best iteration is:
# [4255]	training's rmse: 3.21711	valid_1's rmse: 3.65102
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74264	valid_1's rmse: 3.77267
# [200]	training's rmse: 3.67685	valid_1's rmse: 3.72882
# [300]	training's rmse: 3.63121	valid_1's rmse: 3.70422
# [400]	training's rmse: 3.59571	valid_1's rmse: 3.69013
# [500]	training's rmse: 3.56775	valid_1's rmse: 3.68081
# [600]	training's rmse: 3.54536	valid_1's rmse: 3.67462
# [700]	training's rmse: 3.52622	valid_1's rmse: 3.66938
# [800]	training's rmse: 3.50943	valid_1's rmse: 3.6657
# [900]	training's rmse: 3.4941	valid_1's rmse: 3.66243
# [1000]	training's rmse: 3.48019	valid_1's rmse: 3.66006
# [1100]	training's rmse: 3.46707	valid_1's rmse: 3.65803
# [1200]	training's rmse: 3.45462	valid_1's rmse: 3.65662
# [1300]	training's rmse: 3.44261	valid_1's rmse: 3.65556
# [1400]	training's rmse: 3.43136	valid_1's rmse: 3.65431
# [1500]	training's rmse: 3.421	valid_1's rmse: 3.65313
# [1600]	training's rmse: 3.41094	valid_1's rmse: 3.65237
# [1700]	training's rmse: 3.40118	valid_1's rmse: 3.65152
# [1800]	training's rmse: 3.39234	valid_1's rmse: 3.65084
# [1900]	training's rmse: 3.38344	valid_1's rmse: 3.65051
# [2000]	training's rmse: 3.37482	valid_1's rmse: 3.64997
# [2100]	training's rmse: 3.36644	valid_1's rmse: 3.64955
# [2200]	training's rmse: 3.35864	valid_1's rmse: 3.64893
# [2300]	training's rmse: 3.35066	valid_1's rmse: 3.64855
# [2400]	training's rmse: 3.34296	valid_1's rmse: 3.64833
# [2500]	training's rmse: 3.33562	valid_1's rmse: 3.64794
# [2600]	training's rmse: 3.3283	valid_1's rmse: 3.64786
# [2700]	training's rmse: 3.32078	valid_1's rmse: 3.64758
# [2800]	training's rmse: 3.31374	valid_1's rmse: 3.64742
# [2900]	training's rmse: 3.30691	valid_1's rmse: 3.64732
# [3000]	training's rmse: 3.29975	valid_1's rmse: 3.64737
# [3100]	training's rmse: 3.29326	valid_1's rmse: 3.64723
# [3200]	training's rmse: 3.28642	valid_1's rmse: 3.64724
# [3300]	training's rmse: 3.27996	valid_1's rmse: 3.64732
# [3400]	training's rmse: 3.27348	valid_1's rmse: 3.64725
# [3500]	training's rmse: 3.26697	valid_1's rmse: 3.64712
# [3600]	training's rmse: 3.26049	valid_1's rmse: 3.64703
# [3700]	training's rmse: 3.25391	valid_1's rmse: 3.64692
# [3800]	training's rmse: 3.24778	valid_1's rmse: 3.64692
# [3900]	training's rmse: 3.24144	valid_1's rmse: 3.64665
# [4000]	training's rmse: 3.23546	valid_1's rmse: 3.64647
# [4100]	training's rmse: 3.2296	valid_1's rmse: 3.64641
# [4200]	training's rmse: 3.22342	valid_1's rmse: 3.64629
# [4300]	training's rmse: 3.21759	valid_1's rmse: 3.64616
# [4400]	training's rmse: 3.21198	valid_1's rmse: 3.64613
# [4500]	training's rmse: 3.20601	valid_1's rmse: 3.64617
# [4600]	training's rmse: 3.20002	valid_1's rmse: 3.64631
# [4700]	training's rmse: 3.19418	valid_1's rmse: 3.64635
# [4800]	training's rmse: 3.18838	valid_1's rmse: 3.64633
# Early stopping, best iteration is:
# [4410]	training's rmse: 3.21125	valid_1's rmse: 3.64605
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74373	valid_1's rmse: 3.7676
# [200]	training's rmse: 3.67772	valid_1's rmse: 3.72605
# [300]	training's rmse: 3.63132	valid_1's rmse: 3.70316
# [400]	training's rmse: 3.59611	valid_1's rmse: 3.68995
# [500]	training's rmse: 3.56844	valid_1's rmse: 3.68096
# [600]	training's rmse: 3.54522	valid_1's rmse: 3.67463
# [700]	training's rmse: 3.52543	valid_1's rmse: 3.67007
# [800]	training's rmse: 3.50804	valid_1's rmse: 3.66667
# [900]	training's rmse: 3.49283	valid_1's rmse: 3.66354
# [1000]	training's rmse: 3.47989	valid_1's rmse: 3.66052
# [1100]	training's rmse: 3.46685	valid_1's rmse: 3.65816
# [1200]	training's rmse: 3.45524	valid_1's rmse: 3.65681
# [1300]	training's rmse: 3.44415	valid_1's rmse: 3.65507
# [1400]	training's rmse: 3.43325	valid_1's rmse: 3.65379
# [1500]	training's rmse: 3.42267	valid_1's rmse: 3.65261
# [1600]	training's rmse: 3.41253	valid_1's rmse: 3.65164
# [1700]	training's rmse: 3.40287	valid_1's rmse: 3.65073
# [1800]	training's rmse: 3.39345	valid_1's rmse: 3.65034
# [1900]	training's rmse: 3.38469	valid_1's rmse: 3.64995
# [2000]	training's rmse: 3.3758	valid_1's rmse: 3.64945
# [2100]	training's rmse: 3.3671	valid_1's rmse: 3.64901
# [2200]	training's rmse: 3.35888	valid_1's rmse: 3.64865
# [2300]	training's rmse: 3.35107	valid_1's rmse: 3.6484
# [2400]	training's rmse: 3.34307	valid_1's rmse: 3.64795
# [2500]	training's rmse: 3.33582	valid_1's rmse: 3.64777
# [2600]	training's rmse: 3.32855	valid_1's rmse: 3.6475
# [2700]	training's rmse: 3.32124	valid_1's rmse: 3.64732
# [2800]	training's rmse: 3.31409	valid_1's rmse: 3.64725
# [2900]	training's rmse: 3.30629	valid_1's rmse: 3.64717
# [3000]	training's rmse: 3.2993	valid_1's rmse: 3.64685
# [3100]	training's rmse: 3.29233	valid_1's rmse: 3.64694
# [3200]	training's rmse: 3.28554	valid_1's rmse: 3.64675
# [3300]	training's rmse: 3.27881	valid_1's rmse: 3.64667
# [3400]	training's rmse: 3.27275	valid_1's rmse: 3.64656
# [3500]	training's rmse: 3.26609	valid_1's rmse: 3.64642
# [3600]	training's rmse: 3.25979	valid_1's rmse: 3.64616
# [3700]	training's rmse: 3.2534	valid_1's rmse: 3.64611
# [3800]	training's rmse: 3.2473	valid_1's rmse: 3.64623
# [3900]	training's rmse: 3.24103	valid_1's rmse: 3.64627
# [4000]	training's rmse: 3.23502	valid_1's rmse: 3.64643
# [4100]	training's rmse: 3.22879	valid_1's rmse: 3.64615
# Early stopping, best iteration is:
# [3713]	training's rmse: 3.25269	valid_1's rmse: 3.64607
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74535	valid_1's rmse: 3.75605
# [200]	training's rmse: 3.67878	valid_1's rmse: 3.71601
# [300]	training's rmse: 3.63236	valid_1's rmse: 3.69327
# [400]	training's rmse: 3.59688	valid_1's rmse: 3.67898
# [500]	training's rmse: 3.56881	valid_1's rmse: 3.66967
# [600]	training's rmse: 3.54594	valid_1's rmse: 3.66336
# [700]	training's rmse: 3.52635	valid_1's rmse: 3.6586
# [800]	training's rmse: 3.50917	valid_1's rmse: 3.65497
# [900]	training's rmse: 3.49364	valid_1's rmse: 3.65224
# [1000]	training's rmse: 3.47941	valid_1's rmse: 3.64984
# [1100]	training's rmse: 3.46649	valid_1's rmse: 3.64814
# [1200]	training's rmse: 3.45447	valid_1's rmse: 3.64664
# [1300]	training's rmse: 3.44312	valid_1's rmse: 3.64563
# [1400]	training's rmse: 3.43205	valid_1's rmse: 3.64439
# [1500]	training's rmse: 3.42098	valid_1's rmse: 3.64372
# [1600]	training's rmse: 3.41101	valid_1's rmse: 3.64321
# [1700]	training's rmse: 3.40139	valid_1's rmse: 3.6428
# [1800]	training's rmse: 3.39209	valid_1's rmse: 3.64268
# [1900]	training's rmse: 3.38286	valid_1's rmse: 3.64243
# [2000]	training's rmse: 3.37431	valid_1's rmse: 3.64214
# [2100]	training's rmse: 3.36591	valid_1's rmse: 3.64202
# [2200]	training's rmse: 3.35717	valid_1's rmse: 3.64203
# [2300]	training's rmse: 3.34929	valid_1's rmse: 3.64196
# [2400]	training's rmse: 3.34172	valid_1's rmse: 3.64203
# [2500]	training's rmse: 3.33419	valid_1's rmse: 3.64203
# [2600]	training's rmse: 3.32663	valid_1's rmse: 3.64204
# [2700]	training's rmse: 3.31873	valid_1's rmse: 3.64222
# Early stopping, best iteration is:
# [2302]	training's rmse: 3.34911	valid_1's rmse: 3.64194
# 3.6463247308334688

# %%
# score:  3.6458692529031196

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
# plt.savefig('lgbm_importances.png')

# %%
# import optuna

# def objective(trial):
#     train_x, test_x, train_y, test_y = train_test_split(df_train[df_train_columns], target, test_size=0.25, random_state=4590)
#     dtrain = lgb.Dataset(train_x, label=train_y)

#     num_round = trial.suggest_int('num_round', 1, 1000)
#     param = {'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'bagging_seed':11, 'random_state':4590,
#              'boosting_type': trial.suggest_categorical('boosting', ['gbdt']),
#              'num_leaves': trial.suggest_int('num_leaves', 10, 100),
#              'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1e-1),
#              'min_data_in_leaf': 30,
#              'min_child_samples': trial.suggest_loguniform('min_child_samples', 10, 1000),
#              'feature_fraction': trial.suggest_loguniform('feature_fraction', 0.8, 1.0),
#              'bagging_fraction': trial.suggest_loguniform('bagging_fraction', 0.8, 1.0),
#              }

#     gbm = lgb.train(param, dtrain, num_round)
#     preds = gbm.predict(test_x)
#     pred_labels = np.rint(preds)
#     rmse = np.sqrt(mean_squared_error(test_y, pred_labels))
#     return rmse

# study = optuna.create_study()
# study.optimize(objective, n_trials=20)

# print('Number of finished trials: {}'.format(len(study.trials)))

# print('Best trial:')
# trial = study.best_trial

# print('  Value: {}'.format(trial.value))

# print('  Params: ')
# for key, value in trial.params.items():
#     print('    {}: {}'.format(key, value))

# %%
sub_df = pd.DataFrame({"card_id":df_test["card_id"].values})
sub_df["target"] = predictions
sub_df.to_csv("./output/submission_model20181211.csv", index=False)
