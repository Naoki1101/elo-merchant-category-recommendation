# %%
#helper
import numpy as np
import pandas as pd

# ML
import xgboost as xgb

# scikit-learn
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
raw_train = pd.read_csv("./input/train.csv")
raw_test = pd.read_csv("./input/test.csv")

# %%
data = raw_train[["feature_1", "feature_2", "feature_3"]]
target = raw_train[["target"]]

X_train, X_test, Y_train, Y_test = train_test_split(
    data, target, test_size=0.3, random_state=0
)

reg = xgb.XGBRegressor(
        learning_rate =0.05,
        n_estimators=3000,
        max_depth=5,
        min_child_weight=1,
        gamma=0.5,
        subsample=0.95,
        colsample_bytree=0.5,
        objective= "reg:linear",
        scale_pos_weight=1,
        seed=27
    )

reg.fit(X_train, Y_train)

# %%
np.sqrt(mean_squared_error(reg.predict(X_test), Y_test))
# Out:
# 3.842198883110662

# %%
reg = xgb.XGBRegressor(
        learning_rate =0.05,
        n_estimators=3000,
        max_depth=5,
        min_child_weight=1,
        gamma=0.5,
        subsample=0.95,
        colsample_bytree=0.5,
        objective= "reg:linear",
        scale_pos_weight=1,
        seed=27
    )

# %%
reg.fit(data, target)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.5, gamma=0.5, learning_rate=0.05,
#        max_delta_step=0, max_depth=5, min_child_weight=1, missing=None,
#        n_estimators=3000, n_jobs=1, nthread=None, objective='reg:linear',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=27, silent=True, subsample=0.95)

# %%
predict = reg.predict(raw_test[["feature_1", "feature_2", "feature_3"]])

# %%
pd.read_csv("./input/sample_submission.csv")
# Out:
#                 card_id  target
# 0       C_ID_0ab67a22ab       0
# 1       C_ID_130fd0cbdd       0
# 2       C_ID_b709037bc5       0
# 3       C_ID_d27d835a9f       0
# 4       C_ID_2b5e3df5c2       0
# 5       C_ID_5814b4f13c       0
# 6       C_ID_a1b3c75277       0
# 7       C_ID_f7cada36d3       0
# 8       C_ID_9d2bc8dfc4       0
# 9       C_ID_6d8dba8475       0
# 10      C_ID_4859ac9ed5       0
# 11      C_ID_0e281e8ad6       0
# 12      C_ID_8375dfdaa2       0
# 13      C_ID_79d149c008       0
# 14      C_ID_7f1041e8e1       0
# 15      C_ID_f72513589e       0
# 16      C_ID_a7f2d6984e       0
# 17      C_ID_15489b42d3       0
# 18      C_ID_e457bbd71d       0
# 19      C_ID_3f74e10c7e       0
# 20      C_ID_48243da9c4       0
# 21      C_ID_7ea1fcf117       0
# 22      C_ID_22e4a47c72       0
# 23      C_ID_5d30729184       0
# 24      C_ID_b54cfad8b2       0
# 25      C_ID_4b82e26faa       0
# 26      C_ID_60a453531a       0
# 27      C_ID_0c9315feec       0
# ...

# %%
submission = pd.DataFrame({"card_id":raw_test.card_id, "target":predict})

# %%
submission.to_csv("./output/first_submission.csv", index=False)

# %% [markdown]
# 結果: 3.930
