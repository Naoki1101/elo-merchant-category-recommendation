# %%
import numpy as np
import pandas as pd
import datetime

from itertools import combinations

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import lightgbm as lgb

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error, roc_auc_score, confusion_matrix, f1_score
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')
np.random.seed(4590)

pd.options.display.max_columns = 300
# Out:
# /Users/naoki/.pyenv/versions/3.6.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/naoki/.pyenv/versions/3.6.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/naoki/.pyenv/versions/3.6.6/lib/python3.6/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.1) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
df_train = pd.read_csv('../input/20181216_train.csv')
df_test = pd.read_csv('../input/20181216_test.csv')

# %%
def merge_new_feature(path, use=[]):
    if len(use) > 1:
        df_new_feature = pd.read_csv(path, usecols=use)
    else:
        df_new_feature = pd.read_csv(path)
    
    df_tr = pd.merge(df_train, df_new_feature, on="card_id", how="left")
    df_te = pd.merge(df_test, df_new_feature, on="card_id", how="left")
    
    return df_tr, df_te

# %%
df_train, df_test = merge_new_feature("../input/feature_categorical_count_rate.csv")
df_train, df_test = merge_new_feature("../input/feature_various_time_data.csv")
df_train, df_test = merge_new_feature("../input/merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/payment_splited_by_installments_NMF.csv")
df_train, df_test = merge_new_feature("../input/feature_catogorical_count_weighted_elapsed.csv")
df_train, df_test = merge_new_feature("../input/feature_latest_transaction_data__per__card_id.csv")

df_train, df_test = merge_new_feature("../input/target_raw_20190217.csv")

# %%
dont_use = ['card_id', 'first_active_month','second_active_date','diff_first_and_second','target','outliers', 'category_1_Y_std']

df_train_columns = [c for c in df_train.columns if c not in dont_use]
target = df_train['target']
target_outlier = df_train["outliers"]

# %%
max_each_col = np.max(df_train[df_train_columns].values, axis=0)

for i, max_ in enumerate(max_each_col):
    if max_ >= 1e+7:
        df_train[df_train_columns[i]] = 1/(1+np.exp(-1*df_train[df_train_columns[i]].values))
        df_test[df_train_columns[i]] = 1/(1+np.exp(-1*df_test[df_train_columns[i]].values))

# %%
drop_col = []
comb = list(combinations(df_train_columns, 2))

for c1, c2 in comb:
    corr = np.corrcoef(df_train[c1], df_train[c2])[0,1]
    if corr >= 0.962:
        print("【{i}】 --- 【{j}】".format(i=c1, j=c2))
        print(corr)
        drop_col.append(c2)
        print("\n"*2)

for col in df_train_columns:
    if col in sorted(set(drop_col)):
        df_train_columns.remove(col)
# Out:
# 【hist_authorized_flag_sum】 --- 【hist_card_id_size】
# 0.9945716227736431
#
#
#
# 【hist_authorized_flag_sum】 --- 【card_id_count】
# 0.9935317230513652
#
#
#
# 【hist_authorized_flag_sum】 --- 【authorized_flag_ture】
# 0.9979558326172671
#
#
#
# 【hist_authorized_flag_sum】 --- 【authorized_flag_ture_weighted_elapsed】
# 0.9979558326172671
#
#
#
# 【hist_authorized_flag_mean】 --- 【authorized_flag_ture_rate】
# 0.9871399739794636
#
#
#
# 【hist_category_1_sum】 --- 【category_1_true】
# 0.9996032083806138
#
#
#
# 【hist_category_1_sum】 --- 【category_1_true_weighted_elapsed】
# 0.9996032083806138
#
#
#
# 【hist_category_1_mean】 --- 【category_1_true_rate】
# 0.9915584786977886
#
#
#
# 【hist_card_id_size】 --- 【card_id_count】
# 0.9981205383400666
#
#
#
# 【hist_card_id_size】 --- 【authorized_flag_ture】
# 0.991907744189161
#
#
#
# 【hist_card_id_size】 --- 【authorized_flag_ture_weighted_elapsed】
# 0.991907744189161
#
#
#
# 【hist_purchase_date_diff】 --- 【elapsed_from_oldest_purchase_date_to_latest_purchase_date】
# 0.968714472679401
#
#
#
# 【new_hist_purchase_date_max】 --- 【new_hist_purchase_date_min】
# 1.0
#
#
#
# 【hist_first_buy】 --- 【elapsed_from_oldest_purchase_date_to_first_active】
# 1.0
#
#
#
# 【card_id_count】 --- 【authorized_flag_ture】
# 0.9947805751843393
#
#
#
# 【card_id_count】 --- 【authorized_flag_ture_weighted_elapsed】
# 0.9947805751843393
#
#
#
# 【authorized_flag_ture】 --- 【authorized_flag_ture_weighted_elapsed】
# 0.9999999999999999
#
#
#
# 【category_1_true】 --- 【category_1_true_weighted_elapsed】
# 0.9999999999999998
#
#
#
# 【category_3_A】 --- 【installments_0】
# 1.0
#
#
#
# 【category_3_B】 --- 【installments_1】
# 1.0
#
#
#
# 【category_3_A_rate】 --- 【installments_0_rate】
# 0.9999999999999999
#
#
#
# 【category_3_A_rate】 --- 【category_3_A_latest_trs】
# 0.9891807585016202
#
#
#
# 【category_3_B_rate】 --- 【installments_1_rate】
# 1.0
#
#
#
# 【installments_0_rate】 --- 【category_3_A_latest_trs】
# 0.9891807585016202
#
#
#
# 【month_lag_N13】 --- 【month_lag_N13_weighted_elapsed】
# 0.9993139081259989
#
#
#
# 【month_lag_N12】 --- 【month_lag_N12_weighted_elapsed】
# 0.9965343513872145
#
#
#
# 【month_lag_N11】 --- 【month_lag_N11_weighted_elapsed】
# 0.9914134570536032
#
#
#
# 【month_lag_N10】 --- 【month_lag_N10_weighted_elapsed】
# 0.9803827646550846
#
#
#
# 【month_lag_N9】 --- 【month_lag_N9_weighted_elapsed】
# 0.971953112628116
#
#
#
# 【month_lag_N8】 --- 【month_lag_N8_weighted_elapsed】
# 0.963066903632867
#
#
#
# 【category_3_A_weighted_elapsed】 --- 【installments_0_weighted_elapsed】
# 1.0
#
#
#
# 【category_3_B_weighted_elapsed】 --- 【installments_1_weighted_elapsed】
# 1.0
#
#
#
# 【category_4_null_latest_trs】 --- 【numerical_1_null_latest_trs】
# 1.0
#
#
#
# 【category_4_null_latest_trs】 --- 【most_recent_sales_range_null_latest_trs】
# 1.0
#
#
#
# 【category_4_null_latest_trs】 --- 【most_recent_purchases_range_null_latest_trs】
# 1.0
#
#
#
# 【numerical_1_null_latest_trs】 --- 【most_recent_sales_range_null_latest_trs】
# 1.0
#
#
#
# 【numerical_1_null_latest_trs】 --- 【most_recent_purchases_range_null_latest_trs】
# 1.0
#
#
#
# 【most_recent_sales_range_null_latest_trs】 --- 【most_recent_purchases_range_null_latest_trs】
# 1.0

# %%
sorted(set(drop_col))
# Out:
# ['authorized_flag_ture',
#  'authorized_flag_ture_rate',
#  'authorized_flag_ture_weighted_elapsed',
#  'card_id_count',
#  'category_1_true',
#  'category_1_true_rate',
#  'category_1_true_weighted_elapsed',
#  'category_3_A_latest_trs',
#  'elapsed_from_oldest_purchase_date_to_first_active',
#  'elapsed_from_oldest_purchase_date_to_latest_purchase_date',
#  'hist_card_id_size',
#  'installments_0',
#  'installments_0_rate',
#  'installments_0_weighted_elapsed',
#  'installments_1',
#  'installments_1_rate',
#  'installments_1_weighted_elapsed',
#  'month_lag_N10_weighted_elapsed',
#  'month_lag_N11_weighted_elapsed',
#  'month_lag_N12_weighted_elapsed',
#  'month_lag_N13_weighted_elapsed',
#  'month_lag_N8_weighted_elapsed',
#  'month_lag_N9_weighted_elapsed',
#  'most_recent_purchases_range_null_latest_trs',
#  'most_recent_sales_range_null_latest_trs',
#  'new_hist_purchase_date_min',
#  'numerical_1_null_latest_trs']

# %%
len(df_train_columns)
# Out:
# 275

# %%
#original
param = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'binary',  #regression
    'max_depth': 8,  # -1
    'learning_rate': 0.004,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'auc',  #auc
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=target_outlier.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=target_outlier.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

roc_auc_score(target_outlier, oof)
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's auc: 0.910212	valid_1's auc: 0.895982
# [200]	training's auc: 0.92688	valid_1's auc: 0.902223
# [300]	training's auc: 0.938217	valid_1's auc: 0.904639
# [400]	training's auc: 0.947654	valid_1's auc: 0.905676
# [500]	training's auc: 0.956883	valid_1's auc: 0.906334
# [600]	training's auc: 0.964507	valid_1's auc: 0.90629
# [700]	training's auc: 0.970534	valid_1's auc: 0.906025
# [800]	training's auc: 0.974741	valid_1's auc: 0.905549
# Early stopping, best iteration is:
# [492]	training's auc: 0.956367	valid_1's auc: 0.906429
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's auc: 0.910124	valid_1's auc: 0.882975
# [200]	training's auc: 0.928234	valid_1's auc: 0.888747
# [300]	training's auc: 0.939411	valid_1's auc: 0.891701
# [400]	training's auc: 0.950142	valid_1's auc: 0.894173
# [500]	training's auc: 0.957766	valid_1's auc: 0.895127
# [600]	training's auc: 0.964519	valid_1's auc: 0.896075
# [700]	training's auc: 0.970014	valid_1's auc: 0.896864
# [800]	training's auc: 0.97447	valid_1's auc: 0.897486
# [900]	training's auc: 0.977975	valid_1's auc: 0.89788
# [1000]	training's auc: 0.980772	valid_1's auc: 0.898071
# [1100]	training's auc: 0.983026	valid_1's auc: 0.898253
# [1200]	training's auc: 0.98496	valid_1's auc: 0.898472
# [1300]	training's auc: 0.986739	valid_1's auc: 0.898487
# [1400]	training's auc: 0.988239	valid_1's auc: 0.898479
# [1500]	training's auc: 0.98967	valid_1's auc: 0.898624
# [1600]	training's auc: 0.990812	valid_1's auc: 0.898555
# [1700]	training's auc: 0.991857	valid_1's auc: 0.898521
# [1800]	training's auc: 0.992805	valid_1's auc: 0.898506
# [1900]	training's auc: 0.993671	valid_1's auc: 0.898433
# Early stopping, best iteration is:
# [1521]	training's auc: 0.989887	valid_1's auc: 0.898661
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's auc: 0.909535	valid_1's auc: 0.900902
# [200]	training's auc: 0.924632	valid_1's auc: 0.906636
# [300]	training's auc: 0.934652	valid_1's auc: 0.90844
# [400]	training's auc: 0.944396	valid_1's auc: 0.909936
# [500]	training's auc: 0.953248	valid_1's auc: 0.91083
# [600]	training's auc: 0.961027	valid_1's auc: 0.911655
# [700]	training's auc: 0.9679	valid_1's auc: 0.91222
# [800]	training's auc: 0.973145	valid_1's auc: 0.912685
# [900]	training's auc: 0.977007	valid_1's auc: 0.912944
# [1000]	training's auc: 0.979843	valid_1's auc: 0.913201
# [1100]	training's auc: 0.982127	valid_1's auc: 0.913295
# [1200]	training's auc: 0.984377	valid_1's auc: 0.913435
# [1300]	training's auc: 0.986158	valid_1's auc: 0.913524
# [1400]	training's auc: 0.987757	valid_1's auc: 0.913581
# [1500]	training's auc: 0.989118	valid_1's auc: 0.913551
# [1600]	training's auc: 0.990395	valid_1's auc: 0.913548
# [1700]	training's auc: 0.991529	valid_1's auc: 0.913489
# [1800]	training's auc: 0.992494	valid_1's auc: 0.91345
# Early stopping, best iteration is:
# [1423]	training's auc: 0.98806	valid_1's auc: 0.913617
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's auc: 0.911762	valid_1's auc: 0.872149
# [200]	training's auc: 0.928052	valid_1's auc: 0.880312
# [300]	training's auc: 0.93847	valid_1's auc: 0.884788
# [400]	training's auc: 0.948438	valid_1's auc: 0.887726
# [500]	training's auc: 0.956816	valid_1's auc: 0.888726
# [600]	training's auc: 0.963715	valid_1's auc: 0.889452
# [700]	training's auc: 0.969722	valid_1's auc: 0.889933
# [800]	training's auc: 0.974498	valid_1's auc: 0.890462
# [900]	training's auc: 0.978181	valid_1's auc: 0.891026
# [1000]	training's auc: 0.980787	valid_1's auc: 0.891363
# [1100]	training's auc: 0.983067	valid_1's auc: 0.891615
# [1200]	training's auc: 0.984897	valid_1's auc: 0.891723
# [1300]	training's auc: 0.986673	valid_1's auc: 0.891955
# [1400]	training's auc: 0.988128	valid_1's auc: 0.892
# [1500]	training's auc: 0.989442	valid_1's auc: 0.891974
# [1600]	training's auc: 0.990596	valid_1's auc: 0.891971
# [1700]	training's auc: 0.991641	valid_1's auc: 0.891913
# Early stopping, best iteration is:
# [1375]	training's auc: 0.987775	valid_1's auc: 0.892074
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's auc: 0.90813	valid_1's auc: 0.895754

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,50))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()

# %%
df_train_columns2 = cols[:200]

#original
param = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'binary',  #regression
    'max_depth': 8,  # -1
    'learning_rate': 0.004,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'auc',  #auc
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns2], label=target_outlier.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns2], label=target_outlier.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns2], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns2
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns2], num_iteration=clf.best_iteration) / folds.n_splits

roc_auc_score(target_outlier, oof)

# %%
cols2 = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols2)]

plt.figure(figsize=(14,50))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()

# %%
for k in range(-30, 0, 1):
    rmse = []
    for i in [i/1000.0 for i in range(1,1001)]:
        predict_outliers = np.where(oof>i, k, 0)
        rmse.append(np.sqrt(mean_squared_error(target.values, predict_outliers)))
        if min(rmse) == rmse[-1]:
            best_th = i
    print("%d -- %f -- %f" %(k, min(rmse), best_th))

# %%
df_predict = pd.read_csv("../output/submission_model20181216.csv")
df_no_outliers_predict = pd.read_csv("../output/submission_no_outliers_model20190112.csv")

# %%
df_predict = pd.merge(df_predict, df_no_outliers_predict, on="card_id", how="inner")

# %%
df_predict["target"] = np.where(df_predict.target_x.values < 0, df_predict.target_x, df_predict.target_y)

del df_predict["target_x"]
del df_predict["target_y"]

df_predict
# Out:
#                 card_id    target
# 0       C_ID_0ab67a22ab -2.041275
# 1       C_ID_130fd0cbdd -0.305701
# 2       C_ID_b709037bc5 -0.974894
# 3       C_ID_d27d835a9f -0.090633
# 4       C_ID_2b5e3df5c2 -1.465622
# 5       C_ID_5814b4f13c  0.536912
# 6       C_ID_a1b3c75277  0.176816
# 7       C_ID_f7cada36d3  0.865616
# 8       C_ID_9d2bc8dfc4 -0.709276
# 9       C_ID_6d8dba8475 -1.145146
# 10      C_ID_4859ac9ed5 -0.643432
# 11      C_ID_0e281e8ad6  0.277421
# 12      C_ID_8375dfdaa2  0.119882
# 13      C_ID_79d149c008 -0.081392
# 14      C_ID_7f1041e8e1 -7.587275
# 15      C_ID_f72513589e  0.779489
# 16      C_ID_a7f2d6984e  0.633469
# 17      C_ID_15489b42d3 -0.181125
# 18      C_ID_e457bbd71d  0.182171
# 19      C_ID_3f74e10c7e -0.245650
# 20      C_ID_48243da9c4  0.209894
# 21      C_ID_7ea1fcf117 -0.645681
# 22      C_ID_22e4a47c72 -0.205771
# 23      C_ID_5d30729184  0.233964
# 24      C_ID_b54cfad8b2 -0.773896
# 25      C_ID_4b82e26faa -0.262735
# 26      C_ID_60a453531a -0.788592
# 27      C_ID_0c9315feec -0.437957
# 28      C_ID_1e28804d36 -0.136909
# 29      C_ID_68de79f7e2 -0.416897
# ...                 ...       ...
# 123593  C_ID_cd42a5db89 -0.344464
# 123594  C_ID_715b9a183d -1.097186
# 123595  C_ID_9b25df3309 -0.011294
# 123596  C_ID_043b3c2ccd  1.210842
# 123597  C_ID_7685eae7b2 -0.579362
# 123598  C_ID_7ee1a21a95 -0.569596
# 123599  C_ID_2bf12fed6b  0.708049
# 123600  C_ID_2932a6ea37 -0.750018
# 123601  C_ID_cc33d0d508 -1.028027
# 123602  C_ID_8852708dcb -0.537734
# 123603  C_ID_c3e88ef62d -0.178783
# 123604  C_ID_650557248c  0.713751
# 123605  C_ID_f14af9cb56 -0.563924
# 123606  C_ID_068dcf31e8 -0.558077
# 123607  C_ID_6659f4625a  0.629402
# 123608  C_ID_dc842bba27 -0.417375
# 123609  C_ID_bd625edce0 -0.074797
# 123610  C_ID_278446cc2f  0.423250
# 123611  C_ID_ad358eb92e -1.368579
# 123612  C_ID_7d9bcec574 -0.663539
# 123613  C_ID_b588b35e15 -0.060628
# 123614  C_ID_7147e348c3  0.662036
# 123615  C_ID_727d3ec5da -0.863329
# 123616  C_ID_107d93e20c  1.729334
# 123617  C_ID_0e74bd4966  0.588338
# 123618  C_ID_7a239d2eda  1.093064
# 123619  C_ID_75ace375ae -0.362897
# 123620  C_ID_21d56d950c  1.196001
# 123621  C_ID_6c46fc5a9d -3.002469
# 123622  C_ID_87e7979a5f -0.055991
#
# [123623 rows x 2 columns]

# %%
outliers_idx = np.where(predictions>0.404)[0]

# %%
outliers_idx.shape
# Out:
# (56,)

# %%
df_predict["target"].iloc[outliers_idx] = -27

# %%
df_predict[df_predict.target == -27]
# Out:
#                 card_id  target
# 2624    C_ID_bd59e054f3   -30.0
# 5008    C_ID_be92f84f5c   -30.0
# 6026    C_ID_91cc0c06ca   -30.0
# 16074   C_ID_9c760806b5   -30.0
# 17778   C_ID_866eae8fb0   -30.0
# 18150   C_ID_ccf9ad6bf6   -30.0
# 18363   C_ID_d2871ae781   -30.0
# 20556   C_ID_aae50409e7   -30.0
# 23168   C_ID_3804897561   -30.0
# 26225   C_ID_44c140917d   -30.0
# 26864   C_ID_e7c702e96f   -30.0
# 27314   C_ID_7f5f950342   -30.0
# 27436   C_ID_493de71141   -30.0
# 30531   C_ID_f643abe215   -30.0
# 32446   C_ID_ac114ef831   -30.0
# 35851   C_ID_5ee52cf9f6   -30.0
# 41138   C_ID_d706b6696a   -30.0
# 43763   C_ID_74dd007aec   -30.0
# 54793   C_ID_761c27a0f2   -30.0
# 63978   C_ID_4cf141070f   -30.0
# 67890   C_ID_cde027fde7   -30.0
# 72751   C_ID_c683a599d0   -30.0
# 76013   C_ID_1afd4a6a1f   -30.0
# 77297   C_ID_b0c41ca140   -30.0
# 77945   C_ID_6ab591cf62   -30.0
# 78078   C_ID_922f9c5ea6   -30.0
# 79345   C_ID_63d38cafcb   -30.0
# 79686   C_ID_aeedecc9ae   -30.0
# 80840   C_ID_bced41d837   -30.0
# 81594   C_ID_3ba4759657   -30.0
# 83378   C_ID_8a93017bd2   -30.0
# 84477   C_ID_c32d4bfa02   -30.0
# 88371   C_ID_26f775a95b   -30.0
# 90555   C_ID_0203943aba   -30.0
# 91197   C_ID_7598b04bdf   -30.0
# 94668   C_ID_6e9a4a6008   -30.0
# 96354   C_ID_b237ce01cb   -30.0
# 103851  C_ID_877b879853   -30.0
# 104274  C_ID_bf939aa4e9   -30.0
# 104991  C_ID_86ddafb51c   -30.0
# 106891  C_ID_f617eb9c8e   -30.0
# 107752  C_ID_0c22eb865e   -30.0
# 108111  C_ID_b789a1772c   -30.0
# 108511  C_ID_2bd508a57d   -30.0
# 109705  C_ID_d596794318   -30.0
# 109960  C_ID_ba513d72b8   -30.0
# 111099  C_ID_601974ff16   -30.0
# 113597  C_ID_dc932bbd89   -30.0
# 114106  C_ID_e54aeb08f7   -30.0
# 116264  C_ID_a475834914   -30.0
# 116572  C_ID_f503a136f1   -30.0
# 116936  C_ID_561c8fe332   -30.0
# 119449  C_ID_3d40705001   -30.0
# 119851  C_ID_4cdcd7bbb1   -30.0
# 120151  C_ID_3e3bb028d1   -30.0
# 122519  C_ID_6a5ec7646a   -30.0

# %%
df_predict.target.describe()
# Out:
# count    123623.000000
# mean         -0.340585
# std           1.367283
# min         -30.000000
# 25%          -0.654177
# 50%          -0.214578
# 75%           0.245338
# max           5.014049
# Name: target, dtype: float64

# %%
df_predict
# Out:
#                 card_id    target
# 0       C_ID_0ab67a22ab -2.041275
# 1       C_ID_130fd0cbdd -0.305701
# 2       C_ID_b709037bc5 -0.974894
# 3       C_ID_d27d835a9f -0.090633
# 4       C_ID_2b5e3df5c2 -1.465622
# 5       C_ID_5814b4f13c  0.536912
# 6       C_ID_a1b3c75277  0.176816
# 7       C_ID_f7cada36d3  0.865616
# 8       C_ID_9d2bc8dfc4 -0.709276
# 9       C_ID_6d8dba8475 -1.145146
# 10      C_ID_4859ac9ed5 -0.643432
# 11      C_ID_0e281e8ad6  0.277421
# 12      C_ID_8375dfdaa2  0.119882
# 13      C_ID_79d149c008 -0.081392
# 14      C_ID_7f1041e8e1 -7.587275
# 15      C_ID_f72513589e  0.779489
# 16      C_ID_a7f2d6984e  0.633469
# 17      C_ID_15489b42d3 -0.181125
# 18      C_ID_e457bbd71d  0.182171
# 19      C_ID_3f74e10c7e -0.245650
# 20      C_ID_48243da9c4  0.209894
# 21      C_ID_7ea1fcf117 -0.645681
# 22      C_ID_22e4a47c72 -0.205771
# 23      C_ID_5d30729184  0.233964
# 24      C_ID_b54cfad8b2 -0.773896
# 25      C_ID_4b82e26faa -0.262735
# 26      C_ID_60a453531a -0.788592
# 27      C_ID_0c9315feec -0.437957
# 28      C_ID_1e28804d36 -0.136909
# 29      C_ID_68de79f7e2 -0.416897
# ...                 ...       ...
# 123593  C_ID_cd42a5db89 -0.344464
# 123594  C_ID_715b9a183d -1.097186
# 123595  C_ID_9b25df3309 -0.011294
# 123596  C_ID_043b3c2ccd  1.210842
# 123597  C_ID_7685eae7b2 -0.579362
# 123598  C_ID_7ee1a21a95 -0.569596
# 123599  C_ID_2bf12fed6b  0.708049
# 123600  C_ID_2932a6ea37 -0.750018
# 123601  C_ID_cc33d0d508 -1.028027
# 123602  C_ID_8852708dcb -0.537734
# 123603  C_ID_c3e88ef62d -0.178783
# 123604  C_ID_650557248c  0.713751
# 123605  C_ID_f14af9cb56 -0.563924
# 123606  C_ID_068dcf31e8 -0.558077
# 123607  C_ID_6659f4625a  0.629402
# 123608  C_ID_dc842bba27 -0.417375
# 123609  C_ID_bd625edce0 -0.074797
# 123610  C_ID_278446cc2f  0.423250
# 123611  C_ID_ad358eb92e -1.368579
# 123612  C_ID_7d9bcec574 -0.663539
# 123613  C_ID_b588b35e15 -0.060628
# 123614  C_ID_7147e348c3  0.662036
# 123615  C_ID_727d3ec5da -0.863329
# 123616  C_ID_107d93e20c  1.729334
# 123617  C_ID_0e74bd4966  0.588338
# 123618  C_ID_7a239d2eda  1.093064
# 123619  C_ID_75ace375ae -0.362897
# 123620  C_ID_21d56d950c  1.196001
# 123621  C_ID_6c46fc5a9d -3.002469
# 123622  C_ID_87e7979a5f -0.055991
#
# [123623 rows x 2 columns]

# %%
df_predict[["card_id", "target"]].to_csv("../output/submission_model20190201.csv", index=False)
