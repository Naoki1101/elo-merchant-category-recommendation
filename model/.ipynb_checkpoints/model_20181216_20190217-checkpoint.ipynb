# %%
import numpy as np
import pandas as pd
import datetime
import gc

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import lightgbm as lgb

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error, roc_auc_score
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')
np.random.seed(4590)

# %%
df_train = pd.read_csv('../input/train.csv')

# %%
df_train = pd.read_csv('../input/train.csv')
df_test = pd.read_csv('../input/test.csv')
df_hist_trans = pd.read_csv('../input/historical_transactions.csv')
df_new_merchant_trans = pd.read_csv('../input/new_merchant_transactions.csv')

# %%
df_hist_trans = df_hist_trans[df_hist_trans.purchase_amount < 1e+5].reset_index(drop=True)
df_new_merchant_trans = df_new_merchant_trans[df_new_merchant_trans.purchase_amount < 1e+5].reset_index(drop=True)

# %%
df_hist_trans['purchase_amount'] = np.round(df_hist_trans['purchase_amount'] / 0.00150265118 + 497.06,2)
df_new_merchant_trans['purchase_amount'] = np.round(df_new_merchant_trans['purchase_amount'] / 0.00150265118 + 497.06,2)

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['category_2'].fillna(1.0,inplace=True)
    df['category_3'].fillna('A',inplace=True)
    df['merchant_id'].fillna('M_ID_00a6ca8a8a',inplace=True)

# %%
def get_new_columns(name,aggs):
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    df['year'] = df['purchase_date'].dt.year
    df['weekofyear'] = df['purchase_date'].dt.weekofyear
    df['month'] = df['purchase_date'].dt.month
    df['dayofweek'] = df['purchase_date'].dt.dayofweek
    df['weekend'] = (df.purchase_date.dt.weekday >=5).astype(int)
    df['hour'] = df['purchase_date'].dt.hour
    df['authorized_flag'] = df['authorized_flag'].map({'Y':1, 'N':0})
    df['category_1'] = df['category_1'].map({'Y':1, 'N':0}) 
    #https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/73244
    df['month_diff'] = ((datetime.datetime.today() - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']

aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['authorized_flag'] = ['sum', 'mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_hist_trans[col+'_mean'] = df_hist_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']    

new_columns = get_new_columns('hist',aggs)
df_hist_trans_group = df_hist_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['hist_purchase_date_diff'] = (df_hist_trans_group['hist_purchase_date_max'] - df_hist_trans_group['hist_purchase_date_min']).dt.days
df_hist_trans_group['hist_purchase_date_average'] = df_hist_trans_group['hist_purchase_date_diff']/df_hist_trans_group['hist_card_id_size']
df_hist_trans_group['hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 131

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']
aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_new_merchant_trans[col+'_mean'] = df_new_merchant_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']
    
new_columns = get_new_columns('new_hist',aggs)
df_hist_trans_group = df_new_merchant_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['new_hist_purchase_date_diff'] = (df_hist_trans_group['new_hist_purchase_date_max'] - df_hist_trans_group['new_hist_purchase_date_min']).dt.days
df_hist_trans_group['new_hist_purchase_date_average'] = df_hist_trans_group['new_hist_purchase_date_diff']/df_hist_trans_group['new_hist_card_id_size']
df_hist_trans_group['new_hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['new_hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 131

# %%
del df_hist_trans;gc.collect()
del df_new_merchant_trans;gc.collect()
df_train.head(5)
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
# 3            2017-09  C_ID_186d6a6901          4          3          0
# 4            2017-11  C_ID_cdbd2c0db2          1          3          0
#
#      target  hist_weekend_sum  hist_weekend_mean  hist_year_nunique  \
# 0 -0.820283                90           0.346154                  2
# 1  0.392913               132           0.377143                  2
# 2  0.688056                11           0.255814                  2
# 3  0.142495                11           0.142857                  2
# 4 -0.159749                42           0.315789                  2
#
#    hist_month_lag_max               ...                \
# 0                   0               ...
# 1                   0               ...
# 2                   0               ...
# 3                   0               ...
# 4                   0               ...
#
#    new_hist_category_2_mean_mean  new_hist_card_id_size  \
# 0                     130.933744                   23.0
# 1                     130.933744                    6.0
# 2                     131.695820                    1.0
# 3                     126.702374                    7.0
# 4                     127.416035                   36.0
#
#    new_hist_merchant_id_nunique  new_hist_hour_nunique  \
# 0                          23.0                    8.0
# 1                           6.0                    5.0
# 2                           1.0                    1.0
# 3                           7.0                    5.0
# 4                          36.0                   14.0
#
#    new_hist_purchase_date_max  new_hist_purchase_date_min  \
# 0         2018-04-29 11:23:05         2018-03-05 14:04:36
# 1         2018-03-30 06:48:26         2018-02-01 17:07:54
# 2         2018-04-28 17:43:11         2018-04-28 17:43:11
# 3         2018-04-18 11:00:11         2018-03-07 11:55:06
# 4         2018-04-28 18:50:25         2018-03-02 11:55:43
#
#    new_hist_merchant_category_id_nunique  new_hist_purchase_date_diff  \
# 0                                   14.0                         54.0
# 1                                    5.0                         56.0
# 2                                    1.0                          0.0
# 3                                    6.0                         41.0
# 4                                   17.0                         57.0
#
#    new_hist_purchase_date_average  new_hist_purchase_date_uptonow
# 0                        2.347826                           302.0
# 1                        9.333333                           332.0
# 2                        0.000000                           302.0
# 3                        5.857143                           313.0
# 4                        1.583333                           302.0
#
# [5 rows x 78 columns]

# %%
df_train['outliers'] = 0
df_train.loc[df_train['target'] < -30, 'outliers'] = 1
df_train['outliers'].value_counts()
# Out:
# 0    199710
# 1      2207
# Name: outliers, dtype: int64

# %%
list_outlier_idx = df_train[df_train.outliers == 1].index.tolist()

# %%
for df in [df_train,df_test]:
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['dayofweek'] = df['first_active_month'].dt.dayofweek
    df['weekofyear'] = df['first_active_month'].dt.weekofyear
    df['month'] = df['first_active_month'].dt.month
    df['elapsed_time'] = (datetime.datetime.today() - df['first_active_month']).dt.days
    df['hist_first_buy'] = (df['hist_purchase_date_min'] - df['first_active_month']).dt.days
    df['new_hist_first_buy'] = (df['new_hist_purchase_date_min'] - df['first_active_month']).dt.days
    for f in ['hist_purchase_date_max','hist_purchase_date_min','new_hist_purchase_date_max',\
                     'new_hist_purchase_date_min']:
        df[f] = df[f].astype(np.int64) * 1e-9
    df['card_id_total'] = df['new_hist_card_id_size']+df['hist_card_id_size']
    df['purchase_amount_total'] = df['new_hist_purchase_amount_sum']+df['hist_purchase_amount_sum']

for f in ['feature_1','feature_2','feature_3']:
    order_label = df_train.groupby([f])['outliers'].mean()
    df_train[f] = df_train[f].map(order_label)
    df_test[f] = df_test[f].map(order_label)
    
print(df_train.shape)
# Out:
# (201917, 87)

# %%
high_importance_features = [
    "hist_month_diff_mean", 
    "hist_authorized_flag_mean", 
    "hist_category_1_sum", 
    "hist_month_lag_mean", 
    "new_hist_purchase_amount_sum", 
    "new_hist_purchase_date_uptonow"
]

#smoothing
for col in high_importance_features:
    df_train[col] = np.where(df_train[col].values==0, 0.001, df_train[col].values)
    df_test[col] = np.where(df_test[col].values==0, 0.001, df_test[col].values)


for i in range(len(high_importance_features)):
    for j in range(len((high_importance_features)))[i+1:]:
        col1 = high_importance_features[i]
        col2 = high_importance_features[j]
        new_col_name = "{c1}__div__{c2}".format(c1=col1, c2=col2)
        
        df_train[new_col_name] = df_train[col1] / df_train[col2]
        df_test[new_col_name] = df_test[col1] / df_test[col2]

print(df_train.shape)
# Out:
# (201917, 102)

# %%
def merge_new_feature(path):
    df_new_feature = pd.read_csv(path)
    
    df_tr = pd.merge(df_train, df_new_feature, on="card_id", how="left")
    df_te = pd.merge(df_test, df_new_feature, on="card_id", how="left")
    
    return df_tr, df_te

# %%
df_train, df_test = merge_new_feature("../input/merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/new_merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/purchase_amount_each_merchant_nmf.csv")
df_train, df_test = merge_new_feature("../input/prosperity_merchants_latest.csv")
df_train, df_test = merge_new_feature("../input/merchants_numerical_features.csv")
df_train, df_test = merge_new_feature("../input/merchants_item_scale_feature.csv")
df_train, df_test = merge_new_feature("../input/purchase_pattern.csv")
df_train, df_test = merge_new_feature("../input/purchase_pettern_nmf.csv")
df_train, df_test = merge_new_feature("../input/purchase_amount_pettern_nmf.csv")
df_train, df_test = merge_new_feature("../input/feature_count_merchants_of_zero_target.csv")
df_train, df_test = merge_new_feature("../input/feature_increase_rate_purchase_amount.csv")
df_train, df_test = merge_new_feature("../input/feature_frequency_mean_increase_rate.csv")

# %%
df_train["Null_count"] = df_train.isnull().sum(axis=1)
df_test["Null_count"] = df_test.isnull().sum(axis=1)

# %%
df_train_columns = [c for c in df_train.columns if c not in ['card_id', 'first_active_month','second_active_date','diff_first_and_second','target','outliers']]
target = df_train['target']
target_outlier = df_train["outliers"]

# %%
# import optuna

# def objective(trial):
#     train_x, test_x, train_y, test_y = train_test_split(df_train[df_train_columns], target, test_size=0.20, random_state=4590)
    
#     dtrain = lgb.Dataset(train_x, label=train_y)
#     dval = lgb.Dataset(test_x, label=test_y)

#     num_round = trial.suggest_int('num_round', 1, 10000)
#     param = {
#         'objective': 'regression', 
#         'metric': 'rmse',
#         'verbosity': -1,
#         'feature_fraction': 0.9,
#         'bagging_fraction': 0.9,
#         'bagging_seed': 11,
#         'boosting_type': 'gbdt',
#         'num_leaves': 31,
#         'learning_rate': 0.01,
#         'min_child_samples': 20,
#         'min_data_in_leaf':  30,
#         'lambda_l1':  trial.suggest_loguniform('lambda_l1', 1e-2, 1.0)
#     }

#     gbm = lgb.train(param, dtrain, num_round, valid_sets = [dtrain, dval], verbose_eval=100, early_stopping_rounds=400)
#     preds = gbm.predict(test_x)
#     pred_labels = np.rint(preds)
#     rmse = np.sqrt(mean_squared_error(test_y, pred_labels))
#     return rmse

# study = optuna.create_study()
# study.optimize(objective, n_trials=20)

# print('Number of finished trials: {}'.format(len(study.trials)))

# print('Best trial:')
# trial = study.best_trial

# print('  Value: {}'.format(trial.value))

# print('  Params: ')
# for key, value in trial.params.items():
#     print('    {}: {}'.format(key, value))

# %%
#original
param = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',
    'max_depth': 8,
    "max_bin": 256,  # なし
    'learning_rate': 0.004,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.7296012043929662,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74012	valid_1's rmse: 3.77106
# [200]	training's rmse: 3.67329	valid_1's rmse: 3.72679
# [300]	training's rmse: 3.62833	valid_1's rmse: 3.7023
# [400]	training's rmse: 3.59426	valid_1's rmse: 3.68631
# [500]	training's rmse: 3.5684	valid_1's rmse: 3.67651
# [600]	training's rmse: 3.54833	valid_1's rmse: 3.66937
# [700]	training's rmse: 3.53159	valid_1's rmse: 3.66414
# [800]	training's rmse: 3.51676	valid_1's rmse: 3.66011
# [900]	training's rmse: 3.50335	valid_1's rmse: 3.65705
# [1000]	training's rmse: 3.49092	valid_1's rmse: 3.65469
# [1100]	training's rmse: 3.4793	valid_1's rmse: 3.65296
# [1200]	training's rmse: 3.468	valid_1's rmse: 3.65148
# [1300]	training's rmse: 3.45749	valid_1's rmse: 3.65001
# [1400]	training's rmse: 3.44718	valid_1's rmse: 3.64934
# [1500]	training's rmse: 3.43733	valid_1's rmse: 3.6483
# [1600]	training's rmse: 3.42772	valid_1's rmse: 3.64726
# [1700]	training's rmse: 3.4185	valid_1's rmse: 3.6465
# [1800]	training's rmse: 3.40947	valid_1's rmse: 3.64592
# [1900]	training's rmse: 3.40092	valid_1's rmse: 3.64558
# [2000]	training's rmse: 3.39235	valid_1's rmse: 3.64481
# [2100]	training's rmse: 3.38385	valid_1's rmse: 3.64428
# [2200]	training's rmse: 3.37645	valid_1's rmse: 3.64378
# [2300]	training's rmse: 3.36846	valid_1's rmse: 3.64324
# [2400]	training's rmse: 3.36085	valid_1's rmse: 3.64294
# [2500]	training's rmse: 3.35346	valid_1's rmse: 3.64296
# [2600]	training's rmse: 3.34609	valid_1's rmse: 3.6427
# [2700]	training's rmse: 3.33891	valid_1's rmse: 3.64241
# [2800]	training's rmse: 3.33183	valid_1's rmse: 3.64212
# [2900]	training's rmse: 3.32472	valid_1's rmse: 3.64203
# [3000]	training's rmse: 3.31795	valid_1's rmse: 3.64189
# [3100]	training's rmse: 3.31107	valid_1's rmse: 3.64174
# [3200]	training's rmse: 3.30417	valid_1's rmse: 3.64161
# [3300]	training's rmse: 3.29732	valid_1's rmse: 3.64129
# [3400]	training's rmse: 3.29087	valid_1's rmse: 3.64114
# [3500]	training's rmse: 3.2842	valid_1's rmse: 3.64121
# [3600]	training's rmse: 3.27823	valid_1's rmse: 3.64128
# [3700]	training's rmse: 3.27199	valid_1's rmse: 3.64108
# [3800]	training's rmse: 3.26587	valid_1's rmse: 3.64095
# [3900]	training's rmse: 3.25949	valid_1's rmse: 3.64079
# [4000]	training's rmse: 3.25311	valid_1's rmse: 3.64078
# [4100]	training's rmse: 3.24717	valid_1's rmse: 3.64079
# [4200]	training's rmse: 3.24141	valid_1's rmse: 3.64076
# [4300]	training's rmse: 3.23538	valid_1's rmse: 3.64089
# Early stopping, best iteration is:
# [3975]	training's rmse: 3.25468	valid_1's rmse: 3.64065
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74439	valid_1's rmse: 3.75963
# [200]	training's rmse: 3.67743	valid_1's rmse: 3.7136
# [300]	training's rmse: 3.63151	valid_1's rmse: 3.68744
# [400]	training's rmse: 3.59652	valid_1's rmse: 3.67135
# [500]	training's rmse: 3.57041	valid_1's rmse: 3.66125
# [600]	training's rmse: 3.55018	valid_1's rmse: 3.65462
# [700]	training's rmse: 3.53301	valid_1's rmse: 3.64962
# [800]	training's rmse: 3.51785	valid_1's rmse: 3.64582
# [900]	training's rmse: 3.50477	valid_1's rmse: 3.64311
# [1000]	training's rmse: 3.49252	valid_1's rmse: 3.64112
# [1100]	training's rmse: 3.48049	valid_1's rmse: 3.63934
# [1200]	training's rmse: 3.46912	valid_1's rmse: 3.63804
# [1300]	training's rmse: 3.45774	valid_1's rmse: 3.63709
# [1400]	training's rmse: 3.44696	valid_1's rmse: 3.63627
# [1500]	training's rmse: 3.43669	valid_1's rmse: 3.63576
# [1600]	training's rmse: 3.42672	valid_1's rmse: 3.635
# [1700]	training's rmse: 3.41683	valid_1's rmse: 3.63463
# [1800]	training's rmse: 3.40761	valid_1's rmse: 3.63416
# [1900]	training's rmse: 3.39895	valid_1's rmse: 3.634
# [2000]	training's rmse: 3.39019	valid_1's rmse: 3.63392
# [2100]	training's rmse: 3.38168	valid_1's rmse: 3.63374
# [2200]	training's rmse: 3.3731	valid_1's rmse: 3.63373
# [2300]	training's rmse: 3.36519	valid_1's rmse: 3.63369
# [2400]	training's rmse: 3.35724	valid_1's rmse: 3.63367
# [2500]	training's rmse: 3.34945	valid_1's rmse: 3.63363
# [2600]	training's rmse: 3.34191	valid_1's rmse: 3.63364
# [2700]	training's rmse: 3.33456	valid_1's rmse: 3.63388
# Early stopping, best iteration is:
# [2321]	training's rmse: 3.36341	valid_1's rmse: 3.6336
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74542	valid_1's rmse: 3.75733
# [200]	training's rmse: 3.68038	valid_1's rmse: 3.70765
# [300]	training's rmse: 3.63571	valid_1's rmse: 3.67963
# [400]	training's rmse: 3.60215	valid_1's rmse: 3.66132
# [500]	training's rmse: 3.57678	valid_1's rmse: 3.64948
# [600]	training's rmse: 3.55686	valid_1's rmse: 3.64211
# [700]	training's rmse: 3.53985	valid_1's rmse: 3.63664
# [800]	training's rmse: 3.5253	valid_1's rmse: 3.63304
# [900]	training's rmse: 3.51201	valid_1's rmse: 3.62982
# [1000]	training's rmse: 3.49942	valid_1's rmse: 3.62733
# [1100]	training's rmse: 3.48767	valid_1's rmse: 3.62553
# [1200]	training's rmse: 3.47639	valid_1's rmse: 3.62383
# [1300]	training's rmse: 3.46541	valid_1's rmse: 3.62254
# [1400]	training's rmse: 3.45515	valid_1's rmse: 3.62153
# [1500]	training's rmse: 3.44574	valid_1's rmse: 3.62058
# [1600]	training's rmse: 3.43592	valid_1's rmse: 3.61996
# [1700]	training's rmse: 3.42689	valid_1's rmse: 3.61951
# [1800]	training's rmse: 3.41761	valid_1's rmse: 3.61873
# [1900]	training's rmse: 3.40936	valid_1's rmse: 3.61828
# [2000]	training's rmse: 3.40097	valid_1's rmse: 3.6181
# [2100]	training's rmse: 3.39289	valid_1's rmse: 3.61762
# [2200]	training's rmse: 3.38476	valid_1's rmse: 3.61726
# [2300]	training's rmse: 3.37711	valid_1's rmse: 3.61707
# [2400]	training's rmse: 3.36911	valid_1's rmse: 3.61676
# [2500]	training's rmse: 3.3617	valid_1's rmse: 3.61667
# [2600]	training's rmse: 3.35424	valid_1's rmse: 3.61677
# [2700]	training's rmse: 3.34742	valid_1's rmse: 3.61674
# [2800]	training's rmse: 3.3405	valid_1's rmse: 3.61661
# [2900]	training's rmse: 3.33351	valid_1's rmse: 3.61659
# [3000]	training's rmse: 3.32704	valid_1's rmse: 3.61642
# [3100]	training's rmse: 3.32008	valid_1's rmse: 3.61642
# [3200]	training's rmse: 3.31371	valid_1's rmse: 3.61635
# [3300]	training's rmse: 3.30699	valid_1's rmse: 3.61635
# [3400]	training's rmse: 3.30021	valid_1's rmse: 3.61633
# [3500]	training's rmse: 3.29372	valid_1's rmse: 3.6162
# [3600]	training's rmse: 3.28728	valid_1's rmse: 3.61619
# [3700]	training's rmse: 3.28113	valid_1's rmse: 3.61625
# [3800]	training's rmse: 3.27471	valid_1's rmse: 3.61628
# [3900]	training's rmse: 3.26826	valid_1's rmse: 3.616
# [4000]	training's rmse: 3.2626	valid_1's rmse: 3.6159
# [4100]	training's rmse: 3.25633	valid_1's rmse: 3.61597
# [4200]	training's rmse: 3.2504	valid_1's rmse: 3.61609
# [4300]	training's rmse: 3.24457	valid_1's rmse: 3.61633
# [4400]	training's rmse: 3.23885	valid_1's rmse: 3.61647
# Early stopping, best iteration is:
# [4036]	training's rmse: 3.26014	valid_1's rmse: 3.61584
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74083	valid_1's rmse: 3.76557
# [200]	training's rmse: 3.67212	valid_1's rmse: 3.72306
# [300]	training's rmse: 3.62602	valid_1's rmse: 3.70089
# [400]	training's rmse: 3.59153	valid_1's rmse: 3.68848
# [500]	training's rmse: 3.56501	valid_1's rmse: 3.68123
# [600]	training's rmse: 3.54481	valid_1's rmse: 3.67683
# [700]	training's rmse: 3.52782	valid_1's rmse: 3.67385
# [800]	training's rmse: 3.5125	valid_1's rmse: 3.6713
# [900]	training's rmse: 3.499	valid_1's rmse: 3.66949
# [1000]	training's rmse: 3.4866	valid_1's rmse: 3.6684
# [1100]	training's rmse: 3.4748	valid_1's rmse: 3.66766
# [1200]	training's rmse: 3.46326	valid_1's rmse: 3.66709
# [1300]	training's rmse: 3.45271	valid_1's rmse: 3.66637
# [1400]	training's rmse: 3.44256	valid_1's rmse: 3.66577
# [1500]	training's rmse: 3.43281	valid_1's rmse: 3.66551
# [1600]	training's rmse: 3.42333	valid_1's rmse: 3.66523
# [1700]	training's rmse: 3.41381	valid_1's rmse: 3.66529
# [1800]	training's rmse: 3.40508	valid_1's rmse: 3.66519
# [1900]	training's rmse: 3.39649	valid_1's rmse: 3.66514
# [2000]	training's rmse: 3.38778	valid_1's rmse: 3.66544
# [2100]	training's rmse: 3.37965	valid_1's rmse: 3.66512
# [2200]	training's rmse: 3.37135	valid_1's rmse: 3.66468
# [2300]	training's rmse: 3.36303	valid_1's rmse: 3.66442
# [2400]	training's rmse: 3.35455	valid_1's rmse: 3.66452
# [2500]	training's rmse: 3.34655	valid_1's rmse: 3.66437
# [2600]	training's rmse: 3.33887	valid_1's rmse: 3.66426
# [2700]	training's rmse: 3.33134	valid_1's rmse: 3.66426
# [2800]	training's rmse: 3.32403	valid_1's rmse: 3.66402
# [2900]	training's rmse: 3.3167	valid_1's rmse: 3.66395
# [3000]	training's rmse: 3.30974	valid_1's rmse: 3.66383
# [3100]	training's rmse: 3.30262	valid_1's rmse: 3.66382
# [3200]	training's rmse: 3.29588	valid_1's rmse: 3.66392
# [3300]	training's rmse: 3.28869	valid_1's rmse: 3.66384
# [3400]	training's rmse: 3.28166	valid_1's rmse: 3.66389
# Early stopping, best iteration is:
# [3082]	training's rmse: 3.30402	valid_1's rmse: 3.66376
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.73848	valid_1's rmse: 3.77482
# [200]	training's rmse: 3.67048	valid_1's rmse: 3.73126
# [300]	training's rmse: 3.62404	valid_1's rmse: 3.70794
# [400]	training's rmse: 3.58856	valid_1's rmse: 3.69411
# [500]	training's rmse: 3.56166	valid_1's rmse: 3.6849
# [600]	training's rmse: 3.54106	valid_1's rmse: 3.67902
# [700]	training's rmse: 3.52425	valid_1's rmse: 3.67559
# [800]	training's rmse: 3.50939	valid_1's rmse: 3.6727
# [900]	training's rmse: 3.4954	valid_1's rmse: 3.67027
# [1000]	training's rmse: 3.48269	valid_1's rmse: 3.6686
# [1100]	training's rmse: 3.47087	valid_1's rmse: 3.66749
# [1200]	training's rmse: 3.45948	valid_1's rmse: 3.66631
# [1300]	training's rmse: 3.44868	valid_1's rmse: 3.66573
# [1400]	training's rmse: 3.43804	valid_1's rmse: 3.66527
# [1500]	training's rmse: 3.4279	valid_1's rmse: 3.66457
# [1600]	training's rmse: 3.41826	valid_1's rmse: 3.66416
# [1700]	training's rmse: 3.40876	valid_1's rmse: 3.66387
# [1800]	training's rmse: 3.3998	valid_1's rmse: 3.6633
# [1900]	training's rmse: 3.39079	valid_1's rmse: 3.66291
# [2000]	training's rmse: 3.3825	valid_1's rmse: 3.66274
# [2100]	training's rmse: 3.37387	valid_1's rmse: 3.66243
# [2200]	training's rmse: 3.36582	valid_1's rmse: 3.66218
# [2300]	training's rmse: 3.35793	valid_1's rmse: 3.66204
# [2400]	training's rmse: 3.35012	valid_1's rmse: 3.66193
# [2500]	training's rmse: 3.34303	valid_1's rmse: 3.66173
# [2600]	training's rmse: 3.33533	valid_1's rmse: 3.66164
# [2700]	training's rmse: 3.32847	valid_1's rmse: 3.66157
# [2800]	training's rmse: 3.32178	valid_1's rmse: 3.6613
# [2900]	training's rmse: 3.31488	valid_1's rmse: 3.66138
# [3000]	training's rmse: 3.30828	valid_1's rmse: 3.6615
# [3100]	training's rmse: 3.30169	valid_1's rmse: 3.66164
# [3200]	training's rmse: 3.29567	valid_1's rmse: 3.66171
# Early stopping, best iteration is:
# [2847]	training's rmse: 3.31859	valid_1's rmse: 3.66125
# 3.643062087229375

# %%
# score:  3.6467757129353053

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,50))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
# plt.savefig('lgbm_importances.png')

# %%
df_train2 = df_train[df_train.target >= -20].reset_index(drop=True)
target2 = df_train2["target"]

#original
param2 = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',
    'max_depth': 8,
    'learning_rate': 0.01,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.7296012043929662,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train2))
predictions2 = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train2,df_train2['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train2.iloc[trn_idx][df_train_columns], label=target2.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train2.iloc[val_idx][df_train_columns], label=target2.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param2, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train2.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions2 += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target2))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60317	valid_1's rmse: 1.60322
# [200]	training's rmse: 1.57125	valid_1's rmse: 1.57463
# [300]	training's rmse: 1.55587	valid_1's rmse: 1.56389
# [400]	training's rmse: 1.54571	valid_1's rmse: 1.5585
# [500]	training's rmse: 1.53787	valid_1's rmse: 1.55547
# [600]	training's rmse: 1.53107	valid_1's rmse: 1.5534
# [700]	training's rmse: 1.52517	valid_1's rmse: 1.55202
# [800]	training's rmse: 1.51976	valid_1's rmse: 1.55109
# [900]	training's rmse: 1.51475	valid_1's rmse: 1.5506
# [1000]	training's rmse: 1.50999	valid_1's rmse: 1.5502
# [1100]	training's rmse: 1.50542	valid_1's rmse: 1.54987
# [1200]	training's rmse: 1.50115	valid_1's rmse: 1.54964
# [1300]	training's rmse: 1.4969	valid_1's rmse: 1.54946
# [1400]	training's rmse: 1.49274	valid_1's rmse: 1.54934
# [1500]	training's rmse: 1.4887	valid_1's rmse: 1.54927
# [1600]	training's rmse: 1.48461	valid_1's rmse: 1.54913
# [1700]	training's rmse: 1.48066	valid_1's rmse: 1.54908
# [1800]	training's rmse: 1.47674	valid_1's rmse: 1.54899
# [1900]	training's rmse: 1.47301	valid_1's rmse: 1.54895
# [2000]	training's rmse: 1.46915	valid_1's rmse: 1.549
# [2100]	training's rmse: 1.46539	valid_1's rmse: 1.54889
# [2200]	training's rmse: 1.46174	valid_1's rmse: 1.54887
# [2300]	training's rmse: 1.45807	valid_1's rmse: 1.54873
# [2400]	training's rmse: 1.45446	valid_1's rmse: 1.54871
# [2500]	training's rmse: 1.45085	valid_1's rmse: 1.54873
# [2600]	training's rmse: 1.44722	valid_1's rmse: 1.54859
# [2700]	training's rmse: 1.44371	valid_1's rmse: 1.54854
# [2800]	training's rmse: 1.44023	valid_1's rmse: 1.54862
# [2900]	training's rmse: 1.43667	valid_1's rmse: 1.54863
# [3000]	training's rmse: 1.43328	valid_1's rmse: 1.54871
# Early stopping, best iteration is:
# [2642]	training's rmse: 1.44572	valid_1's rmse: 1.54853
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60557	valid_1's rmse: 1.58972
# [200]	training's rmse: 1.5732	valid_1's rmse: 1.56397
# [300]	training's rmse: 1.55797	valid_1's rmse: 1.55442
# [400]	training's rmse: 1.54789	valid_1's rmse: 1.54938
# [500]	training's rmse: 1.54004	valid_1's rmse: 1.54652
# [600]	training's rmse: 1.53336	valid_1's rmse: 1.54452
# [700]	training's rmse: 1.52745	valid_1's rmse: 1.54312
# [800]	training's rmse: 1.52201	valid_1's rmse: 1.54238
# [900]	training's rmse: 1.51702	valid_1's rmse: 1.54181
# [1000]	training's rmse: 1.51223	valid_1's rmse: 1.54138
# [1100]	training's rmse: 1.50767	valid_1's rmse: 1.54111
# [1200]	training's rmse: 1.50325	valid_1's rmse: 1.54085
# [1300]	training's rmse: 1.49898	valid_1's rmse: 1.54059
# [1400]	training's rmse: 1.49474	valid_1's rmse: 1.54041
# [1500]	training's rmse: 1.49061	valid_1's rmse: 1.54029
# [1600]	training's rmse: 1.48657	valid_1's rmse: 1.54016
# [1700]	training's rmse: 1.48264	valid_1's rmse: 1.53998
# [1800]	training's rmse: 1.47863	valid_1's rmse: 1.53996
# [1900]	training's rmse: 1.47479	valid_1's rmse: 1.53986
# [2000]	training's rmse: 1.47095	valid_1's rmse: 1.53973
# [2100]	training's rmse: 1.46723	valid_1's rmse: 1.53969
# [2200]	training's rmse: 1.46353	valid_1's rmse: 1.5396
# [2300]	training's rmse: 1.45973	valid_1's rmse: 1.53954
# [2400]	training's rmse: 1.45607	valid_1's rmse: 1.53947
# [2500]	training's rmse: 1.45247	valid_1's rmse: 1.5394
# [2600]	training's rmse: 1.449	valid_1's rmse: 1.53931
# [2700]	training's rmse: 1.44546	valid_1's rmse: 1.53932
# [2800]	training's rmse: 1.44203	valid_1's rmse: 1.53929
# [2900]	training's rmse: 1.43845	valid_1's rmse: 1.53921
# [3000]	training's rmse: 1.43508	valid_1's rmse: 1.53924
# [3100]	training's rmse: 1.43158	valid_1's rmse: 1.53922
# [3200]	training's rmse: 1.42823	valid_1's rmse: 1.53915
# [3300]	training's rmse: 1.42493	valid_1's rmse: 1.5392
# [3400]	training's rmse: 1.4216	valid_1's rmse: 1.53925
# [3500]	training's rmse: 1.41828	valid_1's rmse: 1.53927
# [3600]	training's rmse: 1.41498	valid_1's rmse: 1.53931
# Early stopping, best iteration is:
# [3213]	training's rmse: 1.42784	valid_1's rmse: 1.53914
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60173	valid_1's rmse: 1.60753
# [200]	training's rmse: 1.56991	valid_1's rmse: 1.58024
# [300]	training's rmse: 1.55488	valid_1's rmse: 1.56971
# [400]	training's rmse: 1.54487	valid_1's rmse: 1.56441
# [500]	training's rmse: 1.53704	valid_1's rmse: 1.5614
# [600]	training's rmse: 1.53027	valid_1's rmse: 1.5593
# [700]	training's rmse: 1.52428	valid_1's rmse: 1.55804
# [800]	training's rmse: 1.51892	valid_1's rmse: 1.55715
# [900]	training's rmse: 1.51388	valid_1's rmse: 1.55649
# [1000]	training's rmse: 1.50905	valid_1's rmse: 1.55605
# [1100]	training's rmse: 1.5044	valid_1's rmse: 1.55579
# [1200]	training's rmse: 1.49989	valid_1's rmse: 1.55555
# [1300]	training's rmse: 1.49562	valid_1's rmse: 1.55534
# [1400]	training's rmse: 1.49137	valid_1's rmse: 1.55526
# [1500]	training's rmse: 1.48729	valid_1's rmse: 1.55508
# [1600]	training's rmse: 1.48323	valid_1's rmse: 1.55486
# [1700]	training's rmse: 1.47928	valid_1's rmse: 1.55473
# [1800]	training's rmse: 1.47534	valid_1's rmse: 1.5546
# [1900]	training's rmse: 1.47135	valid_1's rmse: 1.55455
# [2000]	training's rmse: 1.46753	valid_1's rmse: 1.55455
# [2100]	training's rmse: 1.4637	valid_1's rmse: 1.55468
# [2200]	training's rmse: 1.46	valid_1's rmse: 1.55455
# [2300]	training's rmse: 1.4562	valid_1's rmse: 1.55454
# [2400]	training's rmse: 1.4525	valid_1's rmse: 1.55451
# [2500]	training's rmse: 1.44873	valid_1's rmse: 1.55447
# [2600]	training's rmse: 1.44524	valid_1's rmse: 1.55446
# [2700]	training's rmse: 1.44174	valid_1's rmse: 1.55446
# [2800]	training's rmse: 1.43826	valid_1's rmse: 1.55442
# [2900]	training's rmse: 1.43476	valid_1's rmse: 1.55444
# [3000]	training's rmse: 1.43126	valid_1's rmse: 1.55448
# [3100]	training's rmse: 1.42781	valid_1's rmse: 1.55451
# [3200]	training's rmse: 1.42434	valid_1's rmse: 1.55452
# Early stopping, best iteration is:
# [2853]	training's rmse: 1.43639	valid_1's rmse: 1.55438
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60166	valid_1's rmse: 1.60668
# [200]	training's rmse: 1.56962	valid_1's rmse: 1.58022
# [300]	training's rmse: 1.55443	valid_1's rmse: 1.57018
# [400]	training's rmse: 1.54441	valid_1's rmse: 1.56497
# [500]	training's rmse: 1.5366	valid_1's rmse: 1.56194
# [600]	training's rmse: 1.52986	valid_1's rmse: 1.55997
# [700]	training's rmse: 1.52387	valid_1's rmse: 1.55858
# [800]	training's rmse: 1.51844	valid_1's rmse: 1.5577
# [900]	training's rmse: 1.51339	valid_1's rmse: 1.55707
# [1000]	training's rmse: 1.50861	valid_1's rmse: 1.55669
# [1100]	training's rmse: 1.50398	valid_1's rmse: 1.55636
# [1200]	training's rmse: 1.49947	valid_1's rmse: 1.556
# [1300]	training's rmse: 1.49523	valid_1's rmse: 1.55578
# [1400]	training's rmse: 1.49101	valid_1's rmse: 1.55563
# [1500]	training's rmse: 1.48684	valid_1's rmse: 1.55552
# [1600]	training's rmse: 1.48281	valid_1's rmse: 1.55527
# [1700]	training's rmse: 1.47891	valid_1's rmse: 1.55526
# [1800]	training's rmse: 1.47509	valid_1's rmse: 1.55512
# [1900]	training's rmse: 1.47116	valid_1's rmse: 1.55503
# [2000]	training's rmse: 1.46731	valid_1's rmse: 1.555
# [2100]	training's rmse: 1.46356	valid_1's rmse: 1.5549
# [2200]	training's rmse: 1.45984	valid_1's rmse: 1.55489
# [2300]	training's rmse: 1.45622	valid_1's rmse: 1.55481
# [2400]	training's rmse: 1.4526	valid_1's rmse: 1.5548
# [2500]	training's rmse: 1.44903	valid_1's rmse: 1.55473
# [2600]	training's rmse: 1.44543	valid_1's rmse: 1.55473
# [2700]	training's rmse: 1.44197	valid_1's rmse: 1.55476
# [2800]	training's rmse: 1.4383	valid_1's rmse: 1.55462
# [2900]	training's rmse: 1.435	valid_1's rmse: 1.55458
# [3000]	training's rmse: 1.43166	valid_1's rmse: 1.55456
# [3100]	training's rmse: 1.4282	valid_1's rmse: 1.55462
# [3200]	training's rmse: 1.42462	valid_1's rmse: 1.55459
# [3300]	training's rmse: 1.42119	valid_1's rmse: 1.55459
# Early stopping, best iteration is:
# [2956]	training's rmse: 1.4331	valid_1's rmse: 1.55454
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.5972	valid_1's rmse: 1.62678
# [200]	training's rmse: 1.56528	valid_1's rmse: 1.59931
# [300]	training's rmse: 1.55015	valid_1's rmse: 1.5888
# [400]	training's rmse: 1.54008	valid_1's rmse: 1.58348
# [500]	training's rmse: 1.53221	valid_1's rmse: 1.58051
# [600]	training's rmse: 1.52551	valid_1's rmse: 1.57853
# [700]	training's rmse: 1.51961	valid_1's rmse: 1.57731
# [800]	training's rmse: 1.51425	valid_1's rmse: 1.57647
# [900]	training's rmse: 1.50923	valid_1's rmse: 1.57597
# [1000]	training's rmse: 1.50451	valid_1's rmse: 1.57562
# [1100]	training's rmse: 1.49997	valid_1's rmse: 1.57544
# [1200]	training's rmse: 1.49561	valid_1's rmse: 1.57518
# [1300]	training's rmse: 1.49141	valid_1's rmse: 1.57493
# [1400]	training's rmse: 1.48729	valid_1's rmse: 1.57487
# [1500]	training's rmse: 1.48313	valid_1's rmse: 1.57484
# [1600]	training's rmse: 1.4791	valid_1's rmse: 1.5747
# [1700]	training's rmse: 1.47512	valid_1's rmse: 1.57465
# [1800]	training's rmse: 1.47131	valid_1's rmse: 1.57456
# [1900]	training's rmse: 1.4675	valid_1's rmse: 1.57454
# [2000]	training's rmse: 1.46373	valid_1's rmse: 1.57446
# [2100]	training's rmse: 1.46002	valid_1's rmse: 1.57432
# [2200]	training's rmse: 1.45624	valid_1's rmse: 1.5743
# [2300]	training's rmse: 1.45261	valid_1's rmse: 1.57434
# [2400]	training's rmse: 1.44899	valid_1's rmse: 1.57435
# [2500]	training's rmse: 1.44542	valid_1's rmse: 1.57422
# [2600]	training's rmse: 1.44182	valid_1's rmse: 1.57422
# [2700]	training's rmse: 1.43822	valid_1's rmse: 1.57423
# [2800]	training's rmse: 1.43468	valid_1's rmse: 1.57416
# [2900]	training's rmse: 1.4314	valid_1's rmse: 1.57417
# [3000]	training's rmse: 1.42786	valid_1's rmse: 1.57426
# [3100]	training's rmse: 1.42439	valid_1's rmse: 1.57419
# [3200]	training's rmse: 1.42103	valid_1's rmse: 1.57415
# [3300]	training's rmse: 1.41761	valid_1's rmse: 1.57408
# [3400]	training's rmse: 1.4142	valid_1's rmse: 1.57412
# [3500]	training's rmse: 1.41096	valid_1's rmse: 1.57413
# [3600]	training's rmse: 1.40757	valid_1's rmse: 1.57421
# [3700]	training's rmse: 1.40433	valid_1's rmse: 1.5742
# Early stopping, best iteration is:
# [3334]	training's rmse: 1.41643	valid_1's rmse: 1.57404
# 1.5541704588979257

# %%
#1.554226886805241

# %%
df_prediction = pd.DataFrame({"prediction1":predictions, "prediction2":predictions2})
df_prediction
# Out:
#         prediction1  prediction2
# 0         -2.008103    -0.372895
# 1         -0.218555    -0.215177
# 2         -0.898778    -0.459814
# 3         -0.237844    -0.150547
# 4         -1.489319    -1.651665
# 5          0.088124     0.637215
# 6          0.181646     0.237036
# 7          0.578753     0.986762
# 8         -0.853610    -0.606477
# 9         -1.049269    -0.211320
# 10        -0.574413    -0.541795
# 11        -0.031053     0.152480
# 12         0.102695     0.189718
# 13        -0.292498    -0.006197
# 14        -6.600879    -0.404153
# 15         0.686956     0.730720
# 16         0.427865     0.674994
# 17        -0.303452    -0.167431
# 18         0.144565     0.129406
# 19         0.041680    -0.213649
# 20         0.075491     0.225886
# 21        -0.859645    -0.892942
# 22        -0.286559     1.409063
# 23         0.081518     0.206497
# 24        -0.796764    -0.027361
# 25         0.070842     0.693120
# 26        -0.837031    -0.917158
# 27        -0.279416    -0.342065
# 28        -0.309614    -0.153683
# 29        -0.548156    -0.578419
# ...             ...          ...
# 123593    -0.365508    -0.354599
# 123594    -1.360083    -1.359069
# 123595    -0.012396    -0.080697
# 123596     0.691835     1.352279
# 123597    -0.460518    -0.471417
# 123598    -0.509634    -0.454631
# 123599     0.578440     0.518929
# 123600    -0.525408    -0.136926
# 123601    -1.255459    -1.539259
# 123602    -0.352772    -0.167490
# 123603    -0.037593    -0.014021
# 123604     0.226632     0.570003
# 123605    -0.654757    -0.553067
# 123606    -0.255826    -0.341276
# 123607     0.553036     0.492032
# 123608    -0.235345    -0.267275
# 123609     0.269454    -0.057827
# 123610     0.192144     0.513021
# 123611    -1.699713    -0.900544
# 123612    -0.767750    -0.681080
# 123613     0.066207    -0.114318
# 123614     0.509002     0.962838
# 123615    -0.817479    -0.735810
# 123616     0.991523     1.571211
# 123617     0.365663     0.567254
# 123618     0.916128     1.381831
# 123619    -0.533447    -0.572880
# 123620     0.999666     1.145379
# 123621    -3.155870    -0.922879
# 123622    -0.126862     0.037844
#
# [123623 rows x 2 columns]

# %%
predictions3 = np.zeros(df_prediction.shape[0])
for i, r in df_prediction.iterrows():
    if r[0] < 0 :
        predictions3[i] = r[0]
    else:
        predictions3[i] = r[1]
df_prediction["prediction3"] = predictions3

# %%
df_prediction
# Out:
#         prediction1  prediction2  prediction3
# 0         -2.008103    -0.372895    -2.008103
# 1         -0.218555    -0.215177    -0.218555
# 2         -0.898778    -0.459814    -0.898778
# 3         -0.237844    -0.150547    -0.237844
# 4         -1.489319    -1.651665    -1.489319
# 5          0.088124     0.637215     0.637215
# 6          0.181646     0.237036     0.237036
# 7          0.578753     0.986762     0.986762
# 8         -0.853610    -0.606477    -0.853610
# 9         -1.049269    -0.211320    -1.049269
# 10        -0.574413    -0.541795    -0.574413
# 11        -0.031053     0.152480    -0.031053
# 12         0.102695     0.189718     0.189718
# 13        -0.292498    -0.006197    -0.292498
# 14        -6.600879    -0.404153    -6.600879
# 15         0.686956     0.730720     0.730720
# 16         0.427865     0.674994     0.674994
# 17        -0.303452    -0.167431    -0.303452
# 18         0.144565     0.129406     0.129406
# 19         0.041680    -0.213649    -0.213649
# 20         0.075491     0.225886     0.225886
# 21        -0.859645    -0.892942    -0.859645
# 22        -0.286559     1.409063    -0.286559
# 23         0.081518     0.206497     0.206497
# 24        -0.796764    -0.027361    -0.796764
# 25         0.070842     0.693120     0.693120
# 26        -0.837031    -0.917158    -0.837031
# 27        -0.279416    -0.342065    -0.279416
# 28        -0.309614    -0.153683    -0.309614
# 29        -0.548156    -0.578419    -0.548156
# ...             ...          ...          ...
# 123593    -0.365508    -0.354599    -0.365508
# 123594    -1.360083    -1.359069    -1.360083
# 123595    -0.012396    -0.080697    -0.012396
# 123596     0.691835     1.352279     1.352279
# 123597    -0.460518    -0.471417    -0.460518
# 123598    -0.509634    -0.454631    -0.509634
# 123599     0.578440     0.518929     0.518929
# 123600    -0.525408    -0.136926    -0.525408
# 123601    -1.255459    -1.539259    -1.255459
# 123602    -0.352772    -0.167490    -0.352772
# 123603    -0.037593    -0.014021    -0.037593
# 123604     0.226632     0.570003     0.570003
# 123605    -0.654757    -0.553067    -0.654757
# 123606    -0.255826    -0.341276    -0.255826
# 123607     0.553036     0.492032     0.492032
# 123608    -0.235345    -0.267275    -0.235345
# 123609     0.269454    -0.057827    -0.057827
# 123610     0.192144     0.513021     0.513021
# 123611    -1.699713    -0.900544    -1.699713
# 123612    -0.767750    -0.681080    -0.767750
# 123613     0.066207    -0.114318    -0.114318
# 123614     0.509002     0.962838     0.962838
# 123615    -0.817479    -0.735810    -0.817479
# 123616     0.991523     1.571211     1.571211
# 123617     0.365663     0.567254     0.567254
# 123618     0.916128     1.381831     1.381831
# 123619    -0.533447    -0.572880    -0.533447
# 123620     0.999666     1.145379     1.145379
# 123621    -3.155870    -0.922879    -3.155870
# 123622    -0.126862     0.037844    -0.126862
#
# [123623 rows x 3 columns]

# %%
final_predictions = df_prediction.prediction3.values

# %%
sub_df = pd.DataFrame({"card_id":df_test["card_id"].values})
sub_df["target"] = final_predictions
sub_df.to_csv("../output/submission_model20181216_20190217.csv", index=False)
