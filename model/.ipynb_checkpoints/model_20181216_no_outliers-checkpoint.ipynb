# %%
import numpy as np
import pandas as pd
import datetime
import gc

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import lightgbm as lgb

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error, roc_auc_score
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')
np.random.seed(4590)

# %%
df_train = pd.read_csv('../input/train.csv')
df_test = pd.read_csv('../input/test.csv')
df_hist_trans = pd.read_csv('../input/historical_transactions.csv')
df_new_merchant_trans = pd.read_csv('../input/new_merchant_transactions.csv')

# %%
df_train = df_train[df_train.target > -30].reset_index(drop=True)

# %%
df_hist_trans['purchase_amount'] = np.exp(df_hist_trans['purchase_amount'])
df_new_merchant_trans['purchase_amount'] = np.exp(df_new_merchant_trans['purchase_amount'])

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['category_2'].fillna(1.0,inplace=True)
    df['category_3'].fillna('A',inplace=True)
    df['merchant_id'].fillna('M_ID_00a6ca8a8a',inplace=True)

# %%
def get_new_columns(name,aggs):
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    df['year'] = df['purchase_date'].dt.year
    df['weekofyear'] = df['purchase_date'].dt.weekofyear
    df['month'] = df['purchase_date'].dt.month
    df['dayofweek'] = df['purchase_date'].dt.dayofweek
    df['weekend'] = (df.purchase_date.dt.weekday >=5).astype(int)
    df['hour'] = df['purchase_date'].dt.hour
    df['authorized_flag'] = df['authorized_flag'].map({'Y':1, 'N':0})
    df['category_1'] = df['category_1'].map({'Y':1, 'N':0}) 
    #https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/73244
    df['month_diff'] = ((datetime.datetime.today() - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']

aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['authorized_flag'] = ['sum', 'mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_hist_trans[col+'_mean'] = df_hist_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']    

new_columns = get_new_columns('hist',aggs)
df_hist_trans_group = df_hist_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['hist_purchase_date_diff'] = (df_hist_trans_group['hist_purchase_date_max'] - df_hist_trans_group['hist_purchase_date_min']).dt.days
df_hist_trans_group['hist_purchase_date_average'] = df_hist_trans_group['hist_purchase_date_diff']/df_hist_trans_group['hist_card_id_size']
df_hist_trans_group['hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 42

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']
aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_new_merchant_trans[col+'_mean'] = df_new_merchant_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']
    
new_columns = get_new_columns('new_hist',aggs)
df_hist_trans_group = df_new_merchant_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['new_hist_purchase_date_diff'] = (df_hist_trans_group['new_hist_purchase_date_max'] - df_hist_trans_group['new_hist_purchase_date_min']).dt.days
df_hist_trans_group['new_hist_purchase_date_average'] = df_hist_trans_group['new_hist_purchase_date_diff']/df_hist_trans_group['new_hist_card_id_size']
df_hist_trans_group['new_hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['new_hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 28

# %%
del df_hist_trans;gc.collect()
del df_new_merchant_trans;gc.collect()
df_train.head(5)
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
# 3            2017-09  C_ID_186d6a6901          4          3          0
# 4            2017-11  C_ID_cdbd2c0db2          1          3          0
#
#      target  hist_month_nunique  hist_hour_nunique  hist_weekofyear_nunique  \
# 0 -0.820283                   9                 23                       35
# 1  0.392913                  12                 24                       50
# 2  0.688056                  10                 14                       22
# 3  0.142495                   6                 16                       20
# 4 -0.159749                   4                 22                       17
#
#    hist_dayofweek_nunique               ...                \
# 0                       7               ...
# 1                       7               ...
# 2                       7               ...
# 3                       7               ...
# 4                       7               ...
#
#    new_hist_weekend_sum  new_hist_weekend_mean  new_hist_category_1_sum  \
# 0                   6.0               0.260870                      0.0
# 1                   0.0               0.000000                      0.0
# 2                   1.0               1.000000                      0.0
# 3                   3.0               0.428571                      1.0
# 4                  12.0               0.333333                      2.0
#
#    new_hist_category_1_mean  new_hist_card_id_size  \
# 0                  0.000000                   23.0
# 1                  0.000000                    6.0
# 2                  0.000000                    1.0
# 3                  0.142857                    7.0
# 4                  0.055556                   36.0
#
#    new_hist_category_2_mean_mean  new_hist_category_3_mean_mean  \
# 0                  1.658319e+108                   1.381361e+36
# 1                  1.658319e+108                   3.557623e+25
# 2                   7.789907e+26                   1.381361e+36
# 3                  2.369028e+107                   1.973373e+35
# 4                  1.842577e+107                  3.624714e+107
#
#    new_hist_purchase_date_diff  new_hist_purchase_date_average  \
# 0                         54.0                        2.347826
# 1                         56.0                        9.333333
# 2                          0.0                        0.000000
# 3                         41.0                        5.857143
# 4                         57.0                        1.583333
#
#    new_hist_purchase_date_uptonow
# 0                           247.0
# 1                           277.0
# 2                           248.0
# 3                           258.0
# 4                           247.0
#
# [5 rows x 78 columns]

# %%
df_train['outliers'] = 0
df_train.loc[df_train['target'] < -30, 'outliers'] = 1
df_train['outliers'].value_counts()
# Out:
# 0    199710
# Name: outliers, dtype: int64

# %%
list_outlier_idx = df_train[df_train.outliers == 1].index.tolist()

# %%
for df in [df_train,df_test]:
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['dayofweek'] = df['first_active_month'].dt.dayofweek
    df['weekofyear'] = df['first_active_month'].dt.weekofyear
    df['month'] = df['first_active_month'].dt.month
    df['elapsed_time'] = (datetime.datetime.today() - df['first_active_month']).dt.days
    df['hist_first_buy'] = (df['hist_purchase_date_min'] - df['first_active_month']).dt.days
    df['new_hist_first_buy'] = (df['new_hist_purchase_date_min'] - df['first_active_month']).dt.days
    for f in ['hist_purchase_date_max','hist_purchase_date_min','new_hist_purchase_date_max',\
                     'new_hist_purchase_date_min']:
        df[f] = df[f].astype(np.int64) * 1e-9
    df['card_id_total'] = df['new_hist_card_id_size']+df['hist_card_id_size']
    df['purchase_amount_total'] = df['new_hist_purchase_amount_sum']+df['hist_purchase_amount_sum']

for f in ['feature_1','feature_2','feature_3']:
    order_label = df_train.groupby([f])['outliers'].mean()
    df_train[f] = df_train[f].map(order_label)
    df_test[f] = df_test[f].map(order_label)

# %%
high_importance_features = [
    "hist_month_diff_mean", 
    "hist_authorized_flag_mean", 
    "hist_category_1_sum", 
    "hist_month_lag_mean", 
    "new_hist_purchase_amount_sum", 
    "new_hist_purchase_date_uptonow"
]

#smoothing
for col in high_importance_features:
    df_train[col] = np.where(df_train[col].values==0, 0.001, df_train[col].values)
    df_test[col] = np.where(df_test[col].values==0, 0.001, df_test[col].values)


for i in range(len(high_importance_features)):
    for j in range(len((high_importance_features)))[i+1:]:
        col1 = high_importance_features[i]
        col2 = high_importance_features[j]
        new_col_name = "{c1}__div__{c2}".format(c1=col1, c2=col2)
        
        df_train[new_col_name] = df_train[col1] / df_train[col2]
        df_test[new_col_name] = df_test[col1] / df_test[col2]

# %%
def merge_new_feature(path):
    df_new_feature = pd.read_csv(path)
    
    df_tr = pd.merge(df_train, df_new_feature, on="card_id", how="left")
    df_te = pd.merge(df_test, df_new_feature, on="card_id", how="left")
    
    return df_tr, df_te

# %%
df_train, df_test = merge_new_feature("../input/merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/new_merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/prosperity_merchants_latest.csv")
df_train, df_test = merge_new_feature("../input/merchants_numerical_features.csv")
df_train, df_test = merge_new_feature("../input/merchants_item_scale_feature.csv")
df_train, df_test = merge_new_feature("../input/purchase_pattern.csv")
df_train, df_test = merge_new_feature("../input/purchase_pettern_nmf.csv")
df_train, df_test = merge_new_feature("../input/purchase_amount_pettern_nmf.csv")

# %%
df_train["Null_count"] = df_train.isnull().sum(axis=1)
df_test["Null_count"] = df_test.isnull().sum(axis=1)

# %%
df_train_columns = [c for c in df_train.columns if c not in ['card_id', 'first_active_month','second_active_date','diff_first_and_second','target','outliers']]
target = df_train['target']
target_outlier = df_train["outliers"]

# %%
#original
param = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',
    'max_depth': -1,
    "max_bin": 256,  # なし
    'learning_rate': 0.004,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65326	valid_1's rmse: 1.65217
# [200]	training's rmse: 1.61845	valid_1's rmse: 1.6178
# [300]	training's rmse: 1.5981	valid_1's rmse: 1.59849
# [400]	training's rmse: 1.58486	valid_1's rmse: 1.58642
# [500]	training's rmse: 1.57552	valid_1's rmse: 1.5785
# [600]	training's rmse: 1.56845	valid_1's rmse: 1.57309
# [700]	training's rmse: 1.56273	valid_1's rmse: 1.56907
# [800]	training's rmse: 1.55789	valid_1's rmse: 1.5661
# [900]	training's rmse: 1.55365	valid_1's rmse: 1.56383
# [1000]	training's rmse: 1.54987	valid_1's rmse: 1.56202
# [1100]	training's rmse: 1.5464	valid_1's rmse: 1.56058
# [1200]	training's rmse: 1.54312	valid_1's rmse: 1.55928
# [1300]	training's rmse: 1.54009	valid_1's rmse: 1.55825
# [1400]	training's rmse: 1.53722	valid_1's rmse: 1.55744
# [1500]	training's rmse: 1.53451	valid_1's rmse: 1.55666
# [1600]	training's rmse: 1.53194	valid_1's rmse: 1.55606
# [1700]	training's rmse: 1.52947	valid_1's rmse: 1.55562
# [1800]	training's rmse: 1.52713	valid_1's rmse: 1.55516
# [1900]	training's rmse: 1.52485	valid_1's rmse: 1.55481
# [2000]	training's rmse: 1.52268	valid_1's rmse: 1.55452
# [2100]	training's rmse: 1.52059	valid_1's rmse: 1.55425
# [2200]	training's rmse: 1.51852	valid_1's rmse: 1.55403
# [2300]	training's rmse: 1.51647	valid_1's rmse: 1.5538
# [2400]	training's rmse: 1.51451	valid_1's rmse: 1.55365
# [2500]	training's rmse: 1.51255	valid_1's rmse: 1.55349
# [2600]	training's rmse: 1.51064	valid_1's rmse: 1.55335
# [2700]	training's rmse: 1.5088	valid_1's rmse: 1.55322
# [2800]	training's rmse: 1.50698	valid_1's rmse: 1.55308
# [2900]	training's rmse: 1.50513	valid_1's rmse: 1.55299
# [3000]	training's rmse: 1.50334	valid_1's rmse: 1.55292
# [3100]	training's rmse: 1.50159	valid_1's rmse: 1.55284
# [3200]	training's rmse: 1.49983	valid_1's rmse: 1.55279
# [3300]	training's rmse: 1.49812	valid_1's rmse: 1.55271
# [3400]	training's rmse: 1.49645	valid_1's rmse: 1.55268
# [3500]	training's rmse: 1.49473	valid_1's rmse: 1.55261
# [3600]	training's rmse: 1.49303	valid_1's rmse: 1.55258
# [3700]	training's rmse: 1.49136	valid_1's rmse: 1.55254
# [3800]	training's rmse: 1.48973	valid_1's rmse: 1.55249
# [3900]	training's rmse: 1.48805	valid_1's rmse: 1.55246
# [4000]	training's rmse: 1.48646	valid_1's rmse: 1.55244
# [4100]	training's rmse: 1.48485	valid_1's rmse: 1.55238
# [4200]	training's rmse: 1.48327	valid_1's rmse: 1.55238
# [4300]	training's rmse: 1.48169	valid_1's rmse: 1.55238
# [4400]	training's rmse: 1.4801	valid_1's rmse: 1.55233
# [4500]	training's rmse: 1.47853	valid_1's rmse: 1.55231
# [4600]	training's rmse: 1.47695	valid_1's rmse: 1.55226
# [4700]	training's rmse: 1.47541	valid_1's rmse: 1.55225
# [4800]	training's rmse: 1.47384	valid_1's rmse: 1.55224
# [4900]	training's rmse: 1.4723	valid_1's rmse: 1.55222
# [5000]	training's rmse: 1.47078	valid_1's rmse: 1.55224
# [5100]	training's rmse: 1.46925	valid_1's rmse: 1.55221
# [5200]	training's rmse: 1.46771	valid_1's rmse: 1.55217
# [5300]	training's rmse: 1.46617	valid_1's rmse: 1.55209
# [5400]	training's rmse: 1.46461	valid_1's rmse: 1.55206
# [5500]	training's rmse: 1.46311	valid_1's rmse: 1.55208
# [5600]	training's rmse: 1.46159	valid_1's rmse: 1.55205
# [5700]	training's rmse: 1.46016	valid_1's rmse: 1.55204
# [5800]	training's rmse: 1.45868	valid_1's rmse: 1.552
# [5900]	training's rmse: 1.45719	valid_1's rmse: 1.55199
# [6000]	training's rmse: 1.45569	valid_1's rmse: 1.55198
# [6100]	training's rmse: 1.45424	valid_1's rmse: 1.552
# [6200]	training's rmse: 1.45279	valid_1's rmse: 1.55201
# [6300]	training's rmse: 1.45135	valid_1's rmse: 1.552
# [6400]	training's rmse: 1.44989	valid_1's rmse: 1.55198
# Early stopping, best iteration is:
# [6004]	training's rmse: 1.45563	valid_1's rmse: 1.55197
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65655	valid_1's rmse: 1.6361
# [200]	training's rmse: 1.62115	valid_1's rmse: 1.60404
# [300]	training's rmse: 1.60051	valid_1's rmse: 1.58636
# [400]	training's rmse: 1.58723	valid_1's rmse: 1.57576
# [500]	training's rmse: 1.5778	valid_1's rmse: 1.56874
# [600]	training's rmse: 1.57071	valid_1's rmse: 1.56394
# [700]	training's rmse: 1.56496	valid_1's rmse: 1.56042
# [800]	training's rmse: 1.56014	valid_1's rmse: 1.5577
# [900]	training's rmse: 1.55597	valid_1's rmse: 1.55555
# [1000]	training's rmse: 1.55216	valid_1's rmse: 1.55379
# [1100]	training's rmse: 1.54876	valid_1's rmse: 1.55238
# [1200]	training's rmse: 1.54552	valid_1's rmse: 1.55114
# [1300]	training's rmse: 1.54252	valid_1's rmse: 1.55009
# [1400]	training's rmse: 1.5397	valid_1's rmse: 1.54925
# [1500]	training's rmse: 1.53697	valid_1's rmse: 1.54856
# [1600]	training's rmse: 1.53443	valid_1's rmse: 1.54798
# [1700]	training's rmse: 1.53198	valid_1's rmse: 1.54742
# [1800]	training's rmse: 1.52961	valid_1's rmse: 1.54701
# [1900]	training's rmse: 1.52735	valid_1's rmse: 1.54668
# [2000]	training's rmse: 1.52517	valid_1's rmse: 1.54637
# [2100]	training's rmse: 1.52301	valid_1's rmse: 1.54608
# [2200]	training's rmse: 1.52092	valid_1's rmse: 1.54586
# [2300]	training's rmse: 1.51883	valid_1's rmse: 1.54563
# [2400]	training's rmse: 1.51687	valid_1's rmse: 1.54541
# [2500]	training's rmse: 1.5149	valid_1's rmse: 1.54529
# [2600]	training's rmse: 1.51294	valid_1's rmse: 1.54517
# [2700]	training's rmse: 1.51107	valid_1's rmse: 1.54501
# [2800]	training's rmse: 1.50922	valid_1's rmse: 1.54485
# [2900]	training's rmse: 1.50742	valid_1's rmse: 1.54473
# [3000]	training's rmse: 1.50562	valid_1's rmse: 1.54462
# [3100]	training's rmse: 1.50385	valid_1's rmse: 1.54448
# [3200]	training's rmse: 1.50211	valid_1's rmse: 1.5444
# [3300]	training's rmse: 1.50038	valid_1's rmse: 1.54432
# [3400]	training's rmse: 1.49863	valid_1's rmse: 1.54421
# [3500]	training's rmse: 1.4969	valid_1's rmse: 1.54411
# [3600]	training's rmse: 1.49516	valid_1's rmse: 1.54402
# [3700]	training's rmse: 1.4935	valid_1's rmse: 1.54394
# [3800]	training's rmse: 1.49189	valid_1's rmse: 1.54389
# [3900]	training's rmse: 1.49026	valid_1's rmse: 1.54381
# [4000]	training's rmse: 1.48864	valid_1's rmse: 1.54375
# [4100]	training's rmse: 1.48699	valid_1's rmse: 1.54371
# [4200]	training's rmse: 1.48541	valid_1's rmse: 1.54365
# [4300]	training's rmse: 1.48381	valid_1's rmse: 1.54355
# [4400]	training's rmse: 1.48223	valid_1's rmse: 1.5435
# [4500]	training's rmse: 1.48071	valid_1's rmse: 1.54346
# [4600]	training's rmse: 1.47913	valid_1's rmse: 1.5434
# [4700]	training's rmse: 1.47758	valid_1's rmse: 1.54336
# [4800]	training's rmse: 1.47597	valid_1's rmse: 1.54332
# [4900]	training's rmse: 1.47441	valid_1's rmse: 1.5433
# [5000]	training's rmse: 1.47282	valid_1's rmse: 1.54326
# [5100]	training's rmse: 1.4713	valid_1's rmse: 1.54324
# [5200]	training's rmse: 1.46982	valid_1's rmse: 1.54317
# [5300]	training's rmse: 1.4683	valid_1's rmse: 1.54313
# [5400]	training's rmse: 1.46682	valid_1's rmse: 1.54308
# [5500]	training's rmse: 1.46528	valid_1's rmse: 1.54305
# [5600]	training's rmse: 1.46374	valid_1's rmse: 1.54302
# [5700]	training's rmse: 1.4623	valid_1's rmse: 1.54299
# [5800]	training's rmse: 1.46082	valid_1's rmse: 1.54295
# [5900]	training's rmse: 1.45927	valid_1's rmse: 1.5429
# [6000]	training's rmse: 1.45778	valid_1's rmse: 1.54287
# [6100]	training's rmse: 1.45634	valid_1's rmse: 1.54283
# [6200]	training's rmse: 1.45489	valid_1's rmse: 1.54279
# [6300]	training's rmse: 1.45346	valid_1's rmse: 1.54278
# [6400]	training's rmse: 1.45198	valid_1's rmse: 1.54272
# [6500]	training's rmse: 1.45052	valid_1's rmse: 1.54271
# [6600]	training's rmse: 1.4491	valid_1's rmse: 1.54267
# [6700]	training's rmse: 1.44762	valid_1's rmse: 1.54265
# [6800]	training's rmse: 1.44621	valid_1's rmse: 1.54256
# [6900]	training's rmse: 1.44475	valid_1's rmse: 1.54257
# [7000]	training's rmse: 1.44335	valid_1's rmse: 1.54254
# [7100]	training's rmse: 1.44192	valid_1's rmse: 1.54252
# [7200]	training's rmse: 1.44046	valid_1's rmse: 1.54248
# [7300]	training's rmse: 1.439	valid_1's rmse: 1.54247
# [7400]	training's rmse: 1.43761	valid_1's rmse: 1.54248
# [7500]	training's rmse: 1.4362	valid_1's rmse: 1.54246
# [7600]	training's rmse: 1.43483	valid_1's rmse: 1.54243
# [7700]	training's rmse: 1.43341	valid_1's rmse: 1.54241
# [7800]	training's rmse: 1.43205	valid_1's rmse: 1.54242
# [7900]	training's rmse: 1.43066	valid_1's rmse: 1.5424
# [8000]	training's rmse: 1.42928	valid_1's rmse: 1.54241
# [8100]	training's rmse: 1.4279	valid_1's rmse: 1.5424
# [8200]	training's rmse: 1.42656	valid_1's rmse: 1.54235
# [8300]	training's rmse: 1.4252	valid_1's rmse: 1.54234
# [8400]	training's rmse: 1.42383	valid_1's rmse: 1.54234
# [8500]	training's rmse: 1.42246	valid_1's rmse: 1.54233
# [8600]	training's rmse: 1.42108	valid_1's rmse: 1.54229
# [8700]	training's rmse: 1.4197	valid_1's rmse: 1.54229
# [8800]	training's rmse: 1.41837	valid_1's rmse: 1.54229
# [8900]	training's rmse: 1.417	valid_1's rmse: 1.54229
# [9000]	training's rmse: 1.41564	valid_1's rmse: 1.54229
# [9100]	training's rmse: 1.41434	valid_1's rmse: 1.54229
# Early stopping, best iteration is:
# [8766]	training's rmse: 1.41886	valid_1's rmse: 1.54227
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65228	valid_1's rmse: 1.65501
# [200]	training's rmse: 1.61736	valid_1's rmse: 1.6217
# [300]	training's rmse: 1.59702	valid_1's rmse: 1.60296
# [400]	training's rmse: 1.58388	valid_1's rmse: 1.59162
# [500]	training's rmse: 1.5746	valid_1's rmse: 1.58428
# [600]	training's rmse: 1.56756	valid_1's rmse: 1.57918
# [700]	training's rmse: 1.56182	valid_1's rmse: 1.5754
# [800]	training's rmse: 1.55697	valid_1's rmse: 1.57239
# [900]	training's rmse: 1.55281	valid_1's rmse: 1.57009
# [1000]	training's rmse: 1.54903	valid_1's rmse: 1.56831
# [1100]	training's rmse: 1.54559	valid_1's rmse: 1.56681
# [1200]	training's rmse: 1.54238	valid_1's rmse: 1.56559
# [1300]	training's rmse: 1.53939	valid_1's rmse: 1.56464
# [1400]	training's rmse: 1.53655	valid_1's rmse: 1.56375
# [1500]	training's rmse: 1.53381	valid_1's rmse: 1.56299
# [1600]	training's rmse: 1.53125	valid_1's rmse: 1.56241
# [1700]	training's rmse: 1.5288	valid_1's rmse: 1.56187
# [1800]	training's rmse: 1.52647	valid_1's rmse: 1.56145
# [1900]	training's rmse: 1.52422	valid_1's rmse: 1.56107
# [2000]	training's rmse: 1.52204	valid_1's rmse: 1.56078
# [2100]	training's rmse: 1.51993	valid_1's rmse: 1.56052
# [2200]	training's rmse: 1.51787	valid_1's rmse: 1.56029
# [2300]	training's rmse: 1.51585	valid_1's rmse: 1.56008
# [2400]	training's rmse: 1.51388	valid_1's rmse: 1.55991
# [2500]	training's rmse: 1.51195	valid_1's rmse: 1.55974
# [2600]	training's rmse: 1.51005	valid_1's rmse: 1.55959
# [2700]	training's rmse: 1.5082	valid_1's rmse: 1.5595
# [2800]	training's rmse: 1.50635	valid_1's rmse: 1.55937
# [2900]	training's rmse: 1.50456	valid_1's rmse: 1.55926
# [3000]	training's rmse: 1.50272	valid_1's rmse: 1.55912
# [3100]	training's rmse: 1.50091	valid_1's rmse: 1.55904
# [3200]	training's rmse: 1.4992	valid_1's rmse: 1.55894
# [3300]	training's rmse: 1.49742	valid_1's rmse: 1.55888
# [3400]	training's rmse: 1.4957	valid_1's rmse: 1.55879
# [3500]	training's rmse: 1.49404	valid_1's rmse: 1.55876
# [3600]	training's rmse: 1.49236	valid_1's rmse: 1.55873
# [3700]	training's rmse: 1.49066	valid_1's rmse: 1.55867
# [3800]	training's rmse: 1.48901	valid_1's rmse: 1.55857
# [3900]	training's rmse: 1.4873	valid_1's rmse: 1.55846
# [4000]	training's rmse: 1.48567	valid_1's rmse: 1.55838
# [4100]	training's rmse: 1.48401	valid_1's rmse: 1.55835
# [4200]	training's rmse: 1.48238	valid_1's rmse: 1.5583
# [4300]	training's rmse: 1.48078	valid_1's rmse: 1.55827
# [4400]	training's rmse: 1.47922	valid_1's rmse: 1.55822
# [4500]	training's rmse: 1.47762	valid_1's rmse: 1.5582
# [4600]	training's rmse: 1.47607	valid_1's rmse: 1.55821
# [4700]	training's rmse: 1.4745	valid_1's rmse: 1.55816
# [4800]	training's rmse: 1.47294	valid_1's rmse: 1.55814
# [4900]	training's rmse: 1.47142	valid_1's rmse: 1.55812
# [5000]	training's rmse: 1.4699	valid_1's rmse: 1.55808
# [5100]	training's rmse: 1.46831	valid_1's rmse: 1.55809
# [5200]	training's rmse: 1.46675	valid_1's rmse: 1.55806
# [5300]	training's rmse: 1.46525	valid_1's rmse: 1.55804
# [5400]	training's rmse: 1.46376	valid_1's rmse: 1.55805
# [5500]	training's rmse: 1.46228	valid_1's rmse: 1.55804
# [5600]	training's rmse: 1.46078	valid_1's rmse: 1.55803
# Early stopping, best iteration is:
# [5286]	training's rmse: 1.46547	valid_1's rmse: 1.55802
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65263	valid_1's rmse: 1.65329
# [200]	training's rmse: 1.61769	valid_1's rmse: 1.62057
# [300]	training's rmse: 1.59725	valid_1's rmse: 1.60226
# [400]	training's rmse: 1.5841	valid_1's rmse: 1.59122
# [500]	training's rmse: 1.57474	valid_1's rmse: 1.58383
# [600]	training's rmse: 1.56766	valid_1's rmse: 1.57883
# [700]	training's rmse: 1.56189	valid_1's rmse: 1.57511
# [800]	training's rmse: 1.55705	valid_1's rmse: 1.57224
# [900]	training's rmse: 1.5529	valid_1's rmse: 1.57008
# [1000]	training's rmse: 1.54906	valid_1's rmse: 1.56824
# [1100]	training's rmse: 1.54561	valid_1's rmse: 1.56679
# [1200]	training's rmse: 1.54239	valid_1's rmse: 1.56558
# [1300]	training's rmse: 1.53938	valid_1's rmse: 1.56461
# [1400]	training's rmse: 1.53654	valid_1's rmse: 1.56369
# [1500]	training's rmse: 1.53382	valid_1's rmse: 1.56292
# [1600]	training's rmse: 1.53125	valid_1's rmse: 1.56233
# [1700]	training's rmse: 1.52878	valid_1's rmse: 1.56179
# [1800]	training's rmse: 1.52645	valid_1's rmse: 1.56135
# [1900]	training's rmse: 1.52417	valid_1's rmse: 1.56099
# [2000]	training's rmse: 1.52193	valid_1's rmse: 1.56063
# [2100]	training's rmse: 1.51978	valid_1's rmse: 1.56029
# [2200]	training's rmse: 1.51774	valid_1's rmse: 1.5601
# [2300]	training's rmse: 1.51572	valid_1's rmse: 1.55993
# [2400]	training's rmse: 1.51374	valid_1's rmse: 1.5598
# [2500]	training's rmse: 1.51184	valid_1's rmse: 1.55966
# [2600]	training's rmse: 1.50995	valid_1's rmse: 1.5595
# [2700]	training's rmse: 1.5081	valid_1's rmse: 1.55932
# [2800]	training's rmse: 1.50623	valid_1's rmse: 1.55919
# [2900]	training's rmse: 1.50443	valid_1's rmse: 1.55908
# [3000]	training's rmse: 1.50264	valid_1's rmse: 1.55897
# [3100]	training's rmse: 1.50089	valid_1's rmse: 1.5589
# [3200]	training's rmse: 1.49915	valid_1's rmse: 1.55885
# [3300]	training's rmse: 1.4974	valid_1's rmse: 1.55875
# [3400]	training's rmse: 1.49572	valid_1's rmse: 1.5587
# [3500]	training's rmse: 1.49399	valid_1's rmse: 1.55858
# [3600]	training's rmse: 1.49227	valid_1's rmse: 1.55853
# [3700]	training's rmse: 1.49061	valid_1's rmse: 1.55846
# [3800]	training's rmse: 1.48897	valid_1's rmse: 1.55841
# [3900]	training's rmse: 1.48728	valid_1's rmse: 1.55836
# [4000]	training's rmse: 1.48571	valid_1's rmse: 1.5583
# [4100]	training's rmse: 1.48405	valid_1's rmse: 1.55824
# [4200]	training's rmse: 1.48242	valid_1's rmse: 1.5582
# [4300]	training's rmse: 1.48078	valid_1's rmse: 1.55814
# [4400]	training's rmse: 1.47919	valid_1's rmse: 1.55812
# [4500]	training's rmse: 1.47758	valid_1's rmse: 1.55812
# [4600]	training's rmse: 1.476	valid_1's rmse: 1.55807
# [4700]	training's rmse: 1.47443	valid_1's rmse: 1.55802
# [4800]	training's rmse: 1.47288	valid_1's rmse: 1.55801
# [4900]	training's rmse: 1.47133	valid_1's rmse: 1.55796
# [5000]	training's rmse: 1.4698	valid_1's rmse: 1.55793
# [5100]	training's rmse: 1.46826	valid_1's rmse: 1.55792
# [5200]	training's rmse: 1.46673	valid_1's rmse: 1.55789
# [5300]	training's rmse: 1.46519	valid_1's rmse: 1.55787
# [5400]	training's rmse: 1.4637	valid_1's rmse: 1.55784
# [5500]	training's rmse: 1.46221	valid_1's rmse: 1.55779
# [5600]	training's rmse: 1.46065	valid_1's rmse: 1.55778
# [5700]	training's rmse: 1.45916	valid_1's rmse: 1.55775
# [5800]	training's rmse: 1.45767	valid_1's rmse: 1.55773
# [5900]	training's rmse: 1.45615	valid_1's rmse: 1.55773
# [6000]	training's rmse: 1.4547	valid_1's rmse: 1.55774
# [6100]	training's rmse: 1.45323	valid_1's rmse: 1.55771
# [6200]	training's rmse: 1.45177	valid_1's rmse: 1.55774
# Early stopping, best iteration is:
# [5832]	training's rmse: 1.45717	valid_1's rmse: 1.55771
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.64765	valid_1's rmse: 1.67471
# [200]	training's rmse: 1.61277	valid_1's rmse: 1.64174
# [300]	training's rmse: 1.59239	valid_1's rmse: 1.62317
# [400]	training's rmse: 1.57923	valid_1's rmse: 1.61179
# [500]	training's rmse: 1.56992	valid_1's rmse: 1.60424
# [600]	training's rmse: 1.56282	valid_1's rmse: 1.59895
# [700]	training's rmse: 1.55707	valid_1's rmse: 1.59518
# [800]	training's rmse: 1.55223	valid_1's rmse: 1.59231
# [900]	training's rmse: 1.54801	valid_1's rmse: 1.59006
# [1000]	training's rmse: 1.54418	valid_1's rmse: 1.58824
# [1100]	training's rmse: 1.54071	valid_1's rmse: 1.58673
# [1200]	training's rmse: 1.5375	valid_1's rmse: 1.58554
# [1300]	training's rmse: 1.5345	valid_1's rmse: 1.58455
# [1400]	training's rmse: 1.53166	valid_1's rmse: 1.5837
# [1500]	training's rmse: 1.529	valid_1's rmse: 1.58302
# [1600]	training's rmse: 1.5264	valid_1's rmse: 1.58239
# [1700]	training's rmse: 1.52395	valid_1's rmse: 1.58189
# [1800]	training's rmse: 1.52158	valid_1's rmse: 1.58145
# [1900]	training's rmse: 1.51931	valid_1's rmse: 1.58109
# [2000]	training's rmse: 1.51711	valid_1's rmse: 1.58082
# [2100]	training's rmse: 1.51495	valid_1's rmse: 1.58051
# [2200]	training's rmse: 1.51284	valid_1's rmse: 1.58037
# [2300]	training's rmse: 1.51081	valid_1's rmse: 1.58019
# [2400]	training's rmse: 1.50888	valid_1's rmse: 1.58006
# [2500]	training's rmse: 1.50689	valid_1's rmse: 1.57993
# [2600]	training's rmse: 1.50498	valid_1's rmse: 1.57981
# [2700]	training's rmse: 1.50309	valid_1's rmse: 1.57972
# [2800]	training's rmse: 1.50125	valid_1's rmse: 1.5796
# [2900]	training's rmse: 1.49946	valid_1's rmse: 1.57951
# [3000]	training's rmse: 1.49766	valid_1's rmse: 1.57943
# [3100]	training's rmse: 1.49588	valid_1's rmse: 1.57935
# [3200]	training's rmse: 1.4941	valid_1's rmse: 1.57927
# [3300]	training's rmse: 1.49239	valid_1's rmse: 1.5792
# [3400]	training's rmse: 1.49064	valid_1's rmse: 1.57915
# [3500]	training's rmse: 1.48895	valid_1's rmse: 1.57908
# [3600]	training's rmse: 1.48729	valid_1's rmse: 1.57901
# [3700]	training's rmse: 1.48559	valid_1's rmse: 1.57889
# [3800]	training's rmse: 1.48392	valid_1's rmse: 1.57886
# [3900]	training's rmse: 1.48227	valid_1's rmse: 1.57879
# [4000]	training's rmse: 1.48065	valid_1's rmse: 1.57872
# [4100]	training's rmse: 1.47902	valid_1's rmse: 1.57867
# [4200]	training's rmse: 1.47744	valid_1's rmse: 1.57865
# [4300]	training's rmse: 1.47584	valid_1's rmse: 1.5786
# [4400]	training's rmse: 1.47427	valid_1's rmse: 1.57855
# [4500]	training's rmse: 1.4727	valid_1's rmse: 1.57851
# [4600]	training's rmse: 1.47111	valid_1's rmse: 1.57847
# [4700]	training's rmse: 1.46952	valid_1's rmse: 1.57842
# [4800]	training's rmse: 1.468	valid_1's rmse: 1.57838
# [4900]	training's rmse: 1.46647	valid_1's rmse: 1.57836
# [5000]	training's rmse: 1.46494	valid_1's rmse: 1.57831
# [5100]	training's rmse: 1.46343	valid_1's rmse: 1.5783
# [5200]	training's rmse: 1.4619	valid_1's rmse: 1.5783
# [5300]	training's rmse: 1.4604	valid_1's rmse: 1.5783
# [5400]	training's rmse: 1.4589	valid_1's rmse: 1.57826
# [5500]	training's rmse: 1.45737	valid_1's rmse: 1.57823
# [5600]	training's rmse: 1.45589	valid_1's rmse: 1.57822
# [5700]	training's rmse: 1.45441	valid_1's rmse: 1.57822
# [5800]	training's rmse: 1.45295	valid_1's rmse: 1.5782
# [5900]	training's rmse: 1.4514	valid_1's rmse: 1.57815
# [6000]	training's rmse: 1.44993	valid_1's rmse: 1.57814
# [6100]	training's rmse: 1.44844	valid_1's rmse: 1.5781
# [6200]	training's rmse: 1.44701	valid_1's rmse: 1.57808
# [6300]	training's rmse: 1.44555	valid_1's rmse: 1.57809
# [6400]	training's rmse: 1.44409	valid_1's rmse: 1.57811
# [6500]	training's rmse: 1.44263	valid_1's rmse: 1.5781
# [6600]	training's rmse: 1.44121	valid_1's rmse: 1.57811
# Early stopping, best iteration is:
# [6225]	training's rmse: 1.44664	valid_1's rmse: 1.57805
# 1.5576484761540395

# %%
# score:  3.6467757129353053

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,50))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
# plt.savefig('lgbm_importances.png')

# %%
sub_df = pd.DataFrame({"card_id":df_test["card_id"].values})
sub_df["target"] = predictions
sub_df.to_csv("../output/submission_model20181216_no_outliers.csv", index=False)
