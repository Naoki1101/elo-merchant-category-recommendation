# %%
import numpy as np
import pandas as pd
import datetime
import gc

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import lightgbm as lgb

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error, roc_auc_score
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')
np.random.seed(4590)
# Out:
# /Users/naoki/.pyenv/versions/3.6.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/naoki/.pyenv/versions/3.6.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/naoki/.pyenv/versions/3.6.6/lib/python3.6/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.1) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
df_train = pd.read_csv('../input/train.csv')
df_test = pd.read_csv('../input/test.csv')
df_hist_trans = pd.read_csv('../input/historical_transactions.csv')
df_new_merchant_trans = pd.read_csv('../input/new_merchant_transactions.csv')

# %%
df_hist_trans['purchase_amount'] = np.exp(df_hist_trans['purchase_amount'])
df_new_merchant_trans['purchase_amount'] = np.exp(df_new_merchant_trans['purchase_amount'])

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['category_2'].fillna(1.0,inplace=True)
    df['category_3'].fillna('A',inplace=True)
    df['merchant_id'].fillna('M_ID_00a6ca8a8a',inplace=True)

# %%
def get_new_columns(name,aggs):
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    df['year'] = df['purchase_date'].dt.year
    df['weekofyear'] = df['purchase_date'].dt.weekofyear
    df['month'] = df['purchase_date'].dt.month
    df['dayofweek'] = df['purchase_date'].dt.dayofweek
    df['weekend'] = (df.purchase_date.dt.weekday >=5).astype(int)
    df['hour'] = df['purchase_date'].dt.hour
    df['authorized_flag'] = df['authorized_flag'].map({'Y':1, 'N':0})
    df['category_1'] = df['category_1'].map({'Y':1, 'N':0}) 
    #https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/73244
    df['month_diff'] = ((datetime.datetime.today() - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']

aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['authorized_flag'] = ['sum', 'mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_hist_trans[col+'_mean'] = df_hist_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']    

new_columns = get_new_columns('hist',aggs)
df_hist_trans_group = df_hist_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['hist_purchase_date_diff'] = (df_hist_trans_group['hist_purchase_date_max'] - df_hist_trans_group['hist_purchase_date_min']).dt.days
df_hist_trans_group['hist_purchase_date_average'] = df_hist_trans_group['hist_purchase_date_diff']/df_hist_trans_group['hist_card_id_size']
df_hist_trans_group['hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 42

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']
aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_new_merchant_trans[col+'_mean'] = df_new_merchant_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']
    
new_columns = get_new_columns('new_hist',aggs)
df_hist_trans_group = df_new_merchant_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['new_hist_purchase_date_diff'] = (df_hist_trans_group['new_hist_purchase_date_max'] - df_hist_trans_group['new_hist_purchase_date_min']).dt.days
df_hist_trans_group['new_hist_purchase_date_average'] = df_hist_trans_group['new_hist_purchase_date_diff']/df_hist_trans_group['new_hist_card_id_size']
df_hist_trans_group['new_hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['new_hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 28

# %%
del df_hist_trans;gc.collect()
del df_new_merchant_trans;gc.collect()
df_train.head(5)
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
# 3            2017-09  C_ID_186d6a6901          4          3          0
# 4            2017-11  C_ID_cdbd2c0db2          1          3          0
#
#      target  hist_month_nunique  hist_hour_nunique  hist_weekofyear_nunique  \
# 0 -0.820283                   9                 23                       35
# 1  0.392913                  12                 24                       50
# 2  0.688056                  10                 14                       22
# 3  0.142495                   6                 16                       20
# 4 -0.159749                   4                 22                       17
#
#    hist_dayofweek_nunique               ...                \
# 0                       7               ...
# 1                       7               ...
# 2                       7               ...
# 3                       7               ...
# 4                       7               ...
#
#    new_hist_weekend_sum  new_hist_weekend_mean  new_hist_category_1_sum  \
# 0                   6.0               0.260870                      0.0
# 1                   0.0               0.000000                      0.0
# 2                   1.0               1.000000                      0.0
# 3                   3.0               0.428571                      1.0
# 4                  12.0               0.333333                      2.0
#
#    new_hist_category_1_mean  new_hist_card_id_size  \
# 0                  0.000000                   23.0
# 1                  0.000000                    6.0
# 2                  0.000000                    1.0
# 3                  0.142857                    7.0
# 4                  0.055556                   36.0
#
#    new_hist_category_2_mean_mean  new_hist_category_3_mean_mean  \
# 0                  1.658319e+108                   1.381361e+36
# 1                  1.658319e+108                   3.557623e+25
# 2                   7.789907e+26                   1.381361e+36
# 3                  2.369028e+107                   1.973373e+35
# 4                  1.842577e+107                  3.624714e+107
#
#    new_hist_purchase_date_diff  new_hist_purchase_date_average  \
# 0                         54.0                        2.347826
# 1                         56.0                        9.333333
# 2                          0.0                        0.000000
# 3                         41.0                        5.857143
# 4                         57.0                        1.583333
#
#    new_hist_purchase_date_uptonow
# 0                           243.0
# 1                           273.0
# 2                           244.0
# 3                           254.0
# 4                           244.0
#
# [5 rows x 78 columns]

# %%
df_train['outliers'] = 0
df_train.loc[df_train['target'] < -30, 'outliers'] = 1
df_train['outliers'].value_counts()
# Out:
# 0    199710
# 1      2207
# Name: outliers, dtype: int64

# %%
list_outlier_idx = df_train[df_train.outliers == 1].index.tolist()

# %%
for df in [df_train,df_test]:
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['dayofweek'] = df['first_active_month'].dt.dayofweek
    df['weekofyear'] = df['first_active_month'].dt.weekofyear
    df['month'] = df['first_active_month'].dt.month
    df['elapsed_time'] = (datetime.datetime.today() - df['first_active_month']).dt.days
    df['hist_first_buy'] = (df['hist_purchase_date_min'] - df['first_active_month']).dt.days
    df['new_hist_first_buy'] = (df['new_hist_purchase_date_min'] - df['first_active_month']).dt.days
    for f in ['hist_purchase_date_max','hist_purchase_date_min','new_hist_purchase_date_max',\
                     'new_hist_purchase_date_min']:
        df[f] = df[f].astype(np.int64) * 1e-9
    df['card_id_total'] = df['new_hist_card_id_size']+df['hist_card_id_size']
    df['purchase_amount_total'] = df['new_hist_purchase_amount_sum']+df['hist_purchase_amount_sum']

for f in ['feature_1','feature_2','feature_3']:
    order_label = df_train.groupby([f])['outliers'].mean()
    df_train[f] = df_train[f].map(order_label)
    df_test[f] = df_test[f].map(order_label)

# %%
high_importance_features = [
    "hist_month_diff_mean", 
    "hist_authorized_flag_mean", 
    "hist_category_1_sum", 
    "hist_month_lag_mean", 
    "new_hist_purchase_amount_sum", 
    "new_hist_purchase_date_uptonow"
]

#smoothing
for col in high_importance_features:
    df_train[col] = np.where(df_train[col].values==0, 0.001, df_train[col].values)
    df_test[col] = np.where(df_test[col].values==0, 0.001, df_test[col].values)


for i in range(len(high_importance_features)):
    for j in range(len((high_importance_features)))[i+1:]:
        col1 = high_importance_features[i]
        col2 = high_importance_features[j]
        new_col_name = "{c1}__div__{c2}".format(c1=col1, c2=col2)
        
        df_train[new_col_name] = df_train[col1] / df_train[col2]
        df_test[new_col_name] = df_test[col1] / df_test[col2]

# %%
def merge_new_feature(path):
    df_new_feature = pd.read_csv(path)
    
    df_tr = pd.merge(df_train, df_new_feature, on="card_id", how="left")
    df_te = pd.merge(df_test, df_new_feature, on="card_id", how="left")
    
    return df_tr, df_te

# %%
df_train, df_test = merge_new_feature("../input/merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/new_merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/prosperity_merchants_latest.csv")
df_train, df_test = merge_new_feature("../input/merchants_numerical_features.csv")
df_train, df_test = merge_new_feature("../input/merchants_item_scale_feature.csv")
df_train, df_test = merge_new_feature("../input/purchase_pattern.csv")
df_train, df_test = merge_new_feature("../input/purchase_pettern_nmf.csv")
df_train, df_test = merge_new_feature("../input/purchase_amount_pettern_nmf.csv")

# %%
df_train["Null_count"] = df_train.isnull().sum(axis=1)
df_test["Null_count"] = df_test.isnull().sum(axis=1)

# %%
df_train_columns = [c for c in df_train.columns if c not in ['card_id', 'first_active_month','second_active_date','diff_first_and_second','target','outliers']]
target = df_train['target']
target_outlier = df_train["outliers"]

# %%
#original
param = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',
    'max_depth': -1,
    "max_bin": 256,  # なし
    'learning_rate': 0.004,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.73837	valid_1's rmse: 3.77436
# [200]	training's rmse: 3.66983	valid_1's rmse: 3.7314
# [300]	training's rmse: 3.62222	valid_1's rmse: 3.7081
# [400]	training's rmse: 3.58551	valid_1's rmse: 3.69387
# [500]	training's rmse: 3.55618	valid_1's rmse: 3.68311
# [600]	training's rmse: 3.53171	valid_1's rmse: 3.67555
# [700]	training's rmse: 3.51129	valid_1's rmse: 3.67041
# [800]	training's rmse: 3.49279	valid_1's rmse: 3.66674
# [900]	training's rmse: 3.47636	valid_1's rmse: 3.66364
# [1000]	training's rmse: 3.46059	valid_1's rmse: 3.66099
# [1100]	training's rmse: 3.44616	valid_1's rmse: 3.65844
# [1200]	training's rmse: 3.43267	valid_1's rmse: 3.6563
# [1300]	training's rmse: 3.41997	valid_1's rmse: 3.65453
# [1400]	training's rmse: 3.40775	valid_1's rmse: 3.65297
# [1500]	training's rmse: 3.39635	valid_1's rmse: 3.65152
# [1600]	training's rmse: 3.38552	valid_1's rmse: 3.65026
# [1700]	training's rmse: 3.37532	valid_1's rmse: 3.64932
# [1800]	training's rmse: 3.3653	valid_1's rmse: 3.64849
# [1900]	training's rmse: 3.35573	valid_1's rmse: 3.64812
# [2000]	training's rmse: 3.34605	valid_1's rmse: 3.64739
# [2100]	training's rmse: 3.33653	valid_1's rmse: 3.6465
# [2200]	training's rmse: 3.32804	valid_1's rmse: 3.6459
# [2300]	training's rmse: 3.31914	valid_1's rmse: 3.64521
# [2400]	training's rmse: 3.31072	valid_1's rmse: 3.64463
# [2500]	training's rmse: 3.30289	valid_1's rmse: 3.64422
# [2600]	training's rmse: 3.29493	valid_1's rmse: 3.64389
# [2700]	training's rmse: 3.28717	valid_1's rmse: 3.64368
# [2800]	training's rmse: 3.2796	valid_1's rmse: 3.64329
# [2900]	training's rmse: 3.27158	valid_1's rmse: 3.64271
# [3000]	training's rmse: 3.26433	valid_1's rmse: 3.64251
# [3100]	training's rmse: 3.25715	valid_1's rmse: 3.64207
# [3200]	training's rmse: 3.2501	valid_1's rmse: 3.64179
# [3300]	training's rmse: 3.24326	valid_1's rmse: 3.64147
# [3400]	training's rmse: 3.23642	valid_1's rmse: 3.64119
# [3500]	training's rmse: 3.22954	valid_1's rmse: 3.6413
# [3600]	training's rmse: 3.223	valid_1's rmse: 3.64101
# [3700]	training's rmse: 3.21642	valid_1's rmse: 3.64077
# [3800]	training's rmse: 3.20957	valid_1's rmse: 3.64068
# [3900]	training's rmse: 3.20296	valid_1's rmse: 3.64066
# [4000]	training's rmse: 3.19666	valid_1's rmse: 3.64055
# [4100]	training's rmse: 3.1904	valid_1's rmse: 3.64054
# [4200]	training's rmse: 3.18383	valid_1's rmse: 3.64031
# [4300]	training's rmse: 3.17738	valid_1's rmse: 3.64041
# [4400]	training's rmse: 3.17146	valid_1's rmse: 3.64039
# [4500]	training's rmse: 3.16524	valid_1's rmse: 3.64038
# [4600]	training's rmse: 3.15875	valid_1's rmse: 3.64026
# [4700]	training's rmse: 3.15315	valid_1's rmse: 3.64018
# [4800]	training's rmse: 3.14725	valid_1's rmse: 3.64013
# [4900]	training's rmse: 3.14154	valid_1's rmse: 3.64005
# [5000]	training's rmse: 3.1356	valid_1's rmse: 3.64013
# [5100]	training's rmse: 3.12993	valid_1's rmse: 3.64006
# [5200]	training's rmse: 3.12399	valid_1's rmse: 3.64017
# [5300]	training's rmse: 3.1182	valid_1's rmse: 3.63991
# [5400]	training's rmse: 3.1125	valid_1's rmse: 3.63988
# [5500]	training's rmse: 3.10698	valid_1's rmse: 3.63973
# [5600]	training's rmse: 3.10128	valid_1's rmse: 3.63973
# [5700]	training's rmse: 3.09545	valid_1's rmse: 3.63961
# [5800]	training's rmse: 3.08966	valid_1's rmse: 3.63968
# [5900]	training's rmse: 3.08392	valid_1's rmse: 3.63982
# [6000]	training's rmse: 3.07848	valid_1's rmse: 3.63987
# Early stopping, best iteration is:
# [5684]	training's rmse: 3.09653	valid_1's rmse: 3.6396
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74383	valid_1's rmse: 3.76063
# [200]	training's rmse: 3.67542	valid_1's rmse: 3.71543
# [300]	training's rmse: 3.62694	valid_1's rmse: 3.68995
# [400]	training's rmse: 3.5897	valid_1's rmse: 3.67565
# [500]	training's rmse: 3.55998	valid_1's rmse: 3.66604
# [600]	training's rmse: 3.53529	valid_1's rmse: 3.65987
# [700]	training's rmse: 3.51396	valid_1's rmse: 3.65509
# [800]	training's rmse: 3.49541	valid_1's rmse: 3.65086
# [900]	training's rmse: 3.47857	valid_1's rmse: 3.64779
# [1000]	training's rmse: 3.46328	valid_1's rmse: 3.64561
# [1100]	training's rmse: 3.44931	valid_1's rmse: 3.64378
# [1200]	training's rmse: 3.4357	valid_1's rmse: 3.64212
# [1300]	training's rmse: 3.42241	valid_1's rmse: 3.64091
# [1400]	training's rmse: 3.41002	valid_1's rmse: 3.64008
# [1500]	training's rmse: 3.3983	valid_1's rmse: 3.63961
# [1600]	training's rmse: 3.38698	valid_1's rmse: 3.63889
# [1700]	training's rmse: 3.37591	valid_1's rmse: 3.63837
# [1800]	training's rmse: 3.36585	valid_1's rmse: 3.63778
# [1900]	training's rmse: 3.35587	valid_1's rmse: 3.63755
# [2000]	training's rmse: 3.34598	valid_1's rmse: 3.63754
# [2100]	training's rmse: 3.3369	valid_1's rmse: 3.63715
# [2200]	training's rmse: 3.32767	valid_1's rmse: 3.63701
# [2300]	training's rmse: 3.31883	valid_1's rmse: 3.6371
# [2400]	training's rmse: 3.31032	valid_1's rmse: 3.63694
# [2500]	training's rmse: 3.30193	valid_1's rmse: 3.6367
# [2600]	training's rmse: 3.2935	valid_1's rmse: 3.63679
# [2700]	training's rmse: 3.28535	valid_1's rmse: 3.63686
# [2800]	training's rmse: 3.27771	valid_1's rmse: 3.6367
# [2900]	training's rmse: 3.26971	valid_1's rmse: 3.63671
# [3000]	training's rmse: 3.26202	valid_1's rmse: 3.63661
# [3100]	training's rmse: 3.25461	valid_1's rmse: 3.63671
# [3200]	training's rmse: 3.2474	valid_1's rmse: 3.63681
# [3300]	training's rmse: 3.24026	valid_1's rmse: 3.63698
# [3400]	training's rmse: 3.23301	valid_1's rmse: 3.63713
# Early stopping, best iteration is:
# [3030]	training's rmse: 3.25992	valid_1's rmse: 3.63654
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74434	valid_1's rmse: 3.75858
# [200]	training's rmse: 3.67656	valid_1's rmse: 3.71026
# [300]	training's rmse: 3.62886	valid_1's rmse: 3.68412
# [400]	training's rmse: 3.59137	valid_1's rmse: 3.66729
# [500]	training's rmse: 3.56158	valid_1's rmse: 3.65611
# [600]	training's rmse: 3.53764	valid_1's rmse: 3.64852
# [700]	training's rmse: 3.51689	valid_1's rmse: 3.64279
# [800]	training's rmse: 3.49854	valid_1's rmse: 3.63836
# [900]	training's rmse: 3.48214	valid_1's rmse: 3.63434
# [1000]	training's rmse: 3.4665	valid_1's rmse: 3.63114
# [1100]	training's rmse: 3.4526	valid_1's rmse: 3.62892
# [1200]	training's rmse: 3.43981	valid_1's rmse: 3.62703
# [1300]	training's rmse: 3.42736	valid_1's rmse: 3.62518
# [1400]	training's rmse: 3.41542	valid_1's rmse: 3.62364
# [1500]	training's rmse: 3.40404	valid_1's rmse: 3.62218
# [1600]	training's rmse: 3.39319	valid_1's rmse: 3.6213
# [1700]	training's rmse: 3.38292	valid_1's rmse: 3.62051
# [1800]	training's rmse: 3.37294	valid_1's rmse: 3.61957
# [1900]	training's rmse: 3.3635	valid_1's rmse: 3.6189
# [2000]	training's rmse: 3.35404	valid_1's rmse: 3.61829
# [2100]	training's rmse: 3.34483	valid_1's rmse: 3.61773
# [2200]	training's rmse: 3.33609	valid_1's rmse: 3.61754
# [2300]	training's rmse: 3.32777	valid_1's rmse: 3.61722
# [2400]	training's rmse: 3.31923	valid_1's rmse: 3.617
# [2500]	training's rmse: 3.31089	valid_1's rmse: 3.61667
# [2600]	training's rmse: 3.30277	valid_1's rmse: 3.61645
# [2700]	training's rmse: 3.29492	valid_1's rmse: 3.61623
# [2800]	training's rmse: 3.2871	valid_1's rmse: 3.61628
# [2900]	training's rmse: 3.27956	valid_1's rmse: 3.61615
# [3000]	training's rmse: 3.2722	valid_1's rmse: 3.61619
# [3100]	training's rmse: 3.26466	valid_1's rmse: 3.61603
# [3200]	training's rmse: 3.2574	valid_1's rmse: 3.61584
# [3300]	training's rmse: 3.25041	valid_1's rmse: 3.61587
# [3400]	training's rmse: 3.24327	valid_1's rmse: 3.61578
# [3500]	training's rmse: 3.23648	valid_1's rmse: 3.61583
# [3600]	training's rmse: 3.22939	valid_1's rmse: 3.61569
# [3700]	training's rmse: 3.22294	valid_1's rmse: 3.61549
# [3800]	training's rmse: 3.21595	valid_1's rmse: 3.61532
# [3900]	training's rmse: 3.2093	valid_1's rmse: 3.61521
# [4000]	training's rmse: 3.20286	valid_1's rmse: 3.61524
# [4100]	training's rmse: 3.19624	valid_1's rmse: 3.61528
# [4200]	training's rmse: 3.19015	valid_1's rmse: 3.61523
# [4300]	training's rmse: 3.18394	valid_1's rmse: 3.61515
# [4400]	training's rmse: 3.17792	valid_1's rmse: 3.61532
# [4500]	training's rmse: 3.17167	valid_1's rmse: 3.61537
# [4600]	training's rmse: 3.16559	valid_1's rmse: 3.61537
# [4700]	training's rmse: 3.15949	valid_1's rmse: 3.61532
# Early stopping, best iteration is:
# [4312]	training's rmse: 3.18324	valid_1's rmse: 3.61511
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.73907	valid_1's rmse: 3.76898
# [200]	training's rmse: 3.66835	valid_1's rmse: 3.72783
# [300]	training's rmse: 3.61896	valid_1's rmse: 3.70715
# [400]	training's rmse: 3.58074	valid_1's rmse: 3.6958
# [500]	training's rmse: 3.55075	valid_1's rmse: 3.68802
# [600]	training's rmse: 3.52555	valid_1's rmse: 3.68365
# [700]	training's rmse: 3.50464	valid_1's rmse: 3.67989
# [800]	training's rmse: 3.48568	valid_1's rmse: 3.67753
# [900]	training's rmse: 3.46918	valid_1's rmse: 3.67561
# [1000]	training's rmse: 3.45325	valid_1's rmse: 3.6743
# [1100]	training's rmse: 3.43801	valid_1's rmse: 3.67316
# [1200]	training's rmse: 3.42401	valid_1's rmse: 3.67227
# [1300]	training's rmse: 3.41069	valid_1's rmse: 3.67142
# [1400]	training's rmse: 3.39871	valid_1's rmse: 3.67074
# [1500]	training's rmse: 3.38692	valid_1's rmse: 3.67015
# [1600]	training's rmse: 3.37601	valid_1's rmse: 3.66974
# [1700]	training's rmse: 3.36554	valid_1's rmse: 3.66932
# [1800]	training's rmse: 3.35534	valid_1's rmse: 3.66916
# [1900]	training's rmse: 3.34561	valid_1's rmse: 3.66883
# [2000]	training's rmse: 3.33545	valid_1's rmse: 3.66851
# [2100]	training's rmse: 3.32614	valid_1's rmse: 3.66826
# [2200]	training's rmse: 3.31687	valid_1's rmse: 3.66805
# [2300]	training's rmse: 3.30808	valid_1's rmse: 3.668
# [2400]	training's rmse: 3.29949	valid_1's rmse: 3.66756
# [2500]	training's rmse: 3.29067	valid_1's rmse: 3.66745
# [2600]	training's rmse: 3.28213	valid_1's rmse: 3.66743
# [2700]	training's rmse: 3.27423	valid_1's rmse: 3.66758
# [2800]	training's rmse: 3.26602	valid_1's rmse: 3.66747
# [2900]	training's rmse: 3.25869	valid_1's rmse: 3.66731
# [3000]	training's rmse: 3.2511	valid_1's rmse: 3.66731
# [3100]	training's rmse: 3.24341	valid_1's rmse: 3.66731
# [3200]	training's rmse: 3.23618	valid_1's rmse: 3.66731
# [3300]	training's rmse: 3.2291	valid_1's rmse: 3.66724
# Early stopping, best iteration is:
# [2927]	training's rmse: 3.25662	valid_1's rmse: 3.6672
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.73751	valid_1's rmse: 3.77723
# [200]	training's rmse: 3.66746	valid_1's rmse: 3.7369
# [300]	training's rmse: 3.61858	valid_1's rmse: 3.71482
# [400]	training's rmse: 3.58032	valid_1's rmse: 3.70209
# [500]	training's rmse: 3.55062	valid_1's rmse: 3.69373
# [600]	training's rmse: 3.52605	valid_1's rmse: 3.68775
# [700]	training's rmse: 3.50452	valid_1's rmse: 3.68375
# [800]	training's rmse: 3.48637	valid_1's rmse: 3.68039
# [900]	training's rmse: 3.46973	valid_1's rmse: 3.67805
# [1000]	training's rmse: 3.45438	valid_1's rmse: 3.67594
# [1100]	training's rmse: 3.43983	valid_1's rmse: 3.6742
# [1200]	training's rmse: 3.42623	valid_1's rmse: 3.67273
# [1300]	training's rmse: 3.41335	valid_1's rmse: 3.67131
# [1400]	training's rmse: 3.40139	valid_1's rmse: 3.67023
# [1500]	training's rmse: 3.38988	valid_1's rmse: 3.66951
# [1600]	training's rmse: 3.37898	valid_1's rmse: 3.66897
# [1700]	training's rmse: 3.36771	valid_1's rmse: 3.66842
# [1800]	training's rmse: 3.3574	valid_1's rmse: 3.66787
# [1900]	training's rmse: 3.3477	valid_1's rmse: 3.6676
# [2000]	training's rmse: 3.3378	valid_1's rmse: 3.66722
# [2100]	training's rmse: 3.32826	valid_1's rmse: 3.66686
# [2200]	training's rmse: 3.31912	valid_1's rmse: 3.66668
# [2300]	training's rmse: 3.31018	valid_1's rmse: 3.66656
# [2400]	training's rmse: 3.30139	valid_1's rmse: 3.66641
# [2500]	training's rmse: 3.29329	valid_1's rmse: 3.6663
# [2600]	training's rmse: 3.28487	valid_1's rmse: 3.66607
# [2700]	training's rmse: 3.27693	valid_1's rmse: 3.66589
# [2800]	training's rmse: 3.26943	valid_1's rmse: 3.66589
# [2900]	training's rmse: 3.26127	valid_1's rmse: 3.66593
# [3000]	training's rmse: 3.25347	valid_1's rmse: 3.66595
# [3100]	training's rmse: 3.24638	valid_1's rmse: 3.66587
# [3200]	training's rmse: 3.23942	valid_1's rmse: 3.6658
# [3300]	training's rmse: 3.23265	valid_1's rmse: 3.66596
# [3400]	training's rmse: 3.22563	valid_1's rmse: 3.66601
# [3500]	training's rmse: 3.21877	valid_1's rmse: 3.66588
# [3600]	training's rmse: 3.21201	valid_1's rmse: 3.66584
# Early stopping, best iteration is:
# [3200]	training's rmse: 3.23942	valid_1's rmse: 3.6658
# 3.644901770811154

# %%
# score:  3.6467757129353053

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,50))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
# plt.savefig('lgbm_importances.png')

# %%
df_train2 = df_train[df_train.target >= -20].reset_index(drop=True)
target2 = df_train2["target"]

#original
param2 = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',
    'max_depth': -1,
    'learning_rate': 0.01,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train2))
predictions2 = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train2,df_train2['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train2.iloc[trn_idx][df_train_columns], label=target2.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train2.iloc[val_idx][df_train_columns], label=target2.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param2, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train2.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions2 += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target2))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65323	valid_1's rmse: 1.6522
# [200]	training's rmse: 1.61841	valid_1's rmse: 1.61787
# [300]	training's rmse: 1.59803	valid_1's rmse: 1.59847
# [400]	training's rmse: 1.58477	valid_1's rmse: 1.58641
# [500]	training's rmse: 1.57536	valid_1's rmse: 1.57842
# [600]	training's rmse: 1.56822	valid_1's rmse: 1.57289
# [700]	training's rmse: 1.56239	valid_1's rmse: 1.56874
# [800]	training's rmse: 1.55752	valid_1's rmse: 1.56563
# [900]	training's rmse: 1.5532	valid_1's rmse: 1.56327
# [1000]	training's rmse: 1.5493	valid_1's rmse: 1.56132
# [1100]	training's rmse: 1.54579	valid_1's rmse: 1.55982
# [1200]	training's rmse: 1.54253	valid_1's rmse: 1.55857
# [1300]	training's rmse: 1.53946	valid_1's rmse: 1.55751
# [1400]	training's rmse: 1.53651	valid_1's rmse: 1.5566
# [1500]	training's rmse: 1.53375	valid_1's rmse: 1.5558
# [1600]	training's rmse: 1.5311	valid_1's rmse: 1.55519
# [1700]	training's rmse: 1.52859	valid_1's rmse: 1.55469
# [1800]	training's rmse: 1.52621	valid_1's rmse: 1.55424
# [1900]	training's rmse: 1.52393	valid_1's rmse: 1.55393
# [2000]	training's rmse: 1.52176	valid_1's rmse: 1.55362
# [2100]	training's rmse: 1.51961	valid_1's rmse: 1.5533
# [2200]	training's rmse: 1.51751	valid_1's rmse: 1.55308
# [2300]	training's rmse: 1.51546	valid_1's rmse: 1.55288
# [2400]	training's rmse: 1.51346	valid_1's rmse: 1.55267
# [2500]	training's rmse: 1.51155	valid_1's rmse: 1.55253
# [2600]	training's rmse: 1.50963	valid_1's rmse: 1.55235
# [2700]	training's rmse: 1.50778	valid_1's rmse: 1.55222
# [2800]	training's rmse: 1.5059	valid_1's rmse: 1.55207
# [2900]	training's rmse: 1.50406	valid_1's rmse: 1.55196
# [3000]	training's rmse: 1.50227	valid_1's rmse: 1.55188
# [3100]	training's rmse: 1.50048	valid_1's rmse: 1.55182
# [3200]	training's rmse: 1.49874	valid_1's rmse: 1.55175
# [3300]	training's rmse: 1.49699	valid_1's rmse: 1.55169
# [3400]	training's rmse: 1.49533	valid_1's rmse: 1.55164
# [3500]	training's rmse: 1.49364	valid_1's rmse: 1.55156
# [3600]	training's rmse: 1.49191	valid_1's rmse: 1.5515
# [3700]	training's rmse: 1.49026	valid_1's rmse: 1.55142
# [3800]	training's rmse: 1.48861	valid_1's rmse: 1.55138
# [3900]	training's rmse: 1.48691	valid_1's rmse: 1.55135
# [4000]	training's rmse: 1.48527	valid_1's rmse: 1.5513
# [4100]	training's rmse: 1.48367	valid_1's rmse: 1.55127
# [4200]	training's rmse: 1.48202	valid_1's rmse: 1.55125
# [4300]	training's rmse: 1.4804	valid_1's rmse: 1.55125
# [4400]	training's rmse: 1.47878	valid_1's rmse: 1.55121
# [4500]	training's rmse: 1.47718	valid_1's rmse: 1.55121
# [4600]	training's rmse: 1.47561	valid_1's rmse: 1.55118
# [4700]	training's rmse: 1.47407	valid_1's rmse: 1.55119
# [4800]	training's rmse: 1.47247	valid_1's rmse: 1.55114
# [4900]	training's rmse: 1.47092	valid_1's rmse: 1.55113
# [5000]	training's rmse: 1.4694	valid_1's rmse: 1.55111
# [5100]	training's rmse: 1.4679	valid_1's rmse: 1.55107
# [5200]	training's rmse: 1.46636	valid_1's rmse: 1.551
# [5300]	training's rmse: 1.46483	valid_1's rmse: 1.551
# [5400]	training's rmse: 1.4633	valid_1's rmse: 1.55099
# [5500]	training's rmse: 1.46186	valid_1's rmse: 1.55098
# [5600]	training's rmse: 1.46033	valid_1's rmse: 1.551
# [5700]	training's rmse: 1.45887	valid_1's rmse: 1.55101
# [5800]	training's rmse: 1.4574	valid_1's rmse: 1.55099
# [5900]	training's rmse: 1.45594	valid_1's rmse: 1.55098
# [6000]	training's rmse: 1.45442	valid_1's rmse: 1.55098
# [6100]	training's rmse: 1.45297	valid_1's rmse: 1.55098
# [6200]	training's rmse: 1.45154	valid_1's rmse: 1.55101
# Early stopping, best iteration is:
# [5832]	training's rmse: 1.45693	valid_1's rmse: 1.55097
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65659	valid_1's rmse: 1.63613
# [200]	training's rmse: 1.62112	valid_1's rmse: 1.60397
# [300]	training's rmse: 1.60046	valid_1's rmse: 1.58622
# [400]	training's rmse: 1.58711	valid_1's rmse: 1.57554
# [500]	training's rmse: 1.57767	valid_1's rmse: 1.56843
# [600]	training's rmse: 1.57057	valid_1's rmse: 1.56358
# [700]	training's rmse: 1.5648	valid_1's rmse: 1.56005
# [800]	training's rmse: 1.55992	valid_1's rmse: 1.55722
# [900]	training's rmse: 1.55568	valid_1's rmse: 1.55499
# [1000]	training's rmse: 1.55181	valid_1's rmse: 1.55311
# [1100]	training's rmse: 1.5483	valid_1's rmse: 1.55164
# [1200]	training's rmse: 1.54499	valid_1's rmse: 1.55033
# [1300]	training's rmse: 1.54186	valid_1's rmse: 1.54926
# [1400]	training's rmse: 1.53897	valid_1's rmse: 1.54832
# [1500]	training's rmse: 1.53622	valid_1's rmse: 1.54756
# [1600]	training's rmse: 1.53362	valid_1's rmse: 1.5469
# [1700]	training's rmse: 1.53114	valid_1's rmse: 1.54634
# [1800]	training's rmse: 1.52874	valid_1's rmse: 1.54583
# [1900]	training's rmse: 1.52645	valid_1's rmse: 1.54546
# [2000]	training's rmse: 1.52419	valid_1's rmse: 1.54511
# [2100]	training's rmse: 1.52201	valid_1's rmse: 1.54484
# [2200]	training's rmse: 1.51987	valid_1's rmse: 1.54459
# [2300]	training's rmse: 1.51777	valid_1's rmse: 1.54435
# [2400]	training's rmse: 1.51577	valid_1's rmse: 1.54414
# [2500]	training's rmse: 1.51382	valid_1's rmse: 1.54396
# [2600]	training's rmse: 1.51187	valid_1's rmse: 1.54382
# [2700]	training's rmse: 1.51001	valid_1's rmse: 1.54368
# [2800]	training's rmse: 1.50816	valid_1's rmse: 1.54351
# [2900]	training's rmse: 1.5063	valid_1's rmse: 1.54337
# [3000]	training's rmse: 1.50448	valid_1's rmse: 1.54319
# [3100]	training's rmse: 1.50269	valid_1's rmse: 1.54311
# [3200]	training's rmse: 1.50097	valid_1's rmse: 1.54301
# [3300]	training's rmse: 1.49924	valid_1's rmse: 1.54292
# [3400]	training's rmse: 1.49745	valid_1's rmse: 1.54281
# [3500]	training's rmse: 1.4957	valid_1's rmse: 1.54272
# [3600]	training's rmse: 1.49399	valid_1's rmse: 1.54267
# [3700]	training's rmse: 1.49223	valid_1's rmse: 1.54257
# [3800]	training's rmse: 1.49056	valid_1's rmse: 1.54248
# [3900]	training's rmse: 1.4889	valid_1's rmse: 1.54244
# [4000]	training's rmse: 1.48727	valid_1's rmse: 1.54241
# [4100]	training's rmse: 1.48563	valid_1's rmse: 1.54232
# [4200]	training's rmse: 1.484	valid_1's rmse: 1.54231
# [4300]	training's rmse: 1.48238	valid_1's rmse: 1.54225
# [4400]	training's rmse: 1.48083	valid_1's rmse: 1.54219
# [4500]	training's rmse: 1.47925	valid_1's rmse: 1.54217
# [4600]	training's rmse: 1.4777	valid_1's rmse: 1.54211
# [4700]	training's rmse: 1.4762	valid_1's rmse: 1.54204
# [4800]	training's rmse: 1.47457	valid_1's rmse: 1.54198
# [4900]	training's rmse: 1.47304	valid_1's rmse: 1.54193
# [5000]	training's rmse: 1.47144	valid_1's rmse: 1.54192
# [5100]	training's rmse: 1.46992	valid_1's rmse: 1.5419
# [5200]	training's rmse: 1.46834	valid_1's rmse: 1.54185
# [5300]	training's rmse: 1.4668	valid_1's rmse: 1.54181
# [5400]	training's rmse: 1.46533	valid_1's rmse: 1.54175
# [5500]	training's rmse: 1.46383	valid_1's rmse: 1.54168
# [5600]	training's rmse: 1.46232	valid_1's rmse: 1.54168
# [5700]	training's rmse: 1.46084	valid_1's rmse: 1.54165
# [5800]	training's rmse: 1.45937	valid_1's rmse: 1.54162
# [5900]	training's rmse: 1.45788	valid_1's rmse: 1.54159
# [6000]	training's rmse: 1.45639	valid_1's rmse: 1.54153
# [6100]	training's rmse: 1.45492	valid_1's rmse: 1.54147
# [6200]	training's rmse: 1.45344	valid_1's rmse: 1.54146
# [6300]	training's rmse: 1.45198	valid_1's rmse: 1.54146
# [6400]	training's rmse: 1.45055	valid_1's rmse: 1.54143
# [6500]	training's rmse: 1.44905	valid_1's rmse: 1.54138
# [6600]	training's rmse: 1.44762	valid_1's rmse: 1.54136
# [6700]	training's rmse: 1.4461	valid_1's rmse: 1.54135
# [6800]	training's rmse: 1.4447	valid_1's rmse: 1.54133
# [6900]	training's rmse: 1.44323	valid_1's rmse: 1.5413
# [7000]	training's rmse: 1.44185	valid_1's rmse: 1.5413
# [7100]	training's rmse: 1.44041	valid_1's rmse: 1.54131
# [7200]	training's rmse: 1.43895	valid_1's rmse: 1.54125
# [7300]	training's rmse: 1.43745	valid_1's rmse: 1.54121
# [7400]	training's rmse: 1.43604	valid_1's rmse: 1.54116
# [7500]	training's rmse: 1.43464	valid_1's rmse: 1.54114
# [7600]	training's rmse: 1.43328	valid_1's rmse: 1.54112
# [7700]	training's rmse: 1.43185	valid_1's rmse: 1.54111
# [7800]	training's rmse: 1.43045	valid_1's rmse: 1.54111
# [7900]	training's rmse: 1.4291	valid_1's rmse: 1.54113
# [8000]	training's rmse: 1.4277	valid_1's rmse: 1.5411
# [8100]	training's rmse: 1.4263	valid_1's rmse: 1.54107
# [8200]	training's rmse: 1.42496	valid_1's rmse: 1.54106
# [8300]	training's rmse: 1.42362	valid_1's rmse: 1.54104
# [8400]	training's rmse: 1.42227	valid_1's rmse: 1.54101
# [8500]	training's rmse: 1.42089	valid_1's rmse: 1.54101
# [8600]	training's rmse: 1.41956	valid_1's rmse: 1.54099
# [8700]	training's rmse: 1.4182	valid_1's rmse: 1.54097
# [8800]	training's rmse: 1.41688	valid_1's rmse: 1.54098
# [8900]	training's rmse: 1.4155	valid_1's rmse: 1.54097
# [9000]	training's rmse: 1.41417	valid_1's rmse: 1.54095
# [9100]	training's rmse: 1.41287	valid_1's rmse: 1.54094
# [9200]	training's rmse: 1.41153	valid_1's rmse: 1.54095
# [9300]	training's rmse: 1.41019	valid_1's rmse: 1.54095
# [9400]	training's rmse: 1.40884	valid_1's rmse: 1.54092
# [9500]	training's rmse: 1.40748	valid_1's rmse: 1.54091
# [9600]	training's rmse: 1.40613	valid_1's rmse: 1.54091
# [9700]	training's rmse: 1.40488	valid_1's rmse: 1.54086
# [9800]	training's rmse: 1.40356	valid_1's rmse: 1.54085
# [9900]	training's rmse: 1.40226	valid_1's rmse: 1.54086
# [10000]	training's rmse: 1.40098	valid_1's rmse: 1.54087
# Did not meet early stopping. Best iteration is:
# [10000]	training's rmse: 1.40098	valid_1's rmse: 1.54087
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65226	valid_1's rmse: 1.65506
# [200]	training's rmse: 1.61729	valid_1's rmse: 1.62176
# [300]	training's rmse: 1.59694	valid_1's rmse: 1.60304
# [400]	training's rmse: 1.5837	valid_1's rmse: 1.59153
# [500]	training's rmse: 1.57439	valid_1's rmse: 1.58404
# [600]	training's rmse: 1.56729	valid_1's rmse: 1.5788
# [700]	training's rmse: 1.56153	valid_1's rmse: 1.57495
# [800]	training's rmse: 1.55666	valid_1's rmse: 1.5719
# [900]	training's rmse: 1.5525	valid_1's rmse: 1.56956
# [1000]	training's rmse: 1.54862	valid_1's rmse: 1.56763
# [1100]	training's rmse: 1.54511	valid_1's rmse: 1.5661
# [1200]	training's rmse: 1.54182	valid_1's rmse: 1.5648
# [1300]	training's rmse: 1.53878	valid_1's rmse: 1.56373
# [1400]	training's rmse: 1.53584	valid_1's rmse: 1.56277
# [1500]	training's rmse: 1.53311	valid_1's rmse: 1.56197
# [1600]	training's rmse: 1.5305	valid_1's rmse: 1.56124
# [1700]	training's rmse: 1.52801	valid_1's rmse: 1.56069
# [1800]	training's rmse: 1.52564	valid_1's rmse: 1.56025
# [1900]	training's rmse: 1.52337	valid_1's rmse: 1.55984
# [2000]	training's rmse: 1.52118	valid_1's rmse: 1.55949
# [2100]	training's rmse: 1.51903	valid_1's rmse: 1.5592
# [2200]	training's rmse: 1.51691	valid_1's rmse: 1.55893
# [2300]	training's rmse: 1.51486	valid_1's rmse: 1.55873
# [2400]	training's rmse: 1.51285	valid_1's rmse: 1.55852
# [2500]	training's rmse: 1.51086	valid_1's rmse: 1.55835
# [2600]	training's rmse: 1.50892	valid_1's rmse: 1.55817
# [2700]	training's rmse: 1.5071	valid_1's rmse: 1.55804
# [2800]	training's rmse: 1.50526	valid_1's rmse: 1.55794
# [2900]	training's rmse: 1.50341	valid_1's rmse: 1.55777
# [3000]	training's rmse: 1.50158	valid_1's rmse: 1.55763
# [3100]	training's rmse: 1.49979	valid_1's rmse: 1.55753
# [3200]	training's rmse: 1.49806	valid_1's rmse: 1.55746
# [3300]	training's rmse: 1.49626	valid_1's rmse: 1.55734
# [3400]	training's rmse: 1.49455	valid_1's rmse: 1.55727
# [3500]	training's rmse: 1.49288	valid_1's rmse: 1.55719
# [3600]	training's rmse: 1.49116	valid_1's rmse: 1.55714
# [3700]	training's rmse: 1.48944	valid_1's rmse: 1.55705
# [3800]	training's rmse: 1.48778	valid_1's rmse: 1.55697
# [3900]	training's rmse: 1.48607	valid_1's rmse: 1.55692
# [4000]	training's rmse: 1.48446	valid_1's rmse: 1.55686
# [4100]	training's rmse: 1.48282	valid_1's rmse: 1.5568
# [4200]	training's rmse: 1.48116	valid_1's rmse: 1.55677
# [4300]	training's rmse: 1.47949	valid_1's rmse: 1.55666
# [4400]	training's rmse: 1.47792	valid_1's rmse: 1.55662
# [4500]	training's rmse: 1.47631	valid_1's rmse: 1.55658
# [4600]	training's rmse: 1.47476	valid_1's rmse: 1.55655
# [4700]	training's rmse: 1.4732	valid_1's rmse: 1.55651
# [4800]	training's rmse: 1.4716	valid_1's rmse: 1.55644
# [4900]	training's rmse: 1.47006	valid_1's rmse: 1.55642
# [5000]	training's rmse: 1.46852	valid_1's rmse: 1.55639
# [5100]	training's rmse: 1.46694	valid_1's rmse: 1.55637
# [5200]	training's rmse: 1.4654	valid_1's rmse: 1.55637
# [5300]	training's rmse: 1.46388	valid_1's rmse: 1.55632
# [5400]	training's rmse: 1.46238	valid_1's rmse: 1.55626
# [5500]	training's rmse: 1.46091	valid_1's rmse: 1.55623
# [5600]	training's rmse: 1.45937	valid_1's rmse: 1.55619
# [5700]	training's rmse: 1.45786	valid_1's rmse: 1.55613
# [5800]	training's rmse: 1.45635	valid_1's rmse: 1.55611
# [5900]	training's rmse: 1.45479	valid_1's rmse: 1.55609
# [6000]	training's rmse: 1.45334	valid_1's rmse: 1.55607
# [6100]	training's rmse: 1.45188	valid_1's rmse: 1.55607
# [6200]	training's rmse: 1.45037	valid_1's rmse: 1.55606
# [6300]	training's rmse: 1.44889	valid_1's rmse: 1.55608
# [6400]	training's rmse: 1.44745	valid_1's rmse: 1.55608
# [6500]	training's rmse: 1.44602	valid_1's rmse: 1.55609
# Early stopping, best iteration is:
# [6151]	training's rmse: 1.45112	valid_1's rmse: 1.55605
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65268	valid_1's rmse: 1.65327
# [200]	training's rmse: 1.61767	valid_1's rmse: 1.62054
# [300]	training's rmse: 1.59724	valid_1's rmse: 1.60224
# [400]	training's rmse: 1.58406	valid_1's rmse: 1.59115
# [500]	training's rmse: 1.57464	valid_1's rmse: 1.58383
# [600]	training's rmse: 1.56749	valid_1's rmse: 1.57871
# [700]	training's rmse: 1.56167	valid_1's rmse: 1.57487
# [800]	training's rmse: 1.55681	valid_1's rmse: 1.57204
# [900]	training's rmse: 1.55261	valid_1's rmse: 1.56974
# [1000]	training's rmse: 1.54873	valid_1's rmse: 1.56784
# [1100]	training's rmse: 1.54514	valid_1's rmse: 1.56625
# [1200]	training's rmse: 1.54185	valid_1's rmse: 1.56491
# [1300]	training's rmse: 1.53878	valid_1's rmse: 1.56382
# [1400]	training's rmse: 1.53582	valid_1's rmse: 1.56285
# [1500]	training's rmse: 1.53309	valid_1's rmse: 1.56209
# [1600]	training's rmse: 1.53048	valid_1's rmse: 1.56142
# [1700]	training's rmse: 1.52795	valid_1's rmse: 1.56082
# [1800]	training's rmse: 1.5256	valid_1's rmse: 1.56034
# [1900]	training's rmse: 1.52327	valid_1's rmse: 1.55993
# [2000]	training's rmse: 1.52105	valid_1's rmse: 1.55957
# [2100]	training's rmse: 1.51885	valid_1's rmse: 1.55922
# [2200]	training's rmse: 1.51675	valid_1's rmse: 1.55898
# [2300]	training's rmse: 1.51473	valid_1's rmse: 1.55879
# [2400]	training's rmse: 1.51273	valid_1's rmse: 1.55857
# [2500]	training's rmse: 1.51079	valid_1's rmse: 1.5584
# [2600]	training's rmse: 1.5089	valid_1's rmse: 1.55828
# [2700]	training's rmse: 1.50702	valid_1's rmse: 1.55811
# [2800]	training's rmse: 1.50513	valid_1's rmse: 1.55797
# [2900]	training's rmse: 1.50332	valid_1's rmse: 1.55783
# [3000]	training's rmse: 1.5015	valid_1's rmse: 1.55771
# [3100]	training's rmse: 1.49973	valid_1's rmse: 1.5576
# [3200]	training's rmse: 1.49797	valid_1's rmse: 1.5575
# [3300]	training's rmse: 1.49617	valid_1's rmse: 1.55739
# [3400]	training's rmse: 1.49447	valid_1's rmse: 1.55729
# [3500]	training's rmse: 1.49276	valid_1's rmse: 1.55723
# [3600]	training's rmse: 1.49107	valid_1's rmse: 1.55719
# [3700]	training's rmse: 1.48942	valid_1's rmse: 1.55716
# [3800]	training's rmse: 1.48777	valid_1's rmse: 1.55709
# [3900]	training's rmse: 1.48605	valid_1's rmse: 1.55702
# [4000]	training's rmse: 1.48442	valid_1's rmse: 1.55697
# [4100]	training's rmse: 1.48278	valid_1's rmse: 1.55688
# [4200]	training's rmse: 1.48117	valid_1's rmse: 1.55684
# [4300]	training's rmse: 1.47954	valid_1's rmse: 1.55681
# [4400]	training's rmse: 1.47795	valid_1's rmse: 1.55678
# [4500]	training's rmse: 1.47637	valid_1's rmse: 1.55673
# [4600]	training's rmse: 1.47481	valid_1's rmse: 1.55669
# [4700]	training's rmse: 1.47323	valid_1's rmse: 1.55664
# [4800]	training's rmse: 1.47169	valid_1's rmse: 1.5566
# [4900]	training's rmse: 1.47015	valid_1's rmse: 1.55655
# [5000]	training's rmse: 1.4686	valid_1's rmse: 1.55647
# [5100]	training's rmse: 1.46703	valid_1's rmse: 1.55647
# [5200]	training's rmse: 1.46552	valid_1's rmse: 1.55644
# [5300]	training's rmse: 1.46401	valid_1's rmse: 1.55637
# [5400]	training's rmse: 1.46247	valid_1's rmse: 1.55632
# [5500]	training's rmse: 1.46094	valid_1's rmse: 1.55627
# [5600]	training's rmse: 1.45943	valid_1's rmse: 1.55624
# [5700]	training's rmse: 1.45794	valid_1's rmse: 1.55624
# [5800]	training's rmse: 1.45644	valid_1's rmse: 1.55625
# [5900]	training's rmse: 1.45489	valid_1's rmse: 1.55626
# [6000]	training's rmse: 1.45338	valid_1's rmse: 1.55624
# [6100]	training's rmse: 1.45189	valid_1's rmse: 1.55622
# [6200]	training's rmse: 1.4504	valid_1's rmse: 1.55619
# [6300]	training's rmse: 1.44893	valid_1's rmse: 1.55617
# [6400]	training's rmse: 1.44747	valid_1's rmse: 1.55616
# [6500]	training's rmse: 1.44601	valid_1's rmse: 1.55614
# [6600]	training's rmse: 1.44456	valid_1's rmse: 1.55611
# [6700]	training's rmse: 1.44309	valid_1's rmse: 1.55613
# [6800]	training's rmse: 1.44166	valid_1's rmse: 1.55611
# [6900]	training's rmse: 1.44024	valid_1's rmse: 1.5561
# [7000]	training's rmse: 1.43881	valid_1's rmse: 1.5561
# [7100]	training's rmse: 1.43742	valid_1's rmse: 1.55611
# [7200]	training's rmse: 1.43597	valid_1's rmse: 1.55609
# [7300]	training's rmse: 1.43455	valid_1's rmse: 1.55608
# [7400]	training's rmse: 1.43318	valid_1's rmse: 1.55607
# [7500]	training's rmse: 1.43183	valid_1's rmse: 1.55606
# [7600]	training's rmse: 1.43045	valid_1's rmse: 1.55608
# [7700]	training's rmse: 1.42903	valid_1's rmse: 1.55605
# [7800]	training's rmse: 1.42767	valid_1's rmse: 1.55603
# [7900]	training's rmse: 1.4263	valid_1's rmse: 1.55603
# [8000]	training's rmse: 1.42488	valid_1's rmse: 1.55603
# [8100]	training's rmse: 1.42349	valid_1's rmse: 1.556
# [8200]	training's rmse: 1.42214	valid_1's rmse: 1.556
# [8300]	training's rmse: 1.4208	valid_1's rmse: 1.55599
# [8400]	training's rmse: 1.41946	valid_1's rmse: 1.55599
# [8500]	training's rmse: 1.41816	valid_1's rmse: 1.55597
# [8600]	training's rmse: 1.41682	valid_1's rmse: 1.55597
# [8700]	training's rmse: 1.41547	valid_1's rmse: 1.55595
# [8800]	training's rmse: 1.41417	valid_1's rmse: 1.55594
# [8900]	training's rmse: 1.41283	valid_1's rmse: 1.55595
# [9000]	training's rmse: 1.41151	valid_1's rmse: 1.55595
# [9100]	training's rmse: 1.41018	valid_1's rmse: 1.55594
# [9200]	training's rmse: 1.40885	valid_1's rmse: 1.55594
# [9300]	training's rmse: 1.40754	valid_1's rmse: 1.55594
# [9400]	training's rmse: 1.40626	valid_1's rmse: 1.55592
# [9500]	training's rmse: 1.4049	valid_1's rmse: 1.55594
# [9600]	training's rmse: 1.4036	valid_1's rmse: 1.5559
# [9700]	training's rmse: 1.40232	valid_1's rmse: 1.55593
# [9800]	training's rmse: 1.40099	valid_1's rmse: 1.55592
# [9900]	training's rmse: 1.3997	valid_1's rmse: 1.55594
# [10000]	training's rmse: 1.39842	valid_1's rmse: 1.55593
# Did not meet early stopping. Best iteration is:
# [10000]	training's rmse: 1.39842	valid_1's rmse: 1.55593
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.64769	valid_1's rmse: 1.6747
# [200]	training's rmse: 1.61278	valid_1's rmse: 1.6417
# [300]	training's rmse: 1.59233	valid_1's rmse: 1.62309
# [400]	training's rmse: 1.57914	valid_1's rmse: 1.61168
# [500]	training's rmse: 1.56975	valid_1's rmse: 1.60406
# [600]	training's rmse: 1.56264	valid_1's rmse: 1.59873
# [700]	training's rmse: 1.55685	valid_1's rmse: 1.59487
# [800]	training's rmse: 1.55199	valid_1's rmse: 1.59195
# [900]	training's rmse: 1.54768	valid_1's rmse: 1.58962
# [1000]	training's rmse: 1.54382	valid_1's rmse: 1.58771
# [1100]	training's rmse: 1.54028	valid_1's rmse: 1.58612
# [1200]	training's rmse: 1.53702	valid_1's rmse: 1.58481
# [1300]	training's rmse: 1.53396	valid_1's rmse: 1.58374
# [1400]	training's rmse: 1.53107	valid_1's rmse: 1.58285
# [1500]	training's rmse: 1.52836	valid_1's rmse: 1.58214
# [1600]	training's rmse: 1.52575	valid_1's rmse: 1.58146
# [1700]	training's rmse: 1.52325	valid_1's rmse: 1.58092
# [1800]	training's rmse: 1.52086	valid_1's rmse: 1.58049
# [1900]	training's rmse: 1.51858	valid_1's rmse: 1.58015
# [2000]	training's rmse: 1.51637	valid_1's rmse: 1.57981
# [2100]	training's rmse: 1.5142	valid_1's rmse: 1.57949
# [2200]	training's rmse: 1.51209	valid_1's rmse: 1.57926
# [2300]	training's rmse: 1.51002	valid_1's rmse: 1.57903
# [2400]	training's rmse: 1.50806	valid_1's rmse: 1.57888
# [2500]	training's rmse: 1.50612	valid_1's rmse: 1.57869
# [2600]	training's rmse: 1.50418	valid_1's rmse: 1.57854
# [2700]	training's rmse: 1.50231	valid_1's rmse: 1.57845
# [2800]	training's rmse: 1.5004	valid_1's rmse: 1.57833
# [2900]	training's rmse: 1.49861	valid_1's rmse: 1.57821
# [3000]	training's rmse: 1.49682	valid_1's rmse: 1.57807
# [3100]	training's rmse: 1.49505	valid_1's rmse: 1.57797
# [3200]	training's rmse: 1.49327	valid_1's rmse: 1.57782
# [3300]	training's rmse: 1.4915	valid_1's rmse: 1.57775
# [3400]	training's rmse: 1.48974	valid_1's rmse: 1.57769
# [3500]	training's rmse: 1.48802	valid_1's rmse: 1.57762
# [3600]	training's rmse: 1.48631	valid_1's rmse: 1.57752
# [3700]	training's rmse: 1.48464	valid_1's rmse: 1.57743
# [3800]	training's rmse: 1.48293	valid_1's rmse: 1.5774
# [3900]	training's rmse: 1.48126	valid_1's rmse: 1.5773
# [4000]	training's rmse: 1.47966	valid_1's rmse: 1.57723
# [4100]	training's rmse: 1.47802	valid_1's rmse: 1.57718
# [4200]	training's rmse: 1.47644	valid_1's rmse: 1.57714
# [4300]	training's rmse: 1.47482	valid_1's rmse: 1.57707
# [4400]	training's rmse: 1.47319	valid_1's rmse: 1.57705
# [4500]	training's rmse: 1.47162	valid_1's rmse: 1.57698
# [4600]	training's rmse: 1.47002	valid_1's rmse: 1.57694
# [4700]	training's rmse: 1.46846	valid_1's rmse: 1.5769
# [4800]	training's rmse: 1.46692	valid_1's rmse: 1.57686
# [4900]	training's rmse: 1.46537	valid_1's rmse: 1.57684
# [5000]	training's rmse: 1.46386	valid_1's rmse: 1.5768
# [5100]	training's rmse: 1.46233	valid_1's rmse: 1.57676
# [5200]	training's rmse: 1.46081	valid_1's rmse: 1.57673
# [5300]	training's rmse: 1.45929	valid_1's rmse: 1.5767
# [5400]	training's rmse: 1.4578	valid_1's rmse: 1.57664
# [5500]	training's rmse: 1.45628	valid_1's rmse: 1.57661
# [5600]	training's rmse: 1.45481	valid_1's rmse: 1.5766
# [5700]	training's rmse: 1.45335	valid_1's rmse: 1.57661
# [5800]	training's rmse: 1.45187	valid_1's rmse: 1.5766
# [5900]	training's rmse: 1.45035	valid_1's rmse: 1.57656
# [6000]	training's rmse: 1.44887	valid_1's rmse: 1.57651
# [6100]	training's rmse: 1.44739	valid_1's rmse: 1.57651
# [6200]	training's rmse: 1.44595	valid_1's rmse: 1.5765
# [6300]	training's rmse: 1.44454	valid_1's rmse: 1.5765
# [6400]	training's rmse: 1.4431	valid_1's rmse: 1.57648
# [6500]	training's rmse: 1.44166	valid_1's rmse: 1.57644
# [6600]	training's rmse: 1.44023	valid_1's rmse: 1.57643
# [6700]	training's rmse: 1.4388	valid_1's rmse: 1.57639
# [6800]	training's rmse: 1.43736	valid_1's rmse: 1.57642
# [6900]	training's rmse: 1.4359	valid_1's rmse: 1.57642
# [7000]	training's rmse: 1.43446	valid_1's rmse: 1.57644
# [7100]	training's rmse: 1.43306	valid_1's rmse: 1.5764
# Early stopping, best iteration is:
# [6730]	training's rmse: 1.43836	valid_1's rmse: 1.57637
# 1.556079755758205

# %%
df_prediction = pd.DataFrame({"prediction1":predictions, "prediction2":predictions2})
df_prediction
# Out:
#         prediction1  prediction2
# 0         -1.903309    -0.500614
# 1         -0.394759    -0.274650
# 2         -0.978352    -0.469376
# 3         -0.092802    -0.077154
# 4         -1.470412    -1.785485
# 5          0.094908     0.594691
# 6          0.040091     0.132220
# 7          0.531916     0.871726
# 8         -0.703896    -0.667052
# 9         -1.023165    -0.264384
# 10        -0.680976    -0.482119
# 11         0.002147     0.208232
# 12         0.001029     0.082074
# 13        -0.047424     0.185301
# 14        -6.990863    -0.277960
# 15         0.542802     0.640581
# 16         0.279930     0.524160
# 17        -0.216910    -0.122791
# 18         0.162364     0.203391
# 19         0.011843    -0.231516
# 20         0.115823     0.255620
# 21        -0.637414    -0.752866
# 22        -0.033690     1.283995
# 23         0.262007     0.290008
# 24        -0.749450     0.052610
# 25        -0.299430     0.472150
# 26        -0.786558    -0.762374
# 27        -0.443532    -0.420449
# 28        -0.166605    -0.062522
# 29        -0.415490    -0.484931
# ...             ...          ...
# 123593    -0.341908    -0.413026
# 123594    -1.147583    -1.183759
# 123595     0.046934    -0.021815
# 123596     0.731034     1.298726
# 123597    -0.575637    -0.465197
# 123598    -0.548902    -0.628474
# 123599     0.451546     0.422502
# 123600    -0.759217     0.010180
# 123601    -1.027695    -1.429900
# 123602    -0.387509    -0.259784
# 123603    -0.162022    -0.025209
# 123604     0.462684     0.682395
# 123605    -0.543738    -0.503439
# 123606    -0.552999    -0.344276
# 123607     0.580173     0.535297
# 123608    -0.421792    -0.514366
# 123609     0.227920    -0.060714
# 123610     0.256687     0.577552
# 123611    -1.408763    -1.048920
# 123612    -0.630824    -0.849915
# 123613     0.063386     0.059706
# 123614     0.365083     0.876717
# 123615    -0.750798    -0.609293
# 123616     0.839989     1.445539
# 123617     0.408057     0.613459
# 123618     0.924106     1.407483
# 123619    -0.376776    -0.450925
# 123620     0.967369     1.132937
# 123621    -3.050521    -0.864958
# 123622     0.081186     0.050978
#
# [123623 rows x 2 columns]

# %%
predictions3 = np.zeros(df_prediction.shape[0])
for i, r in df_prediction.iterrows():
    if r[0] < 0 :
        predictions3[i] = r[0]
    else:
        predictions3[i] = r[1]
df_prediction["prediction3"] = predictions3

# %%
df_prediction
# Out:
#         prediction1  prediction2  prediction3
# 0         -1.903309    -0.500614    -1.903309
# 1         -0.394759    -0.274650    -0.394759
# 2         -0.978352    -0.469376    -0.978352
# 3         -0.092802    -0.077154    -0.092802
# 4         -1.470412    -1.785485    -1.470412
# 5          0.094908     0.594691     0.594691
# 6          0.040091     0.132220     0.132220
# 7          0.531916     0.871726     0.871726
# 8         -0.703896    -0.667052    -0.703896
# 9         -1.023165    -0.264384    -1.023165
# 10        -0.680976    -0.482119    -0.680976
# 11         0.002147     0.208232     0.208232
# 12         0.001029     0.082074     0.082074
# 13        -0.047424     0.185301    -0.047424
# 14        -6.990863    -0.277960    -6.990863
# 15         0.542802     0.640581     0.640581
# 16         0.279930     0.524160     0.524160
# 17        -0.216910    -0.122791    -0.216910
# 18         0.162364     0.203391     0.203391
# 19         0.011843    -0.231516    -0.231516
# 20         0.115823     0.255620     0.255620
# 21        -0.637414    -0.752866    -0.637414
# 22        -0.033690     1.283995    -0.033690
# 23         0.262007     0.290008     0.290008
# 24        -0.749450     0.052610    -0.749450
# 25        -0.299430     0.472150    -0.299430
# 26        -0.786558    -0.762374    -0.786558
# 27        -0.443532    -0.420449    -0.443532
# 28        -0.166605    -0.062522    -0.166605
# 29        -0.415490    -0.484931    -0.415490
# ...             ...          ...          ...
# 123593    -0.341908    -0.413026    -0.341908
# 123594    -1.147583    -1.183759    -1.147583
# 123595     0.046934    -0.021815    -0.021815
# 123596     0.731034     1.298726     1.298726
# 123597    -0.575637    -0.465197    -0.575637
# 123598    -0.548902    -0.628474    -0.548902
# 123599     0.451546     0.422502     0.422502
# 123600    -0.759217     0.010180    -0.759217
# 123601    -1.027695    -1.429900    -1.027695
# 123602    -0.387509    -0.259784    -0.387509
# 123603    -0.162022    -0.025209    -0.162022
# 123604     0.462684     0.682395     0.682395
# 123605    -0.543738    -0.503439    -0.543738
# 123606    -0.552999    -0.344276    -0.552999
# 123607     0.580173     0.535297     0.535297
# 123608    -0.421792    -0.514366    -0.421792
# 123609     0.227920    -0.060714    -0.060714
# 123610     0.256687     0.577552     0.577552
# 123611    -1.408763    -1.048920    -1.408763
# 123612    -0.630824    -0.849915    -0.630824
# 123613     0.063386     0.059706     0.059706
# 123614     0.365083     0.876717     0.876717
# 123615    -0.750798    -0.609293    -0.750798
# 123616     0.839989     1.445539     1.445539
# 123617     0.408057     0.613459     0.613459
# 123618     0.924106     1.407483     1.407483
# 123619    -0.376776    -0.450925    -0.376776
# 123620     0.967369     1.132937     1.132937
# 123621    -3.050521    -0.864958    -3.050521
# 123622     0.081186     0.050978     0.050978
#
# [123623 rows x 3 columns]

# %%
final_predictions = df_prediction.prediction3.values

# %%
# import optuna

# def objective(trial):
#     train_x, test_x, train_y, test_y = train_test_split(df_train[df_train_columns], target, test_size=0.20, random_state=4590)
    
#     dtrain = lgb.Dataset(train_x, label=train_y)
#     dval = lgb.Dataset(test_x, label=test_y)

#     num_round = trial.suggest_int('num_round', 1, 10000)
#     param = {
#         'objective': 'regression', 
#         'metric': 'rmse',
#         'verbosity': -1,
#         'feature_fraction': trial.suggest_loguniform('feature_fraction', 0.8, 0.95),
#         'bagging_fraction': trial.suggest_loguniform('bagging_fraction', 0.8, 0.95),
#         'bagging_seed': 11,
#         'boosting_type': trial.suggest_categorical('boosting', ['gbdt', 'dart', 'goss']),
#         'num_leaves': trial.suggest_int('num_leaves', 10, 100),
#         'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
#         'min_child_samples': trial.suggest_int('min_child_samples', 20, 100),
#         'min_data_in_leaf':  trial.suggest_int('min_data_in_leaf', 10, 1000),
#         'lambda_l1':  trial.suggest_loguniform('lambda_l1', 1e-2, 1.0)
#     }

#     if param['boosting_type'] == 'dart':
#         param['drop_rate'] = trial.suggest_loguniform('drop_rate', 1e-4, 1.0)
#         param['skip_drop'] = trial.suggest_loguniform('skip_drop', 1e-4, 1.0)
#     if param['boosting_type'] == 'goss':
#         param['top_rate'] = trial.suggest_uniform('top_rate', 0.0, 1.0)
#         param['other_rate'] = trial.suggest_uniform('other_rate', 0.0, 1.0 - param['top_rate'])

#     gbm = lgb.train(param, dtrain, num_round, valid_sets = [dtrain, dval], verbose_eval=100, early_stopping_rounds=400)
#     preds = gbm.predict(test_x)
#     pred_labels = np.rint(preds)
#     rmse = np.sqrt(mean_squared_error(test_y, pred_labels))
#     return rmse

# study = optuna.create_study()
# study.optimize(objective, n_trials=20)

# print('Number of finished trials: {}'.format(len(study.trials)))

# print('Best trial:')
# trial = study.best_trial

# print('  Value: {}'.format(trial.value))

# print('  Params: ')
# for key, value in trial.params.items():
#     print('    {}: {}'.format(key, value))

# %%
sub_df = pd.DataFrame({"card_id":df_test["card_id"].values})
sub_df["target"] = final_predictions
sub_df.to_csv("../output/submission_model20181216.csv", index=False)
