# %%
import numpy as np
import pandas as pd
import datetime
from itertools import combinations

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import lightgbm as lgb

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error, roc_auc_score
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')
np.random.seed(4590)

# %%
df_train = pd.read_csv("../input/20181216_train.csv")
df_test = pd.read_csv("../input/20181216_test.csv")

# %%
def merge_new_feature(path):
    df_new_feature = pd.read_csv(path)
    
    df_tr = pd.merge(df_train, df_new_feature, on="card_id", how="left")
    df_te = pd.merge(df_test, df_new_feature, on="card_id", how="left")
    
    return df_tr, df_te

# %%
df_train, df_test = merge_new_feature("../input/merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/new_merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/prosperity_merchants_latest.csv")
df_train, df_test = merge_new_feature("../input/merchants_numerical_features.csv")
df_train, df_test = merge_new_feature("../input/merchants_item_scale_feature.csv")
df_train, df_test = merge_new_feature("../input/purchase_pattern.csv")
df_train, df_test = merge_new_feature("../input/purchase_pettern_nmf.csv")
df_train, df_test = merge_new_feature("../input/purchase_amount_pettern_nmf.csv")

# %%
df_train["Null_count"] = df_train.isnull().sum(axis=1)
df_test["Null_count"] = df_test.isnull().sum(axis=1)

# %%
dont_use = ['card_id', 'first_active_month','second_active_date','diff_first_and_second','target','outliers', 'category_1_Y_std']

df_train_columns = [c for c in df_train.columns if c not in dont_use]
target = df_train['target']
target_outlier = df_train["outliers"]

# %%
max_each_col = np.max(df_train[df_train_columns].values, axis=0)

for i, max_ in enumerate(max_each_col):
    if max_ >= 1e+7:
        df_train[df_train_columns[i]] = 1/(1+np.exp(-1*df_train[df_train_columns[i]].values))
        df_test[df_train_columns[i]] = 1/(1+np.exp(-1*df_test[df_train_columns[i]].values))

# %%
drop_col = []
comb = list(combinations(df_train_columns, 2))

for c1, c2 in comb:
    corr = np.corrcoef(df_train[c1], df_train[c2])[0,1]
    if corr >= 0.962:
        print("【{i}】 --- 【{j}】".format(i=c1, j=c2))
        print(corr)
        drop_col.append(c2)
        print("\n"*2)

for col in df_train_columns:
    if col in sorted(set(drop_col)):
        df_train_columns.remove(col)
# Out:
# 【hist_authorized_flag_sum】 --- 【hist_card_id_size】
# 0.9945716227736431
#
#
#
# 【hist_authorized_flag_sum】 --- 【sales_lag3_div_lag_6_sum】
# 0.991252479458827
#
#
#
# 【hist_authorized_flag_sum】 --- 【sales_lag6_div_lag_12_sum】
# 0.9903479752948366
#
#
#
# 【hist_authorized_flag_sum】 --- 【puchases_lag3_div_lag_6_sum】
# 0.9914139390387703
#
#
#
# 【hist_authorized_flag_sum】 --- 【puchases_lag6_div_lag_12_sum】
# 0.9903376928990004
#
#
#
# 【hist_card_id_size】 --- 【sales_lag3_div_lag_6_sum】
# 0.9975144605006232
#
#
#
# 【hist_card_id_size】 --- 【sales_lag6_div_lag_12_sum】
# 0.9968560102554356
#
#
#
# 【hist_card_id_size】 --- 【puchases_lag3_div_lag_6_sum】
# 0.9976116876313735
#
#
#
# 【hist_card_id_size】 --- 【puchases_lag6_div_lag_12_sum】
# 0.9967725640779598
#
#
#
# 【hist_purchase_date_diff】 --- 【purchase_term】
# 0.968714472679401
#
#
#
# 【new_hist_purchase_date_max】 --- 【new_hist_purchase_date_min】
# 1.0
#
#
#
# 【sales_lag3_div_lag_6_sum】 --- 【sales_lag6_div_lag_12_sum】
# 0.9987015197325084
#
#
#
# 【sales_lag3_div_lag_6_sum】 --- 【puchases_lag3_div_lag_6_sum】
# 0.9998921914972795
#
#
#
# 【sales_lag3_div_lag_6_sum】 --- 【puchases_lag6_div_lag_12_sum】
# 0.9987850314424875
#
#
#
# 【sales_lag6_div_lag_12_sum】 --- 【puchases_lag3_div_lag_6_sum】
# 0.9988416241421113
#
#
#
# 【sales_lag6_div_lag_12_sum】 --- 【puchases_lag6_div_lag_12_sum】
# 0.9998674828098879
#
#
#
# 【puchases_lag3_div_lag_6_sum】 --- 【puchases_lag6_div_lag_12_sum】
# 0.9989802996750587
#
#
#
# 【numerical_pca_sum】 --- 【relu_numerical_pca_sum】
# 0.9999961577696458
#
#
#
# 【numerical_pca_mean】 --- 【relu_numerical_pca_mean】
# 0.9998090700847282
#
#
#
# 【numerical_pca_max】 --- 【relu_numerical_pca_max】
# 0.9999999876840486
#
#
#
# 【numerical_pca_std】 --- 【relu_numerical_pca_std】
# 0.9999638722627805
#
#
#
# 【elapsed_second_absolute】 --- 【elapsed_third_absolute】
# 0.9802596766559624
#
#
#
# 【NMF_comp_purchase_1】 --- 【NMF_comp_purchase_amount_1】
# 0.9999987675761901
#
#
#
# 【NMF_comp_purchase_2】 --- 【NMF_comp_purchase_amount_2】
# 0.9999991679295573
#
#
#
# 【NMF_comp_purchase_3】 --- 【NMF_comp_purchase_amount_3】
# 0.9999986767198484
#
#
#
# 【NMF_comp_purchase_4】 --- 【NMF_comp_purchase_amount_4】
# 0.9999944363649549
#
#
#
# 【NMF_comp_purchase_5】 --- 【NMF_comp_purchase_amount_5】
# 0.999999529224202
#
#
#
# 【NMF_comp_purchase_6】 --- 【NMF_comp_purchase_amount_6】
# 0.9999984402303529
#
#
#
# 【NMF_comp_purchase_7】 --- 【NMF_comp_purchase_amount_7】
# 0.9999992824293512
#
#
#
# 【NMF_comp_purchase_8】 --- 【NMF_comp_purchase_amount_8】
# 0.9999992869433876
#
#
#
# 【NMF_comp_purchase_9】 --- 【NMF_comp_purchase_amount_9】
# 0.9999987836432321
#
#
#
# 【NMF_comp_purchase_10】 --- 【NMF_comp_purchase_amount_10】
# 0.9999978100737257

# %%
#original
param = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',
    'max_depth': -1,
    "max_bin": 256,  # なし
    'learning_rate': 0.004,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.73847	valid_1's rmse: 3.77453
# [200]	training's rmse: 3.66994	valid_1's rmse: 3.73316
# [300]	training's rmse: 3.62224	valid_1's rmse: 3.70993
# [400]	training's rmse: 3.58576	valid_1's rmse: 3.6952
# [500]	training's rmse: 3.55673	valid_1's rmse: 3.68428
# [600]	training's rmse: 3.53198	valid_1's rmse: 3.67609
# [700]	training's rmse: 3.51182	valid_1's rmse: 3.67098
# [800]	training's rmse: 3.49365	valid_1's rmse: 3.66749
# [900]	training's rmse: 3.47781	valid_1's rmse: 3.66429
# [1000]	training's rmse: 3.46232	valid_1's rmse: 3.66131
# [1100]	training's rmse: 3.44853	valid_1's rmse: 3.65906
# [1200]	training's rmse: 3.43535	valid_1's rmse: 3.65699
# [1300]	training's rmse: 3.42332	valid_1's rmse: 3.65509
# [1400]	training's rmse: 3.41147	valid_1's rmse: 3.65354
# [1500]	training's rmse: 3.39992	valid_1's rmse: 3.65195
# [1600]	training's rmse: 3.38924	valid_1's rmse: 3.65069
# [1700]	training's rmse: 3.37891	valid_1's rmse: 3.64982
# [1800]	training's rmse: 3.36889	valid_1's rmse: 3.6489
# [1900]	training's rmse: 3.35956	valid_1's rmse: 3.64852
# [2000]	training's rmse: 3.35055	valid_1's rmse: 3.64792
# [2100]	training's rmse: 3.34137	valid_1's rmse: 3.64753
# [2200]	training's rmse: 3.333	valid_1's rmse: 3.6468
# [2300]	training's rmse: 3.32439	valid_1's rmse: 3.64639
# [2400]	training's rmse: 3.31622	valid_1's rmse: 3.64611
# [2500]	training's rmse: 3.30783	valid_1's rmse: 3.64579
# [2600]	training's rmse: 3.3001	valid_1's rmse: 3.6454
# [2700]	training's rmse: 3.29204	valid_1's rmse: 3.64493
# [2800]	training's rmse: 3.28462	valid_1's rmse: 3.64473
# [2900]	training's rmse: 3.27711	valid_1's rmse: 3.64444
# [3000]	training's rmse: 3.2698	valid_1's rmse: 3.64404
# [3100]	training's rmse: 3.26222	valid_1's rmse: 3.64387
# [3200]	training's rmse: 3.25513	valid_1's rmse: 3.64357
# [3300]	training's rmse: 3.24805	valid_1's rmse: 3.64335
# [3400]	training's rmse: 3.24123	valid_1's rmse: 3.64316
# [3500]	training's rmse: 3.23454	valid_1's rmse: 3.64302
# [3600]	training's rmse: 3.22792	valid_1's rmse: 3.6429
# [3700]	training's rmse: 3.22124	valid_1's rmse: 3.6427
# [3800]	training's rmse: 3.21476	valid_1's rmse: 3.64255
# [3900]	training's rmse: 3.20772	valid_1's rmse: 3.64229
# [4000]	training's rmse: 3.20165	valid_1's rmse: 3.6421
# [4100]	training's rmse: 3.19517	valid_1's rmse: 3.64199
# [4200]	training's rmse: 3.1888	valid_1's rmse: 3.64201
# [4300]	training's rmse: 3.18229	valid_1's rmse: 3.64201
# [4400]	training's rmse: 3.17616	valid_1's rmse: 3.64199
# [4500]	training's rmse: 3.1697	valid_1's rmse: 3.64197
# [4600]	training's rmse: 3.1633	valid_1's rmse: 3.64159
# [4700]	training's rmse: 3.15769	valid_1's rmse: 3.64152
# [4800]	training's rmse: 3.15162	valid_1's rmse: 3.64152
# [4900]	training's rmse: 3.14571	valid_1's rmse: 3.64162
# [5000]	training's rmse: 3.13969	valid_1's rmse: 3.64161
# [5100]	training's rmse: 3.13373	valid_1's rmse: 3.64129
# [5200]	training's rmse: 3.1279	valid_1's rmse: 3.64115
# [5300]	training's rmse: 3.12221	valid_1's rmse: 3.64118
# [5400]	training's rmse: 3.11664	valid_1's rmse: 3.64115
# [5500]	training's rmse: 3.11098	valid_1's rmse: 3.64113
# [5600]	training's rmse: 3.10534	valid_1's rmse: 3.64112
# [5700]	training's rmse: 3.09981	valid_1's rmse: 3.64103
# [5800]	training's rmse: 3.0936	valid_1's rmse: 3.64105
# [5900]	training's rmse: 3.08803	valid_1's rmse: 3.64123
# [6000]	training's rmse: 3.08241	valid_1's rmse: 3.6412
# [6100]	training's rmse: 3.07693	valid_1's rmse: 3.64125
# Early stopping, best iteration is:
# [5712]	training's rmse: 3.09912	valid_1's rmse: 3.64101
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74297	valid_1's rmse: 3.76139
# [200]	training's rmse: 3.67436	valid_1's rmse: 3.71611
# [300]	training's rmse: 3.62557	valid_1's rmse: 3.69077
# [400]	training's rmse: 3.58837	valid_1's rmse: 3.6754
# [500]	training's rmse: 3.55887	valid_1's rmse: 3.66594
# [600]	training's rmse: 3.53487	valid_1's rmse: 3.65906
# [700]	training's rmse: 3.51448	valid_1's rmse: 3.65343
# [800]	training's rmse: 3.49587	valid_1's rmse: 3.64984
# [900]	training's rmse: 3.48002	valid_1's rmse: 3.64669
# [1000]	training's rmse: 3.46476	valid_1's rmse: 3.64425
# [1100]	training's rmse: 3.45061	valid_1's rmse: 3.64238
# [1200]	training's rmse: 3.43782	valid_1's rmse: 3.64059
# [1300]	training's rmse: 3.4248	valid_1's rmse: 3.63929
# [1400]	training's rmse: 3.41272	valid_1's rmse: 3.63826
# [1500]	training's rmse: 3.4014	valid_1's rmse: 3.63744
# [1600]	training's rmse: 3.39004	valid_1's rmse: 3.63645
# [1700]	training's rmse: 3.37907	valid_1's rmse: 3.63589
# [1800]	training's rmse: 3.3689	valid_1's rmse: 3.63522
# [1900]	training's rmse: 3.35883	valid_1's rmse: 3.63496
# [2000]	training's rmse: 3.34928	valid_1's rmse: 3.63463
# [2100]	training's rmse: 3.34	valid_1's rmse: 3.63448
# [2200]	training's rmse: 3.33094	valid_1's rmse: 3.63419
# [2300]	training's rmse: 3.32223	valid_1's rmse: 3.63393
# [2400]	training's rmse: 3.31376	valid_1's rmse: 3.63385
# [2500]	training's rmse: 3.30507	valid_1's rmse: 3.63397
# [2600]	training's rmse: 3.29668	valid_1's rmse: 3.6341
# [2700]	training's rmse: 3.28874	valid_1's rmse: 3.6342
# Early stopping, best iteration is:
# [2348]	training's rmse: 3.31815	valid_1's rmse: 3.63378
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74434	valid_1's rmse: 3.7591
# [200]	training's rmse: 3.67662	valid_1's rmse: 3.71152
# [300]	training's rmse: 3.62886	valid_1's rmse: 3.68491
# [400]	training's rmse: 3.5919	valid_1's rmse: 3.66885
# [500]	training's rmse: 3.56251	valid_1's rmse: 3.65808
# [600]	training's rmse: 3.539	valid_1's rmse: 3.65135
# [700]	training's rmse: 3.5182	valid_1's rmse: 3.64562
# [800]	training's rmse: 3.4996	valid_1's rmse: 3.64147
# [900]	training's rmse: 3.48316	valid_1's rmse: 3.63783
# [1000]	training's rmse: 3.46758	valid_1's rmse: 3.63488
# [1100]	training's rmse: 3.45359	valid_1's rmse: 3.63239
# [1200]	training's rmse: 3.44067	valid_1's rmse: 3.63067
# [1300]	training's rmse: 3.42788	valid_1's rmse: 3.62921
# [1400]	training's rmse: 3.41659	valid_1's rmse: 3.62805
# [1500]	training's rmse: 3.40578	valid_1's rmse: 3.62674
# [1600]	training's rmse: 3.39476	valid_1's rmse: 3.62582
# [1700]	training's rmse: 3.38423	valid_1's rmse: 3.62487
# [1800]	training's rmse: 3.37379	valid_1's rmse: 3.62447
# [1900]	training's rmse: 3.36451	valid_1's rmse: 3.624
# [2000]	training's rmse: 3.35562	valid_1's rmse: 3.62352
# [2100]	training's rmse: 3.34625	valid_1's rmse: 3.62316
# [2200]	training's rmse: 3.33758	valid_1's rmse: 3.62282
# [2300]	training's rmse: 3.3291	valid_1's rmse: 3.62245
# [2400]	training's rmse: 3.3204	valid_1's rmse: 3.62222
# [2500]	training's rmse: 3.31238	valid_1's rmse: 3.62217
# [2600]	training's rmse: 3.30451	valid_1's rmse: 3.622
# [2700]	training's rmse: 3.29673	valid_1's rmse: 3.62169
# [2800]	training's rmse: 3.28868	valid_1's rmse: 3.62175
# [2900]	training's rmse: 3.28124	valid_1's rmse: 3.6217
# [3000]	training's rmse: 3.27375	valid_1's rmse: 3.6217
# [3100]	training's rmse: 3.26634	valid_1's rmse: 3.62154
# [3200]	training's rmse: 3.25889	valid_1's rmse: 3.62148
# [3300]	training's rmse: 3.25198	valid_1's rmse: 3.62126
# [3400]	training's rmse: 3.24463	valid_1's rmse: 3.62116
# [3500]	training's rmse: 3.23751	valid_1's rmse: 3.62122
# [3600]	training's rmse: 3.23077	valid_1's rmse: 3.62125
# [3700]	training's rmse: 3.22419	valid_1's rmse: 3.62102
# [3800]	training's rmse: 3.21755	valid_1's rmse: 3.62103
# [3900]	training's rmse: 3.21067	valid_1's rmse: 3.62089
# [4000]	training's rmse: 3.20462	valid_1's rmse: 3.62083
# [4100]	training's rmse: 3.19807	valid_1's rmse: 3.62093
# [4200]	training's rmse: 3.19214	valid_1's rmse: 3.62102
# [4300]	training's rmse: 3.18574	valid_1's rmse: 3.62106
# [4400]	training's rmse: 3.17963	valid_1's rmse: 3.62112
# Early stopping, best iteration is:
# [4009]	training's rmse: 3.20407	valid_1's rmse: 3.62081
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.7395	valid_1's rmse: 3.76913
# [200]	training's rmse: 3.66906	valid_1's rmse: 3.72879
# [300]	training's rmse: 3.61937	valid_1's rmse: 3.70788
# [400]	training's rmse: 3.58123	valid_1's rmse: 3.69577
# [500]	training's rmse: 3.55095	valid_1's rmse: 3.68841
# [600]	training's rmse: 3.52638	valid_1's rmse: 3.68355
# [700]	training's rmse: 3.50614	valid_1's rmse: 3.68
# [800]	training's rmse: 3.48769	valid_1's rmse: 3.67757
# [900]	training's rmse: 3.47044	valid_1's rmse: 3.67547
# [1000]	training's rmse: 3.45448	valid_1's rmse: 3.6737
# [1100]	training's rmse: 3.43959	valid_1's rmse: 3.67262
# [1200]	training's rmse: 3.42556	valid_1's rmse: 3.67159
# [1300]	training's rmse: 3.41253	valid_1's rmse: 3.67073
# [1400]	training's rmse: 3.40033	valid_1's rmse: 3.66995
# [1500]	training's rmse: 3.38904	valid_1's rmse: 3.6695
# [1600]	training's rmse: 3.37797	valid_1's rmse: 3.66894
# [1700]	training's rmse: 3.36734	valid_1's rmse: 3.66836
# [1800]	training's rmse: 3.35704	valid_1's rmse: 3.66793
# [1900]	training's rmse: 3.34736	valid_1's rmse: 3.66747
# [2000]	training's rmse: 3.33733	valid_1's rmse: 3.66717
# [2100]	training's rmse: 3.32824	valid_1's rmse: 3.66657
# [2200]	training's rmse: 3.31923	valid_1's rmse: 3.66642
# [2300]	training's rmse: 3.31068	valid_1's rmse: 3.66599
# [2400]	training's rmse: 3.30191	valid_1's rmse: 3.66587
# [2500]	training's rmse: 3.29294	valid_1's rmse: 3.66588
# [2600]	training's rmse: 3.28458	valid_1's rmse: 3.66585
# [2700]	training's rmse: 3.27647	valid_1's rmse: 3.66584
# [2800]	training's rmse: 3.2681	valid_1's rmse: 3.6656
# [2900]	training's rmse: 3.26046	valid_1's rmse: 3.66548
# [3000]	training's rmse: 3.25298	valid_1's rmse: 3.66544
# [3100]	training's rmse: 3.24516	valid_1's rmse: 3.66546
# [3200]	training's rmse: 3.23763	valid_1's rmse: 3.66544
# [3300]	training's rmse: 3.23086	valid_1's rmse: 3.66546
# [3400]	training's rmse: 3.22385	valid_1's rmse: 3.6654
# Early stopping, best iteration is:
# [3064]	training's rmse: 3.24808	valid_1's rmse: 3.66531
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.73787	valid_1's rmse: 3.77782
# [200]	training's rmse: 3.66792	valid_1's rmse: 3.73694
# [300]	training's rmse: 3.6191	valid_1's rmse: 3.71413
# [400]	training's rmse: 3.58118	valid_1's rmse: 3.7013
# [500]	training's rmse: 3.55155	valid_1's rmse: 3.69339
# [600]	training's rmse: 3.52699	valid_1's rmse: 3.68791
# [700]	training's rmse: 3.50574	valid_1's rmse: 3.68362
# [800]	training's rmse: 3.48705	valid_1's rmse: 3.6803
# [900]	training's rmse: 3.47007	valid_1's rmse: 3.67791
# [1000]	training's rmse: 3.45447	valid_1's rmse: 3.67607
# [1100]	training's rmse: 3.44023	valid_1's rmse: 3.67469
# [1200]	training's rmse: 3.42662	valid_1's rmse: 3.67338
# [1300]	training's rmse: 3.41397	valid_1's rmse: 3.67239
# [1400]	training's rmse: 3.40173	valid_1's rmse: 3.67136
# [1500]	training's rmse: 3.39075	valid_1's rmse: 3.6704
# [1600]	training's rmse: 3.3799	valid_1's rmse: 3.6698
# [1700]	training's rmse: 3.36915	valid_1's rmse: 3.66921
# [1800]	training's rmse: 3.35905	valid_1's rmse: 3.6688
# [1900]	training's rmse: 3.3495	valid_1's rmse: 3.66853
# [2000]	training's rmse: 3.33946	valid_1's rmse: 3.66821
# [2100]	training's rmse: 3.33007	valid_1's rmse: 3.66786
# [2200]	training's rmse: 3.32125	valid_1's rmse: 3.6676
# [2300]	training's rmse: 3.3125	valid_1's rmse: 3.6676
# [2400]	training's rmse: 3.30412	valid_1's rmse: 3.66758
# [2500]	training's rmse: 3.29635	valid_1's rmse: 3.66741
# [2600]	training's rmse: 3.28806	valid_1's rmse: 3.66738
# [2700]	training's rmse: 3.28058	valid_1's rmse: 3.66735
# [2800]	training's rmse: 3.27297	valid_1's rmse: 3.66737
# [2900]	training's rmse: 3.26481	valid_1's rmse: 3.6671
# [3000]	training's rmse: 3.25759	valid_1's rmse: 3.667
# [3100]	training's rmse: 3.25056	valid_1's rmse: 3.66708
# [3200]	training's rmse: 3.24326	valid_1's rmse: 3.66705
# [3300]	training's rmse: 3.23599	valid_1's rmse: 3.66726
# Early stopping, best iteration is:
# [2988]	training's rmse: 3.25839	valid_1's rmse: 3.66697
# 3.6456196720191207

# %%
# score:  3.6467757129353053

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,50))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
# plt.savefig('lgbm_importances.png')

# %%
df_train2 = df_train[df_train.target >= -20].reset_index(drop=True)
target2 = df_train2["target"]

#original
param2 = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',
    'max_depth': -1,
    'learning_rate': 0.01,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train2))
predictions2 = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train2,df_train2['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train2.iloc[trn_idx][df_train_columns], label=target2.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train2.iloc[val_idx][df_train_columns], label=target2.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param2, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train2.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions2 += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target2))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60727	valid_1's rmse: 1.60689
# [200]	training's rmse: 1.57575	valid_1's rmse: 1.57857
# [300]	training's rmse: 1.56039	valid_1's rmse: 1.56744
# [400]	training's rmse: 1.54989	valid_1's rmse: 1.56171
# [500]	training's rmse: 1.54159	valid_1's rmse: 1.55818
# [600]	training's rmse: 1.53447	valid_1's rmse: 1.55606
# [700]	training's rmse: 1.52819	valid_1's rmse: 1.55458
# [800]	training's rmse: 1.5225	valid_1's rmse: 1.55367
# [900]	training's rmse: 1.51732	valid_1's rmse: 1.55311
# [1000]	training's rmse: 1.51238	valid_1's rmse: 1.55262
# [1100]	training's rmse: 1.50767	valid_1's rmse: 1.55238
# [1200]	training's rmse: 1.50313	valid_1's rmse: 1.55218
# [1300]	training's rmse: 1.4987	valid_1's rmse: 1.55196
# [1400]	training's rmse: 1.49444	valid_1's rmse: 1.55178
# [1500]	training's rmse: 1.49037	valid_1's rmse: 1.55158
# [1600]	training's rmse: 1.48626	valid_1's rmse: 1.55148
# [1700]	training's rmse: 1.48225	valid_1's rmse: 1.55138
# [1800]	training's rmse: 1.4783	valid_1's rmse: 1.55137
# [1900]	training's rmse: 1.47454	valid_1's rmse: 1.5512
# [2000]	training's rmse: 1.4706	valid_1's rmse: 1.55114
# [2100]	training's rmse: 1.4668	valid_1's rmse: 1.55114
# [2200]	training's rmse: 1.4631	valid_1's rmse: 1.55119
# [2300]	training's rmse: 1.45955	valid_1's rmse: 1.55125
# [2400]	training's rmse: 1.45593	valid_1's rmse: 1.55125
# Early stopping, best iteration is:
# [2035]	training's rmse: 1.46922	valid_1's rmse: 1.5511
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.6097	valid_1's rmse: 1.59409
# [200]	training's rmse: 1.57802	valid_1's rmse: 1.56874
# [300]	training's rmse: 1.56264	valid_1's rmse: 1.55898
# [400]	training's rmse: 1.55222	valid_1's rmse: 1.55343
# [500]	training's rmse: 1.54395	valid_1's rmse: 1.55
# [600]	training's rmse: 1.53678	valid_1's rmse: 1.54786
# [700]	training's rmse: 1.53045	valid_1's rmse: 1.54638
# [800]	training's rmse: 1.52481	valid_1's rmse: 1.54548
# [900]	training's rmse: 1.51954	valid_1's rmse: 1.5449
# [1000]	training's rmse: 1.51444	valid_1's rmse: 1.54437
# [1100]	training's rmse: 1.50972	valid_1's rmse: 1.54401
# [1200]	training's rmse: 1.50526	valid_1's rmse: 1.5438
# [1300]	training's rmse: 1.50077	valid_1's rmse: 1.54367
# [1400]	training's rmse: 1.49641	valid_1's rmse: 1.54336
# [1500]	training's rmse: 1.49229	valid_1's rmse: 1.54308
# [1600]	training's rmse: 1.48816	valid_1's rmse: 1.54294
# [1700]	training's rmse: 1.4841	valid_1's rmse: 1.54287
# [1800]	training's rmse: 1.47995	valid_1's rmse: 1.54273
# [1900]	training's rmse: 1.47603	valid_1's rmse: 1.54261
# [2000]	training's rmse: 1.47219	valid_1's rmse: 1.54249
# [2100]	training's rmse: 1.46828	valid_1's rmse: 1.54242
# [2200]	training's rmse: 1.46455	valid_1's rmse: 1.54234
# [2300]	training's rmse: 1.4608	valid_1's rmse: 1.54224
# [2400]	training's rmse: 1.4571	valid_1's rmse: 1.54223
# [2500]	training's rmse: 1.45349	valid_1's rmse: 1.54219
# [2600]	training's rmse: 1.44986	valid_1's rmse: 1.54213
# [2700]	training's rmse: 1.44626	valid_1's rmse: 1.54211
# [2800]	training's rmse: 1.44274	valid_1's rmse: 1.54212
# [2900]	training's rmse: 1.43912	valid_1's rmse: 1.54203
# [3000]	training's rmse: 1.43569	valid_1's rmse: 1.54202
# [3100]	training's rmse: 1.43214	valid_1's rmse: 1.54199
# [3200]	training's rmse: 1.42872	valid_1's rmse: 1.54199
# [3300]	training's rmse: 1.42537	valid_1's rmse: 1.54194
# [3400]	training's rmse: 1.42192	valid_1's rmse: 1.54196
# [3500]	training's rmse: 1.41848	valid_1's rmse: 1.54194
# [3600]	training's rmse: 1.41511	valid_1's rmse: 1.54196
# [3700]	training's rmse: 1.41178	valid_1's rmse: 1.54194
# [3800]	training's rmse: 1.40848	valid_1's rmse: 1.54197
# [3900]	training's rmse: 1.40513	valid_1's rmse: 1.54195
# [4000]	training's rmse: 1.40187	valid_1's rmse: 1.54193
# Early stopping, best iteration is:
# [3680]	training's rmse: 1.4125	valid_1's rmse: 1.5419
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60615	valid_1's rmse: 1.61113
# [200]	training's rmse: 1.57478	valid_1's rmse: 1.58405
# [300]	training's rmse: 1.55944	valid_1's rmse: 1.57337
# [400]	training's rmse: 1.54899	valid_1's rmse: 1.56759
# [500]	training's rmse: 1.54075	valid_1's rmse: 1.56421
# [600]	training's rmse: 1.53362	valid_1's rmse: 1.56197
# [700]	training's rmse: 1.52736	valid_1's rmse: 1.56035
# [800]	training's rmse: 1.52178	valid_1's rmse: 1.55938
# [900]	training's rmse: 1.5165	valid_1's rmse: 1.55873
# [1000]	training's rmse: 1.51155	valid_1's rmse: 1.55825
# [1100]	training's rmse: 1.5069	valid_1's rmse: 1.55792
# [1200]	training's rmse: 1.50238	valid_1's rmse: 1.55756
# [1300]	training's rmse: 1.49795	valid_1's rmse: 1.55726
# [1400]	training's rmse: 1.49364	valid_1's rmse: 1.55707
# [1500]	training's rmse: 1.48939	valid_1's rmse: 1.55681
# [1600]	training's rmse: 1.48524	valid_1's rmse: 1.55666
# [1700]	training's rmse: 1.48124	valid_1's rmse: 1.55649
# [1800]	training's rmse: 1.47728	valid_1's rmse: 1.55647
# [1900]	training's rmse: 1.4733	valid_1's rmse: 1.5564
# [2000]	training's rmse: 1.46946	valid_1's rmse: 1.55639
# [2100]	training's rmse: 1.46561	valid_1's rmse: 1.55642
# [2200]	training's rmse: 1.46198	valid_1's rmse: 1.55635
# [2300]	training's rmse: 1.45814	valid_1's rmse: 1.55637
# [2400]	training's rmse: 1.45446	valid_1's rmse: 1.5564
# [2500]	training's rmse: 1.45073	valid_1's rmse: 1.55649
# [2600]	training's rmse: 1.44719	valid_1's rmse: 1.55634
# [2700]	training's rmse: 1.44358	valid_1's rmse: 1.55629
# [2800]	training's rmse: 1.44003	valid_1's rmse: 1.55628
# [2900]	training's rmse: 1.4366	valid_1's rmse: 1.55626
# [3000]	training's rmse: 1.43311	valid_1's rmse: 1.55633
# [3100]	training's rmse: 1.42958	valid_1's rmse: 1.55636
# [3200]	training's rmse: 1.42608	valid_1's rmse: 1.55637
# Early stopping, best iteration is:
# [2834]	training's rmse: 1.43883	valid_1's rmse: 1.55624
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60642	valid_1's rmse: 1.61028
# [200]	training's rmse: 1.57503	valid_1's rmse: 1.58416
# [300]	training's rmse: 1.55964	valid_1's rmse: 1.5738
# [400]	training's rmse: 1.5493	valid_1's rmse: 1.56849
# [500]	training's rmse: 1.54082	valid_1's rmse: 1.56486
# [600]	training's rmse: 1.53365	valid_1's rmse: 1.56258
# [700]	training's rmse: 1.52729	valid_1's rmse: 1.5611
# [800]	training's rmse: 1.52152	valid_1's rmse: 1.55999
# [900]	training's rmse: 1.51623	valid_1's rmse: 1.55927
# [1000]	training's rmse: 1.51135	valid_1's rmse: 1.55879
# [1100]	training's rmse: 1.5066	valid_1's rmse: 1.55839
# [1200]	training's rmse: 1.50203	valid_1's rmse: 1.55811
# [1300]	training's rmse: 1.49762	valid_1's rmse: 1.55784
# [1400]	training's rmse: 1.49325	valid_1's rmse: 1.55764
# [1500]	training's rmse: 1.48906	valid_1's rmse: 1.55745
# [1600]	training's rmse: 1.48496	valid_1's rmse: 1.55734
# [1700]	training's rmse: 1.48086	valid_1's rmse: 1.55723
# [1800]	training's rmse: 1.47695	valid_1's rmse: 1.55704
# [1900]	training's rmse: 1.473	valid_1's rmse: 1.55694
# [2000]	training's rmse: 1.46912	valid_1's rmse: 1.55682
# [2100]	training's rmse: 1.46532	valid_1's rmse: 1.55673
# [2200]	training's rmse: 1.46159	valid_1's rmse: 1.55674
# [2300]	training's rmse: 1.45789	valid_1's rmse: 1.55667
# [2400]	training's rmse: 1.45412	valid_1's rmse: 1.55656
# [2500]	training's rmse: 1.45045	valid_1's rmse: 1.55651
# [2600]	training's rmse: 1.44683	valid_1's rmse: 1.55643
# [2700]	training's rmse: 1.44332	valid_1's rmse: 1.55636
# [2800]	training's rmse: 1.43973	valid_1's rmse: 1.55632
# [2900]	training's rmse: 1.43629	valid_1's rmse: 1.55628
# [3000]	training's rmse: 1.43283	valid_1's rmse: 1.55631
# [3100]	training's rmse: 1.42944	valid_1's rmse: 1.55637
# [3200]	training's rmse: 1.42595	valid_1's rmse: 1.55643
# [3300]	training's rmse: 1.42246	valid_1's rmse: 1.5565
# Early stopping, best iteration is:
# [2929]	training's rmse: 1.43531	valid_1's rmse: 1.55626
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60137	valid_1's rmse: 1.63154
# [200]	training's rmse: 1.5699	valid_1's rmse: 1.60444
# [300]	training's rmse: 1.55469	valid_1's rmse: 1.59376
# [400]	training's rmse: 1.54424	valid_1's rmse: 1.58808
# [500]	training's rmse: 1.53592	valid_1's rmse: 1.58465
# [600]	training's rmse: 1.52874	valid_1's rmse: 1.58235
# [700]	training's rmse: 1.52251	valid_1's rmse: 1.58103
# [800]	training's rmse: 1.51696	valid_1's rmse: 1.58012
# [900]	training's rmse: 1.51163	valid_1's rmse: 1.57946
# [1000]	training's rmse: 1.50671	valid_1's rmse: 1.57911
# [1100]	training's rmse: 1.50196	valid_1's rmse: 1.57874
# [1200]	training's rmse: 1.49738	valid_1's rmse: 1.57848
# [1300]	training's rmse: 1.49299	valid_1's rmse: 1.57827
# [1400]	training's rmse: 1.48872	valid_1's rmse: 1.57807
# [1500]	training's rmse: 1.48455	valid_1's rmse: 1.57787
# [1600]	training's rmse: 1.48049	valid_1's rmse: 1.57771
# [1700]	training's rmse: 1.47652	valid_1's rmse: 1.57766
# [1800]	training's rmse: 1.47256	valid_1's rmse: 1.57755
# [1900]	training's rmse: 1.4687	valid_1's rmse: 1.57749
# [2000]	training's rmse: 1.46492	valid_1's rmse: 1.57746
# [2100]	training's rmse: 1.46106	valid_1's rmse: 1.57744
# [2200]	training's rmse: 1.45728	valid_1's rmse: 1.57738
# [2300]	training's rmse: 1.45355	valid_1's rmse: 1.5773
# [2400]	training's rmse: 1.44988	valid_1's rmse: 1.57733
# [2500]	training's rmse: 1.44624	valid_1's rmse: 1.57732
# [2600]	training's rmse: 1.44253	valid_1's rmse: 1.57726
# [2700]	training's rmse: 1.43889	valid_1's rmse: 1.57733
# [2800]	training's rmse: 1.43531	valid_1's rmse: 1.57731
# [2900]	training's rmse: 1.43188	valid_1's rmse: 1.57728
# [3000]	training's rmse: 1.42824	valid_1's rmse: 1.5772
# [3100]	training's rmse: 1.42476	valid_1's rmse: 1.57721
# [3200]	training's rmse: 1.42139	valid_1's rmse: 1.57722
# [3300]	training's rmse: 1.41793	valid_1's rmse: 1.5773
# [3400]	training's rmse: 1.41448	valid_1's rmse: 1.57732
# [3500]	training's rmse: 1.41106	valid_1's rmse: 1.5773
# Early stopping, best iteration is:
# [3136]	training's rmse: 1.42346	valid_1's rmse: 1.57718
# 1.5565789160529584

# %%
df_prediction = pd.DataFrame({"prediction1":predictions, "prediction2":predictions2})
df_prediction
# Out:
#         prediction1  prediction2
# 0         -1.845651    -0.505787
# 1         -0.232908    -0.283133
# 2         -0.937265    -0.441285
# 3         -0.100835    -0.060787
# 4         -1.483554    -1.762624
# 5          0.065667     0.621240
# 6          0.058578     0.141981
# 7          0.505436     0.849410
# 8         -0.577394    -0.624598
# 9         -0.923049    -0.139594
# 10        -0.670579    -0.436475
# 11         0.024625     0.246777
# 12        -0.000365     0.095255
# 13        -0.007233     0.185891
# 14        -7.096693    -0.399772
# 15         0.546526     0.669082
# 16         0.289117     0.526204
# 17        -0.224558    -0.118556
# 18         0.160432     0.213252
# 19        -0.056167    -0.257673
# 20         0.103782     0.187890
# 21        -0.636417    -0.742700
# 22        -0.021400     1.175425
# 23         0.260275     0.299899
# 24        -0.592442     0.123542
# 25        -0.308861     0.459098
# 26        -0.610291    -0.744706
# 27        -0.445947    -0.433950
# 28        -0.210248    -0.118833
# 29        -0.397990    -0.487301
# ...             ...          ...
# 123593    -0.347033    -0.387564
# 123594    -1.215211    -1.177907
# 123595    -0.000551    -0.034633
# 123596     0.664994     1.215789
# 123597    -0.516253    -0.486156
# 123598    -0.533596    -0.620872
# 123599     0.449305     0.421248
# 123600    -0.795111    -0.012680
# 123601    -0.985937    -1.441150
# 123602    -0.374510    -0.220095
# 123603    -0.112244    -0.019117
# 123604     0.445109     0.679981
# 123605    -0.555662    -0.436565
# 123606    -0.461226    -0.302155
# 123607     0.574904     0.549804
# 123608    -0.419882    -0.498497
# 123609     0.254099    -0.045170
# 123610     0.226911     0.520675
# 123611    -1.393879    -1.047563
# 123612    -0.661106    -0.823382
# 123613     0.019579     0.057538
# 123614     0.389792     0.846818
# 123615    -0.745549    -0.546557
# 123616     0.911865     1.485287
# 123617     0.390064     0.627118
# 123618     0.919266     1.389071
# 123619    -0.464509    -0.462740
# 123620     0.933849     1.130207
# 123621    -3.024169    -0.854203
# 123622     0.132569     0.080549
#
# [123623 rows x 2 columns]

# %%
predictions3 = np.zeros(df_prediction.shape[0])
for i, r in df_prediction.iterrows():
    if r[0] < 0 :
        predictions3[i] = r[0]
    else:
        predictions3[i] = r[1]
df_prediction["prediction3"] = predictions3

# %%
final_predictions = df_prediction.prediction3.values

# %%
sub_df = pd.DataFrame({"card_id":df_test["card_id"].values})
sub_df["target"] = final_predictions
sub_df.to_csv("../output/submission_model20181216_20190118.csv", index=False)
