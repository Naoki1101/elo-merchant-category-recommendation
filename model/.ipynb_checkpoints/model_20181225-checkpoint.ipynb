# %%
import numpy as np
import pandas as pd
import datetime
import gc

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import lightgbm as lgb

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error, roc_auc_score
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')
np.random.seed(4590)
# Out:
# /Users/naoki/.pyenv/versions/3.6.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/naoki/.pyenv/versions/3.6.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/naoki/.pyenv/versions/3.6.6/lib/python3.6/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.1) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
df_train = pd.read_csv('../input/train.csv')
df_test = pd.read_csv('../input/test.csv')
df_hist_trans = pd.read_csv('../input/historical_transactions.csv')
df_new_merchant_trans = pd.read_csv('../input/new_merchant_transactions.csv')

# %%
df_hist_trans['purchase_amount'] = np.exp(df_hist_trans['purchase_amount'])
df_new_merchant_trans['purchase_amount'] = np.exp(df_new_merchant_trans['purchase_amount'])

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['category_2'].fillna(1.0,inplace=True)
    df['category_3'].fillna('A',inplace=True)
    df['merchant_id'].fillna('M_ID_00a6ca8a8a',inplace=True)

# %%
def get_new_columns(name,aggs):
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    df['year'] = df['purchase_date'].dt.year
    df['weekofyear'] = df['purchase_date'].dt.weekofyear
    df['month'] = df['purchase_date'].dt.month
    df['dayofweek'] = df['purchase_date'].dt.dayofweek
    df['weekend'] = (df.purchase_date.dt.weekday >=5).astype(int)
    df['hour'] = df['purchase_date'].dt.hour
    df['authorized_flag'] = df['authorized_flag'].map({'Y':1, 'N':0})
    df['category_1'] = df['category_1'].map({'Y':1, 'N':0}) 
    #https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/73244
    df['month_diff'] = ((datetime.datetime.today() - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']

aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['authorized_flag'] = ['sum', 'mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_hist_trans[col+'_mean'] = df_hist_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']    

new_columns = get_new_columns('hist',aggs)
df_hist_trans_group = df_hist_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['hist_purchase_date_diff'] = (df_hist_trans_group['hist_purchase_date_max'] - df_hist_trans_group['hist_purchase_date_min']).dt.days
df_hist_trans_group['hist_purchase_date_average'] = df_hist_trans_group['hist_purchase_date_diff']/df_hist_trans_group['hist_card_id_size']
df_hist_trans_group['hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 42

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']
aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_new_merchant_trans[col+'_mean'] = df_new_merchant_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']
    
new_columns = get_new_columns('new_hist',aggs)
df_hist_trans_group = df_new_merchant_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['new_hist_purchase_date_diff'] = (df_hist_trans_group['new_hist_purchase_date_max'] - df_hist_trans_group['new_hist_purchase_date_min']).dt.days
df_hist_trans_group['new_hist_purchase_date_average'] = df_hist_trans_group['new_hist_purchase_date_diff']/df_hist_trans_group['new_hist_card_id_size']
df_hist_trans_group['new_hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['new_hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 28

# %%
del df_hist_trans;gc.collect()
del df_new_merchant_trans;gc.collect()
df_train.head(5)
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
# 3            2017-09  C_ID_186d6a6901          4          3          0
# 4            2017-11  C_ID_cdbd2c0db2          1          3          0
#
#      target  hist_month_nunique  hist_hour_nunique  hist_weekofyear_nunique  \
# 0 -0.820283                   9                 23                       35
# 1  0.392913                  12                 24                       50
# 2  0.688056                  10                 14                       22
# 3  0.142495                   6                 16                       20
# 4 -0.159749                   4                 22                       17
#
#    hist_dayofweek_nunique               ...                \
# 0                       7               ...
# 1                       7               ...
# 2                       7               ...
# 3                       7               ...
# 4                       7               ...
#
#    new_hist_weekend_sum  new_hist_weekend_mean  new_hist_category_1_sum  \
# 0                   6.0               0.260870                      0.0
# 1                   0.0               0.000000                      0.0
# 2                   1.0               1.000000                      0.0
# 3                   3.0               0.428571                      1.0
# 4                  12.0               0.333333                      2.0
#
#    new_hist_category_1_mean  new_hist_card_id_size  \
# 0                  0.000000                   23.0
# 1                  0.000000                    6.0
# 2                  0.000000                    1.0
# 3                  0.142857                    7.0
# 4                  0.055556                   36.0
#
#    new_hist_category_2_mean_mean  new_hist_category_3_mean_mean  \
# 0                  1.658319e+108                   1.381361e+36
# 1                  1.658319e+108                   3.557623e+25
# 2                   7.789907e+26                   1.381361e+36
# 3                  2.369028e+107                   1.973373e+35
# 4                  1.842577e+107                  3.624714e+107
#
#    new_hist_purchase_date_diff  new_hist_purchase_date_average  \
# 0                         54.0                        2.347826
# 1                         56.0                        9.333333
# 2                          0.0                        0.000000
# 3                         41.0                        5.857143
# 4                         57.0                        1.583333
#
#    new_hist_purchase_date_uptonow
# 0                           240.0
# 1                           270.0
# 2                           241.0
# 3                           251.0
# 4                           241.0
#
# [5 rows x 78 columns]

# %%
df_train['outliers'] = 0
df_train.loc[df_train['target'] < -30, 'outliers'] = 1
df_train['outliers'].value_counts()
# Out:
# 0    199710
# 1      2207
# Name: outliers, dtype: int64

# %%
list_outlier_idx = df_train[df_train.outliers == 1].index.tolist()

# %%
for df in [df_train,df_test]:
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['dayofweek'] = df['first_active_month'].dt.dayofweek
    df['weekofyear'] = df['first_active_month'].dt.weekofyear
    df['month'] = df['first_active_month'].dt.month
    df['elapsed_time'] = (datetime.datetime.today() - df['first_active_month']).dt.days
    df['hist_first_buy'] = (df['hist_purchase_date_min'] - df['first_active_month']).dt.days
    df['new_hist_first_buy'] = (df['new_hist_purchase_date_min'] - df['first_active_month']).dt.days
    for f in ['hist_purchase_date_max','hist_purchase_date_min','new_hist_purchase_date_max',\
                     'new_hist_purchase_date_min']:
        df[f] = df[f].astype(np.int64) * 1e-9
    df['card_id_total'] = df['new_hist_card_id_size']+df['hist_card_id_size']
    df['purchase_amount_total'] = df['new_hist_purchase_amount_sum']+df['hist_purchase_amount_sum']

for f in ['feature_1','feature_2','feature_3']:
    order_label = df_train.groupby([f])['outliers'].mean()
    df_train[f] = df_train[f].map(order_label)
    df_test[f] = df_test[f].map(order_label)

# %%
high_importance_features = [
    "hist_month_diff_mean", 
    "hist_authorized_flag_mean", 
    "hist_category_1_sum", 
    "hist_month_lag_mean", 
    "new_hist_purchase_amount_sum", 
    "new_hist_purchase_date_uptonow"
]

#smoothing
for col in high_importance_features:
    df_train[col] = np.where(df_train[col].values==0, 0.001, df_train[col].values)
    df_test[col] = np.where(df_test[col].values==0, 0.001, df_test[col].values)


for i in range(len(high_importance_features)):
    for j in range(len((high_importance_features)))[i+1:]:
        col1 = high_importance_features[i]
        col2 = high_importance_features[j]
        new_col_name = "{c1}__div__{c2}".format(c1=col1, c2=col2)
        
        df_train[new_col_name] = df_train[col1] / df_train[col2]
        df_test[new_col_name] = df_test[col1] / df_test[col2]

# %%
def merge_new_feature(path):
    df_new_feature = pd.read_csv(path)
    
    df_tr = pd.merge(df_train, df_new_feature, on="card_id", how="left")
    df_te = pd.merge(df_test, df_new_feature, on="card_id", how="left")
    
    return df_tr, df_te

# %%
df_train, df_test = merge_new_feature("../input/merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/new_merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/prosperity_merchants_latest.csv")
df_train, df_test = merge_new_feature("../input/merchants_numerical_features.csv")
df_train, df_test = merge_new_feature("../input/merchants_item_scale_feature.csv")
df_train, df_test = merge_new_feature("../input/purchase_pattern.csv")
df_train, df_test = merge_new_feature("../input/purchase_pettern_nmf.csv")
df_train, df_test = merge_new_feature("../input/purchase_amount_pettern_nmf.csv")
df_train, df_test = merge_new_feature("../input/merchants_category.csv")
df_train, df_test = merge_new_feature("../input/fifa_score.csv")
df_train, df_test = merge_new_feature("../input/fifa_score2.csv")
df_train, df_test = merge_new_feature("../input/fifa_score3.csv")
df_train, df_test = merge_new_feature("../input/fifa_score4.csv")

# %%
df_train["Null_count"] = df_train.isnull().sum(axis=1)
df_test["Null_count"] = df_test.isnull().sum(axis=1)

# %%
dont_use = ['card_id', 'first_active_month','second_active_date','diff_first_and_second','target','outliers', 'category_1_Y_std']

df_train_columns = [c for c in df_train.columns if c not in dont_use]
target = df_train['target']
target_outlier = df_train["outliers"]

# %%
#original
param = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',
    'max_depth': -1,
    'learning_rate': 0.004,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.73807	valid_1's rmse: 3.77327
# [200]	training's rmse: 3.6686	valid_1's rmse: 3.73186
# [300]	training's rmse: 3.62001	valid_1's rmse: 3.70867
# [400]	training's rmse: 3.58261	valid_1's rmse: 3.69502
# [500]	training's rmse: 3.55292	valid_1's rmse: 3.6849
# [600]	training's rmse: 3.529	valid_1's rmse: 3.6777
# [700]	training's rmse: 3.50849	valid_1's rmse: 3.67236
# [800]	training's rmse: 3.48955	valid_1's rmse: 3.66851
# [900]	training's rmse: 3.47273	valid_1's rmse: 3.66517
# [1000]	training's rmse: 3.4574	valid_1's rmse: 3.66257
# [1100]	training's rmse: 3.44269	valid_1's rmse: 3.66009
# [1200]	training's rmse: 3.42907	valid_1's rmse: 3.65787
# [1300]	training's rmse: 3.41644	valid_1's rmse: 3.65584
# [1400]	training's rmse: 3.40408	valid_1's rmse: 3.6544
# [1500]	training's rmse: 3.39244	valid_1's rmse: 3.65295
# [1600]	training's rmse: 3.38079	valid_1's rmse: 3.65165
# [1700]	training's rmse: 3.37007	valid_1's rmse: 3.65055
# [1800]	training's rmse: 3.35975	valid_1's rmse: 3.64983
# [1900]	training's rmse: 3.34979	valid_1's rmse: 3.64952
# [2000]	training's rmse: 3.34004	valid_1's rmse: 3.64912
# [2100]	training's rmse: 3.33036	valid_1's rmse: 3.64862
# [2200]	training's rmse: 3.32133	valid_1's rmse: 3.64816
# [2300]	training's rmse: 3.3125	valid_1's rmse: 3.6476
# [2400]	training's rmse: 3.30384	valid_1's rmse: 3.64707
# [2500]	training's rmse: 3.29558	valid_1's rmse: 3.64663
# [2600]	training's rmse: 3.28765	valid_1's rmse: 3.64616
# [2700]	training's rmse: 3.27985	valid_1's rmse: 3.6458
# [2800]	training's rmse: 3.27159	valid_1's rmse: 3.64568
# [2900]	training's rmse: 3.26418	valid_1's rmse: 3.6454
# [3000]	training's rmse: 3.25688	valid_1's rmse: 3.64513
# [3100]	training's rmse: 3.24913	valid_1's rmse: 3.645
# [3200]	training's rmse: 3.24182	valid_1's rmse: 3.64489
# [3300]	training's rmse: 3.2347	valid_1's rmse: 3.64468
# [3400]	training's rmse: 3.22743	valid_1's rmse: 3.64449
# [3500]	training's rmse: 3.22008	valid_1's rmse: 3.64425
# [3600]	training's rmse: 3.21332	valid_1's rmse: 3.64416
# [3700]	training's rmse: 3.2062	valid_1's rmse: 3.64398
# [3800]	training's rmse: 3.19939	valid_1's rmse: 3.64391
# [3900]	training's rmse: 3.19243	valid_1's rmse: 3.64378
# [4000]	training's rmse: 3.18624	valid_1's rmse: 3.64355
# [4100]	training's rmse: 3.17964	valid_1's rmse: 3.64329
# [4200]	training's rmse: 3.173	valid_1's rmse: 3.64323
# [4300]	training's rmse: 3.16634	valid_1's rmse: 3.64312
# [4400]	training's rmse: 3.15991	valid_1's rmse: 3.64297
# [4500]	training's rmse: 3.15359	valid_1's rmse: 3.64282
# [4600]	training's rmse: 3.14684	valid_1's rmse: 3.64278
# [4700]	training's rmse: 3.1411	valid_1's rmse: 3.64283
# [4800]	training's rmse: 3.13529	valid_1's rmse: 3.64276
# [4900]	training's rmse: 3.12924	valid_1's rmse: 3.64254
# [5000]	training's rmse: 3.12298	valid_1's rmse: 3.64266
# [5100]	training's rmse: 3.11695	valid_1's rmse: 3.64263
# [5200]	training's rmse: 3.11073	valid_1's rmse: 3.64273
# [5300]	training's rmse: 3.10444	valid_1's rmse: 3.64281
# Early stopping, best iteration is:
# [4902]	training's rmse: 3.12903	valid_1's rmse: 3.64252
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74228	valid_1's rmse: 3.76041
# [200]	training's rmse: 3.67304	valid_1's rmse: 3.71686
# [300]	training's rmse: 3.62415	valid_1's rmse: 3.69336
# [400]	training's rmse: 3.58649	valid_1's rmse: 3.67848
# [500]	training's rmse: 3.55648	valid_1's rmse: 3.66952
# [600]	training's rmse: 3.53143	valid_1's rmse: 3.66271
# [700]	training's rmse: 3.51018	valid_1's rmse: 3.65745
# [800]	training's rmse: 3.49121	valid_1's rmse: 3.65315
# [900]	training's rmse: 3.47435	valid_1's rmse: 3.64983
# [1000]	training's rmse: 3.45898	valid_1's rmse: 3.64759
# [1100]	training's rmse: 3.44482	valid_1's rmse: 3.6456
# [1200]	training's rmse: 3.43105	valid_1's rmse: 3.64422
# [1300]	training's rmse: 3.41815	valid_1's rmse: 3.64277
# [1400]	training's rmse: 3.40577	valid_1's rmse: 3.6418
# [1500]	training's rmse: 3.39375	valid_1's rmse: 3.64097
# [1600]	training's rmse: 3.38242	valid_1's rmse: 3.64011
# [1700]	training's rmse: 3.37118	valid_1's rmse: 3.63953
# [1800]	training's rmse: 3.36069	valid_1's rmse: 3.63932
# [1900]	training's rmse: 3.35057	valid_1's rmse: 3.63888
# [2000]	training's rmse: 3.34051	valid_1's rmse: 3.63883
# [2100]	training's rmse: 3.33086	valid_1's rmse: 3.63871
# [2200]	training's rmse: 3.32187	valid_1's rmse: 3.6385
# [2300]	training's rmse: 3.31299	valid_1's rmse: 3.63831
# [2400]	training's rmse: 3.30435	valid_1's rmse: 3.63826
# [2500]	training's rmse: 3.29539	valid_1's rmse: 3.63814
# [2600]	training's rmse: 3.28686	valid_1's rmse: 3.63806
# [2700]	training's rmse: 3.27872	valid_1's rmse: 3.638
# [2800]	training's rmse: 3.27083	valid_1's rmse: 3.63781
# [2900]	training's rmse: 3.26291	valid_1's rmse: 3.63763
# [3000]	training's rmse: 3.25511	valid_1's rmse: 3.63749
# [3100]	training's rmse: 3.24768	valid_1's rmse: 3.63756
# [3200]	training's rmse: 3.23979	valid_1's rmse: 3.63762
# [3300]	training's rmse: 3.23275	valid_1's rmse: 3.63776
# Early stopping, best iteration is:
# [2989]	training's rmse: 3.25587	valid_1's rmse: 3.63742
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.7441	valid_1's rmse: 3.75948
# [200]	training's rmse: 3.67605	valid_1's rmse: 3.71101
# [300]	training's rmse: 3.6274	valid_1's rmse: 3.68394
# [400]	training's rmse: 3.58954	valid_1's rmse: 3.66718
# [500]	training's rmse: 3.55972	valid_1's rmse: 3.65533
# [600]	training's rmse: 3.53559	valid_1's rmse: 3.64774
# [700]	training's rmse: 3.51454	valid_1's rmse: 3.64235
# [800]	training's rmse: 3.49569	valid_1's rmse: 3.63796
# [900]	training's rmse: 3.47903	valid_1's rmse: 3.63437
# [1000]	training's rmse: 3.46327	valid_1's rmse: 3.63144
# [1100]	training's rmse: 3.44924	valid_1's rmse: 3.62931
# [1200]	training's rmse: 3.43616	valid_1's rmse: 3.62748
# [1300]	training's rmse: 3.42352	valid_1's rmse: 3.62566
# [1400]	training's rmse: 3.41187	valid_1's rmse: 3.6244
# [1500]	training's rmse: 3.40044	valid_1's rmse: 3.62323
# [1600]	training's rmse: 3.38916	valid_1's rmse: 3.62218
# [1700]	training's rmse: 3.37864	valid_1's rmse: 3.62173
# [1800]	training's rmse: 3.36773	valid_1's rmse: 3.62113
# [1900]	training's rmse: 3.35805	valid_1's rmse: 3.62052
# [2000]	training's rmse: 3.34849	valid_1's rmse: 3.62015
# [2100]	training's rmse: 3.33912	valid_1's rmse: 3.61984
# [2200]	training's rmse: 3.32991	valid_1's rmse: 3.61953
# [2300]	training's rmse: 3.32122	valid_1's rmse: 3.61907
# [2400]	training's rmse: 3.31244	valid_1's rmse: 3.61884
# [2500]	training's rmse: 3.30383	valid_1's rmse: 3.61868
# [2600]	training's rmse: 3.29586	valid_1's rmse: 3.61838
# [2700]	training's rmse: 3.28773	valid_1's rmse: 3.61812
# [2800]	training's rmse: 3.27944	valid_1's rmse: 3.61805
# [2900]	training's rmse: 3.27174	valid_1's rmse: 3.61777
# [3000]	training's rmse: 3.26441	valid_1's rmse: 3.61779
# [3100]	training's rmse: 3.25661	valid_1's rmse: 3.61769
# [3200]	training's rmse: 3.24908	valid_1's rmse: 3.61788
# [3300]	training's rmse: 3.24147	valid_1's rmse: 3.61776
# [3400]	training's rmse: 3.23428	valid_1's rmse: 3.61755
# [3500]	training's rmse: 3.2274	valid_1's rmse: 3.61762
# [3600]	training's rmse: 3.22028	valid_1's rmse: 3.61755
# [3700]	training's rmse: 3.21389	valid_1's rmse: 3.61772
# [3800]	training's rmse: 3.20676	valid_1's rmse: 3.61783
# Early stopping, best iteration is:
# [3421]	training's rmse: 3.23283	valid_1's rmse: 3.61742
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.73883	valid_1's rmse: 3.76958
# [200]	training's rmse: 3.66779	valid_1's rmse: 3.73026
# [300]	training's rmse: 3.6176	valid_1's rmse: 3.70954
# [400]	training's rmse: 3.57851	valid_1's rmse: 3.69734
# [500]	training's rmse: 3.54737	valid_1's rmse: 3.68977
# [600]	training's rmse: 3.52183	valid_1's rmse: 3.6852
# [700]	training's rmse: 3.50017	valid_1's rmse: 3.68202
# [800]	training's rmse: 3.48124	valid_1's rmse: 3.67941
# [900]	training's rmse: 3.46404	valid_1's rmse: 3.67771
# [1000]	training's rmse: 3.448	valid_1's rmse: 3.67617
# [1100]	training's rmse: 3.43286	valid_1's rmse: 3.67518
# [1200]	training's rmse: 3.41836	valid_1's rmse: 3.67427
# [1300]	training's rmse: 3.40516	valid_1's rmse: 3.6734
# [1400]	training's rmse: 3.39313	valid_1's rmse: 3.67261
# [1500]	training's rmse: 3.38147	valid_1's rmse: 3.67219
# [1600]	training's rmse: 3.36999	valid_1's rmse: 3.67155
# [1700]	training's rmse: 3.3591	valid_1's rmse: 3.67127
# [1800]	training's rmse: 3.34823	valid_1's rmse: 3.67092
# [1900]	training's rmse: 3.33831	valid_1's rmse: 3.67063
# [2000]	training's rmse: 3.32838	valid_1's rmse: 3.67049
# [2100]	training's rmse: 3.31884	valid_1's rmse: 3.67006
# [2200]	training's rmse: 3.30971	valid_1's rmse: 3.66971
# [2300]	training's rmse: 3.30047	valid_1's rmse: 3.66953
# [2400]	training's rmse: 3.29143	valid_1's rmse: 3.66933
# [2500]	training's rmse: 3.28265	valid_1's rmse: 3.66936
# [2600]	training's rmse: 3.27423	valid_1's rmse: 3.66932
# [2700]	training's rmse: 3.2662	valid_1's rmse: 3.6693
# [2800]	training's rmse: 3.258	valid_1's rmse: 3.66906
# [2900]	training's rmse: 3.25022	valid_1's rmse: 3.6689
# [3000]	training's rmse: 3.24228	valid_1's rmse: 3.66879
# [3100]	training's rmse: 3.23438	valid_1's rmse: 3.66849
# [3200]	training's rmse: 3.22724	valid_1's rmse: 3.66853
# [3300]	training's rmse: 3.22017	valid_1's rmse: 3.66853
# [3400]	training's rmse: 3.21297	valid_1's rmse: 3.66855
# [3500]	training's rmse: 3.2056	valid_1's rmse: 3.66871
# Early stopping, best iteration is:
# [3132]	training's rmse: 3.23208	valid_1's rmse: 3.66841
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.73671	valid_1's rmse: 3.77775
# [200]	training's rmse: 3.66647	valid_1's rmse: 3.73698
# [300]	training's rmse: 3.61715	valid_1's rmse: 3.71477
# [400]	training's rmse: 3.57875	valid_1's rmse: 3.7019
# [500]	training's rmse: 3.54818	valid_1's rmse: 3.69377
# [600]	training's rmse: 3.5228	valid_1's rmse: 3.68825
# [700]	training's rmse: 3.50114	valid_1's rmse: 3.68418
# [800]	training's rmse: 3.48232	valid_1's rmse: 3.68109
# [900]	training's rmse: 3.46586	valid_1's rmse: 3.67836
# [1000]	training's rmse: 3.45058	valid_1's rmse: 3.67627
# [1100]	training's rmse: 3.43623	valid_1's rmse: 3.67432
# [1200]	training's rmse: 3.42274	valid_1's rmse: 3.67272
# [1300]	training's rmse: 3.41014	valid_1's rmse: 3.67152
# [1400]	training's rmse: 3.39805	valid_1's rmse: 3.67031
# [1500]	training's rmse: 3.38643	valid_1's rmse: 3.66956
# [1600]	training's rmse: 3.37543	valid_1's rmse: 3.66905
# [1700]	training's rmse: 3.36466	valid_1's rmse: 3.66875
# [1800]	training's rmse: 3.35443	valid_1's rmse: 3.66832
# [1900]	training's rmse: 3.34467	valid_1's rmse: 3.66816
# [2000]	training's rmse: 3.33513	valid_1's rmse: 3.66798
# [2100]	training's rmse: 3.32593	valid_1's rmse: 3.6678
# [2200]	training's rmse: 3.31686	valid_1's rmse: 3.66751
# [2300]	training's rmse: 3.30824	valid_1's rmse: 3.66747
# [2400]	training's rmse: 3.2996	valid_1's rmse: 3.66734
# [2500]	training's rmse: 3.29141	valid_1's rmse: 3.66724
# [2600]	training's rmse: 3.28317	valid_1's rmse: 3.66694
# [2700]	training's rmse: 3.27568	valid_1's rmse: 3.66695
# [2800]	training's rmse: 3.26768	valid_1's rmse: 3.66679
# [2900]	training's rmse: 3.25927	valid_1's rmse: 3.66661
# [3000]	training's rmse: 3.25164	valid_1's rmse: 3.66655
# [3100]	training's rmse: 3.2439	valid_1's rmse: 3.66646
# [3200]	training's rmse: 3.23672	valid_1's rmse: 3.6664
# [3300]	training's rmse: 3.2294	valid_1's rmse: 3.66633
# [3400]	training's rmse: 3.22221	valid_1's rmse: 3.66618
# [3500]	training's rmse: 3.21568	valid_1's rmse: 3.66617
# [3600]	training's rmse: 3.20863	valid_1's rmse: 3.66622
# [3700]	training's rmse: 3.20197	valid_1's rmse: 3.66619
# [3800]	training's rmse: 3.19567	valid_1's rmse: 3.66621
# Early stopping, best iteration is:
# [3451]	training's rmse: 3.21873	valid_1's rmse: 3.66606
# 3.6464162745734927

# %%
# score:  3.6467757129353053

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,50))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
# plt.savefig('lgbm_importances.png')

# %%
df_train2 = df_train[df_train.target >= -20].reset_index(drop=True)
target2 = df_train2["target"]

#original
param2 = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',
    'max_depth': -1,
    'learning_rate': 0.004,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train2))
predictions2 = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train2,df_train2['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train2.iloc[trn_idx][df_train_columns], label=target2.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train2.iloc[val_idx][df_train_columns], label=target2.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param2, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train2.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions2 += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target2))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65321	valid_1's rmse: 1.65215
# [200]	training's rmse: 1.61833	valid_1's rmse: 1.61772
# [300]	training's rmse: 1.59794	valid_1's rmse: 1.59836
# [400]	training's rmse: 1.58463	valid_1's rmse: 1.58619
# [500]	training's rmse: 1.57519	valid_1's rmse: 1.5782
# [600]	training's rmse: 1.568	valid_1's rmse: 1.57266
# [700]	training's rmse: 1.56214	valid_1's rmse: 1.56864
# [800]	training's rmse: 1.55719	valid_1's rmse: 1.56563
# [900]	training's rmse: 1.55288	valid_1's rmse: 1.56333
# [1000]	training's rmse: 1.54893	valid_1's rmse: 1.56138
# [1100]	training's rmse: 1.54534	valid_1's rmse: 1.55988
# [1200]	training's rmse: 1.54201	valid_1's rmse: 1.55857
# [1300]	training's rmse: 1.53886	valid_1's rmse: 1.55754
# [1400]	training's rmse: 1.5359	valid_1's rmse: 1.55665
# [1500]	training's rmse: 1.53304	valid_1's rmse: 1.55581
# [1600]	training's rmse: 1.53038	valid_1's rmse: 1.55519
# [1700]	training's rmse: 1.52781	valid_1's rmse: 1.55465
# [1800]	training's rmse: 1.52534	valid_1's rmse: 1.55418
# [1900]	training's rmse: 1.52295	valid_1's rmse: 1.55383
# [2000]	training's rmse: 1.52068	valid_1's rmse: 1.55348
# [2100]	training's rmse: 1.51849	valid_1's rmse: 1.55317
# [2200]	training's rmse: 1.51632	valid_1's rmse: 1.55291
# [2300]	training's rmse: 1.51422	valid_1's rmse: 1.55268
# [2400]	training's rmse: 1.51219	valid_1's rmse: 1.55249
# [2500]	training's rmse: 1.51021	valid_1's rmse: 1.55234
# [2600]	training's rmse: 1.50825	valid_1's rmse: 1.55216
# [2700]	training's rmse: 1.50639	valid_1's rmse: 1.55205
# [2800]	training's rmse: 1.50446	valid_1's rmse: 1.55195
# [2900]	training's rmse: 1.50257	valid_1's rmse: 1.55186
# [3000]	training's rmse: 1.50074	valid_1's rmse: 1.55178
# [3100]	training's rmse: 1.49893	valid_1's rmse: 1.55168
# [3200]	training's rmse: 1.49714	valid_1's rmse: 1.55161
# [3300]	training's rmse: 1.49538	valid_1's rmse: 1.55151
# [3400]	training's rmse: 1.49368	valid_1's rmse: 1.55149
# [3500]	training's rmse: 1.49189	valid_1's rmse: 1.55143
# [3600]	training's rmse: 1.49014	valid_1's rmse: 1.55134
# [3700]	training's rmse: 1.48842	valid_1's rmse: 1.55129
# [3800]	training's rmse: 1.48675	valid_1's rmse: 1.55123
# [3900]	training's rmse: 1.48504	valid_1's rmse: 1.5512
# [4000]	training's rmse: 1.48333	valid_1's rmse: 1.55119
# [4100]	training's rmse: 1.48165	valid_1's rmse: 1.55114
# [4200]	training's rmse: 1.48001	valid_1's rmse: 1.55112
# [4300]	training's rmse: 1.47837	valid_1's rmse: 1.55111
# [4400]	training's rmse: 1.47674	valid_1's rmse: 1.55108
# [4500]	training's rmse: 1.47508	valid_1's rmse: 1.55106
# [4600]	training's rmse: 1.47345	valid_1's rmse: 1.55104
# [4700]	training's rmse: 1.47189	valid_1's rmse: 1.55101
# [4800]	training's rmse: 1.47031	valid_1's rmse: 1.551
# [4900]	training's rmse: 1.46871	valid_1's rmse: 1.55098
# [5000]	training's rmse: 1.46713	valid_1's rmse: 1.55098
# [5100]	training's rmse: 1.46559	valid_1's rmse: 1.55095
# [5200]	training's rmse: 1.46402	valid_1's rmse: 1.55094
# [5300]	training's rmse: 1.46247	valid_1's rmse: 1.55092
# [5400]	training's rmse: 1.46088	valid_1's rmse: 1.55089
# [5500]	training's rmse: 1.45941	valid_1's rmse: 1.55092
# [5600]	training's rmse: 1.45788	valid_1's rmse: 1.55091
# [5700]	training's rmse: 1.45633	valid_1's rmse: 1.5509
# [5800]	training's rmse: 1.45482	valid_1's rmse: 1.55088
# [5900]	training's rmse: 1.45331	valid_1's rmse: 1.55089
# [6000]	training's rmse: 1.45175	valid_1's rmse: 1.55086
# [6100]	training's rmse: 1.45029	valid_1's rmse: 1.55083
# [6200]	training's rmse: 1.44881	valid_1's rmse: 1.55081
# [6300]	training's rmse: 1.44736	valid_1's rmse: 1.55081
# [6400]	training's rmse: 1.44586	valid_1's rmse: 1.55083
# [6500]	training's rmse: 1.44435	valid_1's rmse: 1.55081
# [6600]	training's rmse: 1.4429	valid_1's rmse: 1.55081
# Early stopping, best iteration is:
# [6239]	training's rmse: 1.44822	valid_1's rmse: 1.55079
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65648	valid_1's rmse: 1.63596
# [200]	training's rmse: 1.62092	valid_1's rmse: 1.60374
# [300]	training's rmse: 1.60022	valid_1's rmse: 1.58603
# [400]	training's rmse: 1.58687	valid_1's rmse: 1.57542
# [500]	training's rmse: 1.57738	valid_1's rmse: 1.56828
# [600]	training's rmse: 1.57018	valid_1's rmse: 1.56336
# [700]	training's rmse: 1.56435	valid_1's rmse: 1.55976
# [800]	training's rmse: 1.55943	valid_1's rmse: 1.55696
# [900]	training's rmse: 1.55512	valid_1's rmse: 1.55476
# [1000]	training's rmse: 1.5512	valid_1's rmse: 1.5529
# [1100]	training's rmse: 1.54766	valid_1's rmse: 1.55139
# [1200]	training's rmse: 1.54433	valid_1's rmse: 1.55006
# [1300]	training's rmse: 1.54118	valid_1's rmse: 1.54896
# [1400]	training's rmse: 1.53826	valid_1's rmse: 1.54808
# [1500]	training's rmse: 1.53548	valid_1's rmse: 1.54732
# [1600]	training's rmse: 1.53284	valid_1's rmse: 1.54673
# [1700]	training's rmse: 1.53029	valid_1's rmse: 1.54619
# [1800]	training's rmse: 1.52782	valid_1's rmse: 1.54567
# [1900]	training's rmse: 1.52546	valid_1's rmse: 1.5453
# [2000]	training's rmse: 1.52317	valid_1's rmse: 1.54494
# [2100]	training's rmse: 1.52094	valid_1's rmse: 1.54471
# [2200]	training's rmse: 1.51878	valid_1's rmse: 1.54447
# [2300]	training's rmse: 1.51665	valid_1's rmse: 1.54422
# [2400]	training's rmse: 1.51463	valid_1's rmse: 1.54404
# [2500]	training's rmse: 1.51262	valid_1's rmse: 1.54388
# [2600]	training's rmse: 1.51063	valid_1's rmse: 1.54376
# [2700]	training's rmse: 1.5087	valid_1's rmse: 1.54362
# [2800]	training's rmse: 1.50677	valid_1's rmse: 1.54347
# [2900]	training's rmse: 1.50485	valid_1's rmse: 1.54331
# [3000]	training's rmse: 1.50299	valid_1's rmse: 1.54318
# [3100]	training's rmse: 1.50116	valid_1's rmse: 1.54308
# [3200]	training's rmse: 1.49935	valid_1's rmse: 1.54299
# [3300]	training's rmse: 1.49758	valid_1's rmse: 1.54288
# [3400]	training's rmse: 1.49581	valid_1's rmse: 1.54278
# [3500]	training's rmse: 1.494	valid_1's rmse: 1.54268
# [3600]	training's rmse: 1.49224	valid_1's rmse: 1.54264
# [3700]	training's rmse: 1.49047	valid_1's rmse: 1.54253
# [3800]	training's rmse: 1.48876	valid_1's rmse: 1.54244
# [3900]	training's rmse: 1.48708	valid_1's rmse: 1.54236
# [4000]	training's rmse: 1.48537	valid_1's rmse: 1.54232
# [4100]	training's rmse: 1.48367	valid_1's rmse: 1.54228
# [4200]	training's rmse: 1.48202	valid_1's rmse: 1.54224
# [4300]	training's rmse: 1.48039	valid_1's rmse: 1.54216
# [4400]	training's rmse: 1.47879	valid_1's rmse: 1.54208
# [4500]	training's rmse: 1.47715	valid_1's rmse: 1.54202
# [4600]	training's rmse: 1.47553	valid_1's rmse: 1.54196
# [4700]	training's rmse: 1.47397	valid_1's rmse: 1.54195
# [4800]	training's rmse: 1.4723	valid_1's rmse: 1.54193
# [4900]	training's rmse: 1.47067	valid_1's rmse: 1.54189
# [5000]	training's rmse: 1.46899	valid_1's rmse: 1.54185
# [5100]	training's rmse: 1.46741	valid_1's rmse: 1.54182
# [5200]	training's rmse: 1.46584	valid_1's rmse: 1.54177
# [5300]	training's rmse: 1.46427	valid_1's rmse: 1.54178
# [5400]	training's rmse: 1.46276	valid_1's rmse: 1.54173
# [5500]	training's rmse: 1.46121	valid_1's rmse: 1.54169
# [5600]	training's rmse: 1.45966	valid_1's rmse: 1.54165
# [5700]	training's rmse: 1.45814	valid_1's rmse: 1.5416
# [5800]	training's rmse: 1.45657	valid_1's rmse: 1.54155
# [5900]	training's rmse: 1.45501	valid_1's rmse: 1.54149
# [6000]	training's rmse: 1.45352	valid_1's rmse: 1.54149
# [6100]	training's rmse: 1.45203	valid_1's rmse: 1.54144
# [6200]	training's rmse: 1.45053	valid_1's rmse: 1.54137
# [6300]	training's rmse: 1.44904	valid_1's rmse: 1.54136
# [6400]	training's rmse: 1.44752	valid_1's rmse: 1.5413
# [6500]	training's rmse: 1.44602	valid_1's rmse: 1.54129
# [6600]	training's rmse: 1.44455	valid_1's rmse: 1.54126
# [6700]	training's rmse: 1.44304	valid_1's rmse: 1.54124
# [6800]	training's rmse: 1.44161	valid_1's rmse: 1.54123
# [6900]	training's rmse: 1.44011	valid_1's rmse: 1.54122
# [7000]	training's rmse: 1.43869	valid_1's rmse: 1.54119
# [7100]	training's rmse: 1.4372	valid_1's rmse: 1.54118
# [7200]	training's rmse: 1.43572	valid_1's rmse: 1.54119
# [7300]	training's rmse: 1.43421	valid_1's rmse: 1.54118
# [7400]	training's rmse: 1.43279	valid_1's rmse: 1.54118
# [7500]	training's rmse: 1.43136	valid_1's rmse: 1.54116
# [7600]	training's rmse: 1.42993	valid_1's rmse: 1.54114
# [7700]	training's rmse: 1.42846	valid_1's rmse: 1.54116
# [7800]	training's rmse: 1.42707	valid_1's rmse: 1.54114
# [7900]	training's rmse: 1.4257	valid_1's rmse: 1.54113
# [8000]	training's rmse: 1.42429	valid_1's rmse: 1.54113
# [8100]	training's rmse: 1.42284	valid_1's rmse: 1.54109
# [8200]	training's rmse: 1.42142	valid_1's rmse: 1.54111
# [8300]	training's rmse: 1.42003	valid_1's rmse: 1.54109
# [8400]	training's rmse: 1.41862	valid_1's rmse: 1.54108
# [8500]	training's rmse: 1.41726	valid_1's rmse: 1.54106
# [8600]	training's rmse: 1.41584	valid_1's rmse: 1.54103
# [8700]	training's rmse: 1.41446	valid_1's rmse: 1.54102
# [8800]	training's rmse: 1.41309	valid_1's rmse: 1.54099
# [8900]	training's rmse: 1.41172	valid_1's rmse: 1.541
# [9000]	training's rmse: 1.41032	valid_1's rmse: 1.54099
# [9100]	training's rmse: 1.40898	valid_1's rmse: 1.54096
# [9200]	training's rmse: 1.40761	valid_1's rmse: 1.54092
# [9300]	training's rmse: 1.40625	valid_1's rmse: 1.54092
# [9400]	training's rmse: 1.40491	valid_1's rmse: 1.54093
# [9500]	training's rmse: 1.40355	valid_1's rmse: 1.54093
# [9600]	training's rmse: 1.40214	valid_1's rmse: 1.54094
# Early stopping, best iteration is:
# [9221]	training's rmse: 1.40732	valid_1's rmse: 1.5409
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65219	valid_1's rmse: 1.65504
# [200]	training's rmse: 1.61709	valid_1's rmse: 1.62153
# [300]	training's rmse: 1.59668	valid_1's rmse: 1.60272
# [400]	training's rmse: 1.58347	valid_1's rmse: 1.59134
# [500]	training's rmse: 1.57411	valid_1's rmse: 1.58383
# [600]	training's rmse: 1.56693	valid_1's rmse: 1.57865
# [700]	training's rmse: 1.56117	valid_1's rmse: 1.57476
# [800]	training's rmse: 1.55626	valid_1's rmse: 1.57176
# [900]	training's rmse: 1.55201	valid_1's rmse: 1.56937
# [1000]	training's rmse: 1.5481	valid_1's rmse: 1.56746
# [1100]	training's rmse: 1.54456	valid_1's rmse: 1.56584
# [1200]	training's rmse: 1.54126	valid_1's rmse: 1.56455
# [1300]	training's rmse: 1.53818	valid_1's rmse: 1.5635
# [1400]	training's rmse: 1.53524	valid_1's rmse: 1.56253
# [1500]	training's rmse: 1.53245	valid_1's rmse: 1.56179
# [1600]	training's rmse: 1.5298	valid_1's rmse: 1.5611
# [1700]	training's rmse: 1.52727	valid_1's rmse: 1.56054
# [1800]	training's rmse: 1.5248	valid_1's rmse: 1.56007
# [1900]	training's rmse: 1.52248	valid_1's rmse: 1.55966
# [2000]	training's rmse: 1.52025	valid_1's rmse: 1.55937
# [2100]	training's rmse: 1.51804	valid_1's rmse: 1.55908
# [2200]	training's rmse: 1.5159	valid_1's rmse: 1.55881
# [2300]	training's rmse: 1.51382	valid_1's rmse: 1.55857
# [2400]	training's rmse: 1.51177	valid_1's rmse: 1.55837
# [2500]	training's rmse: 1.50973	valid_1's rmse: 1.55818
# [2600]	training's rmse: 1.50782	valid_1's rmse: 1.55805
# [2700]	training's rmse: 1.50589	valid_1's rmse: 1.55792
# [2800]	training's rmse: 1.50398	valid_1's rmse: 1.55783
# [2900]	training's rmse: 1.50209	valid_1's rmse: 1.55767
# [3000]	training's rmse: 1.50022	valid_1's rmse: 1.55759
# [3100]	training's rmse: 1.4984	valid_1's rmse: 1.55748
# [3200]	training's rmse: 1.49662	valid_1's rmse: 1.55739
# [3300]	training's rmse: 1.49481	valid_1's rmse: 1.55731
# [3400]	training's rmse: 1.49303	valid_1's rmse: 1.55721
# [3500]	training's rmse: 1.4913	valid_1's rmse: 1.55715
# [3600]	training's rmse: 1.48958	valid_1's rmse: 1.55707
# [3700]	training's rmse: 1.4878	valid_1's rmse: 1.55704
# [3800]	training's rmse: 1.48605	valid_1's rmse: 1.55696
# [3900]	training's rmse: 1.48436	valid_1's rmse: 1.55691
# [4000]	training's rmse: 1.4827	valid_1's rmse: 1.55682
# [4100]	training's rmse: 1.481	valid_1's rmse: 1.55678
# [4200]	training's rmse: 1.47935	valid_1's rmse: 1.55671
# [4300]	training's rmse: 1.47772	valid_1's rmse: 1.55666
# [4400]	training's rmse: 1.4761	valid_1's rmse: 1.55661
# [4500]	training's rmse: 1.47445	valid_1's rmse: 1.55658
# [4600]	training's rmse: 1.47285	valid_1's rmse: 1.55653
# [4700]	training's rmse: 1.47119	valid_1's rmse: 1.5565
# [4800]	training's rmse: 1.46959	valid_1's rmse: 1.55647
# [4900]	training's rmse: 1.46797	valid_1's rmse: 1.55644
# [5000]	training's rmse: 1.46638	valid_1's rmse: 1.55643
# [5100]	training's rmse: 1.46477	valid_1's rmse: 1.55638
# [5200]	training's rmse: 1.46322	valid_1's rmse: 1.55636
# [5300]	training's rmse: 1.4617	valid_1's rmse: 1.55632
# [5400]	training's rmse: 1.46011	valid_1's rmse: 1.55633
# [5500]	training's rmse: 1.45857	valid_1's rmse: 1.55634
# [5600]	training's rmse: 1.45696	valid_1's rmse: 1.55631
# [5700]	training's rmse: 1.45534	valid_1's rmse: 1.55629
# [5800]	training's rmse: 1.45381	valid_1's rmse: 1.55631
# [5900]	training's rmse: 1.45226	valid_1's rmse: 1.55629
# [6000]	training's rmse: 1.45078	valid_1's rmse: 1.55629
# Early stopping, best iteration is:
# [5690]	training's rmse: 1.45551	valid_1's rmse: 1.55627
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65259	valid_1's rmse: 1.65331
# [200]	training's rmse: 1.61747	valid_1's rmse: 1.62043
# [300]	training's rmse: 1.59697	valid_1's rmse: 1.60209
# [400]	training's rmse: 1.58373	valid_1's rmse: 1.59108
# [500]	training's rmse: 1.57427	valid_1's rmse: 1.58368
# [600]	training's rmse: 1.56716	valid_1's rmse: 1.57858
# [700]	training's rmse: 1.56131	valid_1's rmse: 1.57478
# [800]	training's rmse: 1.55643	valid_1's rmse: 1.57186
# [900]	training's rmse: 1.55216	valid_1's rmse: 1.56958
# [1000]	training's rmse: 1.5482	valid_1's rmse: 1.56766
# [1100]	training's rmse: 1.54462	valid_1's rmse: 1.56609
# [1200]	training's rmse: 1.54129	valid_1's rmse: 1.56475
# [1300]	training's rmse: 1.53817	valid_1's rmse: 1.56367
# [1400]	training's rmse: 1.53522	valid_1's rmse: 1.56273
# [1500]	training's rmse: 1.53239	valid_1's rmse: 1.56194
# [1600]	training's rmse: 1.5297	valid_1's rmse: 1.56132
# [1700]	training's rmse: 1.52714	valid_1's rmse: 1.56074
# [1800]	training's rmse: 1.52475	valid_1's rmse: 1.56026
# [1900]	training's rmse: 1.52236	valid_1's rmse: 1.55986
# [2000]	training's rmse: 1.52007	valid_1's rmse: 1.55945
# [2100]	training's rmse: 1.51784	valid_1's rmse: 1.55913
# [2200]	training's rmse: 1.51571	valid_1's rmse: 1.55897
# [2300]	training's rmse: 1.51364	valid_1's rmse: 1.55876
# [2400]	training's rmse: 1.51157	valid_1's rmse: 1.55854
# [2500]	training's rmse: 1.50958	valid_1's rmse: 1.55839
# [2600]	training's rmse: 1.5076	valid_1's rmse: 1.55823
# [2700]	training's rmse: 1.50567	valid_1's rmse: 1.55811
# [2800]	training's rmse: 1.50375	valid_1's rmse: 1.55799
# [2900]	training's rmse: 1.50185	valid_1's rmse: 1.55788
# [3000]	training's rmse: 1.50002	valid_1's rmse: 1.55782
# [3100]	training's rmse: 1.49822	valid_1's rmse: 1.55772
# [3200]	training's rmse: 1.49644	valid_1's rmse: 1.55764
# [3300]	training's rmse: 1.49458	valid_1's rmse: 1.55755
# [3400]	training's rmse: 1.49282	valid_1's rmse: 1.55752
# [3500]	training's rmse: 1.49108	valid_1's rmse: 1.55747
# [3600]	training's rmse: 1.48931	valid_1's rmse: 1.5574
# [3700]	training's rmse: 1.48762	valid_1's rmse: 1.5573
# [3800]	training's rmse: 1.48595	valid_1's rmse: 1.55726
# [3900]	training's rmse: 1.48424	valid_1's rmse: 1.55718
# [4000]	training's rmse: 1.48261	valid_1's rmse: 1.55714
# [4100]	training's rmse: 1.4809	valid_1's rmse: 1.55708
# [4200]	training's rmse: 1.47924	valid_1's rmse: 1.55704
# [4300]	training's rmse: 1.47758	valid_1's rmse: 1.557
# [4400]	training's rmse: 1.47595	valid_1's rmse: 1.55694
# [4500]	training's rmse: 1.47434	valid_1's rmse: 1.55693
# [4600]	training's rmse: 1.47272	valid_1's rmse: 1.5569
# [4700]	training's rmse: 1.47103	valid_1's rmse: 1.55686
# [4800]	training's rmse: 1.46941	valid_1's rmse: 1.55684
# [4900]	training's rmse: 1.4678	valid_1's rmse: 1.55682
# [5000]	training's rmse: 1.46621	valid_1's rmse: 1.55677
# [5100]	training's rmse: 1.46462	valid_1's rmse: 1.55671
# [5200]	training's rmse: 1.46305	valid_1's rmse: 1.5567
# [5300]	training's rmse: 1.46149	valid_1's rmse: 1.55669
# [5400]	training's rmse: 1.45993	valid_1's rmse: 1.55668
# [5500]	training's rmse: 1.45842	valid_1's rmse: 1.55661
# [5600]	training's rmse: 1.45686	valid_1's rmse: 1.55658
# [5700]	training's rmse: 1.45532	valid_1's rmse: 1.5566
# [5800]	training's rmse: 1.45379	valid_1's rmse: 1.55658
# [5900]	training's rmse: 1.45222	valid_1's rmse: 1.55654
# [6000]	training's rmse: 1.45074	valid_1's rmse: 1.55652
# [6100]	training's rmse: 1.44919	valid_1's rmse: 1.55652
# [6200]	training's rmse: 1.44768	valid_1's rmse: 1.55649
# [6300]	training's rmse: 1.44614	valid_1's rmse: 1.55648
# [6400]	training's rmse: 1.44459	valid_1's rmse: 1.55648
# [6500]	training's rmse: 1.44308	valid_1's rmse: 1.55644
# [6600]	training's rmse: 1.44158	valid_1's rmse: 1.5564
# [6700]	training's rmse: 1.44004	valid_1's rmse: 1.5564
# [6800]	training's rmse: 1.43858	valid_1's rmse: 1.55643
# [6900]	training's rmse: 1.4371	valid_1's rmse: 1.55641
# [7000]	training's rmse: 1.43565	valid_1's rmse: 1.55639
# [7100]	training's rmse: 1.43425	valid_1's rmse: 1.55637
# [7200]	training's rmse: 1.43275	valid_1's rmse: 1.55634
# [7300]	training's rmse: 1.43129	valid_1's rmse: 1.55635
# [7400]	training's rmse: 1.42986	valid_1's rmse: 1.55635
# [7500]	training's rmse: 1.42841	valid_1's rmse: 1.55635
# [7600]	training's rmse: 1.42696	valid_1's rmse: 1.5564
# [7700]	training's rmse: 1.42546	valid_1's rmse: 1.5564
# [7800]	training's rmse: 1.42405	valid_1's rmse: 1.5564
# Early stopping, best iteration is:
# [7421]	training's rmse: 1.42957	valid_1's rmse: 1.55633
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.64761	valid_1's rmse: 1.67467
# [200]	training's rmse: 1.61261	valid_1's rmse: 1.6415
# [300]	training's rmse: 1.59215	valid_1's rmse: 1.62285
# [400]	training's rmse: 1.57892	valid_1's rmse: 1.61137
# [500]	training's rmse: 1.56949	valid_1's rmse: 1.60374
# [600]	training's rmse: 1.56232	valid_1's rmse: 1.59839
# [700]	training's rmse: 1.55652	valid_1's rmse: 1.5945
# [800]	training's rmse: 1.55164	valid_1's rmse: 1.59158
# [900]	training's rmse: 1.54732	valid_1's rmse: 1.58925
# [1000]	training's rmse: 1.54338	valid_1's rmse: 1.58734
# [1100]	training's rmse: 1.53981	valid_1's rmse: 1.58581
# [1200]	training's rmse: 1.5365	valid_1's rmse: 1.58445
# [1300]	training's rmse: 1.53342	valid_1's rmse: 1.58339
# [1400]	training's rmse: 1.53053	valid_1's rmse: 1.58246
# [1500]	training's rmse: 1.52776	valid_1's rmse: 1.58172
# [1600]	training's rmse: 1.52511	valid_1's rmse: 1.58104
# [1700]	training's rmse: 1.52258	valid_1's rmse: 1.58052
# [1800]	training's rmse: 1.52013	valid_1's rmse: 1.5801
# [1900]	training's rmse: 1.51781	valid_1's rmse: 1.57972
# [2000]	training's rmse: 1.51553	valid_1's rmse: 1.57938
# [2100]	training's rmse: 1.51332	valid_1's rmse: 1.57913
# [2200]	training's rmse: 1.51113	valid_1's rmse: 1.5789
# [2300]	training's rmse: 1.50901	valid_1's rmse: 1.57868
# [2400]	training's rmse: 1.507	valid_1's rmse: 1.57851
# [2500]	training's rmse: 1.50505	valid_1's rmse: 1.57837
# [2600]	training's rmse: 1.50307	valid_1's rmse: 1.5782
# [2700]	training's rmse: 1.50113	valid_1's rmse: 1.57808
# [2800]	training's rmse: 1.49921	valid_1's rmse: 1.57792
# [2900]	training's rmse: 1.49737	valid_1's rmse: 1.57779
# [3000]	training's rmse: 1.49553	valid_1's rmse: 1.57772
# [3100]	training's rmse: 1.49372	valid_1's rmse: 1.57766
# [3200]	training's rmse: 1.4919	valid_1's rmse: 1.57759
# [3300]	training's rmse: 1.49013	valid_1's rmse: 1.57751
# [3400]	training's rmse: 1.48835	valid_1's rmse: 1.57747
# [3500]	training's rmse: 1.48663	valid_1's rmse: 1.57742
# [3600]	training's rmse: 1.48487	valid_1's rmse: 1.57734
# [3700]	training's rmse: 1.48314	valid_1's rmse: 1.57726
# [3800]	training's rmse: 1.48142	valid_1's rmse: 1.57724
# [3900]	training's rmse: 1.47975	valid_1's rmse: 1.57717
# [4000]	training's rmse: 1.47811	valid_1's rmse: 1.57712
# [4100]	training's rmse: 1.4764	valid_1's rmse: 1.57705
# [4200]	training's rmse: 1.47474	valid_1's rmse: 1.577
# [4300]	training's rmse: 1.47309	valid_1's rmse: 1.577
# [4400]	training's rmse: 1.47143	valid_1's rmse: 1.57696
# [4500]	training's rmse: 1.46979	valid_1's rmse: 1.57695
# [4600]	training's rmse: 1.46813	valid_1's rmse: 1.57692
# [4700]	training's rmse: 1.4665	valid_1's rmse: 1.57693
# [4800]	training's rmse: 1.46494	valid_1's rmse: 1.57691
# [4900]	training's rmse: 1.46336	valid_1's rmse: 1.57689
# [5000]	training's rmse: 1.46178	valid_1's rmse: 1.57685
# [5100]	training's rmse: 1.46018	valid_1's rmse: 1.57682
# [5200]	training's rmse: 1.45864	valid_1's rmse: 1.57679
# [5300]	training's rmse: 1.45708	valid_1's rmse: 1.57676
# [5400]	training's rmse: 1.45551	valid_1's rmse: 1.57677
# [5500]	training's rmse: 1.45399	valid_1's rmse: 1.57677
# [5600]	training's rmse: 1.45241	valid_1's rmse: 1.57672
# [5700]	training's rmse: 1.45087	valid_1's rmse: 1.57674
# [5800]	training's rmse: 1.44932	valid_1's rmse: 1.57669
# [5900]	training's rmse: 1.44774	valid_1's rmse: 1.57668
# [6000]	training's rmse: 1.44618	valid_1's rmse: 1.57666
# [6100]	training's rmse: 1.44464	valid_1's rmse: 1.57666
# [6200]	training's rmse: 1.44319	valid_1's rmse: 1.57663
# [6300]	training's rmse: 1.44173	valid_1's rmse: 1.57661
# [6400]	training's rmse: 1.44022	valid_1's rmse: 1.57659
# [6500]	training's rmse: 1.4387	valid_1's rmse: 1.57659
# [6600]	training's rmse: 1.43719	valid_1's rmse: 1.57654
# [6700]	training's rmse: 1.43574	valid_1's rmse: 1.57653
# [6800]	training's rmse: 1.43429	valid_1's rmse: 1.57654
# [6900]	training's rmse: 1.43283	valid_1's rmse: 1.57656
# [7000]	training's rmse: 1.43136	valid_1's rmse: 1.5766
# [7100]	training's rmse: 1.42996	valid_1's rmse: 1.57659
# Early stopping, best iteration is:
# [6777]	training's rmse: 1.43461	valid_1's rmse: 1.57652
# 1.5562034043091038

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,50))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
# plt.savefig('lgbm_importances.png')

# %%
df_prediction = pd.DataFrame({"prediction1":predictions, "prediction2":predictions2})
df_prediction
# Out:
#         prediction1  prediction2
# 0         -1.772101    -0.491993
# 1         -0.340621    -0.284341
# 2         -0.954483    -0.464565
# 3         -0.123750    -0.074070
# 4         -1.639489    -1.847595
# 5         -0.014021     0.586024
# 6          0.052838     0.170597
# 7          0.583666     0.857978
# 8         -0.664657    -0.698879
# 9         -1.041531    -0.272145
# 10        -0.676995    -0.447393
# 11         0.018256     0.262864
# 12         0.012180     0.102948
# 13         0.002203     0.179851
# 14        -7.367515    -0.489559
# 15         0.553450     0.616872
# 16         0.274455     0.485122
# 17        -0.179757    -0.090091
# 18         0.132249     0.165192
# 19        -0.008010    -0.250986
# 20         0.113843     0.224972
# 21        -0.649439    -0.746235
# 22        -0.538195     1.341852
# 23         0.166600     0.215686
# 24        -0.700449     0.058916
# 25        -0.133041     0.511067
# 26        -0.776174    -0.788985
# 27        -0.331908    -0.423469
# 28        -0.163876    -0.103746
# 29        -0.422973    -0.533227
# ...             ...          ...
# 123593    -0.349105    -0.418475
# 123594    -1.148577    -1.162040
# 123595     0.035902    -0.012204
# 123596     0.730319     1.293180
# 123597    -0.525091    -0.433111
# 123598    -0.568560    -0.625279
# 123599     0.485234     0.506979
# 123600    -0.694439     0.002943
# 123601    -1.023044    -1.478935
# 123602    -0.579443    -0.212845
# 123603    -0.164643    -0.027231
# 123604     0.472462     0.662576
# 123605    -0.563443    -0.504198
# 123606    -0.552704    -0.348002
# 123607     0.582311     0.561718
# 123608    -0.420970    -0.486622
# 123609     0.202184    -0.074558
# 123610     0.322321     0.579405
# 123611    -1.347581    -1.032455
# 123612    -0.647174    -0.837541
# 123613     0.109756    -0.013334
# 123614     0.395581     0.822092
# 123615    -0.887823    -0.651215
# 123616     0.946981     1.513596
# 123617     0.429210     0.600799
# 123618     0.923642     1.353806
# 123619    -0.367836    -0.421993
# 123620     0.970074     1.139137
# 123621    -2.863084    -0.886110
# 123622     0.102842     0.007577
#
# [123623 rows x 2 columns]

# %%
predictions3 = np.zeros(df_prediction.shape[0])
for i, r in df_prediction.iterrows():
    if r[0] < 0 :
        predictions3[i] = r[0]
    else:
        predictions3[i] = r[1]
df_prediction["prediction3"] = predictions3

# %%
df_prediction
# Out:
#         prediction1  prediction2  prediction3
# 0         -1.772101    -0.491993    -1.772101
# 1         -0.340621    -0.284341    -0.340621
# 2         -0.954483    -0.464565    -0.954483
# 3         -0.123750    -0.074070    -0.123750
# 4         -1.639489    -1.847595    -1.639489
# 5         -0.014021     0.586024    -0.014021
# 6          0.052838     0.170597     0.170597
# 7          0.583666     0.857978     0.857978
# 8         -0.664657    -0.698879    -0.664657
# 9         -1.041531    -0.272145    -1.041531
# 10        -0.676995    -0.447393    -0.676995
# 11         0.018256     0.262864     0.262864
# 12         0.012180     0.102948     0.102948
# 13         0.002203     0.179851     0.179851
# 14        -7.367515    -0.489559    -7.367515
# 15         0.553450     0.616872     0.616872
# 16         0.274455     0.485122     0.485122
# 17        -0.179757    -0.090091    -0.179757
# 18         0.132249     0.165192     0.165192
# 19        -0.008010    -0.250986    -0.008010
# 20         0.113843     0.224972     0.224972
# 21        -0.649439    -0.746235    -0.649439
# 22        -0.538195     1.341852    -0.538195
# 23         0.166600     0.215686     0.215686
# 24        -0.700449     0.058916    -0.700449
# 25        -0.133041     0.511067    -0.133041
# 26        -0.776174    -0.788985    -0.776174
# 27        -0.331908    -0.423469    -0.331908
# 28        -0.163876    -0.103746    -0.163876
# 29        -0.422973    -0.533227    -0.422973
# ...             ...          ...          ...
# 123593    -0.349105    -0.418475    -0.349105
# 123594    -1.148577    -1.162040    -1.148577
# 123595     0.035902    -0.012204    -0.012204
# 123596     0.730319     1.293180     1.293180
# 123597    -0.525091    -0.433111    -0.525091
# 123598    -0.568560    -0.625279    -0.568560
# 123599     0.485234     0.506979     0.506979
# 123600    -0.694439     0.002943    -0.694439
# 123601    -1.023044    -1.478935    -1.023044
# 123602    -0.579443    -0.212845    -0.579443
# 123603    -0.164643    -0.027231    -0.164643
# 123604     0.472462     0.662576     0.662576
# 123605    -0.563443    -0.504198    -0.563443
# 123606    -0.552704    -0.348002    -0.552704
# 123607     0.582311     0.561718     0.561718
# 123608    -0.420970    -0.486622    -0.420970
# 123609     0.202184    -0.074558    -0.074558
# 123610     0.322321     0.579405     0.579405
# 123611    -1.347581    -1.032455    -1.347581
# 123612    -0.647174    -0.837541    -0.647174
# 123613     0.109756    -0.013334    -0.013334
# 123614     0.395581     0.822092     0.822092
# 123615    -0.887823    -0.651215    -0.887823
# 123616     0.946981     1.513596     1.513596
# 123617     0.429210     0.600799     0.600799
# 123618     0.923642     1.353806     1.353806
# 123619    -0.367836    -0.421993    -0.367836
# 123620     0.970074     1.139137     1.139137
# 123621    -2.863084    -0.886110    -2.863084
# 123622     0.102842     0.007577     0.007577
#
# [123623 rows x 3 columns]

# %%
final_predictions = df_prediction.prediction3.values

# %%
# import optuna

# def objective(trial):
#     train_x, test_x, train_y, test_y = train_test_split(df_train[df_train_columns], target, test_size=0.20, random_state=4590)
    
#     dtrain = lgb.Dataset(train_x, label=train_y)
#     dval = lgb.Dataset(test_x, label=test_y)

#     num_round = trial.suggest_int('num_round', 1, 10000)
#     param = {
#         'objective': 'regression', 
#         'metric': 'rmse',
#         'verbosity': -1,
#         'feature_fraction': trial.suggest_loguniform('feature_fraction', 0.8, 0.95),
#         'bagging_fraction': trial.suggest_loguniform('bagging_fraction', 0.8, 0.95),
#         'bagging_seed': 11,
#         'boosting_type': trial.suggest_categorical('boosting', ['gbdt', 'dart', 'goss']),
#         'num_leaves': trial.suggest_int('num_leaves', 10, 100),
#         'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
#         'min_child_samples': trial.suggest_int('min_child_samples', 20, 100),
#         'min_data_in_leaf':  trial.suggest_int('min_data_in_leaf', 10, 1000),
#         'lambda_l1':  trial.suggest_loguniform('lambda_l1', 1e-2, 1.0)
#     }

#     if param['boosting_type'] == 'dart':
#         param['drop_rate'] = trial.suggest_loguniform('drop_rate', 1e-4, 1.0)
#         param['skip_drop'] = trial.suggest_loguniform('skip_drop', 1e-4, 1.0)
#     if param['boosting_type'] == 'goss':
#         param['top_rate'] = trial.suggest_uniform('top_rate', 0.0, 1.0)
#         param['other_rate'] = trial.suggest_uniform('other_rate', 0.0, 1.0 - param['top_rate'])

#     gbm = lgb.train(param, dtrain, num_round, valid_sets = [dtrain, dval], verbose_eval=100, early_stopping_rounds=400)
#     preds = gbm.predict(test_x)
#     pred_labels = np.rint(preds)
#     rmse = np.sqrt(mean_squared_error(test_y, pred_labels))
#     return rmse

# study = optuna.create_study()
# study.optimize(objective, n_trials=20)

# print('Number of finished trials: {}'.format(len(study.trials)))

# print('Best trial:')
# trial = study.best_trial

# print('  Value: {}'.format(trial.value))

# print('  Params: ')
# for key, value in trial.params.items():
#     print('    {}: {}'.format(key, value))

# %%
sub_df = pd.DataFrame({"card_id":df_test["card_id"].values})
sub_df["target"] = final_predictions
sub_df.to_csv("../output/submission_model20181225.csv", index=False)
