# %%
import numpy as np
import pandas as pd
import datetime
from itertools import combinations

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import lightgbm as lgb

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error, roc_auc_score, confusion_matrix, f1_score
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')
np.random.seed(4590)

# %%
df_train = pd.read_csv('../input/20181216_train.csv')
df_test = pd.read_csv('../input/20181216_test.csv')

df_train = df_train[df_train.target > -30].reset_index(drop=True)

# %%
df_train["outliers"] = np.where(df_train.target < -30, 1, 0)

# %%
def merge_new_feature(path):
    df_new_feature = pd.read_csv(path)
    
    df_tr = pd.merge(df_train, df_new_feature, on="card_id", how="left")
    df_te = pd.merge(df_test, df_new_feature, on="card_id", how="left")
    
    return df_tr, df_te

# %%
df_train, df_test = merge_new_feature("../input/feature_categorical_count_rate.csv")
df_train, df_test = merge_new_feature("../input/feature_various_time_data.csv")
df_train, df_test = merge_new_feature("../input/merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/payment_splited_by_installments_NMF.csv")
df_train, df_test = merge_new_feature("../input/feature_catogorical_count_weighted_elapsed.csv")
df_train, df_test = merge_new_feature("../input/feature_latest_transaction_data__per__card_id.csv")

# %%
dont_use = ['card_id', 'first_active_month','second_active_date','diff_first_and_second','target','outliers', 'category_1_Y_std']

df_train_columns = [c for c in df_train.columns if c not in dont_use]
target = df_train['target']
target_outlier = df_train["outliers"]

# %%
drop_col = []
comb = list(combinations(df_train_columns, 2))

for c1, c2 in comb:
    corr = np.corrcoef(df_train[c1], df_train[c2])[0,1]
    if corr >= 0.95:
        print("【{i}】 --- 【{j}】".format(i=c1, j=c2))
        print(corr)
        drop_col.append(c2)
        print("\n"*2)

for col in df_train_columns:
    if col in sorted(set(drop_col)):
        df_train_columns.remove(col)
# Out:
# 【hist_authorized_flag_sum】 --- 【hist_card_id_size】
# 0.9947393603861712
#
#
#
# 【hist_authorized_flag_sum】 --- 【card_id_count】
# 0.9936737901353109
#
#
#
# 【hist_authorized_flag_sum】 --- 【authorized_flag_ture】
# 0.9979568046035838
#
#
#
# 【hist_authorized_flag_sum】 --- 【authorized_flag_ture_weighted_elapsed】
# 0.9979568046035838
#
#
#
# 【hist_authorized_flag_mean】 --- 【authorized_flag_ture_rate】
# 0.9869741348004349
#
#
#
# 【hist_category_1_sum】 --- 【category_1_true】
# 0.9996021555939594
#
#
#
# 【hist_category_1_sum】 --- 【category_1_true_weighted_elapsed】
# 0.9996021555939594
#
#
#
# 【hist_category_1_mean】 --- 【category_1_true_rate】
# 0.9914367588725521
#
#
#
# 【hist_card_id_size】 --- 【card_id_count】
# 0.998121515061866
#
#
#
# 【hist_card_id_size】 --- 【authorized_flag_ture】
# 0.9920960079272706
#
#
#
# 【hist_card_id_size】 --- 【authorized_flag_ture_weighted_elapsed】
# 0.9920960079272706
#
#
#
# 【hist_purchase_date_diff】 --- 【elapsed_from_oldest_purchase_date_to_latest_purchase_date】
# 0.9690414623940978
#
#
#
# 【new_hist_purchase_date_max】 --- 【new_hist_purchase_date_min】
# 0.9999998770135861
#
#
#
# 【hist_first_buy】 --- 【elapsed_from_oldest_purchase_date_to_first_active】
# 1.0
#
#
#
# 【card_id_count】 --- 【authorized_flag_ture】
# 0.9949413458445171
#
#
#
# 【card_id_count】 --- 【authorized_flag_ture_weighted_elapsed】
# 0.9949413458445171
#
#
#
# 【authorized_flag_ture】 --- 【authorized_flag_ture_weighted_elapsed】
# 0.9999999999999999
#
#
#
# 【category_1_true】 --- 【category_1_true_weighted_elapsed】
# 0.9999999999999998
#
#
#
# 【category_3_A】 --- 【installments_0】
# 1.0
#
#
#
# 【category_3_B】 --- 【installments_1】
# 1.0
#
#
#
# 【category_3_A_rate】 --- 【installments_0_rate】
# 0.9999999999999999
#
#
#
# 【category_3_A_rate】 --- 【category_3_A_latest_trs】
# 0.9892483812245457
#
#
#
# 【category_3_B_rate】 --- 【installments_1_rate】
# 1.0
#
#
#
# 【installments_0_rate】 --- 【category_3_A_latest_trs】
# 0.9892483812245457
#
#
#
# 【month_lag_N13】 --- 【month_lag_N13_weighted_elapsed】
# 0.9993136185136181
#
#
#
# 【month_lag_N12】 --- 【month_lag_N12_weighted_elapsed】
# 0.9965777288701491
#
#
#
# 【month_lag_N11】 --- 【month_lag_N11_weighted_elapsed】
# 0.9917192221045992
#
#
#
# 【month_lag_N10】 --- 【month_lag_N10_weighted_elapsed】
# 0.9810396205200158
#
#
#
# 【month_lag_N9】 --- 【month_lag_N9_weighted_elapsed】
# 0.9727700197295579
#
#
#
# 【month_lag_N8】 --- 【month_lag_N8_weighted_elapsed】
# 0.9644683686298695
#
#
#
# 【month_lag_N7】 --- 【month_lag_N7_weighted_elapsed】
# 0.96312319150466
#
#
#
# 【category_3_A_weighted_elapsed】 --- 【installments_0_weighted_elapsed】
# 1.0
#
#
#
# 【category_3_B_weighted_elapsed】 --- 【installments_1_weighted_elapsed】
# 1.0
#
#
#
# 【category_4_null_latest_trs】 --- 【numerical_1_null_latest_trs】
# 1.0
#
#
#
# 【category_4_null_latest_trs】 --- 【most_recent_sales_range_null_latest_trs】
# 1.0
#
#
#
# 【category_4_null_latest_trs】 --- 【most_recent_purchases_range_null_latest_trs】
# 1.0
#
#
#
# 【numerical_1_null_latest_trs】 --- 【most_recent_sales_range_null_latest_trs】
# 1.0
#
#
#
# 【numerical_1_null_latest_trs】 --- 【most_recent_purchases_range_null_latest_trs】
# 1.0
#
#
#
# 【most_recent_sales_range_null_latest_trs】 --- 【most_recent_purchases_range_null_latest_trs】
# 1.0

# %%
#original
param = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',  #regression
    'max_depth': 8,  # -1
    'learning_rate': 0.004,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',  #auc
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(target, oof))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65301	valid_1's rmse: 1.652
# [200]	training's rmse: 1.61802	valid_1's rmse: 1.61749
# [300]	training's rmse: 1.59742	valid_1's rmse: 1.59784
# [400]	training's rmse: 1.58395	valid_1's rmse: 1.58569
# [500]	training's rmse: 1.57443	valid_1's rmse: 1.57753
# [600]	training's rmse: 1.5671	valid_1's rmse: 1.57184
# [700]	training's rmse: 1.5612	valid_1's rmse: 1.5677
# [800]	training's rmse: 1.5563	valid_1's rmse: 1.56469
# [900]	training's rmse: 1.55201	valid_1's rmse: 1.56235
# [1000]	training's rmse: 1.5481	valid_1's rmse: 1.56038
# [1100]	training's rmse: 1.54454	valid_1's rmse: 1.55873
# [1200]	training's rmse: 1.54127	valid_1's rmse: 1.55743
# [1300]	training's rmse: 1.53821	valid_1's rmse: 1.55633
# [1400]	training's rmse: 1.53538	valid_1's rmse: 1.55545
# [1500]	training's rmse: 1.5327	valid_1's rmse: 1.55467
# [1600]	training's rmse: 1.53017	valid_1's rmse: 1.55403
# [1700]	training's rmse: 1.52769	valid_1's rmse: 1.55348
# [1800]	training's rmse: 1.52534	valid_1's rmse: 1.5531
# [1900]	training's rmse: 1.52312	valid_1's rmse: 1.55273
# [2000]	training's rmse: 1.52098	valid_1's rmse: 1.55246
# [2100]	training's rmse: 1.51887	valid_1's rmse: 1.5522
# [2200]	training's rmse: 1.51685	valid_1's rmse: 1.55197
# [2300]	training's rmse: 1.51488	valid_1's rmse: 1.55173
# [2400]	training's rmse: 1.51297	valid_1's rmse: 1.55152
# [2500]	training's rmse: 1.51109	valid_1's rmse: 1.55135
# [2600]	training's rmse: 1.5092	valid_1's rmse: 1.55122
# [2700]	training's rmse: 1.50736	valid_1's rmse: 1.55109
# [2800]	training's rmse: 1.50558	valid_1's rmse: 1.55096
# [2900]	training's rmse: 1.50377	valid_1's rmse: 1.55086
# [3000]	training's rmse: 1.50204	valid_1's rmse: 1.55079
# [3100]	training's rmse: 1.50037	valid_1's rmse: 1.55067
# [3200]	training's rmse: 1.49864	valid_1's rmse: 1.55059
# [3300]	training's rmse: 1.49693	valid_1's rmse: 1.55055
# [3400]	training's rmse: 1.49528	valid_1's rmse: 1.55045
# [3500]	training's rmse: 1.49362	valid_1's rmse: 1.55039
# [3600]	training's rmse: 1.49197	valid_1's rmse: 1.55033
# [3700]	training's rmse: 1.49033	valid_1's rmse: 1.55028
# [3800]	training's rmse: 1.48872	valid_1's rmse: 1.55025
# [3900]	training's rmse: 1.48711	valid_1's rmse: 1.55022
# [4000]	training's rmse: 1.48554	valid_1's rmse: 1.5502
# [4100]	training's rmse: 1.48396	valid_1's rmse: 1.5502
# [4200]	training's rmse: 1.48238	valid_1's rmse: 1.55014
# [4300]	training's rmse: 1.48083	valid_1's rmse: 1.55014
# [4400]	training's rmse: 1.47926	valid_1's rmse: 1.55012
# [4500]	training's rmse: 1.47773	valid_1's rmse: 1.55008
# [4600]	training's rmse: 1.47618	valid_1's rmse: 1.55003
# [4700]	training's rmse: 1.47467	valid_1's rmse: 1.55003
# [4800]	training's rmse: 1.4731	valid_1's rmse: 1.54998
# [4900]	training's rmse: 1.47158	valid_1's rmse: 1.54994
# [5000]	training's rmse: 1.47007	valid_1's rmse: 1.54989
# [5100]	training's rmse: 1.46859	valid_1's rmse: 1.5499
# [5200]	training's rmse: 1.46712	valid_1's rmse: 1.54988
# [5300]	training's rmse: 1.46563	valid_1's rmse: 1.54984
# [5400]	training's rmse: 1.46415	valid_1's rmse: 1.54981
# [5500]	training's rmse: 1.46269	valid_1's rmse: 1.5498
# [5600]	training's rmse: 1.46128	valid_1's rmse: 1.54979
# [5700]	training's rmse: 1.4598	valid_1's rmse: 1.54975
# [5800]	training's rmse: 1.4584	valid_1's rmse: 1.54977
# [5900]	training's rmse: 1.45701	valid_1's rmse: 1.54977
# [6000]	training's rmse: 1.4555	valid_1's rmse: 1.54974
# [6100]	training's rmse: 1.45407	valid_1's rmse: 1.54974
# [6200]	training's rmse: 1.45268	valid_1's rmse: 1.54974
# [6300]	training's rmse: 1.45123	valid_1's rmse: 1.54971
# [6400]	training's rmse: 1.4498	valid_1's rmse: 1.5497
# [6500]	training's rmse: 1.4484	valid_1's rmse: 1.54971
# [6600]	training's rmse: 1.44694	valid_1's rmse: 1.54974
# [6700]	training's rmse: 1.44553	valid_1's rmse: 1.54975
# [6800]	training's rmse: 1.44415	valid_1's rmse: 1.54974
# Early stopping, best iteration is:
# [6458]	training's rmse: 1.44899	valid_1's rmse: 1.54969
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65625	valid_1's rmse: 1.6359
# [200]	training's rmse: 1.62065	valid_1's rmse: 1.60371
# [300]	training's rmse: 1.5998	valid_1's rmse: 1.58584
# [400]	training's rmse: 1.58626	valid_1's rmse: 1.57499
# [500]	training's rmse: 1.57657	valid_1's rmse: 1.56777
# [600]	training's rmse: 1.56925	valid_1's rmse: 1.56278
# [700]	training's rmse: 1.56334	valid_1's rmse: 1.55914
# [800]	training's rmse: 1.55838	valid_1's rmse: 1.55638
# [900]	training's rmse: 1.55411	valid_1's rmse: 1.55418
# [1000]	training's rmse: 1.55031	valid_1's rmse: 1.55239
# [1100]	training's rmse: 1.54681	valid_1's rmse: 1.55088
# [1200]	training's rmse: 1.54361	valid_1's rmse: 1.5496
# [1300]	training's rmse: 1.54062	valid_1's rmse: 1.54852
# [1400]	training's rmse: 1.5378	valid_1's rmse: 1.54753
# [1500]	training's rmse: 1.53514	valid_1's rmse: 1.54671
# [1600]	training's rmse: 1.53267	valid_1's rmse: 1.54599
# [1700]	training's rmse: 1.53024	valid_1's rmse: 1.54538
# [1800]	training's rmse: 1.52794	valid_1's rmse: 1.54487
# [1900]	training's rmse: 1.52573	valid_1's rmse: 1.54447
# [2000]	training's rmse: 1.52361	valid_1's rmse: 1.54409
# [2100]	training's rmse: 1.52151	valid_1's rmse: 1.54371
# [2200]	training's rmse: 1.51948	valid_1's rmse: 1.54344
# [2300]	training's rmse: 1.51745	valid_1's rmse: 1.54319
# [2400]	training's rmse: 1.51553	valid_1's rmse: 1.54298
# [2500]	training's rmse: 1.51361	valid_1's rmse: 1.54278
# [2600]	training's rmse: 1.51178	valid_1's rmse: 1.54263
# [2700]	training's rmse: 1.50996	valid_1's rmse: 1.54245
# [2800]	training's rmse: 1.50813	valid_1's rmse: 1.54235
# [2900]	training's rmse: 1.50634	valid_1's rmse: 1.54223
# [3000]	training's rmse: 1.50463	valid_1's rmse: 1.5421
# [3100]	training's rmse: 1.50291	valid_1's rmse: 1.54199
# [3200]	training's rmse: 1.50122	valid_1's rmse: 1.5419
# [3300]	training's rmse: 1.49955	valid_1's rmse: 1.54183
# [3400]	training's rmse: 1.49789	valid_1's rmse: 1.54174
# [3500]	training's rmse: 1.49621	valid_1's rmse: 1.54166
# [3600]	training's rmse: 1.49456	valid_1's rmse: 1.54161
# [3700]	training's rmse: 1.49292	valid_1's rmse: 1.54156
# [3800]	training's rmse: 1.49132	valid_1's rmse: 1.54153
# [3900]	training's rmse: 1.4897	valid_1's rmse: 1.54147
# [4000]	training's rmse: 1.48813	valid_1's rmse: 1.54141
# [4100]	training's rmse: 1.48658	valid_1's rmse: 1.54135
# [4200]	training's rmse: 1.48501	valid_1's rmse: 1.5413
# [4300]	training's rmse: 1.48339	valid_1's rmse: 1.54122
# [4400]	training's rmse: 1.48185	valid_1's rmse: 1.5412
# [4500]	training's rmse: 1.48031	valid_1's rmse: 1.54113
# [4600]	training's rmse: 1.4788	valid_1's rmse: 1.5411
# [4700]	training's rmse: 1.47724	valid_1's rmse: 1.54103
# [4800]	training's rmse: 1.47572	valid_1's rmse: 1.54098
# [4900]	training's rmse: 1.47423	valid_1's rmse: 1.54092
# [5000]	training's rmse: 1.47272	valid_1's rmse: 1.54089
# [5100]	training's rmse: 1.47124	valid_1's rmse: 1.54083
# [5200]	training's rmse: 1.46972	valid_1's rmse: 1.54075
# [5300]	training's rmse: 1.46826	valid_1's rmse: 1.54073
# [5400]	training's rmse: 1.46679	valid_1's rmse: 1.54071
# [5500]	training's rmse: 1.46531	valid_1's rmse: 1.54066
# [5600]	training's rmse: 1.46379	valid_1's rmse: 1.54062
# [5700]	training's rmse: 1.46228	valid_1's rmse: 1.54061
# [5800]	training's rmse: 1.46078	valid_1's rmse: 1.5406
# [5900]	training's rmse: 1.45928	valid_1's rmse: 1.54057
# [6000]	training's rmse: 1.45784	valid_1's rmse: 1.54055
# [6100]	training's rmse: 1.45638	valid_1's rmse: 1.54053
# [6200]	training's rmse: 1.45497	valid_1's rmse: 1.5405
# [6300]	training's rmse: 1.45353	valid_1's rmse: 1.54049
# [6400]	training's rmse: 1.4521	valid_1's rmse: 1.54046
# [6500]	training's rmse: 1.4507	valid_1's rmse: 1.54043
# [6600]	training's rmse: 1.4493	valid_1's rmse: 1.5404
# [6700]	training's rmse: 1.44791	valid_1's rmse: 1.54038
# [6800]	training's rmse: 1.4465	valid_1's rmse: 1.54033
# [6900]	training's rmse: 1.4451	valid_1's rmse: 1.54029
# [7000]	training's rmse: 1.44373	valid_1's rmse: 1.54028
# [7100]	training's rmse: 1.44236	valid_1's rmse: 1.54031
# [7200]	training's rmse: 1.44096	valid_1's rmse: 1.5403
# [7300]	training's rmse: 1.43958	valid_1's rmse: 1.54029
# [7400]	training's rmse: 1.4382	valid_1's rmse: 1.5403
# [7500]	training's rmse: 1.43683	valid_1's rmse: 1.54031
# [7600]	training's rmse: 1.43549	valid_1's rmse: 1.54028
# [7700]	training's rmse: 1.43411	valid_1's rmse: 1.54028
# [7800]	training's rmse: 1.43279	valid_1's rmse: 1.54029
# [7900]	training's rmse: 1.43149	valid_1's rmse: 1.54024
# [8000]	training's rmse: 1.43015	valid_1's rmse: 1.54023
# [8100]	training's rmse: 1.42882	valid_1's rmse: 1.54022
# [8200]	training's rmse: 1.42751	valid_1's rmse: 1.54022
# [8300]	training's rmse: 1.42615	valid_1's rmse: 1.54021
# [8400]	training's rmse: 1.4248	valid_1's rmse: 1.5402
# [8500]	training's rmse: 1.42347	valid_1's rmse: 1.54019
# [8600]	training's rmse: 1.42213	valid_1's rmse: 1.54016
# [8700]	training's rmse: 1.42086	valid_1's rmse: 1.54018
# [8800]	training's rmse: 1.41957	valid_1's rmse: 1.54019
# [8900]	training's rmse: 1.41825	valid_1's rmse: 1.54021
# Early stopping, best iteration is:
# [8592]	training's rmse: 1.42223	valid_1's rmse: 1.54016
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.6519	valid_1's rmse: 1.65478
# [200]	training's rmse: 1.61677	valid_1's rmse: 1.62149
# [300]	training's rmse: 1.59617	valid_1's rmse: 1.60268
# [400]	training's rmse: 1.58278	valid_1's rmse: 1.59104
# [500]	training's rmse: 1.5732	valid_1's rmse: 1.58336
# [600]	training's rmse: 1.56592	valid_1's rmse: 1.57804
# [700]	training's rmse: 1.56005	valid_1's rmse: 1.57408
# [800]	training's rmse: 1.5551	valid_1's rmse: 1.57106
# [900]	training's rmse: 1.55084	valid_1's rmse: 1.56877
# [1000]	training's rmse: 1.54699	valid_1's rmse: 1.56686
# [1100]	training's rmse: 1.54354	valid_1's rmse: 1.56528
# [1200]	training's rmse: 1.5403	valid_1's rmse: 1.56396
# [1300]	training's rmse: 1.53735	valid_1's rmse: 1.56289
# [1400]	training's rmse: 1.53458	valid_1's rmse: 1.5619
# [1500]	training's rmse: 1.53193	valid_1's rmse: 1.56112
# [1600]	training's rmse: 1.52948	valid_1's rmse: 1.56042
# [1700]	training's rmse: 1.52707	valid_1's rmse: 1.55985
# [1800]	training's rmse: 1.52479	valid_1's rmse: 1.55939
# [1900]	training's rmse: 1.52259	valid_1's rmse: 1.55899
# [2000]	training's rmse: 1.52046	valid_1's rmse: 1.55863
# [2100]	training's rmse: 1.51839	valid_1's rmse: 1.55834
# [2200]	training's rmse: 1.51638	valid_1's rmse: 1.55806
# [2300]	training's rmse: 1.51443	valid_1's rmse: 1.55781
# [2400]	training's rmse: 1.5125	valid_1's rmse: 1.55762
# [2500]	training's rmse: 1.51057	valid_1's rmse: 1.55743
# [2600]	training's rmse: 1.50876	valid_1's rmse: 1.55731
# [2700]	training's rmse: 1.50696	valid_1's rmse: 1.5572
# [2800]	training's rmse: 1.50519	valid_1's rmse: 1.55704
# [2900]	training's rmse: 1.50346	valid_1's rmse: 1.55691
# [3000]	training's rmse: 1.50174	valid_1's rmse: 1.5568
# [3100]	training's rmse: 1.5	valid_1's rmse: 1.55667
# [3200]	training's rmse: 1.49829	valid_1's rmse: 1.55657
# [3300]	training's rmse: 1.4966	valid_1's rmse: 1.55646
# [3400]	training's rmse: 1.49495	valid_1's rmse: 1.55635
# [3500]	training's rmse: 1.4933	valid_1's rmse: 1.5563
# [3600]	training's rmse: 1.49166	valid_1's rmse: 1.55623
# [3700]	training's rmse: 1.49007	valid_1's rmse: 1.55619
# [3800]	training's rmse: 1.48845	valid_1's rmse: 1.55613
# [3900]	training's rmse: 1.48681	valid_1's rmse: 1.55608
# [4000]	training's rmse: 1.48523	valid_1's rmse: 1.55599
# [4100]	training's rmse: 1.48365	valid_1's rmse: 1.55594
# [4200]	training's rmse: 1.48206	valid_1's rmse: 1.55585
# [4300]	training's rmse: 1.48051	valid_1's rmse: 1.55582
# [4400]	training's rmse: 1.47898	valid_1's rmse: 1.5558
# [4500]	training's rmse: 1.47745	valid_1's rmse: 1.55575
# [4600]	training's rmse: 1.47594	valid_1's rmse: 1.55572
# [4700]	training's rmse: 1.47439	valid_1's rmse: 1.55567
# [4800]	training's rmse: 1.4729	valid_1's rmse: 1.55565
# [4900]	training's rmse: 1.47141	valid_1's rmse: 1.55563
# [5000]	training's rmse: 1.46993	valid_1's rmse: 1.55559
# [5100]	training's rmse: 1.46844	valid_1's rmse: 1.55558
# [5200]	training's rmse: 1.46692	valid_1's rmse: 1.55561
# [5300]	training's rmse: 1.46545	valid_1's rmse: 1.5556
# [5400]	training's rmse: 1.46398	valid_1's rmse: 1.55557
# [5500]	training's rmse: 1.46252	valid_1's rmse: 1.55553
# [5600]	training's rmse: 1.46109	valid_1's rmse: 1.55552
# [5700]	training's rmse: 1.45967	valid_1's rmse: 1.55551
# [5800]	training's rmse: 1.45822	valid_1's rmse: 1.5555
# [5900]	training's rmse: 1.45675	valid_1's rmse: 1.55551
# [6000]	training's rmse: 1.45531	valid_1's rmse: 1.5555
# [6100]	training's rmse: 1.45388	valid_1's rmse: 1.55549
# [6200]	training's rmse: 1.45245	valid_1's rmse: 1.55547
# [6300]	training's rmse: 1.45103	valid_1's rmse: 1.55544
# [6400]	training's rmse: 1.44965	valid_1's rmse: 1.55544
# [6500]	training's rmse: 1.44825	valid_1's rmse: 1.55544
# [6600]	training's rmse: 1.44681	valid_1's rmse: 1.55542
# [6700]	training's rmse: 1.44545	valid_1's rmse: 1.55543
# [6800]	training's rmse: 1.44407	valid_1's rmse: 1.55542
# [6900]	training's rmse: 1.44269	valid_1's rmse: 1.55539
# [7000]	training's rmse: 1.44132	valid_1's rmse: 1.55536
# [7100]	training's rmse: 1.43994	valid_1's rmse: 1.55534
# [7200]	training's rmse: 1.43856	valid_1's rmse: 1.55534
# [7300]	training's rmse: 1.43719	valid_1's rmse: 1.55533
# [7400]	training's rmse: 1.43584	valid_1's rmse: 1.55534
# [7500]	training's rmse: 1.43447	valid_1's rmse: 1.55533
# [7600]	training's rmse: 1.43312	valid_1's rmse: 1.55534
# [7700]	training's rmse: 1.43177	valid_1's rmse: 1.55534
# [7800]	training's rmse: 1.43046	valid_1's rmse: 1.55535
# [7900]	training's rmse: 1.42916	valid_1's rmse: 1.55539
# Early stopping, best iteration is:
# [7514]	training's rmse: 1.43427	valid_1's rmse: 1.55531
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65233	valid_1's rmse: 1.65314
# [200]	training's rmse: 1.61715	valid_1's rmse: 1.62026
# [300]	training's rmse: 1.59653	valid_1's rmse: 1.60191
# [400]	training's rmse: 1.58313	valid_1's rmse: 1.59067
# [500]	training's rmse: 1.57353	valid_1's rmse: 1.58314
# [600]	training's rmse: 1.56624	valid_1's rmse: 1.57781
# [700]	training's rmse: 1.56029	valid_1's rmse: 1.57378
# [800]	training's rmse: 1.55537	valid_1's rmse: 1.57083
# [900]	training's rmse: 1.55111	valid_1's rmse: 1.56844
# [1000]	training's rmse: 1.54727	valid_1's rmse: 1.56647
# [1100]	training's rmse: 1.54379	valid_1's rmse: 1.56475
# [1200]	training's rmse: 1.54061	valid_1's rmse: 1.56333
# [1300]	training's rmse: 1.53764	valid_1's rmse: 1.56214
# [1400]	training's rmse: 1.53486	valid_1's rmse: 1.56114
# [1500]	training's rmse: 1.53222	valid_1's rmse: 1.56031
# [1600]	training's rmse: 1.52972	valid_1's rmse: 1.55961
# [1700]	training's rmse: 1.52734	valid_1's rmse: 1.55899
# [1800]	training's rmse: 1.52505	valid_1's rmse: 1.55846
# [1900]	training's rmse: 1.52284	valid_1's rmse: 1.55799
# [2000]	training's rmse: 1.52073	valid_1's rmse: 1.55759
# [2100]	training's rmse: 1.51864	valid_1's rmse: 1.55726
# [2200]	training's rmse: 1.51662	valid_1's rmse: 1.55695
# [2300]	training's rmse: 1.51464	valid_1's rmse: 1.55669
# [2400]	training's rmse: 1.51272	valid_1's rmse: 1.5565
# [2500]	training's rmse: 1.51084	valid_1's rmse: 1.55639
# [2600]	training's rmse: 1.50893	valid_1's rmse: 1.55623
# [2700]	training's rmse: 1.50712	valid_1's rmse: 1.55606
# [2800]	training's rmse: 1.50529	valid_1's rmse: 1.55594
# [2900]	training's rmse: 1.50351	valid_1's rmse: 1.55581
# [3000]	training's rmse: 1.50173	valid_1's rmse: 1.5557
# [3100]	training's rmse: 1.50002	valid_1's rmse: 1.55559
# [3200]	training's rmse: 1.49827	valid_1's rmse: 1.5555
# [3300]	training's rmse: 1.49654	valid_1's rmse: 1.55545
# [3400]	training's rmse: 1.49485	valid_1's rmse: 1.55535
# [3500]	training's rmse: 1.4932	valid_1's rmse: 1.55532
# [3600]	training's rmse: 1.49156	valid_1's rmse: 1.55529
# [3700]	training's rmse: 1.48996	valid_1's rmse: 1.55521
# [3800]	training's rmse: 1.48837	valid_1's rmse: 1.55517
# [3900]	training's rmse: 1.48672	valid_1's rmse: 1.55512
# [4000]	training's rmse: 1.48513	valid_1's rmse: 1.55506
# [4100]	training's rmse: 1.48353	valid_1's rmse: 1.55501
# [4200]	training's rmse: 1.48194	valid_1's rmse: 1.55502
# [4300]	training's rmse: 1.48036	valid_1's rmse: 1.55497
# [4400]	training's rmse: 1.47882	valid_1's rmse: 1.5549
# [4500]	training's rmse: 1.47728	valid_1's rmse: 1.55482
# [4600]	training's rmse: 1.47577	valid_1's rmse: 1.55479
# [4700]	training's rmse: 1.47426	valid_1's rmse: 1.55476
# [4800]	training's rmse: 1.47272	valid_1's rmse: 1.55475
# [4900]	training's rmse: 1.47125	valid_1's rmse: 1.55474
# [5000]	training's rmse: 1.46971	valid_1's rmse: 1.5547
# [5100]	training's rmse: 1.4682	valid_1's rmse: 1.55469
# [5200]	training's rmse: 1.46668	valid_1's rmse: 1.55465
# [5300]	training's rmse: 1.46518	valid_1's rmse: 1.55461
# [5400]	training's rmse: 1.46366	valid_1's rmse: 1.55459
# [5500]	training's rmse: 1.46219	valid_1's rmse: 1.55455
# [5600]	training's rmse: 1.46076	valid_1's rmse: 1.55452
# [5700]	training's rmse: 1.45929	valid_1's rmse: 1.5545
# [5800]	training's rmse: 1.45781	valid_1's rmse: 1.55448
# [5900]	training's rmse: 1.45636	valid_1's rmse: 1.55445
# [6000]	training's rmse: 1.45497	valid_1's rmse: 1.55444
# [6100]	training's rmse: 1.45353	valid_1's rmse: 1.55443
# [6200]	training's rmse: 1.45211	valid_1's rmse: 1.55445
# [6300]	training's rmse: 1.45067	valid_1's rmse: 1.55446
# Early stopping, best iteration is:
# [5960]	training's rmse: 1.45554	valid_1's rmse: 1.55442
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.64731	valid_1's rmse: 1.67454
# [200]	training's rmse: 1.61215	valid_1's rmse: 1.64137
# [300]	training's rmse: 1.59148	valid_1's rmse: 1.6227
# [400]	training's rmse: 1.57802	valid_1's rmse: 1.61116
# [500]	training's rmse: 1.56839	valid_1's rmse: 1.60338
# [600]	training's rmse: 1.56113	valid_1's rmse: 1.59796
# [700]	training's rmse: 1.55528	valid_1's rmse: 1.59394
# [800]	training's rmse: 1.55038	valid_1's rmse: 1.59097
# [900]	training's rmse: 1.54611	valid_1's rmse: 1.58858
# [1000]	training's rmse: 1.54232	valid_1's rmse: 1.5867
# [1100]	training's rmse: 1.53886	valid_1's rmse: 1.58519
# [1200]	training's rmse: 1.53565	valid_1's rmse: 1.58382
# [1300]	training's rmse: 1.53269	valid_1's rmse: 1.58273
# [1400]	training's rmse: 1.52991	valid_1's rmse: 1.58183
# [1500]	training's rmse: 1.52728	valid_1's rmse: 1.58104
# [1600]	training's rmse: 1.52478	valid_1's rmse: 1.58032
# [1700]	training's rmse: 1.5224	valid_1's rmse: 1.57983
# [1800]	training's rmse: 1.52008	valid_1's rmse: 1.57935
# [1900]	training's rmse: 1.51789	valid_1's rmse: 1.57892
# [2000]	training's rmse: 1.51577	valid_1's rmse: 1.57862
# [2100]	training's rmse: 1.51371	valid_1's rmse: 1.57836
# [2200]	training's rmse: 1.51171	valid_1's rmse: 1.57814
# [2300]	training's rmse: 1.50973	valid_1's rmse: 1.57799
# [2400]	training's rmse: 1.50783	valid_1's rmse: 1.57781
# [2500]	training's rmse: 1.50598	valid_1's rmse: 1.57768
# [2600]	training's rmse: 1.50411	valid_1's rmse: 1.57751
# [2700]	training's rmse: 1.50227	valid_1's rmse: 1.57737
# [2800]	training's rmse: 1.5005	valid_1's rmse: 1.57726
# [2900]	training's rmse: 1.49876	valid_1's rmse: 1.57717
# [3000]	training's rmse: 1.497	valid_1's rmse: 1.57709
# [3100]	training's rmse: 1.49531	valid_1's rmse: 1.57698
# [3200]	training's rmse: 1.49358	valid_1's rmse: 1.57692
# [3300]	training's rmse: 1.49187	valid_1's rmse: 1.57685
# [3400]	training's rmse: 1.49018	valid_1's rmse: 1.57677
# [3500]	training's rmse: 1.48855	valid_1's rmse: 1.57671
# [3600]	training's rmse: 1.48692	valid_1's rmse: 1.57663
# [3700]	training's rmse: 1.48534	valid_1's rmse: 1.57657
# [3800]	training's rmse: 1.48373	valid_1's rmse: 1.57652
# [3900]	training's rmse: 1.48209	valid_1's rmse: 1.57645
# [4000]	training's rmse: 1.4805	valid_1's rmse: 1.57641
# [4100]	training's rmse: 1.47894	valid_1's rmse: 1.57638
# [4200]	training's rmse: 1.47732	valid_1's rmse: 1.57632
# [4300]	training's rmse: 1.47578	valid_1's rmse: 1.57628
# [4400]	training's rmse: 1.47421	valid_1's rmse: 1.57624
# [4500]	training's rmse: 1.47268	valid_1's rmse: 1.57619
# [4600]	training's rmse: 1.47117	valid_1's rmse: 1.57616
# [4700]	training's rmse: 1.46965	valid_1's rmse: 1.57614
# [4800]	training's rmse: 1.46817	valid_1's rmse: 1.57611
# [4900]	training's rmse: 1.4667	valid_1's rmse: 1.57606
# [5000]	training's rmse: 1.46522	valid_1's rmse: 1.576
# [5100]	training's rmse: 1.46373	valid_1's rmse: 1.57596
# [5200]	training's rmse: 1.46226	valid_1's rmse: 1.57592
# [5300]	training's rmse: 1.46077	valid_1's rmse: 1.57593
# [5400]	training's rmse: 1.45929	valid_1's rmse: 1.57588
# [5500]	training's rmse: 1.45781	valid_1's rmse: 1.57585
# [5600]	training's rmse: 1.45632	valid_1's rmse: 1.57584
# [5700]	training's rmse: 1.45486	valid_1's rmse: 1.57584
# [5800]	training's rmse: 1.45341	valid_1's rmse: 1.57583
# [5900]	training's rmse: 1.45195	valid_1's rmse: 1.57581
# [6000]	training's rmse: 1.45049	valid_1's rmse: 1.57581
# [6100]	training's rmse: 1.44905	valid_1's rmse: 1.57577
# [6200]	training's rmse: 1.44765	valid_1's rmse: 1.57576
# [6300]	training's rmse: 1.44619	valid_1's rmse: 1.57576
# [6400]	training's rmse: 1.44481	valid_1's rmse: 1.57576
# [6500]	training's rmse: 1.44342	valid_1's rmse: 1.57575
# [6600]	training's rmse: 1.44202	valid_1's rmse: 1.57573
# [6700]	training's rmse: 1.44058	valid_1's rmse: 1.57573
# [6800]	training's rmse: 1.43915	valid_1's rmse: 1.57574
# [6900]	training's rmse: 1.43776	valid_1's rmse: 1.57572
# [7000]	training's rmse: 1.43632	valid_1's rmse: 1.57568
# [7100]	training's rmse: 1.43497	valid_1's rmse: 1.57565
# [7200]	training's rmse: 1.43363	valid_1's rmse: 1.57565
# [7300]	training's rmse: 1.43224	valid_1's rmse: 1.57565
# [7400]	training's rmse: 1.43088	valid_1's rmse: 1.57566
# [7500]	training's rmse: 1.42945	valid_1's rmse: 1.57566
# Early stopping, best iteration is:
# [7153]	training's rmse: 1.43427	valid_1's rmse: 1.57563
# 1.5550856628397896

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,50))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()

# %%
df_train_columns2 = cols[:200]

#original
param = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',  #regression
    'max_depth': 8,  # -1
    'learning_rate': 0.004,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',  #auc
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns2], label=target.iloc[trn_idx])#, categorical_feature=categorical)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns2], label=target.iloc[val_idx])#, categorical_feature=categorical)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns2], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns2
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns2], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(target, oof))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.653	valid_1's rmse: 1.65198
# [200]	training's rmse: 1.61811	valid_1's rmse: 1.61756
# [300]	training's rmse: 1.59748	valid_1's rmse: 1.59782
# [400]	training's rmse: 1.58405	valid_1's rmse: 1.5856
# [500]	training's rmse: 1.57448	valid_1's rmse: 1.57743
# [600]	training's rmse: 1.56716	valid_1's rmse: 1.57176
# [700]	training's rmse: 1.56127	valid_1's rmse: 1.56763
# [800]	training's rmse: 1.55638	valid_1's rmse: 1.56463
# [900]	training's rmse: 1.55211	valid_1's rmse: 1.56228
# [1000]	training's rmse: 1.54823	valid_1's rmse: 1.56031
# [1100]	training's rmse: 1.54471	valid_1's rmse: 1.55867
# [1200]	training's rmse: 1.54144	valid_1's rmse: 1.55732
# [1300]	training's rmse: 1.53844	valid_1's rmse: 1.55621
# [1400]	training's rmse: 1.53559	valid_1's rmse: 1.55531
# [1500]	training's rmse: 1.53293	valid_1's rmse: 1.55457
# [1600]	training's rmse: 1.5304	valid_1's rmse: 1.55392
# [1700]	training's rmse: 1.52795	valid_1's rmse: 1.5534
# [1800]	training's rmse: 1.52562	valid_1's rmse: 1.553
# [1900]	training's rmse: 1.52337	valid_1's rmse: 1.55263
# [2000]	training's rmse: 1.52124	valid_1's rmse: 1.55233
# [2100]	training's rmse: 1.51916	valid_1's rmse: 1.55207
# [2200]	training's rmse: 1.51711	valid_1's rmse: 1.55184
# [2300]	training's rmse: 1.51515	valid_1's rmse: 1.55163
# [2400]	training's rmse: 1.51326	valid_1's rmse: 1.5514
# [2500]	training's rmse: 1.51134	valid_1's rmse: 1.55124
# [2600]	training's rmse: 1.50945	valid_1's rmse: 1.55107
# [2700]	training's rmse: 1.50762	valid_1's rmse: 1.55096
# [2800]	training's rmse: 1.50583	valid_1's rmse: 1.55087
# [2900]	training's rmse: 1.50401	valid_1's rmse: 1.55079
# [3000]	training's rmse: 1.50228	valid_1's rmse: 1.55071
# [3100]	training's rmse: 1.50062	valid_1's rmse: 1.5506
# [3200]	training's rmse: 1.49892	valid_1's rmse: 1.55048
# [3300]	training's rmse: 1.4972	valid_1's rmse: 1.55043
# [3400]	training's rmse: 1.49558	valid_1's rmse: 1.55034
# [3500]	training's rmse: 1.49388	valid_1's rmse: 1.55024
# [3600]	training's rmse: 1.49223	valid_1's rmse: 1.55018
# [3700]	training's rmse: 1.49058	valid_1's rmse: 1.55012
# [3800]	training's rmse: 1.48895	valid_1's rmse: 1.55009
# [3900]	training's rmse: 1.48734	valid_1's rmse: 1.55005
# [4000]	training's rmse: 1.48578	valid_1's rmse: 1.55001
# [4100]	training's rmse: 1.4842	valid_1's rmse: 1.54996
# [4200]	training's rmse: 1.48262	valid_1's rmse: 1.5499
# [4300]	training's rmse: 1.48107	valid_1's rmse: 1.5499
# [4400]	training's rmse: 1.4795	valid_1's rmse: 1.54987
# [4500]	training's rmse: 1.47794	valid_1's rmse: 1.54982
# [4600]	training's rmse: 1.47635	valid_1's rmse: 1.54977
# [4700]	training's rmse: 1.47485	valid_1's rmse: 1.54979
# [4800]	training's rmse: 1.47331	valid_1's rmse: 1.54977
# [4900]	training's rmse: 1.47183	valid_1's rmse: 1.54973
# [5000]	training's rmse: 1.47031	valid_1's rmse: 1.5497
# [5100]	training's rmse: 1.46879	valid_1's rmse: 1.54972
# [5200]	training's rmse: 1.46734	valid_1's rmse: 1.54969
# [5300]	training's rmse: 1.46583	valid_1's rmse: 1.54967
# [5400]	training's rmse: 1.46434	valid_1's rmse: 1.54965
# [5500]	training's rmse: 1.4629	valid_1's rmse: 1.54966
# [5600]	training's rmse: 1.46144	valid_1's rmse: 1.54965
# [5700]	training's rmse: 1.46001	valid_1's rmse: 1.54966
# [5800]	training's rmse: 1.45857	valid_1's rmse: 1.54959
# [5900]	training's rmse: 1.45717	valid_1's rmse: 1.54961
# [6000]	training's rmse: 1.45567	valid_1's rmse: 1.54957
# [6100]	training's rmse: 1.45425	valid_1's rmse: 1.54957
# [6200]	training's rmse: 1.45287	valid_1's rmse: 1.54955
# [6300]	training's rmse: 1.45145	valid_1's rmse: 1.54954
# [6400]	training's rmse: 1.45002	valid_1's rmse: 1.54949
# [6500]	training's rmse: 1.44863	valid_1's rmse: 1.5495
# [6600]	training's rmse: 1.44715	valid_1's rmse: 1.54949
# [6700]	training's rmse: 1.44576	valid_1's rmse: 1.54949
# [6800]	training's rmse: 1.44437	valid_1's rmse: 1.54946
# [6900]	training's rmse: 1.443	valid_1's rmse: 1.54946
# [7000]	training's rmse: 1.4416	valid_1's rmse: 1.54946
# [7100]	training's rmse: 1.4402	valid_1's rmse: 1.54945
# [7200]	training's rmse: 1.43883	valid_1's rmse: 1.54948
# [7300]	training's rmse: 1.43742	valid_1's rmse: 1.54947
# [7400]	training's rmse: 1.43605	valid_1's rmse: 1.54946
# Early stopping, best iteration is:
# [7084]	training's rmse: 1.44042	valid_1's rmse: 1.54944
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65624	valid_1's rmse: 1.63591
# [200]	training's rmse: 1.62067	valid_1's rmse: 1.60376
# [300]	training's rmse: 1.59991	valid_1's rmse: 1.58593
# [400]	training's rmse: 1.58644	valid_1's rmse: 1.57514
# [500]	training's rmse: 1.57675	valid_1's rmse: 1.56791
# [600]	training's rmse: 1.56942	valid_1's rmse: 1.5629
# [700]	training's rmse: 1.56349	valid_1's rmse: 1.55924
# [800]	training's rmse: 1.55858	valid_1's rmse: 1.55651
# [900]	training's rmse: 1.55437	valid_1's rmse: 1.55439
# [1000]	training's rmse: 1.55056	valid_1's rmse: 1.5526
# [1100]	training's rmse: 1.54709	valid_1's rmse: 1.55114
# [1200]	training's rmse: 1.54383	valid_1's rmse: 1.54979
# [1300]	training's rmse: 1.54084	valid_1's rmse: 1.54869
# [1400]	training's rmse: 1.53801	valid_1's rmse: 1.54773
# [1500]	training's rmse: 1.53534	valid_1's rmse: 1.54696
# [1600]	training's rmse: 1.53286	valid_1's rmse: 1.54621
# [1700]	training's rmse: 1.53046	valid_1's rmse: 1.54559
# [1800]	training's rmse: 1.52815	valid_1's rmse: 1.54507
# [1900]	training's rmse: 1.52597	valid_1's rmse: 1.54463
# [2000]	training's rmse: 1.52383	valid_1's rmse: 1.54427
# [2100]	training's rmse: 1.52172	valid_1's rmse: 1.54395
# [2200]	training's rmse: 1.51968	valid_1's rmse: 1.54369
# [2300]	training's rmse: 1.51767	valid_1's rmse: 1.54341
# [2400]	training's rmse: 1.51575	valid_1's rmse: 1.5432
# [2500]	training's rmse: 1.51387	valid_1's rmse: 1.543
# [2600]	training's rmse: 1.51199	valid_1's rmse: 1.5428
# [2700]	training's rmse: 1.5102	valid_1's rmse: 1.54266
# [2800]	training's rmse: 1.50837	valid_1's rmse: 1.54251
# [2900]	training's rmse: 1.5066	valid_1's rmse: 1.54238
# [3000]	training's rmse: 1.50487	valid_1's rmse: 1.54223
# [3100]	training's rmse: 1.50318	valid_1's rmse: 1.54209
# [3200]	training's rmse: 1.50148	valid_1's rmse: 1.54194
# [3300]	training's rmse: 1.49982	valid_1's rmse: 1.54178
# [3400]	training's rmse: 1.49817	valid_1's rmse: 1.5417
# [3500]	training's rmse: 1.4965	valid_1's rmse: 1.54163
# [3600]	training's rmse: 1.49485	valid_1's rmse: 1.54154
# [3700]	training's rmse: 1.49321	valid_1's rmse: 1.54145
# [3800]	training's rmse: 1.49162	valid_1's rmse: 1.54137
# [3900]	training's rmse: 1.49005	valid_1's rmse: 1.54131
# [4000]	training's rmse: 1.48846	valid_1's rmse: 1.54126
# [4100]	training's rmse: 1.4869	valid_1's rmse: 1.5412
# [4200]	training's rmse: 1.48527	valid_1's rmse: 1.54111
# [4300]	training's rmse: 1.48367	valid_1's rmse: 1.54104
# [4400]	training's rmse: 1.48212	valid_1's rmse: 1.54098
# [4500]	training's rmse: 1.4806	valid_1's rmse: 1.54092
# [4600]	training's rmse: 1.47901	valid_1's rmse: 1.5409
# [4700]	training's rmse: 1.47744	valid_1's rmse: 1.54083
# [4800]	training's rmse: 1.47591	valid_1's rmse: 1.54079
# [4900]	training's rmse: 1.47438	valid_1's rmse: 1.54075
# [5000]	training's rmse: 1.47286	valid_1's rmse: 1.54071
# [5100]	training's rmse: 1.47139	valid_1's rmse: 1.54065
# [5200]	training's rmse: 1.4699	valid_1's rmse: 1.54058
# [5300]	training's rmse: 1.4684	valid_1's rmse: 1.54053
# [5400]	training's rmse: 1.46695	valid_1's rmse: 1.54049
# [5500]	training's rmse: 1.46547	valid_1's rmse: 1.54045
# [5600]	training's rmse: 1.46397	valid_1's rmse: 1.54045
# [5700]	training's rmse: 1.46248	valid_1's rmse: 1.54044
# [5800]	training's rmse: 1.46099	valid_1's rmse: 1.54042
# [5900]	training's rmse: 1.4595	valid_1's rmse: 1.5404
# [6000]	training's rmse: 1.45803	valid_1's rmse: 1.5404
# [6100]	training's rmse: 1.45659	valid_1's rmse: 1.54037
# [6200]	training's rmse: 1.45519	valid_1's rmse: 1.54032
# [6300]	training's rmse: 1.45374	valid_1's rmse: 1.54031
# [6400]	training's rmse: 1.45229	valid_1's rmse: 1.5403
# [6500]	training's rmse: 1.45088	valid_1's rmse: 1.54024
# [6600]	training's rmse: 1.4495	valid_1's rmse: 1.54023
# [6700]	training's rmse: 1.44808	valid_1's rmse: 1.54023
# [6800]	training's rmse: 1.44661	valid_1's rmse: 1.5402
# [6900]	training's rmse: 1.44517	valid_1's rmse: 1.5402
# [7000]	training's rmse: 1.44381	valid_1's rmse: 1.54017
# [7100]	training's rmse: 1.44244	valid_1's rmse: 1.54016
# [7200]	training's rmse: 1.44105	valid_1's rmse: 1.54015
# [7300]	training's rmse: 1.43968	valid_1's rmse: 1.5401
# [7400]	training's rmse: 1.43825	valid_1's rmse: 1.54011
# [7500]	training's rmse: 1.43688	valid_1's rmse: 1.54012
# [7600]	training's rmse: 1.43553	valid_1's rmse: 1.54012
# [7700]	training's rmse: 1.43418	valid_1's rmse: 1.54013
# Early stopping, best iteration is:
# [7340]	training's rmse: 1.43912	valid_1's rmse: 1.54009
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65192	valid_1's rmse: 1.65479
# [200]	training's rmse: 1.61683	valid_1's rmse: 1.62151
# [300]	training's rmse: 1.59628	valid_1's rmse: 1.60269
# [400]	training's rmse: 1.58291	valid_1's rmse: 1.59111
# [500]	training's rmse: 1.57337	valid_1's rmse: 1.58343
# [600]	training's rmse: 1.56613	valid_1's rmse: 1.57814
# [700]	training's rmse: 1.56022	valid_1's rmse: 1.57415
# [800]	training's rmse: 1.55533	valid_1's rmse: 1.5712
# [900]	training's rmse: 1.55114	valid_1's rmse: 1.56896
# [1000]	training's rmse: 1.54733	valid_1's rmse: 1.56706
# [1100]	training's rmse: 1.54385	valid_1's rmse: 1.56549
# [1200]	training's rmse: 1.54068	valid_1's rmse: 1.56416
# [1300]	training's rmse: 1.53774	valid_1's rmse: 1.56315
# [1400]	training's rmse: 1.53499	valid_1's rmse: 1.5622
# [1500]	training's rmse: 1.53231	valid_1's rmse: 1.56133
# [1600]	training's rmse: 1.52982	valid_1's rmse: 1.56066
# [1700]	training's rmse: 1.52744	valid_1's rmse: 1.56002
# [1800]	training's rmse: 1.52518	valid_1's rmse: 1.55958
# [1900]	training's rmse: 1.52298	valid_1's rmse: 1.55916
# [2000]	training's rmse: 1.52088	valid_1's rmse: 1.55883
# [2100]	training's rmse: 1.51883	valid_1's rmse: 1.55852
# [2200]	training's rmse: 1.5168	valid_1's rmse: 1.5583
# [2300]	training's rmse: 1.51483	valid_1's rmse: 1.55805
# [2400]	training's rmse: 1.51289	valid_1's rmse: 1.55785
# [2500]	training's rmse: 1.51098	valid_1's rmse: 1.55767
# [2600]	training's rmse: 1.50915	valid_1's rmse: 1.55752
# [2700]	training's rmse: 1.50738	valid_1's rmse: 1.5574
# [2800]	training's rmse: 1.50562	valid_1's rmse: 1.55727
# [2900]	training's rmse: 1.50393	valid_1's rmse: 1.55714
# [3000]	training's rmse: 1.50224	valid_1's rmse: 1.55704
# [3100]	training's rmse: 1.50047	valid_1's rmse: 1.55692
# [3200]	training's rmse: 1.49876	valid_1's rmse: 1.55679
# [3300]	training's rmse: 1.49704	valid_1's rmse: 1.55674
# [3400]	training's rmse: 1.49537	valid_1's rmse: 1.55663
# [3500]	training's rmse: 1.49371	valid_1's rmse: 1.55656
# [3600]	training's rmse: 1.49207	valid_1's rmse: 1.55652
# [3700]	training's rmse: 1.49046	valid_1's rmse: 1.55645
# [3800]	training's rmse: 1.48883	valid_1's rmse: 1.55638
# [3900]	training's rmse: 1.48721	valid_1's rmse: 1.55632
# [4000]	training's rmse: 1.48566	valid_1's rmse: 1.55626
# [4100]	training's rmse: 1.48403	valid_1's rmse: 1.5562
# [4200]	training's rmse: 1.48244	valid_1's rmse: 1.55613
# [4300]	training's rmse: 1.48091	valid_1's rmse: 1.55607
# [4400]	training's rmse: 1.47937	valid_1's rmse: 1.556
# [4500]	training's rmse: 1.47785	valid_1's rmse: 1.55593
# [4600]	training's rmse: 1.47632	valid_1's rmse: 1.5559
# [4700]	training's rmse: 1.47478	valid_1's rmse: 1.55588
# [4800]	training's rmse: 1.47329	valid_1's rmse: 1.55585
# [4900]	training's rmse: 1.47178	valid_1's rmse: 1.55579
# [5000]	training's rmse: 1.4703	valid_1's rmse: 1.55572
# [5100]	training's rmse: 1.46879	valid_1's rmse: 1.55568
# [5200]	training's rmse: 1.46729	valid_1's rmse: 1.55568
# [5300]	training's rmse: 1.46582	valid_1's rmse: 1.55565
# [5400]	training's rmse: 1.46433	valid_1's rmse: 1.55561
# [5500]	training's rmse: 1.46288	valid_1's rmse: 1.5556
# [5600]	training's rmse: 1.46143	valid_1's rmse: 1.55562
# [5700]	training's rmse: 1.45998	valid_1's rmse: 1.5556
# [5800]	training's rmse: 1.45854	valid_1's rmse: 1.55556
# [5900]	training's rmse: 1.45706	valid_1's rmse: 1.55555
# [6000]	training's rmse: 1.45563	valid_1's rmse: 1.55555
# [6100]	training's rmse: 1.45424	valid_1's rmse: 1.55552
# [6200]	training's rmse: 1.45281	valid_1's rmse: 1.55552
# [6300]	training's rmse: 1.45141	valid_1's rmse: 1.55553
# [6400]	training's rmse: 1.45004	valid_1's rmse: 1.55553
# Early stopping, best iteration is:
# [6095]	training's rmse: 1.4543	valid_1's rmse: 1.55551
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.65235	valid_1's rmse: 1.65311
# [200]	training's rmse: 1.61717	valid_1's rmse: 1.62026
# [300]	training's rmse: 1.59659	valid_1's rmse: 1.60193
# [400]	training's rmse: 1.58319	valid_1's rmse: 1.59075
# [500]	training's rmse: 1.57364	valid_1's rmse: 1.58327
# [600]	training's rmse: 1.56642	valid_1's rmse: 1.57806
# [700]	training's rmse: 1.56051	valid_1's rmse: 1.57406
# [800]	training's rmse: 1.55558	valid_1's rmse: 1.57101
# [900]	training's rmse: 1.55133	valid_1's rmse: 1.56866
# [1000]	training's rmse: 1.54746	valid_1's rmse: 1.56669
# [1100]	training's rmse: 1.54396	valid_1's rmse: 1.56501
# [1200]	training's rmse: 1.54078	valid_1's rmse: 1.56366
# [1300]	training's rmse: 1.53783	valid_1's rmse: 1.56249
# [1400]	training's rmse: 1.53506	valid_1's rmse: 1.56157
# [1500]	training's rmse: 1.5324	valid_1's rmse: 1.56068
# [1600]	training's rmse: 1.52991	valid_1's rmse: 1.56
# [1700]	training's rmse: 1.52751	valid_1's rmse: 1.55935
# [1800]	training's rmse: 1.52525	valid_1's rmse: 1.55886
# [1900]	training's rmse: 1.52305	valid_1's rmse: 1.55843
# [2000]	training's rmse: 1.5209	valid_1's rmse: 1.55803
# [2100]	training's rmse: 1.5188	valid_1's rmse: 1.55765
# [2200]	training's rmse: 1.51681	valid_1's rmse: 1.55735
# [2300]	training's rmse: 1.51485	valid_1's rmse: 1.55711
# [2400]	training's rmse: 1.51288	valid_1's rmse: 1.55691
# [2500]	training's rmse: 1.51099	valid_1's rmse: 1.55672
# [2600]	training's rmse: 1.50912	valid_1's rmse: 1.55657
# [2700]	training's rmse: 1.50731	valid_1's rmse: 1.55639
# [2800]	training's rmse: 1.50548	valid_1's rmse: 1.55628
# [2900]	training's rmse: 1.50373	valid_1's rmse: 1.55616
# [3000]	training's rmse: 1.50199	valid_1's rmse: 1.55604
# [3100]	training's rmse: 1.50029	valid_1's rmse: 1.55597
# [3200]	training's rmse: 1.49859	valid_1's rmse: 1.55594
# [3300]	training's rmse: 1.49686	valid_1's rmse: 1.5559
# [3400]	training's rmse: 1.49516	valid_1's rmse: 1.5558
# [3500]	training's rmse: 1.4935	valid_1's rmse: 1.55574
# [3600]	training's rmse: 1.49187	valid_1's rmse: 1.55566
# [3700]	training's rmse: 1.49021	valid_1's rmse: 1.55556
# [3800]	training's rmse: 1.48863	valid_1's rmse: 1.55552
# [3900]	training's rmse: 1.48697	valid_1's rmse: 1.55551
# [4000]	training's rmse: 1.48539	valid_1's rmse: 1.55547
# [4100]	training's rmse: 1.4838	valid_1's rmse: 1.55544
# [4200]	training's rmse: 1.4822	valid_1's rmse: 1.55543
# [4300]	training's rmse: 1.48064	valid_1's rmse: 1.5554
# [4400]	training's rmse: 1.47905	valid_1's rmse: 1.55534
# [4500]	training's rmse: 1.47753	valid_1's rmse: 1.55527
# [4600]	training's rmse: 1.476	valid_1's rmse: 1.55522
# [4700]	training's rmse: 1.47449	valid_1's rmse: 1.5552
# [4800]	training's rmse: 1.47295	valid_1's rmse: 1.55519
# [4900]	training's rmse: 1.47147	valid_1's rmse: 1.55518
# [5000]	training's rmse: 1.46994	valid_1's rmse: 1.55516
# [5100]	training's rmse: 1.46839	valid_1's rmse: 1.55516
# [5200]	training's rmse: 1.46688	valid_1's rmse: 1.55517
# [5300]	training's rmse: 1.46539	valid_1's rmse: 1.55513
# [5400]	training's rmse: 1.4639	valid_1's rmse: 1.55512
# [5500]	training's rmse: 1.46242	valid_1's rmse: 1.55505
# [5600]	training's rmse: 1.46095	valid_1's rmse: 1.55503
# [5700]	training's rmse: 1.45946	valid_1's rmse: 1.555
# [5800]	training's rmse: 1.45798	valid_1's rmse: 1.55497
# [5900]	training's rmse: 1.45652	valid_1's rmse: 1.55494
# [6000]	training's rmse: 1.4551	valid_1's rmse: 1.55496
# [6100]	training's rmse: 1.45372	valid_1's rmse: 1.55497
# [6200]	training's rmse: 1.45227	valid_1's rmse: 1.55496
# [6300]	training's rmse: 1.45082	valid_1's rmse: 1.55494
# [6400]	training's rmse: 1.44939	valid_1's rmse: 1.55492
# [6500]	training's rmse: 1.44795	valid_1's rmse: 1.5549
# [6600]	training's rmse: 1.44657	valid_1's rmse: 1.55486
# [6700]	training's rmse: 1.44514	valid_1's rmse: 1.55486
# [6800]	training's rmse: 1.44374	valid_1's rmse: 1.55482
# [6900]	training's rmse: 1.4424	valid_1's rmse: 1.55482
# [7000]	training's rmse: 1.44097	valid_1's rmse: 1.5548
# [7100]	training's rmse: 1.43957	valid_1's rmse: 1.55484
# [7200]	training's rmse: 1.4382	valid_1's rmse: 1.5548
# [7300]	training's rmse: 1.43679	valid_1's rmse: 1.55481
# [7400]	training's rmse: 1.43542	valid_1's rmse: 1.55479
# [7500]	training's rmse: 1.43406	valid_1's rmse: 1.55482
# [7600]	training's rmse: 1.43269	valid_1's rmse: 1.55482
# [7700]	training's rmse: 1.43132	valid_1's rmse: 1.55482
# [7800]	training's rmse: 1.42997	valid_1's rmse: 1.55483
# Early stopping, best iteration is:
# [7416]	training's rmse: 1.4352	valid_1's rmse: 1.55479
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.64733	valid_1's rmse: 1.6745
# [200]	training's rmse: 1.61219	valid_1's rmse: 1.64148
# [300]	training's rmse: 1.59152	valid_1's rmse: 1.62279
# [400]	training's rmse: 1.57809	valid_1's rmse: 1.61128
# [500]	training's rmse: 1.56848	valid_1's rmse: 1.60348
# [600]	training's rmse: 1.56122	valid_1's rmse: 1.59805
# [700]	training's rmse: 1.55531	valid_1's rmse: 1.59403
# [800]	training's rmse: 1.55042	valid_1's rmse: 1.59106
# [900]	training's rmse: 1.54617	valid_1's rmse: 1.58869
# [1000]	training's rmse: 1.54232	valid_1's rmse: 1.58681
# [1100]	training's rmse: 1.53888	valid_1's rmse: 1.58525
# [1200]	training's rmse: 1.53569	valid_1's rmse: 1.58388
# [1300]	training's rmse: 1.53276	valid_1's rmse: 1.5828
# [1400]	training's rmse: 1.52999	valid_1's rmse: 1.58195
# [1500]	training's rmse: 1.52738	valid_1's rmse: 1.58116
# [1600]	training's rmse: 1.52489	valid_1's rmse: 1.58051
# [1700]	training's rmse: 1.5225	valid_1's rmse: 1.57997
# [1800]	training's rmse: 1.52023	valid_1's rmse: 1.57951
# [1900]	training's rmse: 1.51805	valid_1's rmse: 1.57912
# [2000]	training's rmse: 1.51594	valid_1's rmse: 1.57877
# [2100]	training's rmse: 1.51387	valid_1's rmse: 1.57851
# [2200]	training's rmse: 1.51185	valid_1's rmse: 1.57827
# [2300]	training's rmse: 1.5099	valid_1's rmse: 1.57809
# [2400]	training's rmse: 1.50801	valid_1's rmse: 1.57793
# [2500]	training's rmse: 1.50617	valid_1's rmse: 1.57783
# [2600]	training's rmse: 1.50436	valid_1's rmse: 1.57767
# [2700]	training's rmse: 1.50251	valid_1's rmse: 1.57755
# [2800]	training's rmse: 1.50075	valid_1's rmse: 1.57742
# [2900]	training's rmse: 1.49897	valid_1's rmse: 1.5773
# [3000]	training's rmse: 1.49725	valid_1's rmse: 1.57719
# [3100]	training's rmse: 1.49557	valid_1's rmse: 1.57714
# [3200]	training's rmse: 1.49386	valid_1's rmse: 1.57711
# [3300]	training's rmse: 1.49214	valid_1's rmse: 1.57706
# [3400]	training's rmse: 1.4905	valid_1's rmse: 1.57701
# [3500]	training's rmse: 1.48886	valid_1's rmse: 1.57696
# [3600]	training's rmse: 1.48724	valid_1's rmse: 1.57684
# [3700]	training's rmse: 1.48565	valid_1's rmse: 1.57679
# [3800]	training's rmse: 1.48403	valid_1's rmse: 1.57674
# [3900]	training's rmse: 1.4824	valid_1's rmse: 1.5767
# [4000]	training's rmse: 1.48081	valid_1's rmse: 1.57669
# [4100]	training's rmse: 1.47928	valid_1's rmse: 1.57664
# [4200]	training's rmse: 1.47768	valid_1's rmse: 1.57661
# [4300]	training's rmse: 1.47613	valid_1's rmse: 1.57656
# [4400]	training's rmse: 1.47453	valid_1's rmse: 1.5766
# [4500]	training's rmse: 1.473	valid_1's rmse: 1.57656
# [4600]	training's rmse: 1.47147	valid_1's rmse: 1.57651
# [4700]	training's rmse: 1.46993	valid_1's rmse: 1.57651
# [4800]	training's rmse: 1.46842	valid_1's rmse: 1.57649
# [4900]	training's rmse: 1.46694	valid_1's rmse: 1.57643
# [5000]	training's rmse: 1.46546	valid_1's rmse: 1.57644
# [5100]	training's rmse: 1.46395	valid_1's rmse: 1.57638
# [5200]	training's rmse: 1.46249	valid_1's rmse: 1.57638
# [5300]	training's rmse: 1.461	valid_1's rmse: 1.57637
# [5400]	training's rmse: 1.45951	valid_1's rmse: 1.57634
# [5500]	training's rmse: 1.45804	valid_1's rmse: 1.57635
# [5600]	training's rmse: 1.45659	valid_1's rmse: 1.57634
# [5700]	training's rmse: 1.45511	valid_1's rmse: 1.57632
# [5800]	training's rmse: 1.45367	valid_1's rmse: 1.57633
# [5900]	training's rmse: 1.45223	valid_1's rmse: 1.57632
# [6000]	training's rmse: 1.4508	valid_1's rmse: 1.57632
# [6100]	training's rmse: 1.44936	valid_1's rmse: 1.57627
# [6200]	training's rmse: 1.44796	valid_1's rmse: 1.57625
# [6300]	training's rmse: 1.44652	valid_1's rmse: 1.57625
# [6400]	training's rmse: 1.44509	valid_1's rmse: 1.57622
# [6500]	training's rmse: 1.44369	valid_1's rmse: 1.57621
# [6600]	training's rmse: 1.4423	valid_1's rmse: 1.5762
# [6700]	training's rmse: 1.44089	valid_1's rmse: 1.57617
# [6800]	training's rmse: 1.43946	valid_1's rmse: 1.57616
# [6900]	training's rmse: 1.43808	valid_1's rmse: 1.57615
# [7000]	training's rmse: 1.43666	valid_1's rmse: 1.57613
# [7100]	training's rmse: 1.43531	valid_1's rmse: 1.5761
# [7200]	training's rmse: 1.43395	valid_1's rmse: 1.57611
# [7300]	training's rmse: 1.4326	valid_1's rmse: 1.57609
# [7400]	training's rmse: 1.43126	valid_1's rmse: 1.57608
# [7500]	training's rmse: 1.42986	valid_1's rmse: 1.57608
# [7600]	training's rmse: 1.42851	valid_1's rmse: 1.57606
# [7700]	training's rmse: 1.42716	valid_1's rmse: 1.57608
# [7800]	training's rmse: 1.42582	valid_1's rmse: 1.57609
# [7900]	training's rmse: 1.42445	valid_1's rmse: 1.57611
# [8000]	training's rmse: 1.42314	valid_1's rmse: 1.57611
# Early stopping, best iteration is:
# [7665]	training's rmse: 1.42764	valid_1's rmse: 1.57605
# 1.5552225367457473

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,50))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()

# %%
submission = pd.DataFrame({"card_id":df_test.card_id, "target":predictions})

# %%
submission.to_csv("../output/submission_no_outliers_model20190112.csv", index=False)
