# %%
import numpy as np
import pandas as pd
import datetime
import gc

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import lightgbm as lgb

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error, roc_auc_score
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')
np.random.seed(4590)
# Out:
# /Users/naoki/.pyenv/versions/3.6.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/naoki/.pyenv/versions/3.6.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/naoki/.pyenv/versions/3.6.6/lib/python3.6/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.1) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
df_train = pd.read_csv('../input/train.csv')
df_test = pd.read_csv('../input/test.csv')
df_hist_trans = pd.read_csv('../input/historical_transactions.csv')
df_new_merchant_trans = pd.read_csv('../input/new_merchant_transactions.csv')

# %%
df_train["target_sign"] = df_train.target.apply(lambda x:0 if x<0 else 1)

# %%
df_hist_trans['purchase_amount'] = np.exp(df_hist_trans['purchase_amount'])
df_new_merchant_trans['purchase_amount'] = np.exp(df_new_merchant_trans['purchase_amount'])

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['category_2'].fillna(1.0,inplace=True)
    df['category_3'].fillna('A',inplace=True)
    df['merchant_id'].fillna('M_ID_00a6ca8a8a',inplace=True)

# %%
def get_new_columns(name,aggs):
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    df['year'] = df['purchase_date'].dt.year
    df['weekofyear'] = df['purchase_date'].dt.weekofyear
    df['month'] = df['purchase_date'].dt.month
    df['dayofweek'] = df['purchase_date'].dt.dayofweek
    df['weekend'] = (df.purchase_date.dt.weekday >=5).astype(int)
    df['hour'] = df['purchase_date'].dt.hour
    df['authorized_flag'] = df['authorized_flag'].map({'Y':1, 'N':0})
    df['category_1'] = df['category_1'].map({'Y':1, 'N':0}) 
    #https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/73244
    df['month_diff'] = ((datetime.datetime.today() - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']

aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['authorized_flag'] = ['sum', 'mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_hist_trans[col+'_mean'] = df_hist_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']    

new_columns = get_new_columns('hist',aggs)
df_hist_trans_group = df_hist_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['hist_purchase_date_diff'] = (df_hist_trans_group['hist_purchase_date_max'] - df_hist_trans_group['hist_purchase_date_min']).dt.days
df_hist_trans_group['hist_purchase_date_average'] = df_hist_trans_group['hist_purchase_date_diff']/df_hist_trans_group['hist_card_id_size']
df_hist_trans_group['hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 42

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']
aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_new_merchant_trans[col+'_mean'] = df_new_merchant_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']
    
new_columns = get_new_columns('new_hist',aggs)
df_hist_trans_group = df_new_merchant_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['new_hist_purchase_date_diff'] = (df_hist_trans_group['new_hist_purchase_date_max'] - df_hist_trans_group['new_hist_purchase_date_min']).dt.days
df_hist_trans_group['new_hist_purchase_date_average'] = df_hist_trans_group['new_hist_purchase_date_diff']/df_hist_trans_group['new_hist_card_id_size']
df_hist_trans_group['new_hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['new_hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 28

# %%
del df_hist_trans;gc.collect()
del df_new_merchant_trans;gc.collect()
df_train.head(5)
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
# 3            2017-09  C_ID_186d6a6901          4          3          0
# 4            2017-11  C_ID_cdbd2c0db2          1          3          0
#
#      target  target_sign  hist_month_nunique  hist_hour_nunique  \
# 0 -0.820283            0                   9                 23
# 1  0.392913            1                  12                 24
# 2  0.688056            1                  10                 14
# 3  0.142495            1                   6                 16
# 4 -0.159749            0                   4                 22
#
#    hist_weekofyear_nunique               ...                \
# 0                       35               ...
# 1                       50               ...
# 2                       22               ...
# 3                       20               ...
# 4                       17               ...
#
#    new_hist_weekend_sum  new_hist_weekend_mean  new_hist_category_1_sum  \
# 0                   6.0               0.260870                      0.0
# 1                   0.0               0.000000                      0.0
# 2                   1.0               1.000000                      0.0
# 3                   3.0               0.428571                      1.0
# 4                  12.0               0.333333                      2.0
#
#    new_hist_category_1_mean  new_hist_card_id_size  \
# 0                  0.000000                   23.0
# 1                  0.000000                    6.0
# 2                  0.000000                    1.0
# 3                  0.142857                    7.0
# 4                  0.055556                   36.0
#
#    new_hist_category_2_mean_mean  new_hist_category_3_mean_mean  \
# 0                  1.658319e+108                   1.381361e+36
# 1                  1.658319e+108                   3.557623e+25
# 2                   7.789907e+26                   1.381361e+36
# 3                  2.369028e+107                   1.973373e+35
# 4                  1.842577e+107                  3.624714e+107
#
#    new_hist_purchase_date_diff  new_hist_purchase_date_average  \
# 0                         54.0                        2.347826
# 1                         56.0                        9.333333
# 2                          0.0                        0.000000
# 3                         41.0                        5.857143
# 4                         57.0                        1.583333
#
#    new_hist_purchase_date_uptonow
# 0                           234.0
# 1                           264.0
# 2                           235.0
# 3                           245.0
# 4                           235.0
#
# [5 rows x 79 columns]

# %%
df_train['outliers'] = 0
df_train.loc[df_train['target'] < -30, 'outliers'] = 1
df_train['outliers'].value_counts()
# Out:
# 0    199710
# 1      2207
# Name: outliers, dtype: int64

# %%
list_outlier_idx = df_train[df_train.outliers == 1].index.tolist()

# %%
for df in [df_train,df_test]:
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['dayofweek'] = df['first_active_month'].dt.dayofweek
    df['weekofyear'] = df['first_active_month'].dt.weekofyear
    df['month'] = df['first_active_month'].dt.month
    df['elapsed_time'] = (datetime.datetime.today() - df['first_active_month']).dt.days
    df['hist_first_buy'] = (df['hist_purchase_date_min'] - df['first_active_month']).dt.days
    df['new_hist_first_buy'] = (df['new_hist_purchase_date_min'] - df['first_active_month']).dt.days
    for f in ['hist_purchase_date_max','hist_purchase_date_min','new_hist_purchase_date_max',\
                     'new_hist_purchase_date_min']:
        df[f] = df[f].astype(np.int64) * 1e-9
    df['card_id_total'] = df['new_hist_card_id_size']+df['hist_card_id_size']
    df['purchase_amount_total'] = df['new_hist_purchase_amount_sum']+df['hist_purchase_amount_sum']

for f in ['feature_1','feature_2','feature_3']:
    order_label = df_train.groupby([f])['outliers'].mean()
    df_train[f] = df_train[f].map(order_label)
    df_test[f] = df_test[f].map(order_label)

# %%
high_importance_features = [
    "hist_month_diff_mean", 
    "hist_authorized_flag_mean", 
    "hist_category_1_sum", 
    "hist_month_lag_mean", 
    "new_hist_purchase_amount_sum", 
    "new_hist_purchase_date_uptonow"
]

#smoothing
for col in high_importance_features:
    df_train[col] = np.where(df_train[col].values==0, 0.001, df_train[col].values)
    df_test[col] = np.where(df_test[col].values==0, 0.001, df_test[col].values)


for i in range(len(high_importance_features)):
    for j in range(len((high_importance_features)))[i+1:]:
        col1 = high_importance_features[i]
        col2 = high_importance_features[j]
        new_col_name = "{c1}__div__{c2}".format(c1=col1, c2=col2)
        
        df_train[new_col_name] = df_train[col1] / df_train[col2]
        df_test[new_col_name] = df_test[col1] / df_test[col2]

# %%
def merge_new_feature(path):
    df_new_feature = pd.read_csv(path)
    
    df_tr = pd.merge(df_train, df_new_feature, on="card_id", how="left")
    df_te = pd.merge(df_test, df_new_feature, on="card_id", how="left")
    
    return df_tr, df_te

# %%
df_train, df_test = merge_new_feature("../input/merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/new_merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/prosperity_merchants_latest.csv")
df_train, df_test = merge_new_feature("../input/merchants_numerical_features.csv")
df_train, df_test = merge_new_feature("../input/merchants_item_scale_feature.csv")
df_train, df_test = merge_new_feature("../input/purchase_pattern.csv")
df_train, df_test = merge_new_feature("../input/purchase_pettern_nmf.csv")
df_train, df_test = merge_new_feature("../input/purchase_amount_pettern_nmf.csv")

# %%
df_train["Null_count"] = df_train.isnull().sum(axis=1)
df_test["Null_count"] = df_test.isnull().sum(axis=1)

# %%
drop_col = ['card_id', 'first_active_month','second_active_date','diff_first_and_second','target','outliers', 'target_sign']
df_train_columns = [c for c in df_train.columns if c not in drop_col]


df_train_null = df_train.isnull().sum().reset_index()
df_train_null.columns = ["col_name", "null_count"]
for i,r in df_train_null.iterrows():
    if r[1] > 0:
        drop_col.append(r[0])
        
target = df_train['target']
target_outliers = df_train["outliers"]

# %%
#original
param = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',
    'max_depth': -1,
    'learning_rate': 0.004,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.73836	valid_1's rmse: 3.77491
# [200]	training's rmse: 3.66988	valid_1's rmse: 3.73391
# [300]	training's rmse: 3.62219	valid_1's rmse: 3.71095
# [400]	training's rmse: 3.58495	valid_1's rmse: 3.69637
# [500]	training's rmse: 3.55571	valid_1's rmse: 3.68576
# [600]	training's rmse: 3.53119	valid_1's rmse: 3.67829
# [700]	training's rmse: 3.51031	valid_1's rmse: 3.67325
# [800]	training's rmse: 3.49231	valid_1's rmse: 3.66944
# [900]	training's rmse: 3.47594	valid_1's rmse: 3.66587
# [1000]	training's rmse: 3.46068	valid_1's rmse: 3.66307
# [1100]	training's rmse: 3.44631	valid_1's rmse: 3.66048
# [1200]	training's rmse: 3.43323	valid_1's rmse: 3.65836
# [1300]	training's rmse: 3.42051	valid_1's rmse: 3.6564
# [1400]	training's rmse: 3.4084	valid_1's rmse: 3.65477
# [1500]	training's rmse: 3.39684	valid_1's rmse: 3.65333
# [1600]	training's rmse: 3.38562	valid_1's rmse: 3.65235
# [1700]	training's rmse: 3.37524	valid_1's rmse: 3.65157
# [1800]	training's rmse: 3.36499	valid_1's rmse: 3.65064
# [1900]	training's rmse: 3.35552	valid_1's rmse: 3.64997
# [2000]	training's rmse: 3.34589	valid_1's rmse: 3.6492
# [2100]	training's rmse: 3.3367	valid_1's rmse: 3.64849
# [2200]	training's rmse: 3.32765	valid_1's rmse: 3.64786
# [2300]	training's rmse: 3.31892	valid_1's rmse: 3.64739
# [2400]	training's rmse: 3.3104	valid_1's rmse: 3.64692
# [2500]	training's rmse: 3.30261	valid_1's rmse: 3.64659
# [2600]	training's rmse: 3.29472	valid_1's rmse: 3.64618
# [2700]	training's rmse: 3.28706	valid_1's rmse: 3.64588
# [2800]	training's rmse: 3.27909	valid_1's rmse: 3.6454
# [2900]	training's rmse: 3.2711	valid_1's rmse: 3.64499
# [3000]	training's rmse: 3.26346	valid_1's rmse: 3.64473
# [3100]	training's rmse: 3.25592	valid_1's rmse: 3.64459
# [3200]	training's rmse: 3.24868	valid_1's rmse: 3.6444
# [3300]	training's rmse: 3.24166	valid_1's rmse: 3.64421
# [3400]	training's rmse: 3.23474	valid_1's rmse: 3.64399
# [3500]	training's rmse: 3.22777	valid_1's rmse: 3.64387
# [3600]	training's rmse: 3.22116	valid_1's rmse: 3.64378
# [3700]	training's rmse: 3.21471	valid_1's rmse: 3.64381
# [3800]	training's rmse: 3.20787	valid_1's rmse: 3.64371
# [3900]	training's rmse: 3.20133	valid_1's rmse: 3.64348
# [4000]	training's rmse: 3.19529	valid_1's rmse: 3.64324
# [4100]	training's rmse: 3.18913	valid_1's rmse: 3.64306
# [4200]	training's rmse: 3.18288	valid_1's rmse: 3.64303
# [4300]	training's rmse: 3.17626	valid_1's rmse: 3.6432
# [4400]	training's rmse: 3.17025	valid_1's rmse: 3.64309
# [4500]	training's rmse: 3.16396	valid_1's rmse: 3.64295
# [4600]	training's rmse: 3.15769	valid_1's rmse: 3.64283
# [4700]	training's rmse: 3.15216	valid_1's rmse: 3.64266
# [4800]	training's rmse: 3.14633	valid_1's rmse: 3.64275
# [4900]	training's rmse: 3.14046	valid_1's rmse: 3.64272
# [5000]	training's rmse: 3.13448	valid_1's rmse: 3.64272
# [5100]	training's rmse: 3.12842	valid_1's rmse: 3.64266
# [5200]	training's rmse: 3.12269	valid_1's rmse: 3.64269
# [5300]	training's rmse: 3.11685	valid_1's rmse: 3.64265
# [5400]	training's rmse: 3.11118	valid_1's rmse: 3.64265
# [5500]	training's rmse: 3.10546	valid_1's rmse: 3.6426
# [5600]	training's rmse: 3.09969	valid_1's rmse: 3.6426
# [5700]	training's rmse: 3.09416	valid_1's rmse: 3.64258
# [5800]	training's rmse: 3.08835	valid_1's rmse: 3.64253
# [5900]	training's rmse: 3.08282	valid_1's rmse: 3.64264
# [6000]	training's rmse: 3.07749	valid_1's rmse: 3.64286
# [6100]	training's rmse: 3.07162	valid_1's rmse: 3.64293
# Early stopping, best iteration is:
# [5795]	training's rmse: 3.08868	valid_1's rmse: 3.64251
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74327	valid_1's rmse: 3.7607
# [200]	training's rmse: 3.67489	valid_1's rmse: 3.71604
# [300]	training's rmse: 3.62662	valid_1's rmse: 3.69048
# [400]	training's rmse: 3.58915	valid_1's rmse: 3.67569
# [500]	training's rmse: 3.55903	valid_1's rmse: 3.66575
# [600]	training's rmse: 3.53439	valid_1's rmse: 3.65872
# [700]	training's rmse: 3.51428	valid_1's rmse: 3.65343
# [800]	training's rmse: 3.49575	valid_1's rmse: 3.6495
# [900]	training's rmse: 3.47913	valid_1's rmse: 3.64635
# [1000]	training's rmse: 3.46346	valid_1's rmse: 3.64395
# [1100]	training's rmse: 3.4496	valid_1's rmse: 3.642
# [1200]	training's rmse: 3.43611	valid_1's rmse: 3.6406
# [1300]	training's rmse: 3.42276	valid_1's rmse: 3.63941
# [1400]	training's rmse: 3.4106	valid_1's rmse: 3.63861
# [1500]	training's rmse: 3.39882	valid_1's rmse: 3.63801
# [1600]	training's rmse: 3.38762	valid_1's rmse: 3.63726
# [1700]	training's rmse: 3.37637	valid_1's rmse: 3.63667
# [1800]	training's rmse: 3.36623	valid_1's rmse: 3.63589
# [1900]	training's rmse: 3.35602	valid_1's rmse: 3.63573
# [2000]	training's rmse: 3.34613	valid_1's rmse: 3.63534
# [2100]	training's rmse: 3.33644	valid_1's rmse: 3.63496
# [1200]	training's rmse: 3.42769	valid_1's rmse: 3.67409
# [1300]	training's rmse: 3.41488	valid_1's rmse: 3.67269
# [1400]	training's rmse: 3.40313	valid_1's rmse: 3.67164
# [1500]	training's rmse: 3.39148	valid_1's rmse: 3.67105
# [1600]	training's rmse: 3.38081	valid_1's rmse: 3.6706
# [1700]	training's rmse: 3.37005	valid_1's rmse: 3.67018
# [1800]	training's rmse: 3.35999	valid_1's rmse: 3.66962
# [1900]	training's rmse: 3.35011	valid_1's rmse: 3.66969
# [2000]	training's rmse: 3.34031	valid_1's rmse: 3.66958
# [2100]	training's rmse: 3.33054	valid_1's rmse: 3.66934
# [2200]	training's rmse: 3.32168	valid_1's rmse: 3.66887
# [2300]	training's rmse: 3.31323	valid_1's rmse: 3.66881
# [2400]	training's rmse: 3.30457	valid_1's rmse: 3.66888
# [2500]	training's rmse: 3.2968	valid_1's rmse: 3.66877
# [2600]	training's rmse: 3.28884	valid_1's rmse: 3.66872
# [2700]	training's rmse: 3.28116	valid_1's rmse: 3.66878
# [2800]	training's rmse: 3.27397	valid_1's rmse: 3.66885
# [2900]	training's rmse: 3.26569	valid_1's rmse: 3.66852
# [3000]	training's rmse: 3.25784	valid_1's rmse: 3.66859
# [3100]	training's rmse: 3.2507	valid_1's rmse: 3.66865
# [3200]	training's rmse: 3.24358	valid_1's rmse: 3.66839
# [3300]	training's rmse: 3.23681	valid_1's rmse: 3.66848
# [3400]	training's rmse: 3.22977	valid_1's rmse: 3.66862
# [3500]	training's rmse: 3.22301	valid_1's rmse: 3.66871
# [3600]	training's rmse: 3.21632	valid_1's rmse: 3.66867
# Early stopping, best iteration is:
# [3214]	training's rmse: 3.24254	valid_1's rmse: 3.66835
# 3.646009839369719

# %%
# score:  3.6467757129353053

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,50))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
# plt.savefig('lgbm_importances.png')

# %%
df_train2 = df_train[df_train.target >= -20].reset_index(drop=True)
target2 = df_train2["target"]

#original
param2 = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',
    'max_depth': -1,
    'learning_rate': 0.01,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train2))
predictions2 = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train2,df_train2['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train2.iloc[trn_idx][df_train_columns], label=target2.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train2.iloc[val_idx][df_train_columns], label=target2.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param2, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train2.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions2 += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target2))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60698	valid_1's rmse: 1.60689
# [200]	training's rmse: 1.57546	valid_1's rmse: 1.57853
# [300]	training's rmse: 1.56007	valid_1's rmse: 1.56727
# [400]	training's rmse: 1.54947	valid_1's rmse: 1.56161
# [500]	training's rmse: 1.54109	valid_1's rmse: 1.55811
# [600]	training's rmse: 1.5339	valid_1's rmse: 1.55585
# [700]	training's rmse: 1.52759	valid_1's rmse: 1.55443
# [800]	training's rmse: 1.52175	valid_1's rmse: 1.55346
# [900]	training's rmse: 1.51657	valid_1's rmse: 1.55284
# [1000]	training's rmse: 1.51163	valid_1's rmse: 1.55246
# [1100]	training's rmse: 1.50706	valid_1's rmse: 1.55214
# [1200]	training's rmse: 1.50259	valid_1's rmse: 1.5519
# [1300]	training's rmse: 1.49822	valid_1's rmse: 1.55167
# [1400]	training's rmse: 1.49394	valid_1's rmse: 1.55148
# [1500]	training's rmse: 1.48979	valid_1's rmse: 1.55129
# [1600]	training's rmse: 1.48568	valid_1's rmse: 1.55113
# [1700]	training's rmse: 1.48168	valid_1's rmse: 1.55107
# [1800]	training's rmse: 1.47768	valid_1's rmse: 1.55103
# [1900]	training's rmse: 1.47375	valid_1's rmse: 1.55088
# [2000]	training's rmse: 1.46982	valid_1's rmse: 1.55089
# [2100]	training's rmse: 1.46607	valid_1's rmse: 1.55088
# [2200]	training's rmse: 1.46228	valid_1's rmse: 1.55088
# [2300]	training's rmse: 1.45876	valid_1's rmse: 1.55095
# [2400]	training's rmse: 1.45508	valid_1's rmse: 1.5509
# [2500]	training's rmse: 1.45138	valid_1's rmse: 1.5509
# [2600]	training's rmse: 1.4477	valid_1's rmse: 1.55078
# [2700]	training's rmse: 1.44411	valid_1's rmse: 1.55078
# [2800]	training's rmse: 1.44055	valid_1's rmse: 1.55073
# [2900]	training's rmse: 1.43706	valid_1's rmse: 1.55081
# [3000]	training's rmse: 1.43354	valid_1's rmse: 1.55078
# [3100]	training's rmse: 1.43014	valid_1's rmse: 1.55085
# Early stopping, best iteration is:
# [2764]	training's rmse: 1.44178	valid_1's rmse: 1.5507
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60946	valid_1's rmse: 1.59389
# [200]	training's rmse: 1.57763	valid_1's rmse: 1.56842
# [300]	training's rmse: 1.56227	valid_1's rmse: 1.55864
# [400]	training's rmse: 1.5519	valid_1's rmse: 1.5533
# [500]	training's rmse: 1.54354	valid_1's rmse: 1.54981
# [600]	training's rmse: 1.53642	valid_1's rmse: 1.54764
# [700]	training's rmse: 1.53017	valid_1's rmse: 1.54632
# [800]	training's rmse: 1.52447	valid_1's rmse: 1.54544
# [900]	training's rmse: 1.51919	valid_1's rmse: 1.54484
# [1000]	training's rmse: 1.51403	valid_1's rmse: 1.54437
# [1100]	training's rmse: 1.50921	valid_1's rmse: 1.54397
# [1200]	training's rmse: 1.50469	valid_1's rmse: 1.54365
# [1300]	training's rmse: 1.50041	valid_1's rmse: 1.5434
# [1400]	training's rmse: 1.49598	valid_1's rmse: 1.54316
# [1500]	training's rmse: 1.49181	valid_1's rmse: 1.54302
# [1600]	training's rmse: 1.48761	valid_1's rmse: 1.54289
# [1700]	training's rmse: 1.48365	valid_1's rmse: 1.5427
# [1800]	training's rmse: 1.47955	valid_1's rmse: 1.54267
# [1900]	training's rmse: 1.47556	valid_1's rmse: 1.54263
# [2000]	training's rmse: 1.47181	valid_1's rmse: 1.54251
# [2100]	training's rmse: 1.46792	valid_1's rmse: 1.54244
# [2200]	training's rmse: 1.46407	valid_1's rmse: 1.5424
# [2300]	training's rmse: 1.46035	valid_1's rmse: 1.54227
# [2400]	training's rmse: 1.45665	valid_1's rmse: 1.54219
# [2500]	training's rmse: 1.45301	valid_1's rmse: 1.54213
# [2600]	training's rmse: 1.44937	valid_1's rmse: 1.54209
# [2700]	training's rmse: 1.44573	valid_1's rmse: 1.54203
# [2800]	training's rmse: 1.44219	valid_1's rmse: 1.54206
# [2900]	training's rmse: 1.43854	valid_1's rmse: 1.54195
# [3000]	training's rmse: 1.43506	valid_1's rmse: 1.54196
# [3100]	training's rmse: 1.43155	valid_1's rmse: 1.54201
# [3200]	training's rmse: 1.42814	valid_1's rmse: 1.54197
# [3300]	training's rmse: 1.42479	valid_1's rmse: 1.54191
# [3400]	training's rmse: 1.42132	valid_1's rmse: 1.54186
# [3500]	training's rmse: 1.41781	valid_1's rmse: 1.54174
# [3600]	training's rmse: 1.41446	valid_1's rmse: 1.5418
# [3700]	training's rmse: 1.41107	valid_1's rmse: 1.54185
# [3800]	training's rmse: 1.40773	valid_1's rmse: 1.5418
# Early stopping, best iteration is:
# [3489]	training's rmse: 1.41817	valid_1's rmse: 1.54173
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.6057	valid_1's rmse: 1.61099
# [200]	training's rmse: 1.57439	valid_1's rmse: 1.58404
# [300]	training's rmse: 1.55899	valid_1's rmse: 1.57326
# [400]	training's rmse: 1.54857	valid_1's rmse: 1.5676
# [500]	training's rmse: 1.54028	valid_1's rmse: 1.5643
# [600]	training's rmse: 1.53316	valid_1's rmse: 1.56205
# [700]	training's rmse: 1.52687	valid_1's rmse: 1.56045
# [800]	training's rmse: 1.52125	valid_1's rmse: 1.55941
# [900]	training's rmse: 1.51607	valid_1's rmse: 1.55886
# [1000]	training's rmse: 1.511	valid_1's rmse: 1.55835
# [1100]	training's rmse: 1.50629	valid_1's rmse: 1.55805
# [1200]	training's rmse: 1.5018	valid_1's rmse: 1.55775
# [1300]	training's rmse: 1.49736	valid_1's rmse: 1.55752
# [1400]	training's rmse: 1.49305	valid_1's rmse: 1.55738
# [1500]	training's rmse: 1.48887	valid_1's rmse: 1.55724
# [1600]	training's rmse: 1.48475	valid_1's rmse: 1.55716
# [1700]	training's rmse: 1.48076	valid_1's rmse: 1.55703
# [1800]	training's rmse: 1.47671	valid_1's rmse: 1.55696
# [1900]	training's rmse: 1.4728	valid_1's rmse: 1.55688
# [2000]	training's rmse: 1.46895	valid_1's rmse: 1.55687
# [2100]	training's rmse: 1.46498	valid_1's rmse: 1.55679
# [2200]	training's rmse: 1.46129	valid_1's rmse: 1.55678
# [2300]	training's rmse: 1.45741	valid_1's rmse: 1.55664
# [2400]	training's rmse: 1.45363	valid_1's rmse: 1.55666
# [2500]	training's rmse: 1.44982	valid_1's rmse: 1.55654
# [2600]	training's rmse: 1.44623	valid_1's rmse: 1.55639
# [2700]	training's rmse: 1.44264	valid_1's rmse: 1.55638
# [2800]	training's rmse: 1.43896	valid_1's rmse: 1.55636
# [2900]	training's rmse: 1.43544	valid_1's rmse: 1.55634
# [3000]	training's rmse: 1.43189	valid_1's rmse: 1.5564
# [3100]	training's rmse: 1.42831	valid_1's rmse: 1.55642
# [3200]	training's rmse: 1.42476	valid_1's rmse: 1.55643
# Early stopping, best iteration is:
# [2897]	training's rmse: 1.43555	valid_1's rmse: 1.55634
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60612	valid_1's rmse: 1.61002
# [200]	training's rmse: 1.57469	valid_1's rmse: 1.58375
# [300]	training's rmse: 1.55935	valid_1's rmse: 1.57344
# [400]	training's rmse: 1.54901	valid_1's rmse: 1.56798
# [500]	training's rmse: 1.54059	valid_1's rmse: 1.56455
# [600]	training's rmse: 1.53343	valid_1's rmse: 1.56221
# [700]	training's rmse: 1.52711	valid_1's rmse: 1.56069
# [800]	training's rmse: 1.52143	valid_1's rmse: 1.55971
# [900]	training's rmse: 1.51623	valid_1's rmse: 1.55911
# [1000]	training's rmse: 1.51118	valid_1's rmse: 1.55861
# [1100]	training's rmse: 1.50635	valid_1's rmse: 1.5584
# [1200]	training's rmse: 1.50179	valid_1's rmse: 1.55813
# [1300]	training's rmse: 1.49732	valid_1's rmse: 1.55784
# [1400]	training's rmse: 1.49298	valid_1's rmse: 1.55762
# [1500]	training's rmse: 1.4888	valid_1's rmse: 1.5575
# [1600]	training's rmse: 1.48464	valid_1's rmse: 1.55741
# [1700]	training's rmse: 1.48072	valid_1's rmse: 1.55736
# [1800]	training's rmse: 1.47683	valid_1's rmse: 1.55726
# [1900]	training's rmse: 1.47282	valid_1's rmse: 1.55718
# [2000]	training's rmse: 1.46893	valid_1's rmse: 1.55704
# [2100]	training's rmse: 1.46514	valid_1's rmse: 1.55694
# [2200]	training's rmse: 1.46133	valid_1's rmse: 1.5569
# [2300]	training's rmse: 1.45756	valid_1's rmse: 1.55691
# [2400]	training's rmse: 1.45393	valid_1's rmse: 1.55683
# [2500]	training's rmse: 1.4503	valid_1's rmse: 1.55675
# [2600]	training's rmse: 1.44664	valid_1's rmse: 1.55667
# [2700]	training's rmse: 1.44312	valid_1's rmse: 1.55665
# [2800]	training's rmse: 1.43951	valid_1's rmse: 1.55664
# [2900]	training's rmse: 1.43613	valid_1's rmse: 1.55662
# [3000]	training's rmse: 1.43261	valid_1's rmse: 1.55668
# [3100]	training's rmse: 1.42931	valid_1's rmse: 1.55669
# Early stopping, best iteration is:
# [2761]	training's rmse: 1.44088	valid_1's rmse: 1.55658
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60107	valid_1's rmse: 1.63089
# [200]	training's rmse: 1.56965	valid_1's rmse: 1.60407
# [300]	training's rmse: 1.55437	valid_1's rmse: 1.59346
# [400]	training's rmse: 1.5439	valid_1's rmse: 1.5879
# [500]	training's rmse: 1.53562	valid_1's rmse: 1.58451
# [600]	training's rmse: 1.52843	valid_1's rmse: 1.58228
# [700]	training's rmse: 1.52215	valid_1's rmse: 1.58103
# [800]	training's rmse: 1.51649	valid_1's rmse: 1.58023
# [900]	training's rmse: 1.51122	valid_1's rmse: 1.57949
# [1000]	training's rmse: 1.50619	valid_1's rmse: 1.57911
# [1100]	training's rmse: 1.50153	valid_1's rmse: 1.57869
# [1200]	training's rmse: 1.49689	valid_1's rmse: 1.57846
# [1300]	training's rmse: 1.49249	valid_1's rmse: 1.57813
# [1400]	training's rmse: 1.48823	valid_1's rmse: 1.57794
# [1500]	training's rmse: 1.48403	valid_1's rmse: 1.57778
# [1600]	training's rmse: 1.47993	valid_1's rmse: 1.57761
# [1700]	training's rmse: 1.47586	valid_1's rmse: 1.57754
# [1800]	training's rmse: 1.47183	valid_1's rmse: 1.57746
# [1900]	training's rmse: 1.46802	valid_1's rmse: 1.57743
# [2000]	training's rmse: 1.46412	valid_1's rmse: 1.57737
# [2100]	training's rmse: 1.46033	valid_1's rmse: 1.5774
# [2200]	training's rmse: 1.45656	valid_1's rmse: 1.57742
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's auc: 0.684257	valid_1's auc: 0.678223
# [200]	training's auc: 0.692789	valid_1's auc: 0.684208
# [300]	training's auc: 0.699569	valid_1's auc: 0.688158
# [400]	training's auc: 0.705226	valid_1's auc: 0.690651
# [500]	training's auc: 0.710075	valid_1's auc: 0.692262
# [600]	training's auc: 0.714334	valid_1's auc: 0.693209
# [700]	training's auc: 0.71824	valid_1's auc: 0.693825
# [800]	training's auc: 0.721907	valid_1's auc: 0.694195
# [900]	training's auc: 0.725377	valid_1's auc: 0.694433
# [1000]	training's auc: 0.728784	valid_1's auc: 0.694614
# [1100]	training's auc: 0.732112	valid_1's auc: 0.694731
# [1200]	training's auc: 0.735364	valid_1's auc: 0.694803
# [1300]	training's auc: 0.738587	valid_1's auc: 0.69483
# [1400]	training's auc: 0.741678	valid_1's auc: 0.694817
# [1500]	training's auc: 0.744732	valid_1's auc: 0.694848
# [1600]	training's auc: 0.747734	valid_1's auc: 0.694934
# [1700]	training's auc: 0.750671	valid_1's auc: 0.694974
# [1800]	training's auc: 0.753621	valid_1's auc: 0.694942
# [1900]	training's auc: 0.756523	valid_1's auc: 0.695026
# [2000]	training's auc: 0.759462	valid_1's auc: 0.695004
# [2100]	training's auc: 0.762319	valid_1's auc: 0.695039
# [2200]	training's auc: 0.765057	valid_1's auc: 0.695025
# [2300]	training's auc: 0.76795	valid_1's auc: 0.695041
# [2400]	training's auc: 0.770677	valid_1's auc: 0.695002
# [2500]	training's auc: 0.773474	valid_1's auc: 0.695072
# [2600]	training's auc: 0.776215	valid_1's auc: 0.69505
# [2700]	training's auc: 0.778885	valid_1's auc: 0.695063
# [2800]	training's auc: 0.78145	valid_1's auc: 0.695047
# [2900]	training's auc: 0.784085	valid_1's auc: 0.69502
# Early stopping, best iteration is:
# [2548]	training's auc: 0.774786	valid_1's auc: 0.695108

# %%
df_train["predict_target_sign"] = np.where(oof>0, oof, 0.001)
df_test["predict_target_sign"] = np.where(predictions_sign>0, predictions_sign, 0.001)

# %%
df_train_columns += ["predict_target_sign"]

# %%
#original
param = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',
    'max_depth': -1,
    'learning_rate': 0.004,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.73144	valid_1's rmse: 3.76481
# [200]	training's rmse: 3.65965	valid_1's rmse: 3.719
# [300]	training's rmse: 3.61033	valid_1's rmse: 3.69338
# [400]	training's rmse: 3.57213	valid_1's rmse: 3.67832
# [500]	training's rmse: 3.54146	valid_1's rmse: 3.6688
# [600]	training's rmse: 3.51587	valid_1's rmse: 3.66272
# [700]	training's rmse: 3.49417	valid_1's rmse: 3.65871
# [800]	training's rmse: 3.47568	valid_1's rmse: 3.65541
# [900]	training's rmse: 3.45872	valid_1's rmse: 3.65345
# [1000]	training's rmse: 3.44375	valid_1's rmse: 3.6521
# [1100]	training's rmse: 3.43074	valid_1's rmse: 3.651
# [1200]	training's rmse: 3.41833	valid_1's rmse: 3.64977
# [1300]	training's rmse: 3.40692	valid_1's rmse: 3.64889
# [1400]	training's rmse: 3.39631	valid_1's rmse: 3.64806
# [1500]	training's rmse: 3.38624	valid_1's rmse: 3.64738
# [1600]	training's rmse: 3.37623	valid_1's rmse: 3.64695
# [1700]	training's rmse: 3.36682	valid_1's rmse: 3.64656
# [1800]	training's rmse: 3.35791	valid_1's rmse: 3.64612
# [1900]	training's rmse: 3.34953	valid_1's rmse: 3.64603
# [2000]	training's rmse: 3.34098	valid_1's rmse: 3.64581
# [2100]	training's rmse: 3.33295	valid_1's rmse: 3.64547
# [2200]	training's rmse: 3.32465	valid_1's rmse: 3.64549
# [2300]	training's rmse: 3.31684	valid_1's rmse: 3.64516
# [2400]	training's rmse: 3.3084	valid_1's rmse: 3.64503
# [2500]	training's rmse: 3.30068	valid_1's rmse: 3.6448
# [2600]	training's rmse: 3.29236	valid_1's rmse: 3.64464
# [2700]	training's rmse: 3.28477	valid_1's rmse: 3.6446
# [2800]	training's rmse: 3.27733	valid_1's rmse: 3.64454
# [2900]	training's rmse: 3.26953	valid_1's rmse: 3.64463
# [3000]	training's rmse: 3.26209	valid_1's rmse: 3.64443
# [3100]	training's rmse: 3.25543	valid_1's rmse: 3.64445
# [3200]	training's rmse: 3.24857	valid_1's rmse: 3.64435
# [3300]	training's rmse: 3.24163	valid_1's rmse: 3.64442
# [3400]	training's rmse: 3.23477	valid_1's rmse: 3.64432
# [3500]	training's rmse: 3.22779	valid_1's rmse: 3.64421
# [3600]	training's rmse: 3.22127	valid_1's rmse: 3.64406
# [3700]	training's rmse: 3.21463	valid_1's rmse: 3.64415
# [3800]	training's rmse: 3.20807	valid_1's rmse: 3.64408
# [3900]	training's rmse: 3.20161	valid_1's rmse: 3.64408
# [4000]	training's rmse: 3.19543	valid_1's rmse: 3.64397
# [4100]	training's rmse: 3.18926	valid_1's rmse: 3.64409
# [4200]	training's rmse: 3.1832	valid_1's rmse: 3.64416
# [4300]	training's rmse: 3.17664	valid_1's rmse: 3.644
# Early stopping, best iteration is:
# [3996]	training's rmse: 3.19563	valid_1's rmse: 3.64394
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.73531	valid_1's rmse: 3.75287
# [200]	training's rmse: 3.6642	valid_1's rmse: 3.70665
# [300]	training's rmse: 3.61442	valid_1's rmse: 3.68154
# [400]	training's rmse: 3.577	valid_1's rmse: 3.66637
# [500]	training's rmse: 3.54591	valid_1's rmse: 3.65648
# [600]	training's rmse: 3.51947	valid_1's rmse: 3.65065
# [700]	training's rmse: 3.49649	valid_1's rmse: 3.64638
# [800]	training's rmse: 3.47642	valid_1's rmse: 3.64366
# [900]	training's rmse: 3.45975	valid_1's rmse: 3.64162
# [1000]	training's rmse: 3.44464	valid_1's rmse: 3.64038
# [1100]	training's rmse: 3.43104	valid_1's rmse: 3.63964
# [1200]	training's rmse: 3.41875	valid_1's rmse: 3.63897
# [1300]	training's rmse: 3.40686	valid_1's rmse: 3.63849
# [1400]	training's rmse: 3.39634	valid_1's rmse: 3.63836
# [1500]	training's rmse: 3.38602	valid_1's rmse: 3.63806
# [1600]	training's rmse: 3.37609	valid_1's rmse: 3.63792
# [1700]	training's rmse: 3.36654	valid_1's rmse: 3.63795
# [1800]	training's rmse: 3.35756	valid_1's rmse: 3.63804
# [1900]	training's rmse: 3.34898	valid_1's rmse: 3.63806
# [2000]	training's rmse: 3.34056	valid_1's rmse: 3.63812
# Early stopping, best iteration is:
# [1658]	training's rmse: 3.37049	valid_1's rmse: 3.63786
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.73694	valid_1's rmse: 3.75241
# [200]	training's rmse: 3.66643	valid_1's rmse: 3.70252
# [300]	training's rmse: 3.61685	valid_1's rmse: 3.6745
# [400]	training's rmse: 3.57902	valid_1's rmse: 3.65704
# [500]	training's rmse: 3.54728	valid_1's rmse: 3.64552
# [600]	training's rmse: 3.52145	valid_1's rmse: 3.63736
# [700]	training's rmse: 3.49919	valid_1's rmse: 3.63203
# [800]	training's rmse: 3.48021	valid_1's rmse: 3.62827
# [900]	training's rmse: 3.46341	valid_1's rmse: 3.62537
# [1000]	training's rmse: 3.44844	valid_1's rmse: 3.62343
# [1100]	training's rmse: 3.43493	valid_1's rmse: 3.62169
# [1200]	training's rmse: 3.42212	valid_1's rmse: 3.62064
# [1300]	training's rmse: 3.41015	valid_1's rmse: 3.6198
# [1400]	training's rmse: 3.39918	valid_1's rmse: 3.61927
# [1500]	training's rmse: 3.38867	valid_1's rmse: 3.61864
# [1600]	training's rmse: 3.37877	valid_1's rmse: 3.61809
# [1700]	training's rmse: 3.36926	valid_1's rmse: 3.61774
# [1800]	training's rmse: 3.35996	valid_1's rmse: 3.61764
# [1900]	training's rmse: 3.35113	valid_1's rmse: 3.61754
# [2000]	training's rmse: 3.34277	valid_1's rmse: 3.61727
# [2100]	training's rmse: 3.33453	valid_1's rmse: 3.6171
# [2200]	training's rmse: 3.32658	valid_1's rmse: 3.61719
# [2300]	training's rmse: 3.31882	valid_1's rmse: 3.61701
# [2400]	training's rmse: 3.31114	valid_1's rmse: 3.61703
# [2500]	training's rmse: 3.30333	valid_1's rmse: 3.61687
# [2600]	training's rmse: 3.29603	valid_1's rmse: 3.61682
# [2700]	training's rmse: 3.2885	valid_1's rmse: 3.61677
# [2800]	training's rmse: 3.28125	valid_1's rmse: 3.61665
# [2900]	training's rmse: 3.27383	valid_1's rmse: 3.61643
# [3000]	training's rmse: 3.26727	valid_1's rmse: 3.61662
# [3100]	training's rmse: 3.26028	valid_1's rmse: 3.61671
# [3200]	training's rmse: 3.25282	valid_1's rmse: 3.61665
# [3300]	training's rmse: 3.24552	valid_1's rmse: 3.6166
# Early stopping, best iteration is:
# [2919]	training's rmse: 3.27257	valid_1's rmse: 3.61637
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.73212	valid_1's rmse: 3.76002
# [200]	training's rmse: 3.65932	valid_1's rmse: 3.71685
# [300]	training's rmse: 3.60808	valid_1's rmse: 3.69402
# [400]	training's rmse: 3.56971	valid_1's rmse: 3.68167
# [500]	training's rmse: 3.53795	valid_1's rmse: 3.67372
# [600]	training's rmse: 3.51106	valid_1's rmse: 3.66825
# [700]	training's rmse: 3.48801	valid_1's rmse: 3.66546
# [800]	training's rmse: 3.46791	valid_1's rmse: 3.6633
# [900]	training's rmse: 3.45082	valid_1's rmse: 3.66184
# [1000]	training's rmse: 3.43491	valid_1's rmse: 3.66094
# [1100]	training's rmse: 3.42071	valid_1's rmse: 3.66073
# [1200]	training's rmse: 3.40764	valid_1's rmse: 3.66051
# [1300]	training's rmse: 3.39576	valid_1's rmse: 3.66021
# [1400]	training's rmse: 3.3848	valid_1's rmse: 3.66013
# [1500]	training's rmse: 3.37464	valid_1's rmse: 3.66014
# [1600]	training's rmse: 3.36501	valid_1's rmse: 3.66019
# [1700]	training's rmse: 3.35577	valid_1's rmse: 3.66018
# Early stopping, best iteration is:
# [1330]	training's rmse: 3.39227	valid_1's rmse: 3.66007
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.72975	valid_1's rmse: 3.77183
# [200]	training's rmse: 3.65767	valid_1's rmse: 3.7278
# [300]	training's rmse: 3.60672	valid_1's rmse: 3.70417
# [400]	training's rmse: 3.56802	valid_1's rmse: 3.69172
# [500]	training's rmse: 3.53604	valid_1's rmse: 3.68325
# [600]	training's rmse: 3.50931	valid_1's rmse: 3.67773
# [700]	training's rmse: 3.48674	valid_1's rmse: 3.67454
# [800]	training's rmse: 3.46744	valid_1's rmse: 3.67299
# [900]	training's rmse: 3.45057	valid_1's rmse: 3.67149
# [1000]	training's rmse: 3.43603	valid_1's rmse: 3.6707
# [1100]	training's rmse: 3.42321	valid_1's rmse: 3.66996
# [1200]	training's rmse: 3.41071	valid_1's rmse: 3.66941
# [1300]	training's rmse: 3.39965	valid_1's rmse: 3.66948
# [1400]	training's rmse: 3.38851	valid_1's rmse: 3.66913
# [1500]	training's rmse: 3.37787	valid_1's rmse: 3.66895
# [1600]	training's rmse: 3.36767	valid_1's rmse: 3.66866
# [1700]	training's rmse: 3.35794	valid_1's rmse: 3.6687
# [1800]	training's rmse: 3.34899	valid_1's rmse: 3.66887
# [1900]	training's rmse: 3.33989	valid_1's rmse: 3.669
# Early stopping, best iteration is:
# [1566]	training's rmse: 3.37069	valid_1's rmse: 3.66853
# 3.645398192849532

# %%
df_prediction = pd.DataFrame({"prediction1":predictions, "prediction2":predictions2})
df_prediction
# Out:
#         prediction1  prediction2
# 0         -2.170251    -0.533903
# 1         -0.267372    -0.294307
# 2         -1.198392    -0.422099
# 3         -0.157428    -0.072560
# 4         -1.495272    -1.704352
# 5          0.403013     0.627065
# 6          0.092908     0.140427
# 7          0.543868     0.825014
# 8         -0.626687    -0.721691
# 9         -0.982991    -0.239120
# 10        -0.586690    -0.480854
# 11         0.177008     0.236420
# 12         0.084891     0.095877
# 13        -0.190723     0.218923
# 14        -6.587102    -0.265708
# 15         0.623337     0.614272
# 16         0.502804     0.526176
# 17        -0.270385    -0.116175
# 18         0.115170     0.171347
# 19        -0.264981    -0.243945
# 20         0.142406     0.262759
# 21        -1.027866    -0.730312
# 22        -0.392927     1.193079
# 23         0.117191     0.295830
# 24        -0.616042     0.051086
# 25        -0.140923     0.449593
# 26        -0.836820    -0.787852
# 27        -0.520758    -0.388496
# 28        -0.059233    -0.052577
# 29        -0.474949    -0.507907
# ...             ...          ...
# 123593    -0.496061    -0.405673
# 123594    -1.154499    -1.175399
# 123595    -0.063818    -0.024978
# 123596     0.758720     1.285669
# 123597    -1.323504    -0.481257
# 123598    -0.886796    -0.636352
# 123599     0.428121     0.390701
# 123600    -1.010684    -0.017493
# 123601    -1.364388    -1.432483
# 123602    -0.322894    -0.253640
# 123603    -0.156395    -0.029091
# 123604     0.682265     0.650045
# 123605    -0.690472    -0.498403
# 123606    -0.419610    -0.363281
# 123607     0.441307     0.516292
# 123608    -0.596734    -0.507023
# 123609    -0.127704    -0.036818
# 123610     0.097563     0.526550
# 123611    -1.439332    -1.084341
# 123612    -0.908786    -0.825043
# 123613    -0.272430     0.045435
# 123614     0.163231     0.914382
# 123615    -0.729970    -0.616226
# 123616     1.185348     1.422053
# 123617     0.667757     0.604873
# 123618     1.082726     1.409636
# 123619    -0.516015    -0.450044
# 123620     0.747368     1.145847
# 123621    -3.088574    -0.920837
# 123622    -0.001665     0.047091
#
# [123623 rows x 2 columns]

# %%
final_predictions = np.zeros(df_prediction.shape[0])
for i, r in df_prediction.iterrows():
    if r[0] < 0:
        final_predictions[i] = r[0]
    else:
        final_predictions[i] = r[1]

# %%
# import optuna

# def objective(trial):
#     train_x, test_x, train_y, test_y = train_test_split(df_train[df_train_columns], target, test_size=0.20, random_state=4590)
    
#     dtrain = lgb.Dataset(train_x, label=train_y)
#     dval = lgb.Dataset(test_x, label=test_y)

#     num_round = trial.suggest_int('num_round', 1, 10000)
#     param = {
#         'objective': 'regression', 
#         'metric': 'rmse',
#         'verbosity': -1,
#         'feature_fraction': trial.suggest_loguniform('feature_fraction', 0.8, 0.95),
#         'bagging_fraction': trial.suggest_loguniform('bagging_fraction', 0.8, 0.95),
#         'bagging_seed': 11,
#         'boosting_type': trial.suggest_categorical('boosting', ['gbdt', 'dart', 'goss']),
#         'num_leaves': trial.suggest_int('num_leaves', 10, 100),
#         'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
#         'min_child_samples': trial.suggest_int('min_child_samples', 20, 100),
#         'min_data_in_leaf':  trial.suggest_int('min_data_in_leaf', 10, 1000),
#         'lambda_l1':  trial.suggest_loguniform('lambda_l1', 1e-2, 1.0)
#     }

#     if param['boosting_type'] == 'dart':
#         param['drop_rate'] = trial.suggest_loguniform('drop_rate', 1e-4, 1.0)
#         param['skip_drop'] = trial.suggest_loguniform('skip_drop', 1e-4, 1.0)
#     if param['boosting_type'] == 'goss':
#         param['top_rate'] = trial.suggest_uniform('top_rate', 0.0, 1.0)
#         param['other_rate'] = trial.suggest_uniform('other_rate', 0.0, 1.0 - param['top_rate'])

#     gbm = lgb.train(param, dtrain, num_round, valid_sets = [dtrain, dval], verbose_eval=100, early_stopping_rounds=400)
#     preds = gbm.predict(test_x)
#     pred_labels = np.rint(preds)
#     rmse = np.sqrt(mean_squared_error(test_y, pred_labels))
#     return rmse

# study = optuna.create_study()
# study.optimize(objective, n_trials=20)

# print('Number of finished trials: {}'.format(len(study.trials)))

# print('Best trial:')
# trial = study.best_trial

# print('  Value: {}'.format(trial.value))

# print('  Params: ')
# for key, value in trial.params.items():
#     print('    {}: {}'.format(key, value))

# %%
sub_df = pd.DataFrame({"card_id":df_test["card_id"].values})
sub_df["target"] = predictions
sub_df.to_csv("../output/submission_model20181218.csv", index=False)
