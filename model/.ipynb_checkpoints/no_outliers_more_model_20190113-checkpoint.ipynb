# %%
import numpy as np
import pandas as pd
import datetime
from itertools import combinations

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import lightgbm as lgb

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error, roc_auc_score, confusion_matrix, f1_score
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')
np.random.seed(4590)

# %%
df_train = pd.read_csv('../input/20181216_train.csv')
df_test = pd.read_csv('../input/20181216_test.csv')

df_train = df_train[(df_train.target >= -10)&(df_train.target <= 10)].reset_index(drop=True)

# %%
df_train["outliers"] = np.where(df_train.target < -30, 1, 0)

# %%
def merge_new_feature(path):
    df_new_feature = pd.read_csv(path)
    
    df_tr = pd.merge(df_train, df_new_feature, on="card_id", how="left")
    df_te = pd.merge(df_test, df_new_feature, on="card_id", how="left")
    
    return df_tr, df_te

# %%
df_train, df_test = merge_new_feature("../input/feature_categorical_count_rate.csv")
df_train, df_test = merge_new_feature("../input/feature_various_time_data.csv")
df_train, df_test = merge_new_feature("../input/merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/payment_splited_by_installments_NMF.csv")
df_train, df_test = merge_new_feature("../input/feature_catogorical_count_weighted_elapsed.csv")
df_train, df_test = merge_new_feature("../input/feature_latest_transaction_data__per__card_id.csv")

# %%
dont_use = ['card_id', 'first_active_month','second_active_date','diff_first_and_second','target','outliers', 'category_1_Y_std']

df_train_columns = [c for c in df_train.columns if c not in dont_use]
target = df_train['target']
target_outlier = df_train["outliers"]

# %%
drop_col = []
comb = list(combinations(df_train_columns, 2))

for c1, c2 in comb:
    corr = np.corrcoef(df_train[c1], df_train[c2])[0,1]
    if corr >= 0.95:
        print("【{i}】 --- 【{j}】".format(i=c1, j=c2))
        print(corr)
        drop_col.append(c2)
        print("\n"*2)

for col in df_train_columns:
    if col in sorted(set(drop_col)):
        df_train_columns.remove(col)
# Out:
# 【hist_month_diff_mean】 --- 【hist_purchase_date_uptonow】
# 0.9572734977022199
#
#
#
# 【hist_authorized_flag_sum】 --- 【hist_card_id_size】
# 0.9947409199340903
#
#
#
# 【hist_authorized_flag_sum】 --- 【card_id_count】
# 0.9936747990380813
#
#
#
# 【hist_authorized_flag_sum】 --- 【authorized_flag_ture】
# 0.9979563032311815
#
#
#
# 【hist_authorized_flag_sum】 --- 【authorized_flag_ture_weighted_elapsed】
# 0.9979563032311815
#
#
#
# 【hist_authorized_flag_mean】 --- 【authorized_flag_ture_rate】
# 0.9869695855649858
#
#
#
# 【hist_category_1_sum】 --- 【category_1_true】
# 0.9996022146047879
#
#
#
# 【hist_category_1_sum】 --- 【category_1_true_weighted_elapsed】
# 0.9996022146047879
#
#
#
# 【hist_category_1_mean】 --- 【category_1_true_rate】
# 0.9914354633474983
#
#
#
# 【hist_card_id_size】 --- 【card_id_count】
# 0.9981210394084882
#
#
#
# 【hist_card_id_size】 --- 【authorized_flag_ture】
# 0.9920970949999207
#
#
#
# 【hist_card_id_size】 --- 【authorized_flag_ture_weighted_elapsed】
# 0.9920970949999207
#
#
#
# 【hist_purchase_date_diff】 --- 【elapsed_from_oldest_purchase_date_to_latest_purchase_date】
# 0.9690746506974126
#
#
#
# 【new_hist_purchase_date_max】 --- 【new_hist_purchase_date_min】
# 0.9999998769334303
#
#
#
# 【hist_first_buy】 --- 【elapsed_from_oldest_purchase_date_to_first_active】
# 1.0
#
#
#
# 【card_id_count】 --- 【authorized_flag_ture】
# 0.994942866394614
#
#
#
# 【card_id_count】 --- 【authorized_flag_ture_weighted_elapsed】
# 0.994942866394614
#
#
#
# 【authorized_flag_ture】 --- 【authorized_flag_ture_weighted_elapsed】
# 1.0
#
#
#
# 【category_1_true】 --- 【category_1_true_weighted_elapsed】
# 1.0
#
#
#
# 【category_3_A】 --- 【installments_0】
# 0.9999999999999999
#
#
#
# 【category_3_B】 --- 【installments_1】
# 1.0
#
#
#
# 【category_3_A_rate】 --- 【installments_0_rate】
# 1.0
#
#
#
# 【category_3_A_rate】 --- 【category_3_A_latest_trs】
# 0.9892599613572244
#
#
#
# 【category_3_B_rate】 --- 【installments_1_rate】
# 1.0
#
#
#
# 【installments_0_rate】 --- 【category_3_A_latest_trs】
# 0.9892599613572244
#
#
#
# 【month_lag_N13】 --- 【month_lag_N13_weighted_elapsed】
# 0.999313396870081
#
#
#
# 【month_lag_N12】 --- 【month_lag_N12_weighted_elapsed】
# 0.996582553642727
#
#
#
# 【month_lag_N11】 --- 【month_lag_N11_weighted_elapsed】
# 0.9917223085652619
#
#
#
# 【month_lag_N10】 --- 【month_lag_N10_weighted_elapsed】
# 0.9810409928990041
#
#
#
# 【month_lag_N9】 --- 【month_lag_N9_weighted_elapsed】
# 0.9727674533774123
#
#
#
# 【month_lag_N8】 --- 【month_lag_N8_weighted_elapsed】
# 0.9644701836842613
#
#
#
# 【month_lag_N7】 --- 【month_lag_N7_weighted_elapsed】
# 0.9631259783754875
#
#
#
# 【month_lag_N6】 --- 【month_lag_N6_weighted_elapsed】
# 0.9546906642775005
#
#
#
# 【category_3_A_weighted_elapsed】 --- 【installments_0_weighted_elapsed】
# 0.9999999999999999
#
#
#
# 【category_3_B_weighted_elapsed】 --- 【installments_1_weighted_elapsed】
# 1.0
#
#
#
# 【most_recent_sales_range_A_weighted_elapsed】 --- 【most_recent_purchases_range_A_weighted_elapsed】
# 0.9541449591668568
#
#
#
# 【category_4_null_latest_trs】 --- 【numerical_1_null_latest_trs】
# 1.0
#
#
#
# 【category_4_null_latest_trs】 --- 【most_recent_sales_range_null_latest_trs】
# 1.0
#
#
#
# 【category_4_null_latest_trs】 --- 【most_recent_purchases_range_null_latest_trs】
# 1.0
#
#
#
# 【numerical_1_null_latest_trs】 --- 【most_recent_sales_range_null_latest_trs】
# 1.0
#
#
#
# 【numerical_1_null_latest_trs】 --- 【most_recent_purchases_range_null_latest_trs】
# 1.0
#
#
#
# 【most_recent_sales_range_null_latest_trs】 --- 【most_recent_purchases_range_null_latest_trs】
# 1.0

# %%
#original
param = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',  #regression
    'max_depth': 8,  # -1
    'learning_rate': 0.004,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',  #auc
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(target, oof))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.62939	valid_1's rmse: 1.62999
# [200]	training's rmse: 1.59464	valid_1's rmse: 1.59695
# [300]	training's rmse: 1.57436	valid_1's rmse: 1.57822
# [400]	training's rmse: 1.56124	valid_1's rmse: 1.56648
# [500]	training's rmse: 1.55191	valid_1's rmse: 1.5584
# [600]	training's rmse: 1.54487	valid_1's rmse: 1.55287
# [700]	training's rmse: 1.5392	valid_1's rmse: 1.54875
# [800]	training's rmse: 1.53442	valid_1's rmse: 1.54555
# [900]	training's rmse: 1.53032	valid_1's rmse: 1.54307
# [1000]	training's rmse: 1.52664	valid_1's rmse: 1.54098
# [1100]	training's rmse: 1.52327	valid_1's rmse: 1.53924
# [1200]	training's rmse: 1.52019	valid_1's rmse: 1.53783
# [1300]	training's rmse: 1.51734	valid_1's rmse: 1.53665
# [1400]	training's rmse: 1.51465	valid_1's rmse: 1.53568
# [1500]	training's rmse: 1.51206	valid_1's rmse: 1.53479
# [1600]	training's rmse: 1.50969	valid_1's rmse: 1.53406
# [1700]	training's rmse: 1.5074	valid_1's rmse: 1.53347
# [1800]	training's rmse: 1.50519	valid_1's rmse: 1.53293
# [1900]	training's rmse: 1.50303	valid_1's rmse: 1.5325
# [2000]	training's rmse: 1.50094	valid_1's rmse: 1.53208
# [2100]	training's rmse: 1.49896	valid_1's rmse: 1.53178
# [2200]	training's rmse: 1.49702	valid_1's rmse: 1.53156
# [2300]	training's rmse: 1.49512	valid_1's rmse: 1.53134
# [2400]	training's rmse: 1.49323	valid_1's rmse: 1.53111
# [2500]	training's rmse: 1.49139	valid_1's rmse: 1.53091
# [2600]	training's rmse: 1.48965	valid_1's rmse: 1.53077
# [2700]	training's rmse: 1.48788	valid_1's rmse: 1.53065
# [2800]	training's rmse: 1.48617	valid_1's rmse: 1.53051
# [2900]	training's rmse: 1.48446	valid_1's rmse: 1.53037
# [3000]	training's rmse: 1.48279	valid_1's rmse: 1.53028
# [3100]	training's rmse: 1.48114	valid_1's rmse: 1.53019
# [3200]	training's rmse: 1.47949	valid_1's rmse: 1.53014
# [3300]	training's rmse: 1.47788	valid_1's rmse: 1.53005
# [3400]	training's rmse: 1.47628	valid_1's rmse: 1.52998
# [3500]	training's rmse: 1.47473	valid_1's rmse: 1.52991
# [3600]	training's rmse: 1.47316	valid_1's rmse: 1.52985
# [3700]	training's rmse: 1.47159	valid_1's rmse: 1.52977
# [3800]	training's rmse: 1.47006	valid_1's rmse: 1.5297
# [3900]	training's rmse: 1.4685	valid_1's rmse: 1.52966
# [4000]	training's rmse: 1.46696	valid_1's rmse: 1.52962
# [4100]	training's rmse: 1.46544	valid_1's rmse: 1.52958
# [4200]	training's rmse: 1.46391	valid_1's rmse: 1.5295
# [4300]	training's rmse: 1.46241	valid_1's rmse: 1.52942
# [4400]	training's rmse: 1.46098	valid_1's rmse: 1.52938
# [4500]	training's rmse: 1.45953	valid_1's rmse: 1.52932
# [4600]	training's rmse: 1.45802	valid_1's rmse: 1.52928
# [4700]	training's rmse: 1.45655	valid_1's rmse: 1.52924
# [4800]	training's rmse: 1.45508	valid_1's rmse: 1.5292
# [4900]	training's rmse: 1.45363	valid_1's rmse: 1.52916
# [5000]	training's rmse: 1.45218	valid_1's rmse: 1.52913
# [5100]	training's rmse: 1.45073	valid_1's rmse: 1.5291
# [5200]	training's rmse: 1.44926	valid_1's rmse: 1.52907
# [5300]	training's rmse: 1.4478	valid_1's rmse: 1.52904
# [5400]	training's rmse: 1.44635	valid_1's rmse: 1.52901
# [5500]	training's rmse: 1.44492	valid_1's rmse: 1.529
# [5600]	training's rmse: 1.44347	valid_1's rmse: 1.52897
# [5700]	training's rmse: 1.44204	valid_1's rmse: 1.52894
# [5800]	training's rmse: 1.44067	valid_1's rmse: 1.52891
# [5900]	training's rmse: 1.43926	valid_1's rmse: 1.52886
# [6000]	training's rmse: 1.43787	valid_1's rmse: 1.52882
# [6100]	training's rmse: 1.43646	valid_1's rmse: 1.52879
# [6200]	training's rmse: 1.43507	valid_1's rmse: 1.52879
# [6300]	training's rmse: 1.43369	valid_1's rmse: 1.52877
# [6400]	training's rmse: 1.43229	valid_1's rmse: 1.52875
# [6500]	training's rmse: 1.43093	valid_1's rmse: 1.52874
# [6600]	training's rmse: 1.42961	valid_1's rmse: 1.52874
# [6700]	training's rmse: 1.42823	valid_1's rmse: 1.52874
# [6800]	training's rmse: 1.42685	valid_1's rmse: 1.52873
# [6900]	training's rmse: 1.42551	valid_1's rmse: 1.5287
# [7000]	training's rmse: 1.42418	valid_1's rmse: 1.52868
# [7100]	training's rmse: 1.42288	valid_1's rmse: 1.52869
# [7200]	training's rmse: 1.42155	valid_1's rmse: 1.52868
# [7300]	training's rmse: 1.4202	valid_1's rmse: 1.52865
# [7400]	training's rmse: 1.41885	valid_1's rmse: 1.52863
# [7500]	training's rmse: 1.41753	valid_1's rmse: 1.52861
# [7600]	training's rmse: 1.41618	valid_1's rmse: 1.52863
# [7700]	training's rmse: 1.41485	valid_1's rmse: 1.52862
# [7800]	training's rmse: 1.41351	valid_1's rmse: 1.52864
# Early stopping, best iteration is:
# [7469]	training's rmse: 1.41794	valid_1's rmse: 1.5286
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.62765	valid_1's rmse: 1.63517
# [200]	training's rmse: 1.59245	valid_1's rmse: 1.60319
# [300]	training's rmse: 1.57186	valid_1's rmse: 1.58533
# [400]	training's rmse: 1.55852	valid_1's rmse: 1.57451
# [500]	training's rmse: 1.54908	valid_1's rmse: 1.56754
# [600]	training's rmse: 1.54191	valid_1's rmse: 1.56268
# [700]	training's rmse: 1.53617	valid_1's rmse: 1.55911
# [800]	training's rmse: 1.5314	valid_1's rmse: 1.55638
# [900]	training's rmse: 1.52725	valid_1's rmse: 1.55424
# [1000]	training's rmse: 1.52352	valid_1's rmse: 1.5525
# [1100]	training's rmse: 1.52012	valid_1's rmse: 1.55104
# [1200]	training's rmse: 1.517	valid_1's rmse: 1.54979
# [1300]	training's rmse: 1.5141	valid_1's rmse: 1.54871
# [1400]	training's rmse: 1.51141	valid_1's rmse: 1.5479
# [1500]	training's rmse: 1.50883	valid_1's rmse: 1.54722
# [1600]	training's rmse: 1.50641	valid_1's rmse: 1.54659
# [1700]	training's rmse: 1.50409	valid_1's rmse: 1.54605
# [1800]	training's rmse: 1.50186	valid_1's rmse: 1.54557
# [1900]	training's rmse: 1.49975	valid_1's rmse: 1.54517
# [2000]	training's rmse: 1.49764	valid_1's rmse: 1.54484
# [2100]	training's rmse: 1.49566	valid_1's rmse: 1.54458
# [2200]	training's rmse: 1.49373	valid_1's rmse: 1.54434
# [2300]	training's rmse: 1.49182	valid_1's rmse: 1.54414
# [2400]	training's rmse: 1.48997	valid_1's rmse: 1.54391
# [2500]	training's rmse: 1.48815	valid_1's rmse: 1.54371
# [2600]	training's rmse: 1.48637	valid_1's rmse: 1.54357
# [2700]	training's rmse: 1.48464	valid_1's rmse: 1.54342
# [2800]	training's rmse: 1.48291	valid_1's rmse: 1.54328
# [2900]	training's rmse: 1.4812	valid_1's rmse: 1.54316
# [3000]	training's rmse: 1.47954	valid_1's rmse: 1.54301
# [3100]	training's rmse: 1.47787	valid_1's rmse: 1.54291
# [3200]	training's rmse: 1.47624	valid_1's rmse: 1.54283
# [3300]	training's rmse: 1.47458	valid_1's rmse: 1.54274
# [3400]	training's rmse: 1.47298	valid_1's rmse: 1.54271
# [3500]	training's rmse: 1.47143	valid_1's rmse: 1.54261
# [3600]	training's rmse: 1.46985	valid_1's rmse: 1.54256
# [3700]	training's rmse: 1.46827	valid_1's rmse: 1.54249
# [3800]	training's rmse: 1.46675	valid_1's rmse: 1.54246
# [3900]	training's rmse: 1.46522	valid_1's rmse: 1.54241
# [4000]	training's rmse: 1.46366	valid_1's rmse: 1.54237
# [4100]	training's rmse: 1.46218	valid_1's rmse: 1.54232
# [4200]	training's rmse: 1.46063	valid_1's rmse: 1.54223
# [4300]	training's rmse: 1.45916	valid_1's rmse: 1.54218
# [4400]	training's rmse: 1.45765	valid_1's rmse: 1.54215
# [4500]	training's rmse: 1.45613	valid_1's rmse: 1.54211
# [4600]	training's rmse: 1.45462	valid_1's rmse: 1.5421
# [4700]	training's rmse: 1.45318	valid_1's rmse: 1.54207
# [4800]	training's rmse: 1.4517	valid_1's rmse: 1.54205
# [4900]	training's rmse: 1.45024	valid_1's rmse: 1.54204
# [5000]	training's rmse: 1.44878	valid_1's rmse: 1.54199
# [5100]	training's rmse: 1.44733	valid_1's rmse: 1.54197
# [5200]	training's rmse: 1.44589	valid_1's rmse: 1.54197
# [5300]	training's rmse: 1.44447	valid_1's rmse: 1.54193
# [5400]	training's rmse: 1.44303	valid_1's rmse: 1.5419
# [5500]	training's rmse: 1.44162	valid_1's rmse: 1.54189
# [5600]	training's rmse: 1.44016	valid_1's rmse: 1.5419
# [5700]	training's rmse: 1.43876	valid_1's rmse: 1.54187
# [5800]	training's rmse: 1.43733	valid_1's rmse: 1.54185
# [5900]	training's rmse: 1.43593	valid_1's rmse: 1.54184
# [6000]	training's rmse: 1.43448	valid_1's rmse: 1.54186
# [6100]	training's rmse: 1.43309	valid_1's rmse: 1.54184
# [6200]	training's rmse: 1.4317	valid_1's rmse: 1.54184
# [6300]	training's rmse: 1.43028	valid_1's rmse: 1.54182
# [6400]	training's rmse: 1.42892	valid_1's rmse: 1.54184
# [6500]	training's rmse: 1.42754	valid_1's rmse: 1.54184
# [6600]	training's rmse: 1.42617	valid_1's rmse: 1.54184
# [6700]	training's rmse: 1.42481	valid_1's rmse: 1.54181
# [6800]	training's rmse: 1.42348	valid_1's rmse: 1.54179
# [6900]	training's rmse: 1.42216	valid_1's rmse: 1.54178
# [7000]	training's rmse: 1.42077	valid_1's rmse: 1.54177
# [7100]	training's rmse: 1.41945	valid_1's rmse: 1.54175
# [7200]	training's rmse: 1.4181	valid_1's rmse: 1.54175
# [7300]	training's rmse: 1.41674	valid_1's rmse: 1.54179
# [7400]	training's rmse: 1.41541	valid_1's rmse: 1.5418
# Early stopping, best iteration is:
# [7072]	training's rmse: 1.41979	valid_1's rmse: 1.54174
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.63032	valid_1's rmse: 1.62552
# [200]	training's rmse: 1.59543	valid_1's rmse: 1.59276
# [300]	training's rmse: 1.57501	valid_1's rmse: 1.57447
# [400]	training's rmse: 1.56172	valid_1's rmse: 1.5633
# [500]	training's rmse: 1.55226	valid_1's rmse: 1.55598
# [600]	training's rmse: 1.5451	valid_1's rmse: 1.55078
# [700]	training's rmse: 1.53935	valid_1's rmse: 1.54692
# [800]	training's rmse: 1.53457	valid_1's rmse: 1.54412
# [900]	training's rmse: 1.53036	valid_1's rmse: 1.54182
# [1000]	training's rmse: 1.52659	valid_1's rmse: 1.53988
# [1100]	training's rmse: 1.52324	valid_1's rmse: 1.53838
# [1200]	training's rmse: 1.52019	valid_1's rmse: 1.53715
# [1300]	training's rmse: 1.51733	valid_1's rmse: 1.53611
# [1400]	training's rmse: 1.51465	valid_1's rmse: 1.53526
# [1500]	training's rmse: 1.51214	valid_1's rmse: 1.5345
# [1600]	training's rmse: 1.50973	valid_1's rmse: 1.53391
# [1700]	training's rmse: 1.50742	valid_1's rmse: 1.53336
# [1800]	training's rmse: 1.50521	valid_1's rmse: 1.53293
# [1900]	training's rmse: 1.50307	valid_1's rmse: 1.53256
# [2000]	training's rmse: 1.50101	valid_1's rmse: 1.53222
# [2100]	training's rmse: 1.49903	valid_1's rmse: 1.53192
# [2200]	training's rmse: 1.49709	valid_1's rmse: 1.53166
# [2300]	training's rmse: 1.49521	valid_1's rmse: 1.53146
# [2400]	training's rmse: 1.49331	valid_1's rmse: 1.53127
# [2500]	training's rmse: 1.4915	valid_1's rmse: 1.53111
# [2600]	training's rmse: 1.48971	valid_1's rmse: 1.53097
# [2700]	training's rmse: 1.488	valid_1's rmse: 1.53082
# [2800]	training's rmse: 1.48624	valid_1's rmse: 1.53071
# [2900]	training's rmse: 1.48455	valid_1's rmse: 1.53065
# [3000]	training's rmse: 1.48285	valid_1's rmse: 1.53057
# [3100]	training's rmse: 1.48118	valid_1's rmse: 1.53047
# [3200]	training's rmse: 1.47954	valid_1's rmse: 1.53041
# [3300]	training's rmse: 1.47791	valid_1's rmse: 1.53035
# [3400]	training's rmse: 1.47635	valid_1's rmse: 1.53028
# [3500]	training's rmse: 1.47475	valid_1's rmse: 1.53025
# [3600]	training's rmse: 1.47318	valid_1's rmse: 1.53019
# [3700]	training's rmse: 1.47161	valid_1's rmse: 1.53016
# [3800]	training's rmse: 1.47007	valid_1's rmse: 1.53007
# [3900]	training's rmse: 1.46853	valid_1's rmse: 1.52999
# [4000]	training's rmse: 1.46698	valid_1's rmse: 1.52994
# [4100]	training's rmse: 1.46543	valid_1's rmse: 1.52987
# [4200]	training's rmse: 1.46385	valid_1's rmse: 1.5298
# [4300]	training's rmse: 1.46236	valid_1's rmse: 1.52978
# [4400]	training's rmse: 1.46081	valid_1's rmse: 1.5297
# [4500]	training's rmse: 1.45926	valid_1's rmse: 1.52966
# [4600]	training's rmse: 1.45778	valid_1's rmse: 1.52962
# [4700]	training's rmse: 1.45632	valid_1's rmse: 1.5296
# [4800]	training's rmse: 1.45488	valid_1's rmse: 1.52956
# [4900]	training's rmse: 1.45341	valid_1's rmse: 1.52954
# [5000]	training's rmse: 1.45193	valid_1's rmse: 1.52952
# [5100]	training's rmse: 1.45046	valid_1's rmse: 1.52946
# [5200]	training's rmse: 1.44903	valid_1's rmse: 1.5294
# [5300]	training's rmse: 1.4476	valid_1's rmse: 1.52939
# [5400]	training's rmse: 1.4462	valid_1's rmse: 1.52939
# [5500]	training's rmse: 1.44478	valid_1's rmse: 1.52935
# [5600]	training's rmse: 1.44334	valid_1's rmse: 1.52935
# [5700]	training's rmse: 1.44193	valid_1's rmse: 1.52935
# [5800]	training's rmse: 1.44054	valid_1's rmse: 1.52934
# [5900]	training's rmse: 1.43916	valid_1's rmse: 1.52932
# [6000]	training's rmse: 1.43773	valid_1's rmse: 1.5293
# [6100]	training's rmse: 1.43636	valid_1's rmse: 1.5293
# [6200]	training's rmse: 1.43499	valid_1's rmse: 1.52927
# [6300]	training's rmse: 1.43357	valid_1's rmse: 1.52927
# [6400]	training's rmse: 1.43217	valid_1's rmse: 1.52925
# [6500]	training's rmse: 1.43082	valid_1's rmse: 1.52925
# [6600]	training's rmse: 1.42944	valid_1's rmse: 1.52922
# [6700]	training's rmse: 1.42807	valid_1's rmse: 1.5292
# [6800]	training's rmse: 1.42674	valid_1's rmse: 1.52919
# [6900]	training's rmse: 1.42538	valid_1's rmse: 1.52917
# [7000]	training's rmse: 1.42402	valid_1's rmse: 1.52914
# [7100]	training's rmse: 1.42268	valid_1's rmse: 1.52912
# [7200]	training's rmse: 1.42133	valid_1's rmse: 1.52911
# [7300]	training's rmse: 1.42	valid_1's rmse: 1.52911
# [7400]	training's rmse: 1.41867	valid_1's rmse: 1.5291
# [7500]	training's rmse: 1.41732	valid_1's rmse: 1.52906
# [7600]	training's rmse: 1.41599	valid_1's rmse: 1.52903
# [7700]	training's rmse: 1.41469	valid_1's rmse: 1.52901
# [7800]	training's rmse: 1.41337	valid_1's rmse: 1.529
# [7900]	training's rmse: 1.41206	valid_1's rmse: 1.529
# [8000]	training's rmse: 1.41072	valid_1's rmse: 1.52902
# [8100]	training's rmse: 1.40942	valid_1's rmse: 1.52902
# [8200]	training's rmse: 1.4081	valid_1's rmse: 1.52902
# Early stopping, best iteration is:
# [7833]	training's rmse: 1.41293	valid_1's rmse: 1.52899
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.62984	valid_1's rmse: 1.62829
# [200]	training's rmse: 1.59513	valid_1's rmse: 1.59513
# [300]	training's rmse: 1.57478	valid_1's rmse: 1.57638
# [400]	training's rmse: 1.56157	valid_1's rmse: 1.56471
# [500]	training's rmse: 1.55224	valid_1's rmse: 1.55678
# [600]	training's rmse: 1.54512	valid_1's rmse: 1.55122
# [700]	training's rmse: 1.53934	valid_1's rmse: 1.54707
# [800]	training's rmse: 1.53454	valid_1's rmse: 1.544
# [900]	training's rmse: 1.53038	valid_1's rmse: 1.54155
# [1000]	training's rmse: 1.52666	valid_1's rmse: 1.53955
# [1100]	training's rmse: 1.52325	valid_1's rmse: 1.5379
# [1200]	training's rmse: 1.52015	valid_1's rmse: 1.53653
# [1300]	training's rmse: 1.51724	valid_1's rmse: 1.53537
# [1400]	training's rmse: 1.51454	valid_1's rmse: 1.53435
# [1500]	training's rmse: 1.51199	valid_1's rmse: 1.5335
# [1600]	training's rmse: 1.50955	valid_1's rmse: 1.53278
# [1700]	training's rmse: 1.50723	valid_1's rmse: 1.53217
# [1800]	training's rmse: 1.50503	valid_1's rmse: 1.53166
# [1900]	training's rmse: 1.50288	valid_1's rmse: 1.53124
# [2000]	training's rmse: 1.50085	valid_1's rmse: 1.53092
# [2100]	training's rmse: 1.49886	valid_1's rmse: 1.53059
# [2200]	training's rmse: 1.4969	valid_1's rmse: 1.53029
# [2300]	training's rmse: 1.49498	valid_1's rmse: 1.53004
# [2400]	training's rmse: 1.49312	valid_1's rmse: 1.52985
# [2500]	training's rmse: 1.49128	valid_1's rmse: 1.52967
# [2600]	training's rmse: 1.48952	valid_1's rmse: 1.5295
# [2700]	training's rmse: 1.48779	valid_1's rmse: 1.52938
# [2800]	training's rmse: 1.48605	valid_1's rmse: 1.52924
# [2900]	training's rmse: 1.48434	valid_1's rmse: 1.52912
# [3000]	training's rmse: 1.48266	valid_1's rmse: 1.52904
# [3100]	training's rmse: 1.48099	valid_1's rmse: 1.52893
# [3200]	training's rmse: 1.47934	valid_1's rmse: 1.52882
# [3300]	training's rmse: 1.47771	valid_1's rmse: 1.52868
# [3400]	training's rmse: 1.47614	valid_1's rmse: 1.52857
# [3500]	training's rmse: 1.47456	valid_1's rmse: 1.52853
# [3600]	training's rmse: 1.47297	valid_1's rmse: 1.52845
# [3700]	training's rmse: 1.4714	valid_1's rmse: 1.52841
# [3800]	training's rmse: 1.46987	valid_1's rmse: 1.52836
# [3900]	training's rmse: 1.4683	valid_1's rmse: 1.52838
# [4000]	training's rmse: 1.46673	valid_1's rmse: 1.52835
# [4100]	training's rmse: 1.46522	valid_1's rmse: 1.52831
# [4200]	training's rmse: 1.4637	valid_1's rmse: 1.52829
# [4300]	training's rmse: 1.46218	valid_1's rmse: 1.52822
# [4400]	training's rmse: 1.4607	valid_1's rmse: 1.52819
# [4500]	training's rmse: 1.45917	valid_1's rmse: 1.52813
# [4600]	training's rmse: 1.45771	valid_1's rmse: 1.52805
# [4700]	training's rmse: 1.45625	valid_1's rmse: 1.52802
# [4800]	training's rmse: 1.45479	valid_1's rmse: 1.52796
# [4900]	training's rmse: 1.45334	valid_1's rmse: 1.52793
# [5000]	training's rmse: 1.45187	valid_1's rmse: 1.52793
# [5100]	training's rmse: 1.45042	valid_1's rmse: 1.52788
# [5200]	training's rmse: 1.44893	valid_1's rmse: 1.52788
# [5300]	training's rmse: 1.44749	valid_1's rmse: 1.52786
# [5400]	training's rmse: 1.44603	valid_1's rmse: 1.52785
# [5500]	training's rmse: 1.44461	valid_1's rmse: 1.52783
# [5600]	training's rmse: 1.44318	valid_1's rmse: 1.52781
# [5700]	training's rmse: 1.44175	valid_1's rmse: 1.52779
# [5800]	training's rmse: 1.44038	valid_1's rmse: 1.5278
# [5900]	training's rmse: 1.43898	valid_1's rmse: 1.52778
# [6000]	training's rmse: 1.43754	valid_1's rmse: 1.52772
# [6100]	training's rmse: 1.43613	valid_1's rmse: 1.52773
# [6200]	training's rmse: 1.43475	valid_1's rmse: 1.5277
# [6300]	training's rmse: 1.43336	valid_1's rmse: 1.52768
# [6400]	training's rmse: 1.432	valid_1's rmse: 1.52769
# [6500]	training's rmse: 1.43063	valid_1's rmse: 1.52769
# [6600]	training's rmse: 1.42923	valid_1's rmse: 1.52769
# [6700]	training's rmse: 1.42785	valid_1's rmse: 1.52772
# [6800]	training's rmse: 1.42649	valid_1's rmse: 1.52775
# [6900]	training's rmse: 1.42513	valid_1's rmse: 1.52775
# Early stopping, best iteration is:
# [6562]	training's rmse: 1.42975	valid_1's rmse: 1.52766
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.62798	valid_1's rmse: 1.63522
# [200]	training's rmse: 1.59347	valid_1's rmse: 1.60153
# [300]	training's rmse: 1.57313	valid_1's rmse: 1.58246
# [400]	training's rmse: 1.55984	valid_1's rmse: 1.57083
# [500]	training's rmse: 1.55047	valid_1's rmse: 1.56308
# [600]	training's rmse: 1.54342	valid_1's rmse: 1.55771
# [700]	training's rmse: 1.53764	valid_1's rmse: 1.55381
# [800]	training's rmse: 1.53285	valid_1's rmse: 1.55085
# [900]	training's rmse: 1.52865	valid_1's rmse: 1.54851
# [1000]	training's rmse: 1.52487	valid_1's rmse: 1.54668
# [1100]	training's rmse: 1.52145	valid_1's rmse: 1.54506
# [1200]	training's rmse: 1.5183	valid_1's rmse: 1.5437
# [1300]	training's rmse: 1.51545	valid_1's rmse: 1.54262
# [1400]	training's rmse: 1.51275	valid_1's rmse: 1.54169
# [1500]	training's rmse: 1.51021	valid_1's rmse: 1.5409
# [1600]	training's rmse: 1.50781	valid_1's rmse: 1.54023
# [1700]	training's rmse: 1.5055	valid_1's rmse: 1.53971
# [1800]	training's rmse: 1.50332	valid_1's rmse: 1.53924
# [1900]	training's rmse: 1.50119	valid_1's rmse: 1.53885
# [2000]	training's rmse: 1.49915	valid_1's rmse: 1.53851
# [2100]	training's rmse: 1.49715	valid_1's rmse: 1.53822
# [2200]	training's rmse: 1.49523	valid_1's rmse: 1.53798
# [2300]	training's rmse: 1.49333	valid_1's rmse: 1.53778
# [2400]	training's rmse: 1.49151	valid_1's rmse: 1.53758
# [2500]	training's rmse: 1.48971	valid_1's rmse: 1.53739
# [2600]	training's rmse: 1.48796	valid_1's rmse: 1.53721
# [2700]	training's rmse: 1.48625	valid_1's rmse: 1.5371
# [2800]	training's rmse: 1.48453	valid_1's rmse: 1.53697
# [2900]	training's rmse: 1.48285	valid_1's rmse: 1.53688
# [3000]	training's rmse: 1.48118	valid_1's rmse: 1.53678
# [3100]	training's rmse: 1.47953	valid_1's rmse: 1.5367
# [3200]	training's rmse: 1.47791	valid_1's rmse: 1.53661
# [3300]	training's rmse: 1.47625	valid_1's rmse: 1.53655
# [3400]	training's rmse: 1.47464	valid_1's rmse: 1.53649
# [3500]	training's rmse: 1.47306	valid_1's rmse: 1.53643
# [3600]	training's rmse: 1.47147	valid_1's rmse: 1.53637
# [3700]	training's rmse: 1.46988	valid_1's rmse: 1.53629
# [3800]	training's rmse: 1.46835	valid_1's rmse: 1.53623
# [3900]	training's rmse: 1.46681	valid_1's rmse: 1.53619
# [4000]	training's rmse: 1.46528	valid_1's rmse: 1.53615
# [4100]	training's rmse: 1.46376	valid_1's rmse: 1.53611
# [4200]	training's rmse: 1.46227	valid_1's rmse: 1.5361
# [4300]	training's rmse: 1.46079	valid_1's rmse: 1.53608
# [4400]	training's rmse: 1.4593	valid_1's rmse: 1.53606
# [4500]	training's rmse: 1.45785	valid_1's rmse: 1.53606
# [4600]	training's rmse: 1.45639	valid_1's rmse: 1.53603
# [4700]	training's rmse: 1.45494	valid_1's rmse: 1.53603
# [4800]	training's rmse: 1.45352	valid_1's rmse: 1.53598
# [4900]	training's rmse: 1.4521	valid_1's rmse: 1.53593
# [5000]	training's rmse: 1.4507	valid_1's rmse: 1.5359
# [5100]	training's rmse: 1.44927	valid_1's rmse: 1.53592
# [5200]	training's rmse: 1.44783	valid_1's rmse: 1.53588
# [5300]	training's rmse: 1.44645	valid_1's rmse: 1.53585
# [5400]	training's rmse: 1.44505	valid_1's rmse: 1.53583
# [5500]	training's rmse: 1.44364	valid_1's rmse: 1.53582
# [5600]	training's rmse: 1.44224	valid_1's rmse: 1.5358
# [5700]	training's rmse: 1.44086	valid_1's rmse: 1.53577
# [5800]	training's rmse: 1.43948	valid_1's rmse: 1.53577
# [5900]	training's rmse: 1.43809	valid_1's rmse: 1.53576
# [6000]	training's rmse: 1.43669	valid_1's rmse: 1.53579
# [6100]	training's rmse: 1.43527	valid_1's rmse: 1.53577
# [6200]	training's rmse: 1.43389	valid_1's rmse: 1.53576
# [6300]	training's rmse: 1.43252	valid_1's rmse: 1.53571
# [6400]	training's rmse: 1.43114	valid_1's rmse: 1.5357
# [6500]	training's rmse: 1.42979	valid_1's rmse: 1.5357
# [6600]	training's rmse: 1.42843	valid_1's rmse: 1.5357
# [6700]	training's rmse: 1.4271	valid_1's rmse: 1.53572
# [6800]	training's rmse: 1.42574	valid_1's rmse: 1.53575
# [6900]	training's rmse: 1.42443	valid_1's rmse: 1.53575
# Early stopping, best iteration is:
# [6582]	training's rmse: 1.42867	valid_1's rmse: 1.53568
# 1.5325423306283972

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,50))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()

# %%
df_train_columns2 = cols[:200]

#original
param = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',  #regression
    'max_depth': 8,  # -1
    'learning_rate': 0.004,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',  #auc
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns2], label=target.iloc[trn_idx])#, categorical_feature=categorical)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns2], label=target.iloc[val_idx])#, categorical_feature=categorical)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns2], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns2
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns2], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(target, oof))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.62942	valid_1's rmse: 1.63001
# [200]	training's rmse: 1.59472	valid_1's rmse: 1.59701
# [300]	training's rmse: 1.57444	valid_1's rmse: 1.57828
# [400]	training's rmse: 1.56134	valid_1's rmse: 1.56656
# [500]	training's rmse: 1.55206	valid_1's rmse: 1.55852
# [600]	training's rmse: 1.54502	valid_1's rmse: 1.55286
# [700]	training's rmse: 1.53931	valid_1's rmse: 1.54876
# [800]	training's rmse: 1.53452	valid_1's rmse: 1.54552
# [900]	training's rmse: 1.53045	valid_1's rmse: 1.54307
# [1000]	training's rmse: 1.52675	valid_1's rmse: 1.54102
# [1100]	training's rmse: 1.52339	valid_1's rmse: 1.53929
# [1200]	training's rmse: 1.52029	valid_1's rmse: 1.53786
# [1300]	training's rmse: 1.51744	valid_1's rmse: 1.53664
# [1400]	training's rmse: 1.51476	valid_1's rmse: 1.53565
# [1500]	training's rmse: 1.51223	valid_1's rmse: 1.53483
# [1600]	training's rmse: 1.50984	valid_1's rmse: 1.53415
# [1700]	training's rmse: 1.50755	valid_1's rmse: 1.53352
# [1800]	training's rmse: 1.50536	valid_1's rmse: 1.53303
# [1900]	training's rmse: 1.50322	valid_1's rmse: 1.5326
# [2000]	training's rmse: 1.50118	valid_1's rmse: 1.53228
# [2100]	training's rmse: 1.49922	valid_1's rmse: 1.532
# [2200]	training's rmse: 1.49726	valid_1's rmse: 1.53173
# [2300]	training's rmse: 1.49539	valid_1's rmse: 1.5315
# [2400]	training's rmse: 1.49355	valid_1's rmse: 1.53132
# [2500]	training's rmse: 1.49174	valid_1's rmse: 1.53113
# [2600]	training's rmse: 1.48997	valid_1's rmse: 1.53095
# [2700]	training's rmse: 1.48823	valid_1's rmse: 1.53082
# [2800]	training's rmse: 1.48649	valid_1's rmse: 1.53067
# [2900]	training's rmse: 1.48477	valid_1's rmse: 1.53056
# [3000]	training's rmse: 1.48309	valid_1's rmse: 1.53045
# [3100]	training's rmse: 1.48146	valid_1's rmse: 1.53034
# [3200]	training's rmse: 1.47984	valid_1's rmse: 1.53024
# [3300]	training's rmse: 1.47823	valid_1's rmse: 1.53016
# [3400]	training's rmse: 1.47666	valid_1's rmse: 1.53007
# [3500]	training's rmse: 1.47512	valid_1's rmse: 1.53001
# [3600]	training's rmse: 1.47354	valid_1's rmse: 1.5299
# [3700]	training's rmse: 1.47202	valid_1's rmse: 1.52985
# [3800]	training's rmse: 1.47049	valid_1's rmse: 1.52978
# [3900]	training's rmse: 1.46896	valid_1's rmse: 1.52972
# [4000]	training's rmse: 1.46743	valid_1's rmse: 1.52967
# [4100]	training's rmse: 1.4659	valid_1's rmse: 1.52967
# [4200]	training's rmse: 1.46436	valid_1's rmse: 1.52964
# [4300]	training's rmse: 1.46286	valid_1's rmse: 1.52961
# [4400]	training's rmse: 1.46139	valid_1's rmse: 1.52955
# [4500]	training's rmse: 1.45993	valid_1's rmse: 1.52951
# [4600]	training's rmse: 1.45844	valid_1's rmse: 1.52949
# [4700]	training's rmse: 1.45698	valid_1's rmse: 1.52944
# [4800]	training's rmse: 1.45549	valid_1's rmse: 1.52939
# [4900]	training's rmse: 1.45405	valid_1's rmse: 1.52937
# [5000]	training's rmse: 1.45263	valid_1's rmse: 1.52934
# [5100]	training's rmse: 1.45122	valid_1's rmse: 1.52931
# [5200]	training's rmse: 1.4498	valid_1's rmse: 1.52925
# [5300]	training's rmse: 1.44835	valid_1's rmse: 1.5292
# [5400]	training's rmse: 1.4469	valid_1's rmse: 1.52916
# [5500]	training's rmse: 1.44548	valid_1's rmse: 1.52911
# [5600]	training's rmse: 1.44404	valid_1's rmse: 1.52911
# [5700]	training's rmse: 1.44266	valid_1's rmse: 1.52908
# [5800]	training's rmse: 1.4413	valid_1's rmse: 1.52904
# [5900]	training's rmse: 1.4399	valid_1's rmse: 1.52899
# [6000]	training's rmse: 1.43852	valid_1's rmse: 1.52896
# [6100]	training's rmse: 1.4371	valid_1's rmse: 1.52895
# [6200]	training's rmse: 1.43568	valid_1's rmse: 1.52891
# [6300]	training's rmse: 1.4343	valid_1's rmse: 1.5289
# [6400]	training's rmse: 1.43289	valid_1's rmse: 1.52889
# [6500]	training's rmse: 1.43151	valid_1's rmse: 1.52888
# [6600]	training's rmse: 1.43014	valid_1's rmse: 1.52888
# [6700]	training's rmse: 1.42875	valid_1's rmse: 1.52889
# [6800]	training's rmse: 1.4274	valid_1's rmse: 1.52885
# [6900]	training's rmse: 1.42606	valid_1's rmse: 1.5288
# [7000]	training's rmse: 1.42472	valid_1's rmse: 1.52883
# [7100]	training's rmse: 1.42339	valid_1's rmse: 1.52884
# [7200]	training's rmse: 1.42198	valid_1's rmse: 1.52882
# [7300]	training's rmse: 1.42064	valid_1's rmse: 1.52883
# Early stopping, best iteration is:
# [6920]	training's rmse: 1.4258	valid_1's rmse: 1.52879
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.62762	valid_1's rmse: 1.63515
# [200]	training's rmse: 1.59253	valid_1's rmse: 1.60325
# [300]	training's rmse: 1.57197	valid_1's rmse: 1.58553
# [400]	training's rmse: 1.55865	valid_1's rmse: 1.57471
# [500]	training's rmse: 1.54917	valid_1's rmse: 1.56776
# [600]	training's rmse: 1.54201	valid_1's rmse: 1.56291
# [700]	training's rmse: 1.53628	valid_1's rmse: 1.55937
# [800]	training's rmse: 1.53154	valid_1's rmse: 1.55671
# [900]	training's rmse: 1.52738	valid_1's rmse: 1.55454
# [1000]	training's rmse: 1.52364	valid_1's rmse: 1.55281
# [1100]	training's rmse: 1.52023	valid_1's rmse: 1.55137
# [1200]	training's rmse: 1.51709	valid_1's rmse: 1.55012
# [1300]	training's rmse: 1.51421	valid_1's rmse: 1.54911
# [1400]	training's rmse: 1.51153	valid_1's rmse: 1.54825
# [1500]	training's rmse: 1.50898	valid_1's rmse: 1.54758
# [1600]	training's rmse: 1.50659	valid_1's rmse: 1.547
# [1700]	training's rmse: 1.50428	valid_1's rmse: 1.54646
# [1800]	training's rmse: 1.50206	valid_1's rmse: 1.54599
# [1900]	training's rmse: 1.49993	valid_1's rmse: 1.54555
# [2000]	training's rmse: 1.49783	valid_1's rmse: 1.54521
# [2100]	training's rmse: 1.49588	valid_1's rmse: 1.54493
# [2200]	training's rmse: 1.49396	valid_1's rmse: 1.54466
# [2300]	training's rmse: 1.49204	valid_1's rmse: 1.54443
# [2400]	training's rmse: 1.49018	valid_1's rmse: 1.54423
# [2500]	training's rmse: 1.48841	valid_1's rmse: 1.54406
# [2600]	training's rmse: 1.48665	valid_1's rmse: 1.54392
# [2700]	training's rmse: 1.48493	valid_1's rmse: 1.54378
# [2800]	training's rmse: 1.48318	valid_1's rmse: 1.54368
# [2900]	training's rmse: 1.48147	valid_1's rmse: 1.54359
# [3000]	training's rmse: 1.47979	valid_1's rmse: 1.54347
# [3100]	training's rmse: 1.4781	valid_1's rmse: 1.54333
# [3200]	training's rmse: 1.47648	valid_1's rmse: 1.54323
# [3300]	training's rmse: 1.47483	valid_1's rmse: 1.54315
# [3400]	training's rmse: 1.47322	valid_1's rmse: 1.54313
# [3500]	training's rmse: 1.47164	valid_1's rmse: 1.54306
# [3600]	training's rmse: 1.47006	valid_1's rmse: 1.54299
# [3700]	training's rmse: 1.46852	valid_1's rmse: 1.54294
# [3800]	training's rmse: 1.46699	valid_1's rmse: 1.54288
# [3900]	training's rmse: 1.46548	valid_1's rmse: 1.54282
# [4000]	training's rmse: 1.46394	valid_1's rmse: 1.54277
# [4100]	training's rmse: 1.46244	valid_1's rmse: 1.54275
# [4200]	training's rmse: 1.46091	valid_1's rmse: 1.54267
# [4300]	training's rmse: 1.45943	valid_1's rmse: 1.54264
# [4400]	training's rmse: 1.45792	valid_1's rmse: 1.54259
# [4500]	training's rmse: 1.45642	valid_1's rmse: 1.54255
# [4600]	training's rmse: 1.45494	valid_1's rmse: 1.5425
# [4700]	training's rmse: 1.45349	valid_1's rmse: 1.54249
# [4800]	training's rmse: 1.45203	valid_1's rmse: 1.54246
# [4900]	training's rmse: 1.45059	valid_1's rmse: 1.54247
# [5000]	training's rmse: 1.44913	valid_1's rmse: 1.54242
# [5100]	training's rmse: 1.44768	valid_1's rmse: 1.54238
# [5200]	training's rmse: 1.44627	valid_1's rmse: 1.54236
# [5300]	training's rmse: 1.44488	valid_1's rmse: 1.54232
# [5400]	training's rmse: 1.44346	valid_1's rmse: 1.5423
# [5500]	training's rmse: 1.44206	valid_1's rmse: 1.54232
# [5600]	training's rmse: 1.44061	valid_1's rmse: 1.54231
# [5700]	training's rmse: 1.43923	valid_1's rmse: 1.5423
# [5800]	training's rmse: 1.43783	valid_1's rmse: 1.54229
# [5900]	training's rmse: 1.43642	valid_1's rmse: 1.54227
# [6000]	training's rmse: 1.43501	valid_1's rmse: 1.54223
# [6100]	training's rmse: 1.43362	valid_1's rmse: 1.54221
# [6200]	training's rmse: 1.43223	valid_1's rmse: 1.54219
# [6300]	training's rmse: 1.43082	valid_1's rmse: 1.54218
# [6400]	training's rmse: 1.42945	valid_1's rmse: 1.54218
# [6500]	training's rmse: 1.42812	valid_1's rmse: 1.54218
# [6600]	training's rmse: 1.42672	valid_1's rmse: 1.54217
# [6700]	training's rmse: 1.42536	valid_1's rmse: 1.54213
# [6800]	training's rmse: 1.42401	valid_1's rmse: 1.54211
# [6900]	training's rmse: 1.42267	valid_1's rmse: 1.54208
# [7000]	training's rmse: 1.42131	valid_1's rmse: 1.54207
# [7100]	training's rmse: 1.41995	valid_1's rmse: 1.54209
# [7200]	training's rmse: 1.4186	valid_1's rmse: 1.54211
# [7300]	training's rmse: 1.41726	valid_1's rmse: 1.54213
# Early stopping, best iteration is:
# [6959]	training's rmse: 1.42187	valid_1's rmse: 1.54205
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.63034	valid_1's rmse: 1.62548
# [200]	training's rmse: 1.59548	valid_1's rmse: 1.59279
# [300]	training's rmse: 1.57511	valid_1's rmse: 1.57452
# [400]	training's rmse: 1.56186	valid_1's rmse: 1.56341
# [500]	training's rmse: 1.5524	valid_1's rmse: 1.55605
# [600]	training's rmse: 1.54519	valid_1's rmse: 1.55081
# [700]	training's rmse: 1.5394	valid_1's rmse: 1.54699
# [800]	training's rmse: 1.53457	valid_1's rmse: 1.54413
# [900]	training's rmse: 1.53039	valid_1's rmse: 1.54186
# [1000]	training's rmse: 1.52664	valid_1's rmse: 1.53999
# [1100]	training's rmse: 1.52328	valid_1's rmse: 1.5385
# [1200]	training's rmse: 1.52023	valid_1's rmse: 1.53728
# [1300]	training's rmse: 1.51735	valid_1's rmse: 1.53619
# [1400]	training's rmse: 1.51468	valid_1's rmse: 1.53531
# [1500]	training's rmse: 1.51214	valid_1's rmse: 1.53453
# [1600]	training's rmse: 1.50976	valid_1's rmse: 1.53392
# [1700]	training's rmse: 1.50749	valid_1's rmse: 1.53338
# [1800]	training's rmse: 1.50528	valid_1's rmse: 1.53294
# [1900]	training's rmse: 1.50319	valid_1's rmse: 1.53259
# [2000]	training's rmse: 1.50114	valid_1's rmse: 1.53224
# [2100]	training's rmse: 1.49915	valid_1's rmse: 1.53197
# [2200]	training's rmse: 1.49723	valid_1's rmse: 1.53172
# [2300]	training's rmse: 1.49538	valid_1's rmse: 1.53149
# [2400]	training's rmse: 1.49354	valid_1's rmse: 1.53128
# [2500]	training's rmse: 1.4917	valid_1's rmse: 1.53107
# [2600]	training's rmse: 1.48992	valid_1's rmse: 1.53093
# [2700]	training's rmse: 1.48821	valid_1's rmse: 1.53077
# [2800]	training's rmse: 1.48646	valid_1's rmse: 1.53063
# [2900]	training's rmse: 1.48478	valid_1's rmse: 1.53053
# [3000]	training's rmse: 1.48305	valid_1's rmse: 1.53045
# [3100]	training's rmse: 1.48136	valid_1's rmse: 1.53033
# [3200]	training's rmse: 1.47973	valid_1's rmse: 1.53024
# [3300]	training's rmse: 1.47812	valid_1's rmse: 1.53017
# [3400]	training's rmse: 1.47651	valid_1's rmse: 1.53008
# [3500]	training's rmse: 1.47496	valid_1's rmse: 1.53002
# [3600]	training's rmse: 1.47343	valid_1's rmse: 1.52995
# [3700]	training's rmse: 1.47186	valid_1's rmse: 1.52992
# [3800]	training's rmse: 1.4703	valid_1's rmse: 1.52986
# [3900]	training's rmse: 1.46873	valid_1's rmse: 1.52977
# [4000]	training's rmse: 1.46719	valid_1's rmse: 1.5297
# [4100]	training's rmse: 1.46565	valid_1's rmse: 1.52962
# [4200]	training's rmse: 1.46411	valid_1's rmse: 1.52957
# [4300]	training's rmse: 1.46262	valid_1's rmse: 1.52953
# [4400]	training's rmse: 1.4611	valid_1's rmse: 1.52945
# [4500]	training's rmse: 1.45959	valid_1's rmse: 1.52942
# [4600]	training's rmse: 1.45812	valid_1's rmse: 1.52939
# [4700]	training's rmse: 1.45665	valid_1's rmse: 1.52936
# [4800]	training's rmse: 1.45524	valid_1's rmse: 1.52931
# [4900]	training's rmse: 1.45376	valid_1's rmse: 1.52931
# [5000]	training's rmse: 1.45232	valid_1's rmse: 1.52929
# [5100]	training's rmse: 1.45089	valid_1's rmse: 1.52925
# [5200]	training's rmse: 1.44944	valid_1's rmse: 1.5292
# [5300]	training's rmse: 1.44803	valid_1's rmse: 1.52918
# [5400]	training's rmse: 1.44662	valid_1's rmse: 1.52912
# [5500]	training's rmse: 1.44518	valid_1's rmse: 1.52909
# [5600]	training's rmse: 1.44376	valid_1's rmse: 1.52904
# [5700]	training's rmse: 1.44237	valid_1's rmse: 1.52903
# [5800]	training's rmse: 1.44096	valid_1's rmse: 1.52901
# [5900]	training's rmse: 1.43955	valid_1's rmse: 1.529
# [6000]	training's rmse: 1.43815	valid_1's rmse: 1.52897
# [6100]	training's rmse: 1.43677	valid_1's rmse: 1.52894
# [6200]	training's rmse: 1.43539	valid_1's rmse: 1.5289
# [6300]	training's rmse: 1.434	valid_1's rmse: 1.52888
# [6400]	training's rmse: 1.43261	valid_1's rmse: 1.52887
# [6500]	training's rmse: 1.43124	valid_1's rmse: 1.52889
# [6600]	training's rmse: 1.42985	valid_1's rmse: 1.52884
# [6700]	training's rmse: 1.42851	valid_1's rmse: 1.52884
# [6800]	training's rmse: 1.42715	valid_1's rmse: 1.52882
# [6900]	training's rmse: 1.42576	valid_1's rmse: 1.52878
# [7000]	training's rmse: 1.42439	valid_1's rmse: 1.52879
# [7100]	training's rmse: 1.42304	valid_1's rmse: 1.52877
# [7200]	training's rmse: 1.42172	valid_1's rmse: 1.52875
# [7300]	training's rmse: 1.42039	valid_1's rmse: 1.52876
# [7400]	training's rmse: 1.41905	valid_1's rmse: 1.52875
# [7500]	training's rmse: 1.4177	valid_1's rmse: 1.52871
# [7600]	training's rmse: 1.4164	valid_1's rmse: 1.5287
# [7700]	training's rmse: 1.4151	valid_1's rmse: 1.5287
# [7800]	training's rmse: 1.41382	valid_1's rmse: 1.52869
# [7900]	training's rmse: 1.41249	valid_1's rmse: 1.52867
# [8000]	training's rmse: 1.41115	valid_1's rmse: 1.52868
# [8100]	training's rmse: 1.40986	valid_1's rmse: 1.52866
# [8200]	training's rmse: 1.40856	valid_1's rmse: 1.52863
# [8300]	training's rmse: 1.40729	valid_1's rmse: 1.5286
# [8400]	training's rmse: 1.40596	valid_1's rmse: 1.52857
# [8500]	training's rmse: 1.40466	valid_1's rmse: 1.52856
# [8600]	training's rmse: 1.4034	valid_1's rmse: 1.52857
# [8700]	training's rmse: 1.4021	valid_1's rmse: 1.52855
# [8800]	training's rmse: 1.40085	valid_1's rmse: 1.52853
# [8900]	training's rmse: 1.39958	valid_1's rmse: 1.52856
# [9000]	training's rmse: 1.3983	valid_1's rmse: 1.52856
# [9100]	training's rmse: 1.39705	valid_1's rmse: 1.52854
# [9200]	training's rmse: 1.39579	valid_1's rmse: 1.52855
# Early stopping, best iteration is:
# [8803]	training's rmse: 1.40081	valid_1's rmse: 1.52853
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.62982	valid_1's rmse: 1.62828
# [200]	training's rmse: 1.59516	valid_1's rmse: 1.59514
# [300]	training's rmse: 1.57482	valid_1's rmse: 1.57643
# [400]	training's rmse: 1.56167	valid_1's rmse: 1.56483
# [500]	training's rmse: 1.55236	valid_1's rmse: 1.55696
# [600]	training's rmse: 1.5452	valid_1's rmse: 1.55133
# [700]	training's rmse: 1.53941	valid_1's rmse: 1.54721
# [800]	training's rmse: 1.53463	valid_1's rmse: 1.54419
# [900]	training's rmse: 1.53052	valid_1's rmse: 1.5418
# [1000]	training's rmse: 1.52676	valid_1's rmse: 1.53983
# [1100]	training's rmse: 1.52338	valid_1's rmse: 1.53815
# [1200]	training's rmse: 1.52028	valid_1's rmse: 1.53677
# [1300]	training's rmse: 1.51738	valid_1's rmse: 1.53562
# [1400]	training's rmse: 1.51467	valid_1's rmse: 1.53462
# [1500]	training's rmse: 1.51209	valid_1's rmse: 1.53376
# [1600]	training's rmse: 1.50968	valid_1's rmse: 1.53307
# [1700]	training's rmse: 1.50735	valid_1's rmse: 1.53245
# [1800]	training's rmse: 1.50509	valid_1's rmse: 1.53188
# [1900]	training's rmse: 1.50296	valid_1's rmse: 1.53144
# [2000]	training's rmse: 1.50096	valid_1's rmse: 1.5311
# [2100]	training's rmse: 1.49894	valid_1's rmse: 1.5308
# [2200]	training's rmse: 1.497	valid_1's rmse: 1.53054
# [2300]	training's rmse: 1.49507	valid_1's rmse: 1.53024
# [2400]	training's rmse: 1.49321	valid_1's rmse: 1.53007
# [2500]	training's rmse: 1.49142	valid_1's rmse: 1.52988
# [2600]	training's rmse: 1.48964	valid_1's rmse: 1.52972
# [2700]	training's rmse: 1.48791	valid_1's rmse: 1.52959
# [2800]	training's rmse: 1.48619	valid_1's rmse: 1.52945
# [2900]	training's rmse: 1.48449	valid_1's rmse: 1.52933
# [3000]	training's rmse: 1.48283	valid_1's rmse: 1.52922
# [3100]	training's rmse: 1.48119	valid_1's rmse: 1.52915
# [3200]	training's rmse: 1.47951	valid_1's rmse: 1.52903
# [3300]	training's rmse: 1.47787	valid_1's rmse: 1.52891
# [3400]	training's rmse: 1.47632	valid_1's rmse: 1.52882
# [3500]	training's rmse: 1.47472	valid_1's rmse: 1.52877
# [3600]	training's rmse: 1.47315	valid_1's rmse: 1.52868
# [3700]	training's rmse: 1.4716	valid_1's rmse: 1.52864
# [3800]	training's rmse: 1.47007	valid_1's rmse: 1.52859
# [3900]	training's rmse: 1.46854	valid_1's rmse: 1.52853
# [4000]	training's rmse: 1.467	valid_1's rmse: 1.52848
# [4100]	training's rmse: 1.46551	valid_1's rmse: 1.52844
# [4200]	training's rmse: 1.46401	valid_1's rmse: 1.52842
# [4300]	training's rmse: 1.4625	valid_1's rmse: 1.52836
# [4400]	training's rmse: 1.46103	valid_1's rmse: 1.52831
# [4500]	training's rmse: 1.45951	valid_1's rmse: 1.52826
# [4600]	training's rmse: 1.45807	valid_1's rmse: 1.52825
# [4700]	training's rmse: 1.4566	valid_1's rmse: 1.52821
# [4800]	training's rmse: 1.45513	valid_1's rmse: 1.52818
# [4900]	training's rmse: 1.45369	valid_1's rmse: 1.52814
# [5000]	training's rmse: 1.4522	valid_1's rmse: 1.52812
# [5100]	training's rmse: 1.45078	valid_1's rmse: 1.52808
# [5200]	training's rmse: 1.44931	valid_1's rmse: 1.52809
# [5300]	training's rmse: 1.4479	valid_1's rmse: 1.52809
# [5400]	training's rmse: 1.44649	valid_1's rmse: 1.52807
# [5500]	training's rmse: 1.44504	valid_1's rmse: 1.52807
# [5600]	training's rmse: 1.44361	valid_1's rmse: 1.52802
# [5700]	training's rmse: 1.44223	valid_1's rmse: 1.52802
# [5800]	training's rmse: 1.44084	valid_1's rmse: 1.52804
# [5900]	training's rmse: 1.43944	valid_1's rmse: 1.52804
# [6000]	training's rmse: 1.43802	valid_1's rmse: 1.52802
# Early stopping, best iteration is:
# [5633]	training's rmse: 1.44316	valid_1's rmse: 1.528
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.62802	valid_1's rmse: 1.6352
# [200]	training's rmse: 1.59352	valid_1's rmse: 1.60147
# [300]	training's rmse: 1.57331	valid_1's rmse: 1.5824
# [400]	training's rmse: 1.55997	valid_1's rmse: 1.57064
# [500]	training's rmse: 1.55059	valid_1's rmse: 1.5628
# [600]	training's rmse: 1.54353	valid_1's rmse: 1.55743
# [700]	training's rmse: 1.5378	valid_1's rmse: 1.55346
# [800]	training's rmse: 1.53301	valid_1's rmse: 1.55051
# [900]	training's rmse: 1.52881	valid_1's rmse: 1.54818
# [1000]	training's rmse: 1.52508	valid_1's rmse: 1.54631
# [1100]	training's rmse: 1.52169	valid_1's rmse: 1.54473
# [1200]	training's rmse: 1.51858	valid_1's rmse: 1.54336
# [1300]	training's rmse: 1.5157	valid_1's rmse: 1.54222
# [1400]	training's rmse: 1.51299	valid_1's rmse: 1.54126
# [1500]	training's rmse: 1.51046	valid_1's rmse: 1.54046
# [1600]	training's rmse: 1.50804	valid_1's rmse: 1.53978
# [1700]	training's rmse: 1.50577	valid_1's rmse: 1.53919
# [1800]	training's rmse: 1.50358	valid_1's rmse: 1.53873
# [1900]	training's rmse: 1.50147	valid_1's rmse: 1.53836
# [2000]	training's rmse: 1.49943	valid_1's rmse: 1.538
# [2100]	training's rmse: 1.49747	valid_1's rmse: 1.53773
# [2200]	training's rmse: 1.49556	valid_1's rmse: 1.53756
# [2300]	training's rmse: 1.49373	valid_1's rmse: 1.53736
# [2400]	training's rmse: 1.49192	valid_1's rmse: 1.53718
# [2500]	training's rmse: 1.49014	valid_1's rmse: 1.537
# [2600]	training's rmse: 1.48839	valid_1's rmse: 1.53681
# [2700]	training's rmse: 1.4867	valid_1's rmse: 1.53668
# [2800]	training's rmse: 1.48502	valid_1's rmse: 1.53655
# [2900]	training's rmse: 1.48338	valid_1's rmse: 1.53644
# [3000]	training's rmse: 1.48173	valid_1's rmse: 1.53633
# [3100]	training's rmse: 1.48009	valid_1's rmse: 1.53627
# [3200]	training's rmse: 1.47844	valid_1's rmse: 1.53616
# [3300]	training's rmse: 1.47684	valid_1's rmse: 1.5361
# [3400]	training's rmse: 1.47522	valid_1's rmse: 1.53602
# [3500]	training's rmse: 1.47366	valid_1's rmse: 1.53595
# [3600]	training's rmse: 1.47206	valid_1's rmse: 1.53588
# [3700]	training's rmse: 1.47049	valid_1's rmse: 1.53583
# [3800]	training's rmse: 1.46897	valid_1's rmse: 1.53575
# [3900]	training's rmse: 1.46745	valid_1's rmse: 1.53571
# [4000]	training's rmse: 1.46591	valid_1's rmse: 1.53566
# [4100]	training's rmse: 1.46441	valid_1's rmse: 1.53565
# [4200]	training's rmse: 1.46293	valid_1's rmse: 1.53566
# [4300]	training's rmse: 1.46146	valid_1's rmse: 1.53566
# [4400]	training's rmse: 1.45995	valid_1's rmse: 1.53563
# [4500]	training's rmse: 1.45852	valid_1's rmse: 1.53565
# [4600]	training's rmse: 1.45706	valid_1's rmse: 1.5356
# [4700]	training's rmse: 1.45559	valid_1's rmse: 1.53562
# [4800]	training's rmse: 1.45416	valid_1's rmse: 1.53558
# [4900]	training's rmse: 1.45275	valid_1's rmse: 1.53556
# [5000]	training's rmse: 1.45133	valid_1's rmse: 1.53558
# [5100]	training's rmse: 1.4499	valid_1's rmse: 1.53554
# [5200]	training's rmse: 1.44848	valid_1's rmse: 1.53553
# [5300]	training's rmse: 1.44708	valid_1's rmse: 1.53553
# [5400]	training's rmse: 1.4457	valid_1's rmse: 1.53549
# [5500]	training's rmse: 1.4443	valid_1's rmse: 1.53546
# [5600]	training's rmse: 1.44288	valid_1's rmse: 1.53547
# [5700]	training's rmse: 1.44151	valid_1's rmse: 1.53545
# [5800]	training's rmse: 1.44013	valid_1's rmse: 1.53547
# [5900]	training's rmse: 1.43877	valid_1's rmse: 1.53546
# [6000]	training's rmse: 1.43739	valid_1's rmse: 1.53546
# [6100]	training's rmse: 1.43598	valid_1's rmse: 1.53546
# [6200]	training's rmse: 1.43461	valid_1's rmse: 1.53544
# [6300]	training's rmse: 1.43326	valid_1's rmse: 1.53544
# [6400]	training's rmse: 1.43191	valid_1's rmse: 1.53543
# [6500]	training's rmse: 1.43056	valid_1's rmse: 1.53542
# [6600]	training's rmse: 1.42923	valid_1's rmse: 1.5354
# [6700]	training's rmse: 1.42789	valid_1's rmse: 1.5354
# [6800]	training's rmse: 1.42656	valid_1's rmse: 1.53543
# [6900]	training's rmse: 1.42522	valid_1's rmse: 1.53545
# [7000]	training's rmse: 1.42392	valid_1's rmse: 1.53544
# Early stopping, best iteration is:
# [6693]	training's rmse: 1.42798	valid_1's rmse: 1.53539
# 1.5325627257005716

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,50))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()

# %%
sns.distplot(predictions)

# %%
submission = pd.DataFrame({"card_id":df_test.card_id, "target":predictions})

# %%
submission.to_csv("../output/submission_no_outliers_model20190113.csv", index=False)
