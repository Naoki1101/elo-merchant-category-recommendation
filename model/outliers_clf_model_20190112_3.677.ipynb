# %%
import numpy as np
import pandas as pd
import datetime

from itertools import combinations

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import lightgbm as lgb

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error, roc_auc_score, confusion_matrix, f1_score
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')
np.random.seed(4590)

# %%
df_train = pd.read_csv('../input/20181216_train.csv')
df_test = pd.read_csv('../input/20181216_test.csv')

# %%
def merge_new_feature(path, use=[]):
    if len(use) > 1:
        df_new_feature = pd.read_csv(path, usecols=use)
    else:
        df_new_feature = pd.read_csv(path)
    
    df_tr = pd.merge(df_train, df_new_feature, on="card_id", how="left")
    df_te = pd.merge(df_test, df_new_feature, on="card_id", how="left")
    
    return df_tr, df_te

# %%
df_train, df_test = merge_new_feature("../input/feature_categorical_count_rate.csv")
df_train, df_test = merge_new_feature("../input/feature_various_time_data.csv")
df_train, df_test = merge_new_feature("../input/merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/payment_splited_by_installments_NMF.csv")
df_train, df_test = merge_new_feature("../input/feature_catogorical_count_weighted_elapsed.csv")
df_train, df_test = merge_new_feature("../input/feature_latest_transaction_data__per__card_id.csv")

# %%
dont_use = ['card_id', 'first_active_month','second_active_date','diff_first_and_second','target','outliers', 'category_1_Y_std']

df_train_columns = [c for c in df_train.columns if c not in dont_use]
target = df_train['target']
target_outlier = df_train["outliers"]

# %%
drop_col = []
comb = list(combinations(df_train_columns, 2))

for c1, c2 in comb:
    corr = np.corrcoef(df_train[c1], df_train[c2])[0,1]
    if corr >= 0.962:
        print("【{i}】 --- 【{j}】".format(i=c1, j=c2))
        print(corr)
        drop_col.append(c2)
        print("\n"*2)

for col in df_train_columns:
    if col in sorted(set(drop_col)):
        df_train_columns.remove(col)
# Out:
# 【hist_authorized_flag_sum】 --- 【hist_card_id_size】
# 0.9945716227736431
#
#
#
# 【hist_authorized_flag_sum】 --- 【card_id_count】
# 0.9935317230513652
#
#
#
# 【hist_authorized_flag_sum】 --- 【authorized_flag_ture】
# 0.9979558326172671
#
#
#
# 【hist_authorized_flag_sum】 --- 【authorized_flag_ture_weighted_elapsed】
# 0.9979558326172671
#
#
#
# 【hist_authorized_flag_mean】 --- 【authorized_flag_ture_rate】
# 0.9871399739794636
#
#
#
# 【hist_category_1_sum】 --- 【category_1_true】
# 0.9996032083806138
#
#
#
# 【hist_category_1_sum】 --- 【category_1_true_weighted_elapsed】
# 0.9996032083806138
#
#
#
# 【hist_category_1_mean】 --- 【category_1_true_rate】
# 0.9915584786977886
#
#
#
# 【hist_card_id_size】 --- 【card_id_count】
# 0.9981205383400666
#
#
#
# 【hist_card_id_size】 --- 【authorized_flag_ture】
# 0.991907744189161
#
#
#
# 【hist_card_id_size】 --- 【authorized_flag_ture_weighted_elapsed】
# 0.991907744189161
#
#
#
# 【hist_purchase_date_diff】 --- 【elapsed_from_oldest_purchase_date_to_latest_purchase_date】
# 0.968714472679401
#
#
#
# 【new_hist_purchase_date_max】 --- 【new_hist_purchase_date_min】
# 0.9999998787394552
#
#
#
# 【hist_first_buy】 --- 【elapsed_from_oldest_purchase_date_to_first_active】
# 1.0
#
#
#
# 【card_id_count】 --- 【authorized_flag_ture】
# 0.9947805751843393
#
#
#
# 【card_id_count】 --- 【authorized_flag_ture_weighted_elapsed】
# 0.9947805751843393
#
#
#
# 【authorized_flag_ture】 --- 【authorized_flag_ture_weighted_elapsed】
# 0.9999999999999999
#
#
#
# 【category_1_true】 --- 【category_1_true_weighted_elapsed】
# 0.9999999999999998
#
#
#
# 【category_3_A】 --- 【installments_0】
# 1.0
#
#
#
# 【category_3_B】 --- 【installments_1】
# 1.0
#
#
#
# 【category_3_A_rate】 --- 【installments_0_rate】
# 0.9999999999999999
#
#
#
# 【category_3_A_rate】 --- 【category_3_A_latest_trs】
# 0.9891807585016202
#
#
#
# 【category_3_B_rate】 --- 【installments_1_rate】
# 1.0
#
#
#
# 【installments_0_rate】 --- 【category_3_A_latest_trs】
# 0.9891807585016202
#
#
#
# 【month_lag_N13】 --- 【month_lag_N13_weighted_elapsed】
# 0.9993139081259989
#
#
#
# 【month_lag_N12】 --- 【month_lag_N12_weighted_elapsed】
# 0.9965343513872145
#
#
#
# 【month_lag_N11】 --- 【month_lag_N11_weighted_elapsed】
# 0.9914134570536032
#
#
#
# 【month_lag_N10】 --- 【month_lag_N10_weighted_elapsed】
# 0.9803827646550846
#
#
#
# 【month_lag_N9】 --- 【month_lag_N9_weighted_elapsed】
# 0.971953112628116
#
#
#
# 【month_lag_N8】 --- 【month_lag_N8_weighted_elapsed】
# 0.963066903632867
#
#
#
# 【category_3_A_weighted_elapsed】 --- 【installments_0_weighted_elapsed】
# 1.0
#
#
#
# 【category_3_B_weighted_elapsed】 --- 【installments_1_weighted_elapsed】
# 1.0
#
#
#
# 【category_4_null_latest_trs】 --- 【numerical_1_null_latest_trs】
# 1.0
#
#
#
# 【category_4_null_latest_trs】 --- 【most_recent_sales_range_null_latest_trs】
# 1.0
#
#
#
# 【category_4_null_latest_trs】 --- 【most_recent_purchases_range_null_latest_trs】
# 1.0
#
#
#
# 【numerical_1_null_latest_trs】 --- 【most_recent_sales_range_null_latest_trs】
# 1.0
#
#
#
# 【numerical_1_null_latest_trs】 --- 【most_recent_purchases_range_null_latest_trs】
# 1.0
#
#
#
# 【most_recent_sales_range_null_latest_trs】 --- 【most_recent_purchases_range_null_latest_trs】
# 1.0

# %%
sorted(set(drop_col))
# Out:
# ['authorized_flag_ture',
#  'authorized_flag_ture_rate',
#  'authorized_flag_ture_weighted_elapsed',
#  'card_id_count',
#  'category_1_true',
#  'category_1_true_rate',
#  'category_1_true_weighted_elapsed',
#  'category_3_A_latest_trs',
#  'elapsed_from_oldest_purchase_date_to_first_active',
#  'elapsed_from_oldest_purchase_date_to_latest_purchase_date',
#  'hist_card_id_size',
#  'installments_0',
#  'installments_0_rate',
#  'installments_0_weighted_elapsed',
#  'installments_1',
#  'installments_1_rate',
#  'installments_1_weighted_elapsed',
#  'month_lag_N10_weighted_elapsed',
#  'month_lag_N11_weighted_elapsed',
#  'month_lag_N12_weighted_elapsed',
#  'month_lag_N13_weighted_elapsed',
#  'month_lag_N8_weighted_elapsed',
#  'month_lag_N9_weighted_elapsed',
#  'most_recent_purchases_range_null_latest_trs',
#  'most_recent_sales_range_null_latest_trs',
#  'new_hist_purchase_date_min',
#  'numerical_1_null_latest_trs']

# %%
len(df_train_columns)
# Out:
# 274

# %%
#original
param = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':
# [1100]	training's auc: 0.982581	valid_1's auc: 0.89075
# [1200]	training's auc: 0.984499	valid_1's auc: 0.890851
# [1300]	training's auc: 0.986171	valid_1's auc: 0.890921
# [1400]	training's auc: 0.987733	valid_1's auc: 0.890899
# [1500]	training's auc: 0.98915	valid_1's auc: 0.890937
# [1600]	training's auc: 0.990389	valid_1's auc: 0.890971
# [1700]	training's auc: 0.991436	valid_1's auc: 0.890831
# [1800]	training's auc: 0.992367	valid_1's auc: 0.890833
# [1900]	training's auc: 0.993186	valid_1's auc: 0.890708
# Early stopping, best iteration is:
# [1596]	training's auc: 0.99035	valid_1's auc: 0.891005
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's auc: 0.908304	valid_1's auc: 0.895597
# [200]	training's auc: 0.924264	valid_1's auc: 0.90019
# [300]	training's auc: 0.937216	valid_1's auc: 0.901299
# [400]	training's auc: 0.946953	valid_1's auc: 0.90288
# [500]	training's auc: 0.955452	valid_1's auc: 0.904411
# [600]	training's auc: 0.962946	valid_1's auc: 0.905487
# [700]	training's auc: 0.96961	valid_1's auc: 0.906024
# [800]	training's auc: 0.974511	valid_1's auc: 0.906704
# [900]	training's auc: 0.978031	valid_1's auc: 0.906942
# [1000]	training's auc: 0.980752	valid_1's auc: 0.907136
# [1100]	training's auc: 0.982984	valid_1's auc: 0.907257
# [1200]	training's auc: 0.984967	valid_1's auc: 0.907315
# [1300]	training's auc: 0.986741	valid_1's auc: 0.907193
# [1400]	training's auc: 0.988381	valid_1's auc: 0.907123
# [1500]	training's auc: 0.989753	valid_1's auc: 0.906936
# Early stopping, best iteration is:
# [1195]	training's auc: 0.984878	valid_1's auc: 0.907317
# 0.9011876418813624

# %%
cols2 = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols2)]

plt.figure(figsize=(14,50))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()

# %%
for k in range(-30, 0, 1):
    rmse = []
    for i in [i/1000.0 for i in range(1,1001)]:
        predict_outliers = np.where(oof>i, k, 0)
        rmse.append(np.sqrt(mean_squared_error(target.values, predict_outliers)))
        if min(rmse) == rmse[-1]:
            best_th = i
    print("%d -- %f -- %f" %(k, min(rmse), best_th))
# Out:
# -30 -- 3.856198 -- 0.452000
# -29 -- 3.855653 -- 0.452000
# -28 -- 3.855120 -- 0.446000
# -27 -- 3.854597 -- 0.446000
# -26 -- 3.854029 -- 0.397000
# -25 -- 3.852803 -- 0.397000
# -24 -- 3.851082 -- 0.333000
# -23 -- 3.848167 -- 0.333000
# -22 -- 3.845575 -- 0.333000
# -21 -- 3.842761 -- 0.313000
# -20 -- 3.837410 -- 0.258000
# -19 -- 3.831410 -- 0.249000
# -18 -- 3.825566 -- 0.249000
# -17 -- 3.820594 -- 0.249000
# -16 -- 3.815319 -- 0.217000
# -15 -- 3.809133 -- 0.217000
# -14 -- 3.803511 -- 0.187000
# -13 -- 3.796749 -- 0.187000
# -12 -- 3.791765 -- 0.187000
# -11 -- 3.784263 -- 0.136000
# -10 -- 3.776921 -- 0.133000
# -9 -- 3.772404 -- 0.132000
# -8 -- 3.769389 -- 0.106000
# -7 -- 3.764539 -- 0.090000
# -6 -- 3.763736 -- 0.090000
# -5 -- 3.765223 -- 0.077000
# -4 -- 3.770118 -- 0.046000
# -3 -- 3.774036 -- 0.038000
# -2 -- 3.786072 -- 0.028000
# -1 -- 3.815488 -- 0.012000

# %%
df_predict = pd.read_csv("../output/submission_model20181216.csv")
df_no_outliers_predict = pd.read_csv("../output/submission_no_outliers_model20190112.csv")

# %%
df_predict = pd.merge(df_predict, df_no_outliers_predict, on="card_id", how="inner")

# %%
df_predict["target"] = np.where(df_predict.target_x.values < 0, df_predict.target_x, df_predict.target_y)

del df_predict["target_x"]
del df_predict["target_y"]

df_predict
# Out:
#                 card_id    target
# 0       C_ID_0ab67a22ab -2.041275
# 1       C_ID_130fd0cbdd -0.305701
# 2       C_ID_b709037bc5 -0.974894
# 3       C_ID_d27d835a9f -0.090633
# 4       C_ID_2b5e3df5c2 -1.465622
# 5       C_ID_5814b4f13c  0.536912
# 6       C_ID_a1b3c75277  0.176816
# 7       C_ID_f7cada36d3  0.865616
# 8       C_ID_9d2bc8dfc4 -0.709276
# 9       C_ID_6d8dba8475 -1.145146
# 10      C_ID_4859ac9ed5 -0.643432
# 11      C_ID_0e281e8ad6  0.277421
# 12      C_ID_8375dfdaa2  0.119882
# 13      C_ID_79d149c008 -0.081392
# 14      C_ID_7f1041e8e1 -7.587275
# 15      C_ID_f72513589e  0.779489
# 16      C_ID_a7f2d6984e  0.633469
# 17      C_ID_15489b42d3 -0.181125
# 18      C_ID_e457bbd71d  0.182171
# 19      C_ID_3f74e10c7e -0.245650
# 20      C_ID_48243da9c4  0.209894
# 21      C_ID_7ea1fcf117 -0.645681
# 22      C_ID_22e4a47c72 -0.205771
# 23      C_ID_5d30729184  0.233964
# 24      C_ID_b54cfad8b2 -0.773896
# 25      C_ID_4b82e26faa -0.262735
# 26      C_ID_60a453531a -0.788592
# 27      C_ID_0c9315feec -0.437957
# 28      C_ID_1e28804d36 -0.136909
# 29      C_ID_68de79f7e2 -0.416897
# ...                 ...       ...
# 123593  C_ID_cd42a5db89 -0.344464
# 123594  C_ID_715b9a183d -1.097186
# 123595  C_ID_9b25df3309 -0.011294
# 123596  C_ID_043b3c2ccd  1.210842
# 123597  C_ID_7685eae7b2 -0.579362
# 123598  C_ID_7ee1a21a95 -0.569596
# 123599  C_ID_2bf12fed6b  0.708049
# 123600  C_ID_2932a6ea37 -0.750018
# 123601  C_ID_cc33d0d508 -1.028027
# 123602  C_ID_8852708dcb -0.537734
# 123603  C_ID_c3e88ef62d -0.178783
# 123604  C_ID_650557248c  0.713751
# 123605  C_ID_f14af9cb56 -0.563924
# 123606  C_ID_068dcf31e8 -0.558077
# 123607  C_ID_6659f4625a  0.629402
# 123608  C_ID_dc842bba27 -0.417375
# 123609  C_ID_bd625edce0 -0.074797
# 123610  C_ID_278446cc2f  0.423250
# 123611  C_ID_ad358eb92e -1.368579
# 123612  C_ID_7d9bcec574 -0.663539
# 123613  C_ID_b588b35e15 -0.060628
# 123614  C_ID_7147e348c3  0.662036
# 123615  C_ID_727d3ec5da -0.863329
# 123616  C_ID_107d93e20c  1.729334
# 123617  C_ID_0e74bd4966  0.588338
# 123618  C_ID_7a239d2eda  1.093064
# 123619  C_ID_75ace375ae -0.362897
# 123620  C_ID_21d56d950c  1.196001
# 123621  C_ID_6c46fc5a9d -3.002469
# 123622  C_ID_87e7979a5f -0.055991
#
# [123623 rows x 2 columns]

# %%
outliers_idx = np.where(predictions>0.4)[0]

# %%
outliers_idx.shape
# Out:
# (63,)

# %%
df_predict["target"].iloc[outliers_idx] = -25

# %%
df_predict[df_predict.target == -25]
# Out:
#                 card_id  target
# 2624    C_ID_bd59e054f3   -25.0
# 5008    C_ID_be92f84f5c   -25.0
# 5009    C_ID_695b445408   -25.0
# 5656    C_ID_126a403be9   -25.0
# 6026    C_ID_91cc0c06ca   -25.0
# 7750    C_ID_a74b12dcf8   -25.0
# 16074   C_ID_9c760806b5   -25.0
# 18363   C_ID_d2871ae781   -25.0
# 19114   C_ID_0be3fb41d2   -25.0
# 20556   C_ID_aae50409e7   -25.0
# 23168   C_ID_3804897561   -25.0
# 26225   C_ID_44c140917d   -25.0
# 26864   C_ID_e7c702e96f   -25.0
# 27314   C_ID_7f5f950342   -25.0
# 27436   C_ID_493de71141   -25.0
# 30531   C_ID_f643abe215   -25.0
# 32446   C_ID_ac114ef831   -25.0
# 35851   C_ID_5ee52cf9f6   -25.0
# 41138   C_ID_d706b6696a   -25.0
# 41756   C_ID_04214ceb9f   -25.0
# 48908   C_ID_eff57c75a3   -25.0
# 59178   C_ID_a4dfae60b0   -25.0
# 61601   C_ID_55f33eeda6   -25.0
# 63978   C_ID_4cf141070f   -25.0
# 66362   C_ID_0bcfec9f5c   -25.0
# 67890   C_ID_cde027fde7   -25.0
# 70804   C_ID_833aa2f7af   -25.0
# 76013   C_ID_1afd4a6a1f   -25.0
# 77297   C_ID_b0c41ca140   -25.0
# 77945   C_ID_6ab591cf62   -25.0
# ...                 ...     ...
# 80840   C_ID_bced41d837   -25.0
# 82194   C_ID_5bc03fa634   -25.0
# 83378   C_ID_8a93017bd2   -25.0
# 84477   C_ID_c32d4bfa02   -25.0
# 88199   C_ID_15af13cd78   -25.0
# 88371   C_ID_26f775a95b   -25.0
# 88824   C_ID_73ddacd425   -25.0
# 90555   C_ID_0203943aba   -25.0
# 91197   C_ID_7598b04bdf   -25.0
# 91624   C_ID_21a98a9c2e   -25.0
# 94668   C_ID_6e9a4a6008   -25.0
# 96354   C_ID_b237ce01cb   -25.0
# 103851  C_ID_877b879853   -25.0
# 104274  C_ID_bf939aa4e9   -25.0
# 104991  C_ID_86ddafb51c   -25.0
# 107511  C_ID_a9933253aa   -25.0
# 107752  C_ID_0c22eb865e   -25.0
# 108079  C_ID_84e90acaf9   -25.0
# 108111  C_ID_b789a1772c   -25.0
# 108511  C_ID_2bd508a57d   -25.0
# 109705  C_ID_d596794318   -25.0
# 111099  C_ID_601974ff16   -25.0
# 113597  C_ID_dc932bbd89   -25.0
# 116264  C_ID_a475834914   -25.0
# 116572  C_ID_f503a136f1   -25.0
# 116936  C_ID_561c8fe332   -25.0
# 119449  C_ID_3d40705001   -25.0
# 119851  C_ID_4cdcd7bbb1   -25.0
# 120151  C_ID_3e3bb028d1   -25.0
# 122519  C_ID_6a5ec7646a   -25.0
#
# [63 rows x 2 columns]

# %%
df_predict.target.describe()
# Out:
# count    123623.000000
# mean         -0.338795
# std           1.328831
# min         -25.000000
# 25%          -0.654177
# 50%          -0.214578
# 75%           0.245338
# max           5.014049
# Name: target, dtype: float64

# %%
df_predict
# Out:
#                 card_id    target
# 0       C_ID_0ab67a22ab -2.041275
# 1       C_ID_130fd0cbdd -0.305701
# 2       C_ID_b709037bc5 -0.974894
# 3       C_ID_d27d835a9f -0.090633
# 4       C_ID_2b5e3df5c2 -1.465622
# 5       C_ID_5814b4f13c  0.536912
# 6       C_ID_a1b3c75277  0.176816
# 7       C_ID_f7cada36d3  0.865616
# 8       C_ID_9d2bc8dfc4 -0.709276
# 9       C_ID_6d8dba8475 -1.145146
# 10      C_ID_4859ac9ed5 -0.643432
# 11      C_ID_0e281e8ad6  0.277421
# 12      C_ID_8375dfdaa2  0.119882
# 13      C_ID_79d149c008 -0.081392
# 14      C_ID_7f1041e8e1 -7.587275
# 15      C_ID_f72513589e  0.779489
# 16      C_ID_a7f2d6984e  0.633469
# 17      C_ID_15489b42d3 -0.181125
# 18      C_ID_e457bbd71d  0.182171
# 19      C_ID_3f74e10c7e -0.245650
# 20      C_ID_48243da9c4  0.209894
# 21      C_ID_7ea1fcf117 -0.645681
# 22      C_ID_22e4a47c72 -0.205771
# 23      C_ID_5d30729184  0.233964
# 24      C_ID_b54cfad8b2 -0.773896
# 25      C_ID_4b82e26faa -0.262735
# 26      C_ID_60a453531a -0.788592
# 27      C_ID_0c9315feec -0.437957
# 28      C_ID_1e28804d36 -0.136909
# 29      C_ID_68de79f7e2 -0.416897
# ...                 ...       ...
# 123593  C_ID_cd42a5db89 -0.344464
# 123594  C_ID_715b9a183d -1.097186
# 123595  C_ID_9b25df3309 -0.011294
# 123596  C_ID_043b3c2ccd  1.210842
# 123597  C_ID_7685eae7b2 -0.579362
# 123598  C_ID_7ee1a21a95 -0.569596
# 123599  C_ID_2bf12fed6b  0.708049
# 123600  C_ID_2932a6ea37 -0.750018
# 123601  C_ID_cc33d0d508 -1.028027
# 123602  C_ID_8852708dcb -0.537734
# 123603  C_ID_c3e88ef62d -0.178783
# 123604  C_ID_650557248c  0.713751
# 123605  C_ID_f14af9cb56 -0.563924
# 123606  C_ID_068dcf31e8 -0.558077
# 123607  C_ID_6659f4625a  0.629402
# 123608  C_ID_dc842bba27 -0.417375
# 123609  C_ID_bd625edce0 -0.074797
# 123610  C_ID_278446cc2f  0.423250
# 123611  C_ID_ad358eb92e -1.368579
# 123612  C_ID_7d9bcec574 -0.663539
# 123613  C_ID_b588b35e15 -0.060628
# 123614  C_ID_7147e348c3  0.662036
# 123615  C_ID_727d3ec5da -0.863329
# 123616  C_ID_107d93e20c  1.729334
# 123617  C_ID_0e74bd4966  0.588338
# 123618  C_ID_7a239d2eda  1.093064
# 123619  C_ID_75ace375ae -0.362897
# 123620  C_ID_21d56d950c  1.196001
# 123621  C_ID_6c46fc5a9d -3.002469
# 123622  C_ID_87e7979a5f -0.055991
#
# [123623 rows x 2 columns]

# %%
df_predict[["card_id", "target"]].to_csv("../output/submission_model20190112.csv", index=False)
