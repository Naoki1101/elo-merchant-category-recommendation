# %%
import numpy as np
import pandas as pd
import datetime
import gc

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import lightgbm as lgb

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error, roc_auc_score
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')
np.random.seed(4590)

# %%
df_train = pd.read_csv('../input/train.csv')
df_test = pd.read_csv('../input/test.csv')
df_hist_trans = pd.read_csv('../input/historical_transactions.csv')
df_new_merchant_trans = pd.read_csv('../input/new_merchant_transactions.csv')

# %%
df_hist_trans['purchase_amount'] = np.exp(df_hist_trans['purchase_amount'])
df_new_merchant_trans['purchase_amount'] = np.exp(df_new_merchant_trans['purchase_amount'])

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['category_2'].fillna(1.0,inplace=True)
    df['category_3'].fillna('A',inplace=True)
    df['merchant_id'].fillna('M_ID_00a6ca8a8a',inplace=True)

# %%
def get_new_columns(name,aggs):
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    df['year'] = df['purchase_date'].dt.year
    df['weekofyear'] = df['purchase_date'].dt.weekofyear
    df['month'] = df['purchase_date'].dt.month
    df['dayofweek'] = df['purchase_date'].dt.dayofweek
    df['weekend'] = (df.purchase_date.dt.weekday >=5).astype(int)
    df['hour'] = df['purchase_date'].dt.hour
    df['authorized_flag'] = df['authorized_flag'].map({'Y':1, 'N':0})
    df['category_1'] = df['category_1'].map({'Y':1, 'N':0}) 
    #https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/73244
    df['month_diff'] = ((datetime.datetime.today() - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']

aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['authorized_flag'] = ['sum', 'mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_hist_trans[col+'_mean'] = df_hist_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']    

new_columns = get_new_columns('hist',aggs)
df_hist_trans_group = df_hist_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['hist_purchase_date_diff'] = (df_hist_trans_group['hist_purchase_date_max'] - df_hist_trans_group['hist_purchase_date_min']).dt.days
df_hist_trans_group['hist_purchase_date_average'] = df_hist_trans_group['hist_purchase_date_diff']/df_hist_trans_group['hist_card_id_size']
df_hist_trans_group['hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 175

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']
aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_new_merchant_trans[col+'_mean'] = df_new_merchant_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']
    
new_columns = get_new_columns('new_hist',aggs)
df_hist_trans_group = df_new_merchant_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['new_hist_purchase_date_diff'] = (df_hist_trans_group['new_hist_purchase_date_max'] - df_hist_trans_group['new_hist_purchase_date_min']).dt.days
df_hist_trans_group['new_hist_purchase_date_average'] = df_hist_trans_group['new_hist_purchase_date_diff']/df_hist_trans_group['new_hist_card_id_size']
df_hist_trans_group['new_hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['new_hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 28

# %%
del df_hist_trans;gc.collect()
del df_new_merchant_trans;gc.collect()
df_train.head(5)
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
# 3            2017-09  C_ID_186d6a6901          4          3          0
# 4            2017-11  C_ID_cdbd2c0db2          1          3          0
#
#      target  hist_month_nunique  hist_hour_nunique  hist_weekofyear_nunique  \
# 0 -0.820283                   9                 23                       35
# 1  0.392913                  12                 24                       50
# 2  0.688056                  10                 14                       22
# 3  0.142495                   6                 16                       20
# 4 -0.159749                   4                 22                       17
#
#    hist_dayofweek_nunique               ...                \
# 0                       7               ...
# 1                       7               ...
# 2                       7               ...
# 3                       7               ...
# 4                       7               ...
#
#    new_hist_weekend_sum  new_hist_weekend_mean  new_hist_category_1_sum  \
# 0                   6.0               0.260870                      0.0
# 1                   0.0               0.000000                      0.0
# 2                   1.0               1.000000                      0.0
# 3                   3.0               0.428571                      1.0
# 4                  12.0               0.333333                      2.0
#
#    new_hist_category_1_mean  new_hist_card_id_size  \
# 0                  0.000000                   23.0
# 1                  0.000000                    6.0
# 2                  0.000000                    1.0
# 3                  0.142857                    7.0
# 4                  0.055556                   36.0
#
#    new_hist_category_2_mean_mean  new_hist_category_3_mean_mean  \
# 0                  1.658319e+108                   1.381361e+36
# 1                  1.658319e+108                   3.557623e+25
# 2                   7.789907e+26                   1.381361e+36
# 3                  2.369028e+107                   1.973373e+35
# 4                  1.842577e+107                  3.624714e+107
#
#    new_hist_purchase_date_diff  new_hist_purchase_date_average  \
# 0                         54.0                        2.347826
# 1                         56.0                        9.333333
# 2                          0.0                        0.000000
# 3                         41.0                        5.857143
# 4                         57.0                        1.583333
#
#    new_hist_purchase_date_uptonow
# 0                           245.0
# 1                           275.0
# 2                           246.0
# 3                           256.0
# 4                           246.0
#
# [5 rows x 78 columns]

# %%
df_train['outliers'] = 0
df_train.loc[df_train['target'] < -30, 'outliers'] = 1
df_train['outliers'].value_counts()
# Out:
# 0    199710
# 1      2207
# Name: outliers, dtype: int64

# %%
list_outlier_idx = df_train[df_train.outliers == 1].index.tolist()

# %%
for df in [df_train,df_test]:
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['dayofweek'] = df['first_active_month'].dt.dayofweek
    df['weekofyear'] = df['first_active_month'].dt.weekofyear
    df['month'] = df['first_active_month'].dt.month
    df['elapsed_time'] = (datetime.datetime.today() - df['first_active_month']).dt.days
    df['hist_first_buy'] = (df['hist_purchase_date_min'] - df['first_active_month']).dt.days
    df['new_hist_first_buy'] = (df['new_hist_purchase_date_min'] - df['first_active_month']).dt.days
    for f in ['hist_purchase_date_max','hist_purchase_date_min','new_hist_purchase_date_max',\
                     'new_hist_purchase_date_min']:
        df[f] = df[f].astype(np.int64) * 1e-9
    df['card_id_total'] = df['new_hist_card_id_size']+df['hist_card_id_size']
    df['purchase_amount_total'] = df['new_hist_purchase_amount_sum']+df['hist_purchase_amount_sum']

for f in ['feature_1','feature_2','feature_3']:
    order_label = df_train.groupby([f])['outliers'].mean()
    df_train[f] = df_train[f].map(order_label)
    df_test[f] = df_test[f].map(order_label)

# %%
high_importance_features = [
    "hist_month_diff_mean", 
    "hist_authorized_flag_mean", 
    "hist_category_1_sum", 
    "hist_month_lag_mean", 
    "new_hist_purchase_amount_sum", 
    "new_hist_purchase_date_uptonow"
]

#smoothing
for col in high_importance_features:
    df_train[col] = np.where(df_train[col].values==0, 0.001, df_train[col].values)
    df_test[col] = np.where(df_test[col].values==0, 0.001, df_test[col].values)


for i in range(len(high_importance_features)):
    for j in range(len((high_importance_features)))[i+1:]:
        col1 = high_importance_features[i]
        col2 = high_importance_features[j]
        new_col_name = "{c1}__div__{c2}".format(c1=col1, c2=col2)
        
        df_train[new_col_name] = df_train[col1] / df_train[col2]
        df_test[new_col_name] = df_test[col1] / df_test[col2]

# %%
def merge_new_feature(path):
    df_new_feature = pd.read_csv(path)
    
    df_tr = pd.merge(df_train, df_new_feature, on="card_id", how="left")
    df_te = pd.merge(df_test, df_new_feature, on="card_id", how="left")
    
    return df_tr, df_te

# %%
df_train, df_test = merge_new_feature("../input/merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/new_merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/prosperity_merchants_latest.csv")
df_train, df_test = merge_new_feature("../input/merchants_numerical_features.csv")
df_train, df_test = merge_new_feature("../input/merchants_item_scale_feature.csv")
df_train, df_test = merge_new_feature("../input/purchase_pattern.csv")
df_train, df_test = merge_new_feature("../input/purchase_pettern_nmf.csv")
df_train, df_test = merge_new_feature("../input/purchase_amount_pettern_nmf.csv")
df_train, df_test = merge_new_feature("../input/feature_latest_transaction_data__per__card_id.csv")
df_train, df_test = merge_new_feature("../input/feature_out_count_rate_summary.csv")

# %%
df_train["Null_count"] = df_train.isnull().sum(axis=1)
df_test["Null_count"] = df_test.isnull().sum(axis=1)

# %%
df_train_columns = [c for c in df_train.columns if c not in ['card_id', 'first_active_month','second_active_date','diff_first_and_second','target','outliers']]
target = df_train['target']
target_outlier = df_train["outliers"]

# %%
#original
param = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',
    'max_depth': -1,
    "max_bin": 256,  # なし
    'learning_rate': 0.005,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.5517	valid_1's rmse: 3.57712
# [200]	training's rmse: 3.38779	valid_1's rmse: 3.4425
# [300]	training's rmse: 3.28238	valid_1's rmse: 3.36685
# [400]	training's rmse: 3.20799	valid_1's rmse: 3.32093
# [500]	training's rmse: 3.155	valid_1's rmse: 3.29322
# [600]	training's rmse: 3.11342	valid_1's rmse: 3.27529
# [700]	training's rmse: 3.07916	valid_1's rmse: 3.26368
# [800]	training's rmse: 3.04858	valid_1's rmse: 3.25473
# [900]	training's rmse: 3.0222	valid_1's rmse: 3.24719
# [1000]	training's rmse: 2.99811	valid_1's rmse: 3.24096
# [1100]	training's rmse: 2.97578	valid_1's rmse: 3.23539
# [1200]	training's rmse: 2.95681	valid_1's rmse: 3.23023
# [1300]	training's rmse: 2.93881	valid_1's rmse: 3.22637
# [1400]	training's rmse: 2.9213	valid_1's rmse: 3.22306
# [1500]	training's rmse: 2.90595	valid_1's rmse: 3.21996
# [1600]	training's rmse: 2.8915	valid_1's rmse: 3.21794
# [1700]	training's rmse: 2.87688	valid_1's rmse: 3.21587
# [1800]	training's rmse: 2.8637	valid_1's rmse: 3.21438
# [1900]	training's rmse: 2.85132	valid_1's rmse: 3.21288
# [2000]	training's rmse: 2.83902	valid_1's rmse: 3.21143
# [2100]	training's rmse: 2.82681	valid_1's rmse: 3.21022
# [2200]	training's rmse: 2.816	valid_1's rmse: 3.20924
# [2300]	training's rmse: 2.80505	valid_1's rmse: 3.20842
# [2400]	training's rmse: 2.79428	valid_1's rmse: 3.20779
# [2500]	training's rmse: 2.78408	valid_1's rmse: 3.20676
# [2600]	training's rmse: 2.77397	valid_1's rmse: 3.20572
# [2700]	training's rmse: 2.76433	valid_1's rmse: 3.20537
# [2800]	training's rmse: 2.75434	valid_1's rmse: 3.20462
# [2900]	training's rmse: 2.74515	valid_1's rmse: 3.20402
# [3000]	training's rmse: 2.73628	valid_1's rmse: 3.20368
# [3100]	training's rmse: 2.72746	valid_1's rmse: 3.20303
# [3200]	training's rmse: 2.71882	valid_1's rmse: 3.20241
# [3300]	training's rmse: 2.71068	valid_1's rmse: 3.20199
# [3400]	training's rmse: 2.70273	valid_1's rmse: 3.20166
# [3500]	training's rmse: 2.69442	valid_1's rmse: 3.20123
# [3600]	training's rmse: 2.68626	valid_1's rmse: 3.20067
# [3700]	training's rmse: 2.67857	valid_1's rmse: 3.20025
# [3800]	training's rmse: 2.67079	valid_1's rmse: 3.19998
# [3900]	training's rmse: 2.66247	valid_1's rmse: 3.19955
# [4000]	training's rmse: 2.65523	valid_1's rmse: 3.19916
# [4100]	training's rmse: 2.64812	valid_1's rmse: 3.19902
# [4200]	training's rmse: 2.64066	valid_1's rmse: 3.19881
# [4300]	training's rmse: 2.6336	valid_1's rmse: 3.19851
# [4400]	training's rmse: 2.62636	valid_1's rmse: 3.19851
# [4500]	training's rmse: 2.61919	valid_1's rmse: 3.19823
# [4600]	training's rmse: 2.61227	valid_1's rmse: 3.19808
# [4700]	training's rmse: 2.60557	valid_1's rmse: 3.19769
# [4800]	training's rmse: 2.5988	valid_1's rmse: 3.19746
# [4900]	training's rmse: 2.59202	valid_1's rmse: 3.19713
# [5000]	training's rmse: 2.5856	valid_1's rmse: 3.19697
# [5100]	training's rmse: 2.57943	valid_1's rmse: 3.19695
# [5200]	training's rmse: 2.5736	valid_1's rmse: 3.19691
# [5300]	training's rmse: 2.56729	valid_1's rmse: 3.19686
# [5400]	training's rmse: 2.56137	valid_1's rmse: 3.19668
# [5500]	training's rmse: 2.55477	valid_1's rmse: 3.1964
# [5600]	training's rmse: 2.54858	valid_1's rmse: 3.19628
# [5700]	training's rmse: 2.54185	valid_1's rmse: 3.1963
# [5800]	training's rmse: 2.5356	valid_1's rmse: 3.19585
# [5900]	training's rmse: 2.52948	valid_1's rmse: 3.19579
# [6000]	training's rmse: 2.52354	valid_1's rmse: 3.19555
# [6100]	training's rmse: 2.51736	valid_1's rmse: 3.19519
# [6200]	training's rmse: 2.51185	valid_1's rmse: 3.19528
# [6300]	training's rmse: 2.50608	valid_1's rmse: 3.1951
# [6400]	training's rmse: 2.5004	valid_1's rmse: 3.19501
# [6500]	training's rmse: 2.495	valid_1's rmse: 3.19476
# [6600]	training's rmse: 2.48957	valid_1's rmse: 3.19471
# [6700]	training's rmse: 2.48429	valid_1's rmse: 3.19465
# [6800]	training's rmse: 2.47877	valid_1's rmse: 3.19455
# [6900]	training's rmse: 2.4732	valid_1's rmse: 3.19431
# [7000]	training's rmse: 2.46783	valid_1's rmse: 3.19433
# [7100]	training's rmse: 2.46234	valid_1's rmse: 3.19429
# [7200]	training's rmse: 2.45677	valid_1's rmse: 3.19418
# [7300]	training's rmse: 2.45149	valid_1's rmse: 3.19404
# [7400]	training's rmse: 2.4459	valid_1's rmse: 3.1939
# [7500]	training's rmse: 2.44091	valid_1's rmse: 3.19385
# [7600]	training's rmse: 2.4354	valid_1's rmse: 3.1935
# [7700]	training's rmse: 2.43044	valid_1's rmse: 3.19356
# [7800]	training's rmse: 2.42472	valid_1's rmse: 3.19337
# [7900]	training's rmse: 2.41935	valid_1's rmse: 3.19355
# [8000]	training's rmse: 2.41432	valid_1's rmse: 3.19356
# [8100]	training's rmse: 2.40949	valid_1's rmse: 3.19361
# [8200]	training's rmse: 2.40441	valid_1's rmse: 3.19354
# Early stopping, best iteration is:
# [7800]	training's rmse: 2.42472	valid_1's rmse: 3.19337
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.54513	valid_1's rmse: 3.5753
# [200]	training's rmse: 3.37833	valid_1's rmse: 3.44605
# [300]	training's rmse: 3.27288	valid_1's rmse: 3.37687
# [400]	training's rmse: 3.198	valid_1's rmse: 3.33618
# [500]	training's rmse: 3.14433	valid_1's rmse: 3.31249
# [600]	training's rmse: 3.10106	valid_1's rmse: 3.29805
# [700]	training's rmse: 3.06552	valid_1's rmse: 3.288
# [800]	training's rmse: 3.03598	valid_1's rmse: 3.28052
# [900]	training's rmse: 3.00985	valid_1's rmse: 3.27523
# [1000]	training's rmse: 2.98623	valid_1's rmse: 3.27059
# [1100]	training's rmse: 2.9645	valid_1's rmse: 3.26648
# [1200]	training's rmse: 2.9446	valid_1's rmse: 3.26287
# [1300]	training's rmse: 2.92572	valid_1's rmse: 3.25967
# [1400]	training's rmse: 2.90763	valid_1's rmse: 3.25719
# [1500]	training's rmse: 2.89105	valid_1's rmse: 3.25509
# [1600]	training's rmse: 2.87614	valid_1's rmse: 3.25343
# [1700]	training's rmse: 2.86102	valid_1's rmse: 3.25168
# [1800]	training's rmse: 2.8475	valid_1's rmse: 3.25059
# [1900]	training's rmse: 2.83491	valid_1's rmse: 3.24956
# [2000]	training's rmse: 2.8218	valid_1's rmse: 3.24804
# [2100]	training's rmse: 2.80963	valid_1's rmse: 3.24685
# [2200]	training's rmse: 2.79836	valid_1's rmse: 3.24617
# [2300]	training's rmse: 2.78697	valid_1's rmse: 3.24536
# [2400]	training's rmse: 2.77643	valid_1's rmse: 3.2446
# [2500]	training's rmse: 2.76561	valid_1's rmse: 3.24364
# [2600]	training's rmse: 2.75507	valid_1's rmse: 3.24344
# [2700]	training's rmse: 2.74588	valid_1's rmse: 3.24263
# [2800]	training's rmse: 2.73663	valid_1's rmse: 3.24225
# [2900]	training's rmse: 2.72691	valid_1's rmse: 3.24151
# [3000]	training's rmse: 2.7172	valid_1's rmse: 3.24098
# [3100]	training's rmse: 2.70787	valid_1's rmse: 3.24054
# [3200]	training's rmse: 2.69904	valid_1's rmse: 3.24038
# [3300]	training's rmse: 2.69005	valid_1's rmse: 3.24
# [3400]	training's rmse: 2.68186	valid_1's rmse: 3.23981
# [3500]	training's rmse: 2.67387	valid_1's rmse: 3.23962
# [3600]	training's rmse: 2.66589	valid_1's rmse: 3.23913
# [3700]	training's rmse: 2.6577	valid_1's rmse: 3.23852
# [3800]	training's rmse: 2.64948	valid_1's rmse: 3.23803
# [3900]	training's rmse: 2.64169	valid_1's rmse: 3.23791
# [4000]	training's rmse: 2.63401	valid_1's rmse: 3.23764
# [4100]	training's rmse: 2.62674	valid_1's rmse: 3.2376
# [4200]	training's rmse: 2.61954	valid_1's rmse: 3.23735
# [4300]	training's rmse: 2.61207	valid_1's rmse: 3.2372
# [4400]	training's rmse: 2.60499	valid_1's rmse: 3.23714
# [4500]	training's rmse: 2.59811	valid_1's rmse: 3.23672
# [4600]	training's rmse: 2.59117	valid_1's rmse: 3.23664
# [4700]	training's rmse: 2.58433	valid_1's rmse: 3.23653
# [4800]	training's rmse: 2.57736	valid_1's rmse: 3.23642
# [4900]	training's rmse: 2.57083	valid_1's rmse: 3.23621
# [5000]	training's rmse: 2.56431	valid_1's rmse: 3.23605
# [5100]	training's rmse: 2.55792	valid_1's rmse: 3.23596
# [5200]	training's rmse: 2.55125	valid_1's rmse: 3.2357
# [5300]	training's rmse: 2.54479	valid_1's rmse: 3.23576
# [5400]	training's rmse: 2.53814	valid_1's rmse: 3.23558
# [5500]	training's rmse: 2.53199	valid_1's rmse: 3.23558
# [5600]	training's rmse: 2.52542	valid_1's rmse: 3.23535
# [5700]	training's rmse: 2.51908	valid_1's rmse: 3.23517
# [5800]	training's rmse: 2.51327	valid_1's rmse: 3.23514
# [5900]	training's rmse: 2.50736	valid_1's rmse: 3.23526
# [6000]	training's rmse: 2.50163	valid_1's rmse: 3.23531
# [6100]	training's rmse: 2.49532	valid_1's rmse: 3.23514
# [6200]	training's rmse: 2.48937	valid_1's rmse: 3.2352
# Early stopping, best iteration is:
# [5812]	training's rmse: 2.51251	valid_1's rmse: 3.2351
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.54774	valid_1's rmse: 3.57562
# [200]	training's rmse: 3.37789	valid_1's rmse: 3.44416
# [300]	training's rmse: 3.27142	valid_1's rmse: 3.37544
# [400]	training's rmse: 3.19712	valid_1's rmse: 3.33659
# [500]	training's rmse: 3.14278	valid_1's rmse: 3.31408
# [600]	training's rmse: 3.10119	valid_1's rmse: 3.30061
# [700]	training's rmse: 3.06618	valid_1's rmse: 3.29066
# [800]	training's rmse: 3.03536	valid_1's rmse: 3.28263
# [900]	training's rmse: 3.01003	valid_1's rmse: 3.27759
# [1000]	training's rmse: 2.98527	valid_1's rmse: 3.27217
# [1100]	training's rmse: 2.96408	valid_1's rmse: 3.26785
# [1200]	training's rmse: 2.94423	valid_1's rmse: 3.26427
# [1300]	training's rmse: 2.92533	valid_1's rmse: 3.26085
# [1400]	training's rmse: 2.90859	valid_1's rmse: 3.25816
# [1500]	training's rmse: 2.89268	valid_1's rmse: 3.25657
# [1600]	training's rmse: 2.87753	valid_1's rmse: 3.255
# [1700]	training's rmse: 2.86452	valid_1's rmse: 3.25369
# [1800]	training's rmse: 2.85013	valid_1's rmse: 3.25211
# [1900]	training's rmse: 2.83774	valid_1's rmse: 3.25103
# [2000]	training's rmse: 2.82585	valid_1's rmse: 3.24989
# [2100]	training's rmse: 2.81451	valid_1's rmse: 3.24901
# [2200]	training's rmse: 2.80305	valid_1's rmse: 3.2479
# [2300]	training's rmse: 2.7922	valid_1's rmse: 3.24675
# [2400]	training's rmse: 2.78217	valid_1's rmse: 3.2461
# [2500]	training's rmse: 2.77205	valid_1's rmse: 3.24545
# [2600]	training's rmse: 2.76207	valid_1's rmse: 3.24465
# [2700]	training's rmse: 2.75229	valid_1's rmse: 3.24422
# [2800]	training's rmse: 2.74264	valid_1's rmse: 3.24406
# [2900]	training's rmse: 2.733	valid_1's rmse: 3.24367
# [3000]	training's rmse: 2.72409	valid_1's rmse: 3.24329
# [3100]	training's rmse: 2.71543	valid_1's rmse: 3.24295
# [3200]	training's rmse: 2.70654	valid_1's rmse: 3.24255
# [3300]	training's rmse: 2.69847	valid_1's rmse: 3.24226
# [3400]	training's rmse: 2.69036	valid_1's rmse: 3.24208
# [3500]	training's rmse: 2.68203	valid_1's rmse: 3.24158
# [3600]	training's rmse: 2.67405	valid_1's rmse: 3.24136
# [3700]	training's rmse: 2.66652	valid_1's rmse: 3.24122
# [3800]	training's rmse: 2.65853	valid_1's rmse: 3.24116
# [3900]	training's rmse: 2.6511	valid_1's rmse: 3.24094
# [4000]	training's rmse: 2.64304	valid_1's rmse: 3.24057
# [4100]	training's rmse: 2.63544	valid_1's rmse: 3.24051
# [4200]	training's rmse: 2.62833	valid_1's rmse: 3.24025
# [4300]	training's rmse: 2.62117	valid_1's rmse: 3.24025
# [4400]	training's rmse: 2.61476	valid_1's rmse: 3.24009
# [4500]	training's rmse: 2.60812	valid_1's rmse: 3.24
# [4600]	training's rmse: 2.60154	valid_1's rmse: 3.24008
# [4700]	training's rmse: 2.59395	valid_1's rmse: 3.24009
# [4800]	training's rmse: 2.58753	valid_1's rmse: 3.23987
# [4900]	training's rmse: 2.58072	valid_1's rmse: 3.23997
# [5000]	training's rmse: 2.57439	valid_1's rmse: 3.24005
# [5100]	training's rmse: 2.56824	valid_1's rmse: 3.24004
# [5200]	training's rmse: 2.56188	valid_1's rmse: 3.24014
# Early stopping, best iteration is:
# [4810]	training's rmse: 2.58672	valid_1's rmse: 3.23973
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.54132	valid_1's rmse: 3.59201
# [200]	training's rmse: 3.37022	valid_1's rmse: 3.47069
# [300]	training's rmse: 3.26244	valid_1's rmse: 3.40531
# [400]	training's rmse: 3.18727	valid_1's rmse: 3.36623
# [500]	training's rmse: 3.13219	valid_1's rmse: 3.34316
# [600]	training's rmse: 3.08997	valid_1's rmse: 3.329
# [700]	training's rmse: 3.05503	valid_1's rmse: 3.31921
# [800]	training's rmse: 3.02454	valid_1's rmse: 3.31188
# [900]	training's rmse: 2.99699	valid_1's rmse: 3.3064
# [1000]	training's rmse: 2.97299	valid_1's rmse: 3.30142
# [1100]	training's rmse: 2.95053	valid_1's rmse: 3.29683
# [1200]	training's rmse: 2.93151	valid_1's rmse: 3.29256
# [1300]	training's rmse: 2.91296	valid_1's rmse: 3.28947
# [1400]	training's rmse: 2.89573	valid_1's rmse: 3.28674
# [1500]	training's rmse: 2.8796	valid_1's rmse: 3.2843
# [1600]	training's rmse: 2.86449	valid_1's rmse: 3.28209
# [1700]	training's rmse: 2.84936	valid_1's rmse: 3.28017
# [1800]	training's rmse: 2.8357	valid_1's rmse: 3.27878
# [1900]	training's rmse: 2.823	valid_1's rmse: 3.27766
# [2000]	training's rmse: 2.81065	valid_1's rmse: 3.27633
# [2100]	training's rmse: 2.79828	valid_1's rmse: 3.27545
# [2200]	training's rmse: 2.78688	valid_1's rmse: 3.27428
# [2300]	training's rmse: 2.77573	valid_1's rmse: 3.27352
# [2400]	training's rmse: 2.765	valid_1's rmse: 3.27262
# [2500]	training's rmse: 2.75443	valid_1's rmse: 3.27186
# [2600]	training's rmse: 2.74433	valid_1's rmse: 3.27157
# [2700]	training's rmse: 2.73433	valid_1's rmse: 3.27098
# [2800]	training's rmse: 2.72453	valid_1's rmse: 3.27061
# [2900]	training's rmse: 2.71452	valid_1's rmse: 3.27008
# [3000]	training's rmse: 2.7046	valid_1's rmse: 3.26945
# [3100]	training's rmse: 2.69532	valid_1's rmse: 3.26892
# [3200]	training's rmse: 2.68661	valid_1's rmse: 3.26856
# [3300]	training's rmse: 2.67771	valid_1's rmse: 3.26807
# [3400]	training's rmse: 2.66912	valid_1's rmse: 3.26776
# [3500]	training's rmse: 2.65996	valid_1's rmse: 3.26745
# [3600]	training's rmse: 2.65193	valid_1's rmse: 3.26704
# [3700]	training's rmse: 2.64394	valid_1's rmse: 3.26666
# [3800]	training's rmse: 2.63614	valid_1's rmse: 3.26642
# [3900]	training's rmse: 2.62887	valid_1's rmse: 3.26621
# [4000]	training's rmse: 2.62133	valid_1's rmse: 3.26602
# [4100]	training's rmse: 2.61357	valid_1's rmse: 3.26579
# [4200]	training's rmse: 2.60574	valid_1's rmse: 3.26554
# [4300]	training's rmse: 2.59906	valid_1's rmse: 3.2653
# [4400]	training's rmse: 2.59202	valid_1's rmse: 3.26529
# [4500]	training's rmse: 2.58547	valid_1's rmse: 3.26532
# [4600]	training's rmse: 2.57819	valid_1's rmse: 3.26513
# [4700]	training's rmse: 2.57123	valid_1's rmse: 3.26514
# [4800]	training's rmse: 2.5647	valid_1's rmse: 3.26496
# [4900]	training's rmse: 2.5577	valid_1's rmse: 3.2647
# [5000]	training's rmse: 2.55096	valid_1's rmse: 3.26441
# [5100]	training's rmse: 2.54489	valid_1's rmse: 3.26429
# [5200]	training's rmse: 2.5381	valid_1's rmse: 3.26417
# [5300]	training's rmse: 2.53147	valid_1's rmse: 3.26425
# [5400]	training's rmse: 2.52467	valid_1's rmse: 3.26403
# [5500]	training's rmse: 2.51815	valid_1's rmse: 3.26388
# [5600]	training's rmse: 2.51194	valid_1's rmse: 3.26395
# [5700]	training's rmse: 2.50544	valid_1's rmse: 3.26374
# [5800]	training's rmse: 2.49914	valid_1's rmse: 3.2638
# [5900]	training's rmse: 2.49306	valid_1's rmse: 3.26377
# [6000]	training's rmse: 2.48726	valid_1's rmse: 3.26382
# [6100]	training's rmse: 2.48141	valid_1's rmse: 3.26372
# [6200]	training's rmse: 2.47552	valid_1's rmse: 3.26357
# [6300]	training's rmse: 2.46954	valid_1's rmse: 3.26356
# [6400]	training's rmse: 2.46435	valid_1's rmse: 3.26347
# [6500]	training's rmse: 2.45889	valid_1's rmse: 3.26336
# [6600]	training's rmse: 2.45313	valid_1's rmse: 3.26337
# [6700]	training's rmse: 2.44712	valid_1's rmse: 3.26344
# [6800]	training's rmse: 2.44146	valid_1's rmse: 3.26334
# Early stopping, best iteration is:
# [6470]	training's rmse: 2.46069	valid_1's rmse: 3.26327
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.54567	valid_1's rmse: 3.59401
# [200]	training's rmse: 3.37764	valid_1's rmse: 3.46047
# [300]	training's rmse: 3.27143	valid_1's rmse: 3.38662
# [400]	training's rmse: 3.19778	valid_1's rmse: 3.34426
# [500]	training's rmse: 3.1443	valid_1's rmse: 3.31769
# [600]	training's rmse: 3.10217	valid_1's rmse: 3.2995
# [700]	training's rmse: 3.06811	valid_1's rmse: 3.28743
# [800]	training's rmse: 3.03762	valid_1's rmse: 3.27792
# [900]	training's rmse: 3.01147	valid_1's rmse: 3.27021
# [1000]	training's rmse: 2.98737	valid_1's rmse: 3.2635
# [1100]	training's rmse: 2.96579	valid_1's rmse: 3.25816
# [1200]	training's rmse: 2.94621	valid_1's rmse: 3.25428
# [1300]	training's rmse: 2.92839	valid_1's rmse: 3.25112
# [1400]	training's rmse: 2.91098	valid_1's rmse: 3.24768
# [1500]	training's rmse: 2.89514	valid_1's rmse: 3.24529
# [1600]	training's rmse: 2.88046	valid_1's rmse: 3.24317
# [1700]	training's rmse: 2.86637	valid_1's rmse: 3.24131
# [1800]	training's rmse: 2.85322	valid_1's rmse: 3.23961
# [1900]	training's rmse: 2.84037	valid_1's rmse: 3.23827
# [2000]	training's rmse: 2.82872	valid_1's rmse: 3.23758
# [2100]	training's rmse: 2.81687	valid_1's rmse: 3.23642
# [2200]	training's rmse: 2.8058	valid_1's rmse: 3.23547
# [2300]	training's rmse: 2.79452	valid_1's rmse: 3.23445
# [2400]	training's rmse: 2.78414	valid_1's rmse: 3.234
# [2500]	training's rmse: 2.77407	valid_1's rmse: 3.23359
# [2600]	training's rmse: 2.76341	valid_1's rmse: 3.23312
# [2700]	training's rmse: 2.75333	valid_1's rmse: 3.23252
# [2800]	training's rmse: 2.74435	valid_1's rmse: 3.23207
# [2900]	training's rmse: 2.73504	valid_1's rmse: 3.23162
# [3000]	training's rmse: 2.72566	valid_1's rmse: 3.23096
# [3100]	training's rmse: 2.71671	valid_1's rmse: 3.23033
# [3200]	training's rmse: 2.70801	valid_1's rmse: 3.2301
# [3300]	training's rmse: 2.69951	valid_1's rmse: 3.22976
# [3400]	training's rmse: 2.69165	valid_1's rmse: 3.22947
# [3500]	training's rmse: 2.68328	valid_1's rmse: 3.22925
# [3600]	training's rmse: 2.67549	valid_1's rmse: 3.22887
# [3700]	training's rmse: 2.66709	valid_1's rmse: 3.22859
# [3800]	training's rmse: 2.65903	valid_1's rmse: 3.22808
# [3900]	training's rmse: 2.65106	valid_1's rmse: 3.2277
# [4000]	training's rmse: 2.64392	valid_1's rmse: 3.22746
# [4100]	training's rmse: 2.63629	valid_1's rmse: 3.22738
# [4200]	training's rmse: 2.62895	valid_1's rmse: 3.22741
# [4300]	training's rmse: 2.6222	valid_1's rmse: 3.22739
# [4400]	training's rmse: 2.61532	valid_1's rmse: 3.22715
# [4500]	training's rmse: 2.60819	valid_1's rmse: 3.22678
# [4600]	training's rmse: 2.60097	valid_1's rmse: 3.22659
# [4700]	training's rmse: 2.5941	valid_1's rmse: 3.22661
# [4800]	training's rmse: 2.58727	valid_1's rmse: 3.22646
# [4900]	training's rmse: 2.57943	valid_1's rmse: 3.22613
# [5000]	training's rmse: 2.57255	valid_1's rmse: 3.22601
# [5100]	training's rmse: 2.56631	valid_1's rmse: 3.22594
# [5200]	training's rmse: 2.55957	valid_1's rmse: 3.22571
# [5300]	training's rmse: 2.55342	valid_1's rmse: 3.22559
# [5400]	training's rmse: 2.54685	valid_1's rmse: 3.22538
# [5500]	training's rmse: 2.54105	valid_1's rmse: 3.22531
# [5600]	training's rmse: 2.53472	valid_1's rmse: 3.22516
# [5700]	training's rmse: 2.52872	valid_1's rmse: 3.22508
# [5800]	training's rmse: 2.52239	valid_1's rmse: 3.22519
# [5900]	training's rmse: 2.51697	valid_1's rmse: 3.22517
# [6000]	training's rmse: 2.51069	valid_1's rmse: 3.22517
# [6100]	training's rmse: 2.50446	valid_1's rmse: 3.22503
# [6200]	training's rmse: 2.49817	valid_1's rmse: 3.225
# [6300]	training's rmse: 2.49289	valid_1's rmse: 3.22499
# [6400]	training's rmse: 2.48678	valid_1's rmse: 3.22493
# [6500]	training's rmse: 2.48105	valid_1's rmse: 3.22484
# [6600]	training's rmse: 2.47502	valid_1's rmse: 3.22478
# [6700]	training's rmse: 2.46978	valid_1's rmse: 3.22494
# [6800]	training's rmse: 2.46358	valid_1's rmse: 3.22496
# [6900]	training's rmse: 2.45772	valid_1's rmse: 3.22484
# [7000]	training's rmse: 2.45252	valid_1's rmse: 3.22477
# [7100]	training's rmse: 2.44752	valid_1's rmse: 3.22469
# [7200]	training's rmse: 2.44223	valid_1's rmse: 3.22457
# [7300]	training's rmse: 2.43682	valid_1's rmse: 3.2246
# [7400]	training's rmse: 2.43136	valid_1's rmse: 3.22483
# [7500]	training's rmse: 2.42564	valid_1's rmse: 3.22501
# [7600]	training's rmse: 2.42035	valid_1's rmse: 3.22491
# Early stopping, best iteration is:
# [7226]	training's rmse: 2.44075	valid_1's rmse: 3.22452
# 3.2312772087401873

# %%
# score:  3.6467757129353053

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,50))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()

# %%
df_train2 = df_train[df_train.target >= -20].reset_index(drop=True)
target2 = df_train2["target"]

#original
param2 = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',
    'max_depth': -1,
    'learning_rate': 0.01,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train2))
predictions2 = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train2,df_train2['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train2.iloc[trn_idx][df_train_columns], label=target2.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train2.iloc[val_idx][df_train_columns], label=target2.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param2, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train2.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions2 += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target2))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60708	valid_1's rmse: 1.60695
# [200]	training's rmse: 1.57525	valid_1's rmse: 1.57847
# [300]	training's rmse: 1.55973	valid_1's rmse: 1.56739
# [400]	training's rmse: 1.54905	valid_1's rmse: 1.56148
# [500]	training's rmse: 1.54055	valid_1's rmse: 1.55821
# [600]	training's rmse: 1.53328	valid_1's rmse: 1.55587
# [700]	training's rmse: 1.52685	valid_1's rmse: 1.55444
# [800]	training's rmse: 1.52101	valid_1's rmse: 1.55361
# [900]	training's rmse: 1.51569	valid_1's rmse: 1.55301
# [1000]	training's rmse: 1.51069	valid_1's rmse: 1.5526
# [1100]	training's rmse: 1.50597	valid_1's rmse: 1.55229
# [1200]	training's rmse: 1.50144	valid_1's rmse: 1.552
# [1300]	training's rmse: 1.49705	valid_1's rmse: 1.55181
# [1400]	training's rmse: 1.49276	valid_1's rmse: 1.55167
# [1500]	training's rmse: 1.48853	valid_1's rmse: 1.55152
# [1600]	training's rmse: 1.48431	valid_1's rmse: 1.55129
# [1700]	training's rmse: 1.48014	valid_1's rmse: 1.55118
# [1800]	training's rmse: 1.47605	valid_1's rmse: 1.55107
# [1900]	training's rmse: 1.47224	valid_1's rmse: 1.55103
# [2000]	training's rmse: 1.46827	valid_1's rmse: 1.55093
# [2100]	training's rmse: 1.46441	valid_1's rmse: 1.55088
# [2200]	training's rmse: 1.46046	valid_1's rmse: 1.55087
# [2300]	training's rmse: 1.4568	valid_1's rmse: 1.55094
# [2400]	training's rmse: 1.45313	valid_1's rmse: 1.55094
# [2500]	training's rmse: 1.44936	valid_1's rmse: 1.55093
# Early stopping, best iteration is:
# [2159]	training's rmse: 1.46204	valid_1's rmse: 1.55083
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60936	valid_1's rmse: 1.59386
# [200]	training's rmse: 1.57757	valid_1's rmse: 1.56844
# [300]	training's rmse: 1.56202	valid_1's rmse: 1.55862
# [400]	training's rmse: 1.55136	valid_1's rmse: 1.55325
# [500]	training's rmse: 1.54288	valid_1's rmse: 1.54984
# [600]	training's rmse: 1.53563	valid_1's rmse: 1.54777
# [700]	training's rmse: 1.52925	valid_1's rmse: 1.54643
# [800]	training's rmse: 1.5235	valid_1's rmse: 1.54553
# [900]	training's rmse: 1.51816	valid_1's rmse: 1.54496
# [1000]	training's rmse: 1.51317	valid_1's rmse: 1.54438
# [1100]	training's rmse: 1.50842	valid_1's rmse: 1.54405
# [1200]	training's rmse: 1.50379	valid_1's rmse: 1.54376
# [1300]	training's rmse: 1.49933	valid_1's rmse: 1.54358
# [1400]	training's rmse: 1.49498	valid_1's rmse: 1.54334
# [1500]	training's rmse: 1.49084	valid_1's rmse: 1.5431
# [1600]	training's rmse: 1.48662	valid_1's rmse: 1.54292
# [1700]	training's rmse: 1.4825	valid_1's rmse: 1.54279
# [1800]	training's rmse: 1.47836	valid_1's rmse: 1.54266
# [1900]	training's rmse: 1.47447	valid_1's rmse: 1.54255
# [2000]	training's rmse: 1.47065	valid_1's rmse: 1.54244
# [2100]	training's rmse: 1.46673	valid_1's rmse: 1.54238
# [2200]	training's rmse: 1.46286	valid_1's rmse: 1.54234
# [2300]	training's rmse: 1.45898	valid_1's rmse: 1.54224
# [2400]	training's rmse: 1.45525	valid_1's rmse: 1.54215
# [2500]	training's rmse: 1.45157	valid_1's rmse: 1.54204
# [2600]	training's rmse: 1.44798	valid_1's rmse: 1.54198
# [2700]	training's rmse: 1.44428	valid_1's rmse: 1.54191
# [2800]	training's rmse: 1.44077	valid_1's rmse: 1.54196
# [2900]	training's rmse: 1.43707	valid_1's rmse: 1.5419
# [3000]	training's rmse: 1.43352	valid_1's rmse: 1.54186
# [3100]	training's rmse: 1.42997	valid_1's rmse: 1.54187
# [3200]	training's rmse: 1.42663	valid_1's rmse: 1.54187
# [3300]	training's rmse: 1.42317	valid_1's rmse: 1.54185
# [3400]	training's rmse: 1.41963	valid_1's rmse: 1.54174
# [3500]	training's rmse: 1.41616	valid_1's rmse: 1.54174
# [3600]	training's rmse: 1.41274	valid_1's rmse: 1.54178
# [3700]	training's rmse: 1.40938	valid_1's rmse: 1.54174
# [3800]	training's rmse: 1.4061	valid_1's rmse: 1.54176
# [3900]	training's rmse: 1.40272	valid_1's rmse: 1.54177
# [4000]	training's rmse: 1.39945	valid_1's rmse: 1.54182
# [4100]	training's rmse: 1.39615	valid_1's rmse: 1.5418
# Early stopping, best iteration is:
# [3708]	training's rmse: 1.40913	valid_1's rmse: 1.54172
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60587	valid_1's rmse: 1.61111
# [200]	training's rmse: 1.57439	valid_1's rmse: 1.58402
# [300]	training's rmse: 1.55881	valid_1's rmse: 1.57329
# [400]	training's rmse: 1.54817	valid_1's rmse: 1.5676
# [500]	training's rmse: 1.53978	valid_1's rmse: 1.56419
# [600]	training's rmse: 1.53253	valid_1's rmse: 1.56187
# [700]	training's rmse: 1.52609	valid_1's rmse: 1.56047
# [800]	training's rmse: 1.5204	valid_1's rmse: 1.55945
# [900]	training's rmse: 1.51508	valid_1's rmse: 1.55876
# [1000]	training's rmse: 1.51001	valid_1's rmse: 1.55841
# [1100]	training's rmse: 1.50513	valid_1's rmse: 1.55805
# [1200]	training's rmse: 1.5005	valid_1's rmse: 1.55766
# [1300]	training's rmse: 1.49599	valid_1's rmse: 1.55737
# [1400]	training's rmse: 1.49154	valid_1's rmse: 1.55709
# [1500]	training's rmse: 1.48731	valid_1's rmse: 1.55692
# [1600]	training's rmse: 1.48315	valid_1's rmse: 1.55673
# [1700]	training's rmse: 1.47912	valid_1's rmse: 1.55665
# [1800]	training's rmse: 1.47518	valid_1's rmse: 1.55662
# [1900]	training's rmse: 1.47122	valid_1's rmse: 1.55649
# [2000]	training's rmse: 1.46736	valid_1's rmse: 1.55643
# [2100]	training's rmse: 1.46341	valid_1's rmse: 1.55643
# [2200]	training's rmse: 1.4596	valid_1's rmse: 1.55641
# [2300]	training's rmse: 1.45572	valid_1's rmse: 1.5564
# [2400]	training's rmse: 1.45194	valid_1's rmse: 1.5565
# [2500]	training's rmse: 1.44812	valid_1's rmse: 1.5564
# [2600]	training's rmse: 1.44442	valid_1's rmse: 1.55643
# Early stopping, best iteration is:
# [2269]	training's rmse: 1.45694	valid_1's rmse: 1.55637
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60604	valid_1's rmse: 1.61003
# [200]	training's rmse: 1.5745	valid_1's rmse: 1.58368
# [300]	training's rmse: 1.55897	valid_1's rmse: 1.57309
# [400]	training's rmse: 1.54842	valid_1's rmse: 1.56743
# [500]	training's rmse: 1.53987	valid_1's rmse: 1.564
# [600]	training's rmse: 1.53265	valid_1's rmse: 1.56151
# [700]	training's rmse: 1.52629	valid_1's rmse: 1.56013
# [800]	training's rmse: 1.52053	valid_1's rmse: 1.55911
# [900]	training's rmse: 1.51528	valid_1's rmse: 1.55839
# [1000]	training's rmse: 1.51024	valid_1's rmse: 1.55787
# [1100]	training's rmse: 1.50539	valid_1's rmse: 1.5574
# [1200]	training's rmse: 1.50085	valid_1's rmse: 1.55707
# [1300]	training's rmse: 1.49634	valid_1's rmse: 1.55695
# [1400]	training's rmse: 1.492	valid_1's rmse: 1.55679
# [1500]	training's rmse: 1.48783	valid_1's rmse: 1.55664
# [1600]	training's rmse: 1.48368	valid_1's rmse: 1.55647
# [1700]	training's rmse: 1.47962	valid_1's rmse: 1.55646
# [1800]	training's rmse: 1.47568	valid_1's rmse: 1.55642
# [1900]	training's rmse: 1.47164	valid_1's rmse: 1.55628
# [2000]	training's rmse: 1.46775	valid_1's rmse: 1.55609
# [2100]	training's rmse: 1.46393	valid_1's rmse: 1.55598
# [2200]	training's rmse: 1.46018	valid_1's rmse: 1.55599
# [2300]	training's rmse: 1.45643	valid_1's rmse: 1.55589
# [2400]	training's rmse: 1.45267	valid_1's rmse: 1.55578
# [2500]	training's rmse: 1.44897	valid_1's rmse: 1.55569
# [2600]	training's rmse: 1.44527	valid_1's rmse: 1.55559
# [2700]	training's rmse: 1.44165	valid_1's rmse: 1.55543
# [2800]	training's rmse: 1.43805	valid_1's rmse: 1.55536
# [2900]	training's rmse: 1.4345	valid_1's rmse: 1.55536
# [3000]	training's rmse: 1.43099	valid_1's rmse: 1.55537
# [3100]	training's rmse: 1.4275	valid_1's rmse: 1.55541
# [3200]	training's rmse: 1.42408	valid_1's rmse: 1.55538
# [3300]	training's rmse: 1.42059	valid_1's rmse: 1.5554
# Early stopping, best iteration is:
# [2919]	training's rmse: 1.43381	valid_1's rmse: 1.55533
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60113	valid_1's rmse: 1.63109
# [200]	training's rmse: 1.56947	valid_1's rmse: 1.60405
# [300]	training's rmse: 1.55399	valid_1's rmse: 1.59335
# [400]	training's rmse: 1.54328	valid_1's rmse: 1.58761
# [500]	training's rmse: 1.5348	valid_1's rmse: 1.58422
# [600]	training's rmse: 1.52766	valid_1's rmse: 1.58197
# [700]	training's rmse: 1.52139	valid_1's rmse: 1.58054
# [800]	training's rmse: 1.51563	valid_1's rmse: 1.57964
# [900]	training's rmse: 1.51026	valid_1's rmse: 1.57903
# [1000]	training's rmse: 1.5052	valid_1's rmse: 1.57847
# [1100]	training's rmse: 1.50047	valid_1's rmse: 1.578
# [1200]	training's rmse: 1.49582	valid_1's rmse: 1.57774
# [1300]	training's rmse: 1.49134	valid_1's rmse: 1.57756
# [1400]	training's rmse: 1.48702	valid_1's rmse: 1.57739
# [1500]	training's rmse: 1.4828	valid_1's rmse: 1.57726
# [1600]	training's rmse: 1.47869	valid_1's rmse: 1.57723
# [1700]	training's rmse: 1.47462	valid_1's rmse: 1.57714
# [1800]	training's rmse: 1.47057	valid_1's rmse: 1.57698
# [1900]	training's rmse: 1.46667	valid_1's rmse: 1.57694
# [2000]	training's rmse: 1.46282	valid_1's rmse: 1.57698
# [2100]	training's rmse: 1.45905	valid_1's rmse: 1.57705
# [2200]	training's rmse: 1.45525	valid_1's rmse: 1.57697
# [2300]	training's rmse: 1.4515	valid_1's rmse: 1.5769
# [2400]	training's rmse: 1.44785	valid_1's rmse: 1.57689
# [2500]	training's rmse: 1.44409	valid_1's rmse: 1.57695
# [2600]	training's rmse: 1.44043	valid_1's rmse: 1.57694
# [2700]	training's rmse: 1.4368	valid_1's rmse: 1.57698
# Early stopping, best iteration is:
# [2324]	training's rmse: 1.45062	valid_1's rmse: 1.57685
# 1.5562622012364913

# %%
df_prediction = pd.DataFrame({"prediction1":predictions, "prediction2":predictions2})
df_prediction
# Out:
#         prediction1  prediction2
# 0         -0.776705    -0.576543
# 1         -0.282078    -0.325371
# 2         -0.740959    -0.361586
# 3         -0.154199    -0.097735
# 4         -1.682709    -1.793248
# 5          0.207359     0.547805
# 6          0.125610     0.168009
# 7          0.821773     0.768376
# 8         -0.668980    -0.739997
# 9         -0.513189    -0.199306
# 10        -0.807895    -0.469785
# 11         0.003333     0.227543
# 12         0.020890     0.084917
# 13        -0.298472     0.208214
# 14        -3.598665    -0.369747
# 15         0.454119     0.569205
# 16         0.424403     0.525135
# 17        -0.247948    -0.097883
# 18         0.198774     0.204354
# 19        -0.025883    -0.263360
# 20         0.248226     0.200836
# 21        -0.647638    -0.762801
# 22        -1.336253     1.184430
# 23         0.232680     0.298703
# 24        -0.446393     0.071969
# 25        -0.372605     0.435418
# 26        -0.665397    -0.786479
# 27        -0.233678    -0.412139
# 28        -0.269972    -0.109068
# 29        -0.343010    -0.470030
# ...             ...          ...
# 123593    -0.463267    -0.407629
# 123594    -1.475661    -1.208600
# 123595     0.072687    -0.018389
# 123596     0.888470     1.293465
# 123597    -0.371199    -0.435098
# 123598    -0.657690    -0.641021
# 123599     0.452112     0.393244
# 123600     0.345084    -0.094140
# 123601    -1.032306    -1.434995
# 123602    -0.383231    -0.240777
# 123603    -0.086386    -0.009702
# 123604     0.595800     0.736477
# 123605    -0.619467    -0.554759
# 123606    -0.704735    -0.326273
# 123607     0.436510     0.529202
# 123608    -0.353227    -0.489025
# 123609     0.371052    -0.028233
# 123610     0.224381     0.474047
# 123611    -1.161371    -1.032628
# 123612    -0.441951    -0.803038
# 123613    -0.470831     0.125488
# 123614     0.411008     0.859269
# 123615    -0.704966    -0.498071
# 123616     0.995405     1.412317
# 123617     0.499477     0.572086
# 123618     1.093794     1.381427
# 123619    -0.564715    -0.448471
# 123620     1.146667     1.141871
# 123621    -1.231737    -0.857882
# 123622     0.167996     0.035124
#
# [123623 rows x 2 columns]

# %%
predictions3 = np.zeros(df_prediction.shape[0])
for i, r in df_prediction.iterrows():
    if r[0] < 0 :
        predictions3[i] = r[0]
    else:
        predictions3[i] = r[1]
df_prediction["prediction3"] = predictions3

# %%
df_prediction
# Out:
#         prediction1  prediction2  prediction3
# 0         -0.776705    -0.576543    -0.776705
# 1         -0.282078    -0.325371    -0.282078
# 2         -0.740959    -0.361586    -0.740959
# 3         -0.154199    -0.097735    -0.154199
# 4         -1.682709    -1.793248    -1.682709
# 5          0.207359     0.547805     0.547805
# 6          0.125610     0.168009     0.168009
# 7          0.821773     0.768376     0.768376
# 8         -0.668980    -0.739997    -0.668980
# 9         -0.513189    -0.199306    -0.513189
# 10        -0.807895    -0.469785    -0.807895
# 11         0.003333     0.227543     0.227543
# 12         0.020890     0.084917     0.084917
# 13        -0.298472     0.208214    -0.298472
# 14        -3.598665    -0.369747    -3.598665
# 15         0.454119     0.569205     0.569205
# 16         0.424403     0.525135     0.525135
# 17        -0.247948    -0.097883    -0.247948
# 18         0.198774     0.204354     0.204354
# 19        -0.025883    -0.263360    -0.025883
# 20         0.248226     0.200836     0.200836
# 21        -0.647638    -0.762801    -0.647638
# 22        -1.336253     1.184430    -1.336253
# 23         0.232680     0.298703     0.298703
# 24        -0.446393     0.071969    -0.446393
# 25        -0.372605     0.435418    -0.372605
# 26        -0.665397    -0.786479    -0.665397
# 27        -0.233678    -0.412139    -0.233678
# 28        -0.269972    -0.109068    -0.269972
# 29        -0.343010    -0.470030    -0.343010
# ...             ...          ...          ...
# 123593    -0.463267    -0.407629    -0.463267
# 123594    -1.475661    -1.208600    -1.475661
# 123595     0.072687    -0.018389    -0.018389
# 123596     0.888470     1.293465     1.293465
# 123597    -0.371199    -0.435098    -0.371199
# 123598    -0.657690    -0.641021    -0.657690
# 123599     0.452112     0.393244     0.393244
# 123600     0.345084    -0.094140    -0.094140
# 123601    -1.032306    -1.434995    -1.032306
# 123602    -0.383231    -0.240777    -0.383231
# 123603    -0.086386    -0.009702    -0.086386
# 123604     0.595800     0.736477     0.736477
# 123605    -0.619467    -0.554759    -0.619467
# 123606    -0.704735    -0.326273    -0.704735
# 123607     0.436510     0.529202     0.529202
# 123608    -0.353227    -0.489025    -0.353227
# 123609     0.371052    -0.028233    -0.028233
# 123610     0.224381     0.474047     0.474047
# 123611    -1.161371    -1.032628    -1.161371
# 123612    -0.441951    -0.803038    -0.441951
# 123613    -0.470831     0.125488    -0.470831
# 123614     0.411008     0.859269     0.859269
# 123615    -0.704966    -0.498071    -0.704966
# 123616     0.995405     1.412317     1.412317
# 123617     0.499477     0.572086     0.572086
# 123618     1.093794     1.381427     1.381427
# 123619    -0.564715    -0.448471    -0.564715
# 123620     1.146667     1.141871     1.141871
# 123621    -1.231737    -0.857882    -1.231737
# 123622     0.167996     0.035124     0.035124
#
# [123623 rows x 3 columns]

# %%
final_predictions = df_prediction.prediction3.values

# %%
# import optuna

# def objective(trial):
#     train_x, test_x, train_y, test_y = train_test_split(df_train[df_train_columns], target, test_size=0.20, random_state=4590)
    
#     dtrain = lgb.Dataset(train_x, label=train_y)
#     dval = lgb.Dataset(test_x, label=test_y)

#     num_round = trial.suggest_int('num_round', 1, 10000)
#     param = {
#         'objective': 'regression', 
#         'metric': 'rmse',
#         'verbosity': -1,
#         'feature_fraction': trial.suggest_loguniform('feature_fraction', 0.8, 0.95),
#         'bagging_fraction': trial.suggest_loguniform('bagging_fraction', 0.8, 0.95),
#         'bagging_seed': 11,
#         'boosting_type': trial.suggest_categorical('boosting', ['gbdt', 'dart', 'goss']),
#         'num_leaves': trial.suggest_int('num_leaves', 10, 100),
#         'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
#         'min_child_samples': trial.suggest_int('min_child_samples', 20, 100),
#         'min_data_in_leaf':  trial.suggest_int('min_data_in_leaf', 10, 1000),
#         'lambda_l1':  trial.suggest_loguniform('lambda_l1', 1e-2, 1.0)
#     }

#     if param['boosting_type'] == 'dart':
#         param['drop_rate'] = trial.suggest_loguniform('drop_rate', 1e-4, 1.0)
#         param['skip_drop'] = trial.suggest_loguniform('skip_drop', 1e-4, 1.0)
#     if param['boosting_type'] == 'goss':
#         param['top_rate'] = trial.suggest_uniform('top_rate', 0.0, 1.0)
#         param['other_rate'] = trial.suggest_uniform('other_rate', 0.0, 1.0 - param['top_rate'])

#     gbm = lgb.train(param, dtrain, num_round, valid_sets = [dtrain, dval], verbose_eval=100, early_stopping_rounds=400)
#     preds = gbm.predict(test_x)
#     pred_labels = np.rint(preds)
#     rmse = np.sqrt(mean_squared_error(test_y, pred_labels))
#     return rmse

# study = optuna.create_study()
# study.optimize(objective, n_trials=20)

# print('Number of finished trials: {}'.format(len(study.trials)))

# print('Best trial:')
# trial = study.best_trial

# print('  Value: {}'.format(trial.value))

# print('  Params: ')
# for key, value in trial.params.items():
#     print('    {}: {}'.format(key, value))

# %%
sub_df = pd.DataFrame({"card_id":df_test["card_id"].values})
# sub_df["target"] = final_predictions
sub_df["target"] = predictions
sub_df.to_csv("../output/submission_model20181229.csv", index=False)
