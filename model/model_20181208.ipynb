# %%
import numpy as np
import pandas as pd
import datetime
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')
np.random.seed(4590)

# %%
df_train = pd.read_csv('./input/train.csv')
df_test = pd.read_csv('./input/test.csv')
df_hist_trans = pd.read_csv('./input/historical_transactions.csv')
df_new_merchant_trans = pd.read_csv('./input/new_merchant_transactions.csv')

# %%
df_hist_trans['purchase_amount'] = np.exp(df_hist_trans['purchase_amount'])
df_new_merchant_trans['purchase_amount'] = np.exp(df_new_merchant_trans['purchase_amount'])

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['category_2'].fillna(1.0,inplace=True)
    df['category_3'].fillna('A',inplace=True)
    df['merchant_id'].fillna('M_ID_00a6ca8a8a',inplace=True)

# %%
def get_new_columns(name,aggs):
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    df['year'] = df['purchase_date'].dt.year
    df['weekofyear'] = df['purchase_date'].dt.weekofyear
    df['month'] = df['purchase_date'].dt.month
    df['dayofweek'] = df['purchase_date'].dt.dayofweek
    df['weekend'] = (df.purchase_date.dt.weekday >=5).astype(int)
    df['hour'] = df['purchase_date'].dt.hour
    df['authorized_flag'] = df['authorized_flag'].map({'Y':1, 'N':0})
    df['category_1'] = df['category_1'].map({'Y':1, 'N':0}) 
    #https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/73244
    df['month_diff'] = ((datetime.datetime.today() - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']

aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['authorized_flag'] = ['sum', 'mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_hist_trans[col+'_mean'] = df_hist_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']    

new_columns = get_new_columns('hist',aggs)
df_hist_trans_group = df_hist_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['hist_purchase_date_diff'] = (df_hist_trans_group['hist_purchase_date_max'] - df_hist_trans_group['hist_purchase_date_min']).dt.days
df_hist_trans_group['hist_purchase_date_average'] = df_hist_trans_group['hist_purchase_date_diff']/df_hist_trans_group['hist_card_id_size']
df_hist_trans_group['hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 175

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']
aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_new_merchant_trans[col+'_mean'] = df_new_merchant_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']
    
new_columns = get_new_columns('new_hist',aggs)
df_hist_trans_group = df_new_merchant_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['new_hist_purchase_date_diff'] = (df_hist_trans_group['new_hist_purchase_date_max'] - df_hist_trans_group['new_hist_purchase_date_min']).dt.days
df_hist_trans_group['new_hist_purchase_date_average'] = df_hist_trans_group['new_hist_purchase_date_diff']/df_hist_trans_group['new_hist_card_id_size']
df_hist_trans_group['new_hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['new_hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 28

# %%
del df_hist_trans;gc.collect()
del df_new_merchant_trans;gc.collect()
df_train.head(5)
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
# 3            2017-09  C_ID_186d6a6901          4          3          0
# 4            2017-11  C_ID_cdbd2c0db2          1          3          0
#
#      target  hist_month_nunique  hist_hour_nunique  hist_weekofyear_nunique  \
# 0 -0.820283                   9                 23                       35
# 1  0.392913                  12                 24                       50
# 2  0.688056                  10                 14                       22
# 3  0.142495                   6                 16                       20
# 4 -0.159749                   4                 22                       17
#
#    hist_dayofweek_nunique               ...                \
# 0                       7               ...
# 1                       7               ...
# 2                       7               ...
# 3                       7               ...
# 4                       7               ...
#
#    new_hist_weekend_sum  new_hist_weekend_mean  new_hist_category_1_sum  \
# 0                   6.0               0.260870                      0.0
# 1                   0.0               0.000000                      0.0
# 2                   1.0               1.000000                      0.0
# 3                   3.0               0.428571                      1.0
# 4                  12.0               0.333333                      2.0
#
#    new_hist_category_1_mean  new_hist_card_id_size  \
# 0                  0.000000                   23.0
# 1                  0.000000                    6.0
# 2                  0.000000                    1.0
# 3                  0.142857                    7.0
# 4                  0.055556                   36.0
#
#    new_hist_category_2_mean_mean  new_hist_category_3_mean_mean  \
# 0                  1.658319e+108                   1.381361e+36
# 1                  1.658319e+108                   3.557623e+25
# 2                   7.789907e+26                   1.381361e+36
# 3                  2.369028e+107                   1.973373e+35
# 4                  1.842577e+107                  3.624714e+107
#
#    new_hist_purchase_date_diff  new_hist_purchase_date_average  \
# 0                         54.0                        2.347826
# 1                         56.0                        9.333333
# 2                          0.0                        0.000000
# 3                         41.0                        5.857143
# 4                         57.0                        1.583333
#
#    new_hist_purchase_date_uptonow
# 0                           223.0
# 1                           253.0
# 2                           224.0
# 3                           234.0
# 4                           224.0
#
# [5 rows x 78 columns]

# %%
df_train['outliers'] = 0
df_train.loc[df_train['target'] < -30, 'outliers'] = 1
df_train['outliers'].value_counts()
# Out:
# 0    199710
# 1      2207
# Name: outliers, dtype: int64

# %%
for df in [df_train,df_test]:
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['dayofweek'] = df['first_active_month'].dt.dayofweek
    df['weekofyear'] = df['first_active_month'].dt.weekofyear
    df['month'] = df['first_active_month'].dt.month
    df['elapsed_time'] = (datetime.datetime.today() - df['first_active_month']).dt.days
    df['hist_first_buy'] = (df['hist_purchase_date_min'] - df['first_active_month']).dt.days
    df['new_hist_first_buy'] = (df['new_hist_purchase_date_min'] - df['first_active_month']).dt.days
    for f in ['hist_purchase_date_max','hist_purchase_date_min','new_hist_purchase_date_max',\
                     'new_hist_purchase_date_min']:
        df[f] = df[f].astype(np.int64) * 1e-9
    df['card_id_total'] = df['new_hist_card_id_size']+df['hist_card_id_size']
    df['purchase_amount_total'] = df['new_hist_purchase_amount_sum']+df['hist_purchase_amount_sum']

for f in ['feature_1','feature_2','feature_3']:
    order_label = df_train.groupby([f])['outliers'].mean()
    df_train[f] = df_train[f].map(order_label)
    df_test[f] = df_test[f].map(order_label)

# %%
high_importance_features = [
    "hist_month_diff_mean", 
    "hist_authorized_flag_mean", 
    "hist_category_1_sum", 
    "hist_month_lag_mean", 
    "new_hist_purchase_amount_sum", 
    "new_hist_purchase_date_uptonow"
]

#smoothing
for col in high_importance_features:
    df_train[col] = np.where(df_train[col].values==0, 0.001, df_train[col].values)
    df_test[col] = np.where(df_test[col].values==0, 0.001, df_test[col].values)


for i in range(len(high_importance_features)):
    for j in range(len((high_importance_features)))[i+1:]:
        col1 = high_importance_features[i]
        col2 = high_importance_features[j]
        new_col_name = f"{col1}__div__{col2}"
        
        df_train[new_col_name] = df_train[col1] / df_train[col2]
        df_test[new_col_name] = df_test[col1] / df_test[col2]

# %%
df_train_columns = [c for c in df_train.columns if c not in ['card_id', 'first_active_month','target','outliers']]
target = df_train['target']
del df_train['target']

# %%
#original
param = {'num_leaves': 31,
         'min_data_in_leaf': 30, 
         'objective':'regression',
         'max_depth': -1,
         'learning_rate': 0.004,
         "min_child_samples": 20,
         "boosting": "gbdt",
         "feature_fraction": 0.9,
         "bagging_freq": 1,
         "bagging_fraction": 0.9 ,
         "bagging_seed": 11,
         "metric": 'rmse',
         "lambda_l1": 0.1,
         "verbosity": -1,
         "nthread": 4,
         "random_state": 4590}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=4590)
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 200)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target))
# Out:
# fold 0
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.74544	valid_1's rmse: 3.77629
# [200]	training's rmse: 3.68254	valid_1's rmse: 3.73155
# [300]	training's rmse: 3.63953	valid_1's rmse: 3.70643
# [400]	training's rmse: 3.60664	valid_1's rmse: 3.69203
# [500]	training's rmse: 3.58091	valid_1's rmse: 3.68243
# [600]	training's rmse: 3.55993	valid_1's rmse: 3.67612
# [700]	training's rmse: 3.54211	valid_1's rmse: 3.67108
# [800]	training's rmse: 3.52656	valid_1's rmse: 3.6673
# [900]	training's rmse: 3.51177	valid_1's rmse: 3.66447
# [1000]	training's rmse: 3.49827	valid_1's rmse: 3.66225
# [1100]	training's rmse: 3.48642	valid_1's rmse: 3.6602
# [1200]	training's rmse: 3.47475	valid_1's rmse: 3.65851
# [1300]	training's rmse: 3.46344	valid_1's rmse: 3.65699
# [1400]	training's rmse: 3.4532	valid_1's rmse: 3.65604
# [1500]	training's rmse: 3.4435	valid_1's rmse: 3.65487
# [1600]	training's rmse: 3.43388	valid_1's rmse: 3.65422
# [1700]	training's rmse: 3.42501	valid_1's rmse: 3.65353
# [1800]	training's rmse: 3.41586	valid_1's rmse: 3.65287
# [1900]	training's rmse: 3.40698	valid_1's rmse: 3.65272
# [2000]	training's rmse: 3.39852	valid_1's rmse: 3.65209
# [2100]	training's rmse: 3.39083	valid_1's rmse: 3.65171
# [2200]	training's rmse: 3.38323	valid_1's rmse: 3.65135
# [2300]	training's rmse: 3.37616	valid_1's rmse: 3.65122
# [2400]	training's rmse: 3.36913	valid_1's rmse: 3.65115
# [2500]	training's rmse: 3.36223	valid_1's rmse: 3.65101
# [2600]	training's rmse: 3.35549	valid_1's rmse: 3.6509
# [2700]	training's rmse: 3.34884	valid_1's rmse: 3.65099
# [2800]	training's rmse: 3.34253	valid_1's rmse: 3.65093
# [2900]	training's rmse: 3.33628	valid_1's rmse: 3.65097
# [3000]	training's rmse: 3.32988	valid_1's rmse: 3.65076
# [3100]	training's rmse: 3.32411	valid_1's rmse: 3.65087
# [3200]	training's rmse: 3.31789	valid_1's rmse: 3.65088
# Early stopping, best iteration is:
# [3005]	training's rmse: 3.32963	valid_1's rmse: 3.65073
# fold 1
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.74659	valid_1's rmse: 3.76699
# [200]	training's rmse: 3.68346	valid_1's rmse: 3.72503
# [300]	training's rmse: 3.63998	valid_1's rmse: 3.70143
# [400]	training's rmse: 3.60694	valid_1's rmse: 3.68793
# [500]	training's rmse: 3.58044	valid_1's rmse: 3.67958
# [600]	training's rmse: 3.55873	valid_1's rmse: 3.67435
# [700]	training's rmse: 3.54075	valid_1's rmse: 3.67079
# [800]	training's rmse: 3.5247	valid_1's rmse: 3.66802
# [900]	training's rmse: 3.5101	valid_1's rmse: 3.66536
# [1000]	training's rmse: 3.49673	valid_1's rmse: 3.66339
# [1100]	training's rmse: 3.48415	valid_1's rmse: 3.66156
# [1200]	training's rmse: 3.47247	valid_1's rmse: 3.66026
# [1300]	training's rmse: 3.46162	valid_1's rmse: 3.65916
# [1400]	training's rmse: 3.45065	valid_1's rmse: 3.6583
# [1500]	training's rmse: 3.44059	valid_1's rmse: 3.65745
# [1600]	training's rmse: 3.43113	valid_1's rmse: 3.65681
# [1700]	training's rmse: 3.42182	valid_1's rmse: 3.65583
# [1800]	training's rmse: 3.41288	valid_1's rmse: 3.65531
# [1900]	training's rmse: 3.40425	valid_1's rmse: 3.65482
# [2000]	training's rmse: 3.39613	valid_1's rmse: 3.65438
# [2100]	training's rmse: 3.38805	valid_1's rmse: 3.65398
# [2200]	training's rmse: 3.37986	valid_1's rmse: 3.65362
# [2300]	training's rmse: 3.37227	valid_1's rmse: 3.65315
# [2400]	training's rmse: 3.36477	valid_1's rmse: 3.65315
# [2500]	training's rmse: 3.35762	valid_1's rmse: 3.65298
# [2600]	training's rmse: 3.35067	valid_1's rmse: 3.65285
# [2700]	training's rmse: 3.34343	valid_1's rmse: 3.65268
# [2800]	training's rmse: 3.33693	valid_1's rmse: 3.65264
# [2900]	training's rmse: 3.33032	valid_1's rmse: 3.65263
# [3000]	training's rmse: 3.32382	valid_1's rmse: 3.65276
# Early stopping, best iteration is:
# [2894]	training's rmse: 3.33068	valid_1's rmse: 3.65259
# fold 2
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.74415	valid_1's rmse: 3.77313
# [200]	training's rmse: 3.68057	valid_1's rmse: 3.72966
# [300]	training's rmse: 3.63701	valid_1's rmse: 3.70617
# [400]	training's rmse: 3.60358	valid_1's rmse: 3.69302
# [500]	training's rmse: 3.57665	valid_1's rmse: 3.68407
# [600]	training's rmse: 3.55534	valid_1's rmse: 3.67811
# [700]	training's rmse: 3.53699	valid_1's rmse: 3.67399
# [800]	training's rmse: 3.52073	valid_1's rmse: 3.67069
# [900]	training's rmse: 3.50624	valid_1's rmse: 3.66785
# [1000]	training's rmse: 3.493	valid_1's rmse: 3.66561
# [1100]	training's rmse: 3.48093	valid_1's rmse: 3.66367
# [1200]	training's rmse: 3.46885	valid_1's rmse: 3.66233
# [1300]	training's rmse: 3.45776	valid_1's rmse: 3.66113
# [1400]	training's rmse: 3.4471	valid_1's rmse: 3.65985
# [1500]	training's rmse: 3.43728	valid_1's rmse: 3.65897
# [1600]	training's rmse: 3.42757	valid_1's rmse: 3.65837
# [1700]	training's rmse: 3.41838	valid_1's rmse: 3.65775
# [1800]	training's rmse: 3.40964	valid_1's rmse: 3.65715
# [1900]	training's rmse: 3.40083	valid_1's rmse: 3.65667
# [2000]	training's rmse: 3.39279	valid_1's rmse: 3.65617
# [2100]	training's rmse: 3.38504	valid_1's rmse: 3.65586
# [2200]	training's rmse: 3.37758	valid_1's rmse: 3.6555
# [2300]	training's rmse: 3.37014	valid_1's rmse: 3.6552
# [2400]	training's rmse: 3.36287	valid_1's rmse: 3.6549
# [2500]	training's rmse: 3.3558	valid_1's rmse: 3.65478
# [2600]	training's rmse: 3.34887	valid_1's rmse: 3.65456
# [2700]	training's rmse: 3.34227	valid_1's rmse: 3.6543
# [2800]	training's rmse: 3.33555	valid_1's rmse: 3.65451
# Early stopping, best iteration is:
# [2679]	training's rmse: 3.34365	valid_1's rmse: 3.65429
# fold 3
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.74601	valid_1's rmse: 3.76867
# [200]	training's rmse: 3.68191	valid_1's rmse: 3.72645
# [300]	training's rmse: 3.63816	valid_1's rmse: 3.70289
# [400]	training's rmse: 3.60534	valid_1's rmse: 3.68984
# [500]	training's rmse: 3.57904	valid_1's rmse: 3.68154
# [600]	training's rmse: 3.55686	valid_1's rmse: 3.67546
# [700]	training's rmse: 3.53808	valid_1's rmse: 3.67073
# [800]	training's rmse: 3.52135	valid_1's rmse: 3.66749
# [900]	training's rmse: 3.507	valid_1's rmse: 3.66441
# [1000]	training's rmse: 3.49431	valid_1's rmse: 3.66224
# [1100]	training's rmse: 3.4824	valid_1's rmse: 3.65992
# [1200]	training's rmse: 3.47126	valid_1's rmse: 3.65806
# [1300]	training's rmse: 3.46029	valid_1's rmse: 3.65646
# [1400]	training's rmse: 3.45013	valid_1's rmse: 3.6555
# [1500]	training's rmse: 3.44023	valid_1's rmse: 3.65415
# [1600]	training's rmse: 3.43048	valid_1's rmse: 3.65302
# [1700]	training's rmse: 3.42129	valid_1's rmse: 3.65242
# [1800]	training's rmse: 3.41259	valid_1's rmse: 3.65193
# [1900]	training's rmse: 3.40402	valid_1's rmse: 3.6518
# [2000]	training's rmse: 3.39609	valid_1's rmse: 3.65156
# [2100]	training's rmse: 3.38808	valid_1's rmse: 3.65128
# [2200]	training's rmse: 3.38042	valid_1's rmse: 3.65121
# [2300]	training's rmse: 3.37327	valid_1's rmse: 3.65124
# Early stopping, best iteration is:
# [2148]	training's rmse: 3.38433	valid_1's rmse: 3.65119
# fold 4
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.74749	valid_1's rmse: 3.75775
# [200]	training's rmse: 3.6826	valid_1's rmse: 3.7179
# [300]	training's rmse: 3.63828	valid_1's rmse: 3.69693
# [400]	training's rmse: 3.6044	valid_1's rmse: 3.68502
# [500]	training's rmse: 3.5778	valid_1's rmse: 3.67718
# [600]	training's rmse: 3.55581	valid_1's rmse: 3.67134
# [700]	training's rmse: 3.53707	valid_1's rmse: 3.66716
# [800]	training's rmse: 3.52118	valid_1's rmse: 3.66361
# [900]	training's rmse: 3.50652	valid_1's rmse: 3.66147
# [1000]	training's rmse: 3.49273	valid_1's rmse: 3.65974
# [1100]	training's rmse: 3.48024	valid_1's rmse: 3.65847
# [1200]	training's rmse: 3.46881	valid_1's rmse: 3.65759
# [1300]	training's rmse: 3.45832	valid_1's rmse: 3.65642
# [1400]	training's rmse: 3.44743	valid_1's rmse: 3.65572
# [1500]	training's rmse: 3.43701	valid_1's rmse: 3.65524
# [1600]	training's rmse: 3.4276	valid_1's rmse: 3.6549
# [1700]	training's rmse: 3.41893	valid_1's rmse: 3.65486
# [1800]	training's rmse: 3.40969	valid_1's rmse: 3.65446
# [1900]	training's rmse: 3.40129	valid_1's rmse: 3.65413
# [2000]	training's rmse: 3.39296	valid_1's rmse: 3.65382
# [2100]	training's rmse: 3.38492	valid_1's rmse: 3.65375
# [2200]	training's rmse: 3.37656	valid_1's rmse: 3.65377
# [2300]	training's rmse: 3.36881	valid_1's rmse: 3.65389
# [2400]	training's rmse: 3.36156	valid_1's rmse: 3.65376
# [2500]	training's rmse: 3.35407	valid_1's rmse: 3.65368
# [2600]	training's rmse: 3.34686	valid_1's rmse: 3.65372
# [2700]	training's rmse: 3.33948	valid_1's rmse: 3.65356
# [2800]	training's rmse: 3.33294	valid_1's rmse: 3.65338
# [2900]	training's rmse: 3.32624	valid_1's rmse: 3.65338
# [3000]	training's rmse: 3.31969	valid_1's rmse: 3.65333
# [3100]	training's rmse: 3.31316	valid_1's rmse: 3.65321
# [3200]	training's rmse: 3.30717	valid_1's rmse: 3.65348
# Early stopping, best iteration is:
# [3054]	training's rmse: 3.31627	valid_1's rmse: 3.65318
# 3.65239670535439

# %%
# score:  3.652508256832721

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
# plt.savefig('lgbm_importances.png')

# %%
# import optuna

# def objective(trial):
#     train_x, test_x, train_y, test_y = train_test_split(df_train[df_train_columns], target, test_size=0.25, random_state=4590)
#     dtrain = lgb.Dataset(train_x, label=train_y)

#     num_round = trial.suggest_int('num_round', 1, 1000)
#     param = {'objective': 'regression', 'metric': 'rmse', 'verbosity': -1, 'bagging_seed':11, 'random_state':4590,
#              'boosting_type': trial.suggest_categorical('boosting', ['gbdt']),
#              'num_leaves': trial.suggest_int('num_leaves', 10, 100),
#              'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1e-1),
#              'min_data_in_leaf': 30,
#              'min_child_samples': trial.suggest_loguniform('min_child_samples', 10, 1000),
#              'feature_fraction': trial.suggest_loguniform('feature_fraction', 0.8, 1.0),
#              'bagging_fraction': trial.suggest_loguniform('bagging_fraction', 0.8, 1.0),
#              }

#     gbm = lgb.train(param, dtrain, num_round)
#     preds = gbm.predict(test_x)
#     pred_labels = np.rint(preds)
#     rmse = np.sqrt(mean_squared_error(test_y, pred_labels))
#     return rmse

# study = optuna.create_study()
# study.optimize(objective, n_trials=20)

# print('Number of finished trials: {}'.format(len(study.trials)))

# print('Best trial:')
# trial = study.best_trial

# print('  Value: {}'.format(trial.value))

# print('  Params: ')
# for key, value in trial.params.items():
#     print('    {}: {}'.format(key, value))

# %%
sub_df = pd.DataFrame({"card_id":df_test["card_id"].values})
sub_df["target"] = predictions
sub_df.to_csv("./output/submission_model20181208.csv", index=False)
