# %%
import numpy as np
import pandas as pd
import datetime
import gc

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import lightgbm as lgb

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error, roc_auc_score
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')
np.random.seed(4590)

# %%
df_train = pd.read_csv('../input/train.csv')
df_test = pd.read_csv('../input/test.csv')
df_hist_trans = pd.read_csv('../input/historical_transactions.csv')
df_new_merchant_trans = pd.read_csv('../input/new_merchant_transactions.csv')

# %%
df_hist_trans['purchase_amount'] = np.exp(df_hist_trans['purchase_amount'])
df_new_merchant_trans['purchase_amount'] = np.exp(df_new_merchant_trans['purchase_amount'])

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['category_2'].fillna(1.0,inplace=True)
    df['category_3'].fillna('A',inplace=True)
    df['merchant_id'].fillna('M_ID_00a6ca8a8a',inplace=True)

# %%
def get_new_columns(name,aggs):
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    df['year'] = df['purchase_date'].dt.year
    df['weekofyear'] = df['purchase_date'].dt.weekofyear
    df['month'] = df['purchase_date'].dt.month
    df['dayofweek'] = df['purchase_date'].dt.dayofweek
    df['weekend'] = (df.purchase_date.dt.weekday >=5).astype(int)
    df['hour'] = df['purchase_date'].dt.hour
    df['authorized_flag'] = df['authorized_flag'].map({'Y':1, 'N':0})
    df['category_1'] = df['category_1'].map({'Y':1, 'N':0}) 
    #https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/73244
    df['month_diff'] = ((datetime.datetime.today() - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']

aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['authorized_flag'] = ['sum', 'mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_hist_trans[col+'_mean'] = df_hist_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']    

new_columns = get_new_columns('hist',aggs)
df_hist_trans_group = df_hist_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['hist_purchase_date_diff'] = (df_hist_trans_group['hist_purchase_date_max'] - df_hist_trans_group['hist_purchase_date_min']).dt.days
df_hist_trans_group['hist_purchase_date_average'] = df_hist_trans_group['hist_purchase_date_diff']/df_hist_trans_group['hist_card_id_size']
df_hist_trans_group['hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 175

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']
aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_new_merchant_trans[col+'_mean'] = df_new_merchant_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']
    
new_columns = get_new_columns('new_hist',aggs)
df_hist_trans_group = df_new_merchant_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['new_hist_purchase_date_diff'] = (df_hist_trans_group['new_hist_purchase_date_max'] - df_hist_trans_group['new_hist_purchase_date_min']).dt.days
df_hist_trans_group['new_hist_purchase_date_average'] = df_hist_trans_group['new_hist_purchase_date_diff']/df_hist_trans_group['new_hist_card_id_size']
df_hist_trans_group['new_hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['new_hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# 28

# %%
del df_hist_trans;gc.collect()
del df_new_merchant_trans;gc.collect()
df_train.head(5)
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
# 3            2017-09  C_ID_186d6a6901          4          3          0
# 4            2017-11  C_ID_cdbd2c0db2          1          3          0
#
#      target  hist_month_nunique  hist_hour_nunique  hist_weekofyear_nunique  \
# 0 -0.820283                   9                 23                       35
# 1  0.392913                  12                 24                       50
# 2  0.688056                  10                 14                       22
# 3  0.142495                   6                 16                       20
# 4 -0.159749                   4                 22                       17
#
#    hist_dayofweek_nunique               ...                \
# 0                       7               ...
# 1                       7               ...
# 2                       7               ...
# 3                       7               ...
# 4                       7               ...
#
#    new_hist_weekend_sum  new_hist_weekend_mean  new_hist_category_1_sum  \
# 0                   6.0               0.260870                      0.0
# 1                   0.0               0.000000                      0.0
# 2                   1.0               1.000000                      0.0
# 3                   3.0               0.428571                      1.0
# 4                  12.0               0.333333                      2.0
#
#    new_hist_category_1_mean  new_hist_card_id_size  \
# 0                  0.000000                   23.0
# 1                  0.000000                    6.0
# 2                  0.000000                    1.0
# 3                  0.142857                    7.0
# 4                  0.055556                   36.0
#
#    new_hist_category_2_mean_mean  new_hist_category_3_mean_mean  \
# 0                  1.658319e+108                   1.381361e+36
# 1                  1.658319e+108                   3.557623e+25
# 2                   7.789907e+26                   1.381361e+36
# 3                  2.369028e+107                   1.973373e+35
# 4                  1.842577e+107                  3.624714e+107
#
#    new_hist_purchase_date_diff  new_hist_purchase_date_average  \
# 0                         54.0                        2.347826
# 1                         56.0                        9.333333
# 2                          0.0                        0.000000
# 3                         41.0                        5.857143
# 4                         57.0                        1.583333
#
#    new_hist_purchase_date_uptonow
# 0                           246.0
# 1                           276.0
# 2                           247.0
# 3                           257.0
# 4                           247.0
#
# [5 rows x 78 columns]

# %%
df_train['outliers'] = 0
df_train.loc[df_train['target'] < -30, 'outliers'] = 1
df_train['outliers'].value_counts()
# Out:
# 0    199710
# 1      2207
# Name: outliers, dtype: int64

# %%
list_outlier_idx = df_train[df_train.outliers == 1].index.tolist()

# %%
for df in [df_train,df_test]:
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['dayofweek'] = df['first_active_month'].dt.dayofweek
    df['weekofyear'] = df['first_active_month'].dt.weekofyear
    df['month'] = df['first_active_month'].dt.month
    df['elapsed_time'] = (datetime.datetime.today() - df['first_active_month']).dt.days
    df['hist_first_buy'] = (df['hist_purchase_date_min'] - df['first_active_month']).dt.days
    df['new_hist_first_buy'] = (df['new_hist_purchase_date_min'] - df['first_active_month']).dt.days
    for f in ['hist_purchase_date_max','hist_purchase_date_min','new_hist_purchase_date_max',\
                     'new_hist_purchase_date_min']:
        df[f] = df[f].astype(np.int64) * 1e-9
    df['card_id_total'] = df['new_hist_card_id_size']+df['hist_card_id_size']
    df['purchase_amount_total'] = df['new_hist_purchase_amount_sum']+df['hist_purchase_amount_sum']

for f in ['feature_1','feature_2','feature_3']:
    order_label = df_train.groupby([f])['outliers'].mean()
    df_train[f] = df_train[f].map(order_label)
    df_test[f] = df_test[f].map(order_label)

# %%
high_importance_features = [
    "hist_month_diff_mean", 
    "hist_authorized_flag_mean", 
    "hist_category_1_sum", 
    "hist_month_lag_mean", 
    "new_hist_purchase_amount_sum", 
    "new_hist_purchase_date_uptonow"
]

#smoothing
for col in high_importance_features:
    df_train[col] = np.where(df_train[col].values==0, 0.001, df_train[col].values)
    df_test[col] = np.where(df_test[col].values==0, 0.001, df_test[col].values)


for i in range(len(high_importance_features)):
    for j in range(len((high_importance_features)))[i+1:]:
        col1 = high_importance_features[i]
        col2 = high_importance_features[j]
        new_col_name = "{c1}__div__{c2}".format(c1=col1, c2=col2)
        
        df_train[new_col_name] = df_train[col1] / df_train[col2]
        df_test[new_col_name] = df_test[col1] / df_test[col2]

# %%
def merge_new_feature(path):
    df_new_feature = pd.read_csv(path)
    
    df_tr = pd.merge(df_train, df_new_feature, on="card_id", how="left")
    df_te = pd.merge(df_test, df_new_feature, on="card_id", how="left")
    
    return df_tr, df_te

# %%
df_train, df_test = merge_new_feature("../input/merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/new_merchants_nmf.csv")
df_train, df_test = merge_new_feature("../input/prosperity_merchants_latest.csv")
df_train, df_test = merge_new_feature("../input/merchants_numerical_features.csv")
df_train, df_test = merge_new_feature("../input/merchants_item_scale_feature.csv")
df_train, df_test = merge_new_feature("../input/purchase_pattern.csv")
df_train, df_test = merge_new_feature("../input/purchase_pettern_nmf.csv")
df_train, df_test = merge_new_feature("../input/purchase_amount_pettern_nmf.csv")
df_train, df_test = merge_new_feature("../input/feature_latest_transaction_data__per__card_id.csv")
df_train, df_test = merge_new_feature("../input/feature_term_from_second_latest_to_latest.csv")
df_train, df_test = merge_new_feature("../input/feature_purchase_amount_mean_max_increase.csv")
df_train, df_test = merge_new_feature("../input/feature_frequency_mean_increase_rate.csv")

# %%
df_train["Null_count"] = df_train.isnull().sum(axis=1)
df_test["Null_count"] = df_test.isnull().sum(axis=1)

# %%
df_train_columns = [c for c in df_train.columns if c not in ['card_id', 'first_active_month','second_active_date','diff_first_and_second','target','outliers']]
target = df_train['target']
target_outlier = df_train["outliers"]

# %%
#original
param = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',
    'max_depth': -1,
    "max_bin": 256,  # なし
    'learning_rate': 0.004,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.73864	valid_1's rmse: 3.77446
# [200]	training's rmse: 3.67011	valid_1's rmse: 3.73171
# [300]	training's rmse: 3.62206	valid_1's rmse: 3.70761
# [400]	training's rmse: 3.5852	valid_1's rmse: 3.69332
# [500]	training's rmse: 3.55601	valid_1's rmse: 3.68403
# [600]	training's rmse: 3.53163	valid_1's rmse: 3.67675
# [700]	training's rmse: 3.51137	valid_1's rmse: 3.67184
# [800]	training's rmse: 3.4927	valid_1's rmse: 3.668
# [900]	training's rmse: 3.4757	valid_1's rmse: 3.66486
# [1000]	training's rmse: 3.46051	valid_1's rmse: 3.66217
# [1100]	training's rmse: 3.44589	valid_1's rmse: 3.65976
# [1200]	training's rmse: 3.43227	valid_1's rmse: 3.6579
# [1300]	training's rmse: 3.41948	valid_1's rmse: 3.65625
# [1400]	training's rmse: 3.40685	valid_1's rmse: 3.65448
# [1500]	training's rmse: 3.3951	valid_1's rmse: 3.65286
# [1600]	training's rmse: 3.38378	valid_1's rmse: 3.65178
# [1700]	training's rmse: 3.37313	valid_1's rmse: 3.65095
# [1800]	training's rmse: 3.36285	valid_1's rmse: 3.64998
# [1900]	training's rmse: 3.35301	valid_1's rmse: 3.64948
# [2000]	training's rmse: 3.34404	valid_1's rmse: 3.6486
# [2100]	training's rmse: 3.33459	valid_1's rmse: 3.64803
# [2200]	training's rmse: 3.32525	valid_1's rmse: 3.64757
# [2300]	training's rmse: 3.31651	valid_1's rmse: 3.64721
# [2400]	training's rmse: 3.30795	valid_1's rmse: 3.6469
# [2500]	training's rmse: 3.29938	valid_1's rmse: 3.64658
# [2600]	training's rmse: 3.29156	valid_1's rmse: 3.64623
# [2700]	training's rmse: 3.2835	valid_1's rmse: 3.64592
# [2800]	training's rmse: 3.27583	valid_1's rmse: 3.64588
# [2900]	training's rmse: 3.26822	valid_1's rmse: 3.64548
# [3000]	training's rmse: 3.26046	valid_1's rmse: 3.64513
# [3100]	training's rmse: 3.25274	valid_1's rmse: 3.64509
# [3200]	training's rmse: 3.2449	valid_1's rmse: 3.64487
# [3300]	training's rmse: 3.23757	valid_1's rmse: 3.64463
# [3400]	training's rmse: 3.23055	valid_1's rmse: 3.64446
# [3500]	training's rmse: 3.22335	valid_1's rmse: 3.64436
# [3600]	training's rmse: 3.2168	valid_1's rmse: 3.64438
# [3700]	training's rmse: 3.21009	valid_1's rmse: 3.64429
# [3800]	training's rmse: 3.20374	valid_1's rmse: 3.64419
# [3900]	training's rmse: 3.19723	valid_1's rmse: 3.64385
# [4000]	training's rmse: 3.19106	valid_1's rmse: 3.64368
# [4100]	training's rmse: 3.18462	valid_1's rmse: 3.64355
# [4200]	training's rmse: 3.17858	valid_1's rmse: 3.64357
# [4300]	training's rmse: 3.17156	valid_1's rmse: 3.64361
# [4400]	training's rmse: 3.16575	valid_1's rmse: 3.64358
# Early stopping, best iteration is:
# [4095]	training's rmse: 3.18492	valid_1's rmse: 3.6435
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.7425	valid_1's rmse: 3.75969
# [200]	training's rmse: 3.67294	valid_1's rmse: 3.71489
# [300]	training's rmse: 3.62367	valid_1's rmse: 3.68953
# [400]	training's rmse: 3.58663	valid_1's rmse: 3.67433
# [500]	training's rmse: 3.55703	valid_1's rmse: 3.66442
# [600]	training's rmse: 3.5327	valid_1's rmse: 3.6582
# [700]	training's rmse: 3.51202	valid_1's rmse: 3.6533
# [800]	training's rmse: 3.49293	valid_1's rmse: 3.6492
# [900]	training's rmse: 3.47613	valid_1's rmse: 3.64579
# [1000]	training's rmse: 3.46087	valid_1's rmse: 3.64345
# [1100]	training's rmse: 3.44642	valid_1's rmse: 3.64146
# [1200]	training's rmse: 3.43332	valid_1's rmse: 3.64033
# [1300]	training's rmse: 3.4202	valid_1's rmse: 3.63927
# [1400]	training's rmse: 3.40774	valid_1's rmse: 3.63832
# [1500]	training's rmse: 3.39597	valid_1's rmse: 3.63744
# [1600]	training's rmse: 3.3845	valid_1's rmse: 3.63672
# [1700]	training's rmse: 3.37312	valid_1's rmse: 3.63649
# [1800]	training's rmse: 3.36287	valid_1's rmse: 3.63593
# [1900]	training's rmse: 3.35273	valid_1's rmse: 3.63551
# [2000]	training's rmse: 3.34293	valid_1's rmse: 3.63545
# [2100]	training's rmse: 3.33348	valid_1's rmse: 3.63544
# [2200]	training's rmse: 3.3244	valid_1's rmse: 3.63536
# [2300]	training's rmse: 3.31532	valid_1's rmse: 3.63516
# [2400]	training's rmse: 3.30652	valid_1's rmse: 3.6351
# [2500]	training's rmse: 3.29797	valid_1's rmse: 3.63498
# [2600]	training's rmse: 3.28928	valid_1's rmse: 3.63504
# [2700]	training's rmse: 3.28118	valid_1's rmse: 3.63501
# [2800]	training's rmse: 3.2734	valid_1's rmse: 3.63501
# [2900]	training's rmse: 3.26537	valid_1's rmse: 3.63511
# Early stopping, best iteration is:
# [2571]	training's rmse: 3.29151	valid_1's rmse: 3.6349
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.74416	valid_1's rmse: 3.75856
# [200]	training's rmse: 3.6765	valid_1's rmse: 3.7102
# [300]	training's rmse: 3.62835	valid_1's rmse: 3.68247
# [400]	training's rmse: 3.59191	valid_1's rmse: 3.66617
# [500]	training's rmse: 3.56272	valid_1's rmse: 3.65498
# [600]	training's rmse: 3.53781	valid_1's rmse: 3.64766
# [700]	training's rmse: 3.51704	valid_1's rmse: 3.6425
# [800]	training's rmse: 3.49787	valid_1's rmse: 3.63782
# [900]	training's rmse: 3.48108	valid_1's rmse: 3.63392
# [1000]	training's rmse: 3.46548	valid_1's rmse: 3.63098
# [1100]	training's rmse: 3.45127	valid_1's rmse: 3.62844
# [1200]	training's rmse: 3.43747	valid_1's rmse: 3.62623
# [1300]	training's rmse: 3.4248	valid_1's rmse: 3.62455
# [1400]	training's rmse: 3.41239	valid_1's rmse: 3.62292
# [1500]	training's rmse: 3.40114	valid_1's rmse: 3.62133
# [1600]	training's rmse: 3.3899	valid_1's rmse: 3.62034
# [1700]	training's rmse: 3.37885	valid_1's rmse: 3.61966
# [1800]	training's rmse: 3.368	valid_1's rmse: 3.61897
# [1900]	training's rmse: 3.35835	valid_1's rmse: 3.61817
# [2000]	training's rmse: 3.34875	valid_1's rmse: 3.61741
# [2100]	training's rmse: 3.33961	valid_1's rmse: 3.6169
# [2200]	training's rmse: 3.33053	valid_1's rmse: 3.61634
# [2300]	training's rmse: 3.32188	valid_1's rmse: 3.61602
# [2400]	training's rmse: 3.31311	valid_1's rmse: 3.61576
# [2500]	training's rmse: 3.30469	valid_1's rmse: 3.61554
# [2600]	training's rmse: 3.29652	valid_1's rmse: 3.61534
# [2700]	training's rmse: 3.28854	valid_1's rmse: 3.61517
# [2800]	training's rmse: 3.28082	valid_1's rmse: 3.61487
# [2900]	training's rmse: 3.27343	valid_1's rmse: 3.61481
# [3000]	training's rmse: 3.26568	valid_1's rmse: 3.61489
# [3100]	training's rmse: 3.25784	valid_1's rmse: 3.61493
# [3200]	training's rmse: 3.25008	valid_1's rmse: 3.61504
# [3300]	training's rmse: 3.24263	valid_1's rmse: 3.61506
# [3400]	training's rmse: 3.235	valid_1's rmse: 3.61513
# Early stopping, best iteration is:
# [3049]	training's rmse: 3.26172	valid_1's rmse: 3.61479
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.73889	valid_1's rmse: 3.76938
# [200]	training's rmse: 3.6676	valid_1's rmse: 3.72872
# [300]	training's rmse: 3.6174	valid_1's rmse: 3.70775
# [400]	training's rmse: 3.57906	valid_1's rmse: 3.69544
# [500]	training's rmse: 3.54949	valid_1's rmse: 3.68783
# [600]	training's rmse: 3.52446	valid_1's rmse: 3.68309
# [700]	training's rmse: 3.50336	valid_1's rmse: 3.67947
# [800]	training's rmse: 3.48383	valid_1's rmse: 3.67704
# [900]	training's rmse: 3.46659	valid_1's rmse: 3.67512
# [1000]	training's rmse: 3.45048	valid_1's rmse: 3.67357
# [1100]	training's rmse: 3.4353	valid_1's rmse: 3.67295
# [1200]	training's rmse: 3.42119	valid_1's rmse: 3.67218
# [1300]	training's rmse: 3.40843	valid_1's rmse: 3.6714
# [1400]	training's rmse: 3.39588	valid_1's rmse: 3.67068
# [1500]	training's rmse: 3.38389	valid_1's rmse: 3.67021
# [1600]	training's rmse: 3.37259	valid_1's rmse: 3.66988
# [1700]	training's rmse: 3.36171	valid_1's rmse: 3.66942
# [1800]	training's rmse: 3.35127	valid_1's rmse: 3.66915
# [1900]	training's rmse: 3.34101	valid_1's rmse: 3.66896
# [2000]	training's rmse: 3.33099	valid_1's rmse: 3.66893
# [2100]	training's rmse: 3.3215	valid_1's rmse: 3.66876
# [2200]	training's rmse: 3.3124	valid_1's rmse: 3.66837
# [2300]	training's rmse: 3.30363	valid_1's rmse: 3.66813
# [2400]	training's rmse: 3.29491	valid_1's rmse: 3.66784
# [2500]	training's rmse: 3.28629	valid_1's rmse: 3.66773
# [2600]	training's rmse: 3.2779	valid_1's rmse: 3.66763
# [2700]	training's rmse: 3.26975	valid_1's rmse: 3.66765
# [2800]	training's rmse: 3.26186	valid_1's rmse: 3.66762
# [2900]	training's rmse: 3.25443	valid_1's rmse: 3.66752
# [3000]	training's rmse: 3.24673	valid_1's rmse: 3.66737
# [3100]	training's rmse: 3.23886	valid_1's rmse: 3.66754
# [3200]	training's rmse: 3.23168	valid_1's rmse: 3.66754
# [3300]	training's rmse: 3.2245	valid_1's rmse: 3.66769
# Early stopping, best iteration is:
# [2995]	training's rmse: 3.24718	valid_1's rmse: 3.66734
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 3.73792	valid_1's rmse: 3.7783
# [200]	training's rmse: 3.66778	valid_1's rmse: 3.73641
# [300]	training's rmse: 3.61802	valid_1's rmse: 3.71382
# [400]	training's rmse: 3.58057	valid_1's rmse: 3.70162
# [500]	training's rmse: 3.55043	valid_1's rmse: 3.6932
# [600]	training's rmse: 3.52562	valid_1's rmse: 3.68708
# [700]	training's rmse: 3.50392	valid_1's rmse: 3.68316
# [800]	training's rmse: 3.48483	valid_1's rmse: 3.68005
# [900]	training's rmse: 3.46784	valid_1's rmse: 3.6775
# [1000]	training's rmse: 3.45186	valid_1's rmse: 3.67574
# [1100]	training's rmse: 3.4376	valid_1's rmse: 3.67428
# [1200]	training's rmse: 3.42364	valid_1's rmse: 3.67303
# [1300]	training's rmse: 3.41068	valid_1's rmse: 3.67173
# [1400]	training's rmse: 3.39824	valid_1's rmse: 3.67082
# [1500]	training's rmse: 3.38663	valid_1's rmse: 3.6701
# [1600]	training's rmse: 3.37569	valid_1's rmse: 3.66933
# [1700]	training's rmse: 3.36512	valid_1's rmse: 3.66883
# [1800]	training's rmse: 3.355	valid_1's rmse: 3.66837
# [1900]	training's rmse: 3.34509	valid_1's rmse: 3.66788
# [2000]	training's rmse: 3.33533	valid_1's rmse: 3.66746
# [2100]	training's rmse: 3.3258	valid_1's rmse: 3.6669
# [2200]	training's rmse: 3.31669	valid_1's rmse: 3.66671
# [2300]	training's rmse: 3.3079	valid_1's rmse: 3.66655
# [2400]	training's rmse: 3.29916	valid_1's rmse: 3.66645
# [2500]	training's rmse: 3.29066	valid_1's rmse: 3.66626
# [2600]	training's rmse: 3.28197	valid_1's rmse: 3.66604
# [2700]	training's rmse: 3.27383	valid_1's rmse: 3.66582
# [2800]	training's rmse: 3.26621	valid_1's rmse: 3.6658
# [2900]	training's rmse: 3.25836	valid_1's rmse: 3.66578
# [3000]	training's rmse: 3.25082	valid_1's rmse: 3.66566
# [3100]	training's rmse: 3.24338	valid_1's rmse: 3.66571
# [3200]	training's rmse: 3.2364	valid_1's rmse: 3.66566
# [3300]	training's rmse: 3.22939	valid_1's rmse: 3.66568
# Early stopping, best iteration is:
# [2976]	training's rmse: 3.25259	valid_1's rmse: 3.66557
# 3.645274184394355

# %%
# score:  3.6467757129353053

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,50))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
# plt.savefig('lgbm_importances.png')

# %%
df_train2 = df_train[df_train.target > -30].reset_index(drop=True)
target2 = df_train2["target"]

#original
param2 = {
    'num_leaves': 31,  # 31
    'min_data_in_leaf': 30,
    'objective':'regression',
    'max_depth': -1,
    'learning_rate': 0.01,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1,
    "verbosity": -1,
    "nthread": 4,
    "random_state": 1000 #4590
}


folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1000) #4590
oof = np.zeros(len(df_train2))
predictions2 = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train2,df_train2['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train2.iloc[trn_idx][df_train_columns], label=target2.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train2.iloc[val_idx][df_train_columns], label=target2.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param2, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(df_train2.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions2 += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target2))
# Out:
# fold 0
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60677	valid_1's rmse: 1.6066
# [200]	training's rmse: 1.57457	valid_1's rmse: 1.57775
# [300]	training's rmse: 1.55888	valid_1's rmse: 1.56662
# [400]	training's rmse: 1.54817	valid_1's rmse: 1.56095
# [500]	training's rmse: 1.53965	valid_1's rmse: 1.55768
# [600]	training's rmse: 1.53221	valid_1's rmse: 1.55539
# [700]	training's rmse: 1.52578	valid_1's rmse: 1.55399
# [800]	training's rmse: 1.51981	valid_1's rmse: 1.55307
# [900]	training's rmse: 1.51445	valid_1's rmse: 1.55257
# [1000]	training's rmse: 1.5094	valid_1's rmse: 1.55212
# [1100]	training's rmse: 1.50454	valid_1's rmse: 1.55173
# [1200]	training's rmse: 1.49981	valid_1's rmse: 1.55149
# [1300]	training's rmse: 1.49528	valid_1's rmse: 1.55128
# [1400]	training's rmse: 1.49084	valid_1's rmse: 1.55112
# [1500]	training's rmse: 1.48655	valid_1's rmse: 1.55095
# [1600]	training's rmse: 1.48233	valid_1's rmse: 1.55076
# [1700]	training's rmse: 1.47809	valid_1's rmse: 1.55068
# [1800]	training's rmse: 1.47392	valid_1's rmse: 1.55055
# [1900]	training's rmse: 1.46989	valid_1's rmse: 1.55038
# [2000]	training's rmse: 1.46586	valid_1's rmse: 1.55036
# [2100]	training's rmse: 1.46194	valid_1's rmse: 1.55018
# [2200]	training's rmse: 1.45801	valid_1's rmse: 1.5501
# [2300]	training's rmse: 1.45428	valid_1's rmse: 1.55012
# [2400]	training's rmse: 1.45037	valid_1's rmse: 1.55014
# [2500]	training's rmse: 1.44649	valid_1's rmse: 1.55009
# [2600]	training's rmse: 1.44261	valid_1's rmse: 1.5501
# [2700]	training's rmse: 1.43893	valid_1's rmse: 1.55011
# [2800]	training's rmse: 1.43527	valid_1's rmse: 1.55009
# [2900]	training's rmse: 1.43163	valid_1's rmse: 1.55001
# [3000]	training's rmse: 1.42795	valid_1's rmse: 1.55004
# [3100]	training's rmse: 1.42438	valid_1's rmse: 1.5501
# [3200]	training's rmse: 1.42079	valid_1's rmse: 1.55006
# [3300]	training's rmse: 1.41738	valid_1's rmse: 1.55007
# Early stopping, best iteration is:
# [2928]	training's rmse: 1.4306	valid_1's rmse: 1.54996
# fold 1
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60921	valid_1's rmse: 1.59321
# [200]	training's rmse: 1.57673	valid_1's rmse: 1.56738
# [300]	training's rmse: 1.56099	valid_1's rmse: 1.55762
# [400]	training's rmse: 1.55037	valid_1's rmse: 1.55232
# [500]	training's rmse: 1.54193	valid_1's rmse: 1.54909
# [600]	training's rmse: 1.53463	valid_1's rmse: 1.54686
# [700]	training's rmse: 1.52817	valid_1's rmse: 1.54555
# [800]	training's rmse: 1.52235	valid_1's rmse: 1.54483
# [900]	training's rmse: 1.51692	valid_1's rmse: 1.54414
# [1000]	training's rmse: 1.51176	valid_1's rmse: 1.54363
# [1100]	training's rmse: 1.50691	valid_1's rmse: 1.54335
# [1200]	training's rmse: 1.50222	valid_1's rmse: 1.54308
# [1300]	training's rmse: 1.49763	valid_1's rmse: 1.54291
# [1400]	training's rmse: 1.49302	valid_1's rmse: 1.54258
# [1500]	training's rmse: 1.48884	valid_1's rmse: 1.54238
# [1600]	training's rmse: 1.4845	valid_1's rmse: 1.5422
# [1700]	training's rmse: 1.48027	valid_1's rmse: 1.54203
# [1800]	training's rmse: 1.47593	valid_1's rmse: 1.5419
# [1900]	training's rmse: 1.47187	valid_1's rmse: 1.5418
# [2000]	training's rmse: 1.46792	valid_1's rmse: 1.54168
# [2100]	training's rmse: 1.46385	valid_1's rmse: 1.5415
# [2200]	training's rmse: 1.45996	valid_1's rmse: 1.54145
# [2300]	training's rmse: 1.45591	valid_1's rmse: 1.54141
# [2400]	training's rmse: 1.45206	valid_1's rmse: 1.54135
# [2500]	training's rmse: 1.44829	valid_1's rmse: 1.54133
# [2600]	training's rmse: 1.44457	valid_1's rmse: 1.54133
# [2700]	training's rmse: 1.44083	valid_1's rmse: 1.54141
# [2800]	training's rmse: 1.43718	valid_1's rmse: 1.54143
# Early stopping, best iteration is:
# [2488]	training's rmse: 1.44875	valid_1's rmse: 1.54131
# fold 2
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60534	valid_1's rmse: 1.61151
# [200]	training's rmse: 1.57333	valid_1's rmse: 1.58411
# [300]	training's rmse: 1.55768	valid_1's rmse: 1.57339
# [400]	training's rmse: 1.54709	valid_1's rmse: 1.56763
# [500]	training's rmse: 1.53865	valid_1's rmse: 1.56432
# [600]	training's rmse: 1.53137	valid_1's rmse: 1.56209
# [700]	training's rmse: 1.52496	valid_1's rmse: 1.56071
# [800]	training's rmse: 1.51911	valid_1's rmse: 1.55961
# [900]	training's rmse: 1.51366	valid_1's rmse: 1.55888
# [1000]	training's rmse: 1.50851	valid_1's rmse: 1.55844
# [1100]	training's rmse: 1.50353	valid_1's rmse: 1.55802
# [1200]	training's rmse: 1.49877	valid_1's rmse: 1.55766
# [1300]	training's rmse: 1.49415	valid_1's rmse: 1.55745
# [1400]	training's rmse: 1.48972	valid_1's rmse: 1.55732
# [1500]	training's rmse: 1.4853	valid_1's rmse: 1.55711
# [1600]	training's rmse: 1.48103	valid_1's rmse: 1.55703
# [1700]	training's rmse: 1.47675	valid_1's rmse: 1.55689
# [1800]	training's rmse: 1.47259	valid_1's rmse: 1.55674
# [1900]	training's rmse: 1.46844	valid_1's rmse: 1.55659
# [2000]	training's rmse: 1.46449	valid_1's rmse: 1.55651
# [2100]	training's rmse: 1.46047	valid_1's rmse: 1.55643
# [2200]	training's rmse: 1.45664	valid_1's rmse: 1.55632
# [2300]	training's rmse: 1.45263	valid_1's rmse: 1.55621
# [2400]	training's rmse: 1.44864	valid_1's rmse: 1.5561
# [2500]	training's rmse: 1.44476	valid_1's rmse: 1.55611
# [2600]	training's rmse: 1.44108	valid_1's rmse: 1.55601
# [2700]	training's rmse: 1.43751	valid_1's rmse: 1.55599
# [2800]	training's rmse: 1.43373	valid_1's rmse: 1.55599
# [2900]	training's rmse: 1.43009	valid_1's rmse: 1.556
# [3000]	training's rmse: 1.42639	valid_1's rmse: 1.55613
# [3100]	training's rmse: 1.42262	valid_1's rmse: 1.55604
# Early stopping, best iteration is:
# [2713]	training's rmse: 1.43696	valid_1's rmse: 1.55594
# fold 3
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60567	valid_1's rmse: 1.60977
# [200]	training's rmse: 1.57361	valid_1's rmse: 1.58297
# [300]	training's rmse: 1.55801	valid_1's rmse: 1.57249
# [400]	training's rmse: 1.54739	valid_1's rmse: 1.56691
# [500]	training's rmse: 1.53892	valid_1's rmse: 1.56351
# [600]	training's rmse: 1.53156	valid_1's rmse: 1.56109
# [700]	training's rmse: 1.52518	valid_1's rmse: 1.55958
# [800]	training's rmse: 1.5194	valid_1's rmse: 1.55865
# [900]	training's rmse: 1.51405	valid_1's rmse: 1.55797
# [1000]	training's rmse: 1.50885	valid_1's rmse: 1.55747
# [1100]	training's rmse: 1.50384	valid_1's rmse: 1.55705
# [1200]	training's rmse: 1.49899	valid_1's rmse: 1.55673
# [1300]	training's rmse: 1.49443	valid_1's rmse: 1.55647
# [1400]	training's rmse: 1.48985	valid_1's rmse: 1.55609
# [1500]	training's rmse: 1.48538	valid_1's rmse: 1.55591
# [1600]	training's rmse: 1.48101	valid_1's rmse: 1.55582
# [1700]	training's rmse: 1.47679	valid_1's rmse: 1.55567
# [1800]	training's rmse: 1.47267	valid_1's rmse: 1.55549
# [1900]	training's rmse: 1.46853	valid_1's rmse: 1.55552
# [2000]	training's rmse: 1.4645	valid_1's rmse: 1.55545
# [2100]	training's rmse: 1.46041	valid_1's rmse: 1.55527
# [2200]	training's rmse: 1.45644	valid_1's rmse: 1.55521
# [2300]	training's rmse: 1.45257	valid_1's rmse: 1.5552
# [2400]	training's rmse: 1.44867	valid_1's rmse: 1.55525
# [2500]	training's rmse: 1.44487	valid_1's rmse: 1.55526
# [2600]	training's rmse: 1.44112	valid_1's rmse: 1.55532
# [2700]	training's rmse: 1.43738	valid_1's rmse: 1.55527
# Early stopping, best iteration is:
# [2313]	training's rmse: 1.45203	valid_1's rmse: 1.55517
# fold 4
# Training until validation scores don't improve for 400 rounds.
# [100]	training's rmse: 1.60081	valid_1's rmse: 1.63094
# [200]	training's rmse: 1.56864	valid_1's rmse: 1.60365
# [300]	training's rmse: 1.55315	valid_1's rmse: 1.59286
# [400]	training's rmse: 1.54247	valid_1's rmse: 1.58735
# [500]	training's rmse: 1.53399	valid_1's rmse: 1.5839
# [600]	training's rmse: 1.52662	valid_1's rmse: 1.58173
# [700]	training's rmse: 1.52019	valid_1's rmse: 1.58042
# [800]	training's rmse: 1.51444	valid_1's rmse: 1.5796
# [900]	training's rmse: 1.50902	valid_1's rmse: 1.57902
# [1000]	training's rmse: 1.50402	valid_1's rmse: 1.5786
# [1100]	training's rmse: 1.49913	valid_1's rmse: 1.57819
# [1200]	training's rmse: 1.49439	valid_1's rmse: 1.57797
# [1300]	training's rmse: 1.48983	valid_1's rmse: 1.57781
# [1400]	training's rmse: 1.48539	valid_1's rmse: 1.57766
# [1500]	training's rmse: 1.48107	valid_1's rmse: 1.57752
# [1600]	training's rmse: 1.47689	valid_1's rmse: 1.57734
# [1700]	training's rmse: 1.47277	valid_1's rmse: 1.57716
# [1800]	training's rmse: 1.46859	valid_1's rmse: 1.57705
# [1900]	training's rmse: 1.46449	valid_1's rmse: 1.57703
# [2000]	training's rmse: 1.46052	valid_1's rmse: 1.57702
# [2100]	training's rmse: 1.45663	valid_1's rmse: 1.57699
# [2200]	training's rmse: 1.45263	valid_1's rmse: 1.57697
# [2300]	training's rmse: 1.44866	valid_1's rmse: 1.57681
# [2400]	training's rmse: 1.44494	valid_1's rmse: 1.57682
# [2500]	training's rmse: 1.44101	valid_1's rmse: 1.57688
# [2600]	training's rmse: 1.43722	valid_1's rmse: 1.57682
# [2700]	training's rmse: 1.43355	valid_1's rmse: 1.57679
# [2800]	training's rmse: 1.42995	valid_1's rmse: 1.57674
# [2900]	training's rmse: 1.4264	valid_1's rmse: 1.57673
# [3000]	training's rmse: 1.42263	valid_1's rmse: 1.5767
# [3100]	training's rmse: 1.419	valid_1's rmse: 1.57671
# [3200]	training's rmse: 1.41543	valid_1's rmse: 1.57668
# [3300]	training's rmse: 1.41185	valid_1's rmse: 1.57663
# [3400]	training's rmse: 1.40836	valid_1's rmse: 1.57668
# [3500]	training's rmse: 1.40491	valid_1's rmse: 1.57674
# [3600]	training's rmse: 1.40134	valid_1's rmse: 1.57676
# Early stopping, best iteration is:
# [3299]	training's rmse: 1.4119	valid_1's rmse: 1.57662
# 1.5558435220107991

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,50))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
# plt.savefig('lgbm_importances.png')

# %%
df_prediction = pd.DataFrame({"prediction1":predictions, "prediction2":predictions2})
df_prediction
# Out:
#         prediction1  prediction2
# 0         -1.949786    -0.432420
# 1         -0.218026    -0.271613
# 2         -1.440994    -0.620069
# 3         -0.014673    -0.044073
# 4         -1.470941    -1.522645
# 5          0.180210     0.551373
# 6          0.121752     0.162428
# 7          0.581048     0.795238
# 8         -0.518957    -0.524482
# 9         -0.957859    -0.145012
# 10        -0.612002    -0.499770
# 11         0.022102     0.228069
# 12         0.035331     0.086088
# 13         0.081493     0.217884
# 14        -6.236427    -0.328479
# 15         0.570932     0.641636
# 16         0.205531     0.467645
# 17        -0.320482    -0.180308
# 18         0.125914     0.197507
# 19         0.024911    -0.223728
# 20         0.165133     0.287240
# 21        -0.653953    -0.732421
# 22         0.064232     1.336051
# 23         0.259652     0.282380
# 24        -0.720833     0.079660
# 25        -0.341281     0.364370
# 26        -0.575631    -0.713291
# 27        -0.466945    -0.411725
# 28        -0.224496    -0.142115
# 29        -0.381722    -0.495550
# ...             ...          ...
# 123593    -0.353557    -0.349565
# 123594    -1.125640    -1.197009
# 123595    -0.011610    -0.017086
# 123596     0.676648     1.228737
# 123597    -0.628723    -0.445517
# 123598    -0.536105    -0.493787
# 123599     0.545200     0.494821
# 123600    -0.843765    -0.148289
# 123601    -0.919865    -1.314069
# 123602    -0.341770    -0.196546
# 123603    -0.091656    -0.022268
# 123604     0.222163     0.562407
# 123605    -0.464326    -0.409251
# 123606    -0.591141    -0.462911
# 123607     0.612177     0.557933
# 123608    -0.365837    -0.405618
# 123609     0.187024    -0.082048
# 123610     0.169724     0.610025
# 123611    -1.277167    -0.833651
# 123612    -0.568781    -0.665240
# 123613     0.120650     0.103037
# 123614     0.428194     0.837233
# 123615    -0.945774    -0.739478
# 123616     0.969598     1.491844
# 123617     0.426548     0.604286
# 123618     0.893057     1.348708
# 123619    -0.481302    -0.535205
# 123620     0.858052     1.167490
# 123621    -3.332587    -0.988421
# 123622    -0.033781     0.041315
#
# [123623 rows x 2 columns]

# %%
predictions3 = np.zeros(df_prediction.shape[0])
for i, r in df_prediction.iterrows():
    if r[0] < 0 :
        predictions3[i] = r[0]
    else:
        predictions3[i] = r[1]
df_prediction["prediction3"] = predictions3

# %%
df_prediction
# Out:
#         prediction1  prediction2  prediction3
# 0         -1.949786    -0.432420    -1.949786
# 1         -0.218026    -0.271613    -0.218026
# 2         -1.440994    -0.620069    -1.440994
# 3         -0.014673    -0.044073    -0.014673
# 4         -1.470941    -1.522645    -1.470941
# 5          0.180210     0.551373     0.551373
# 6          0.121752     0.162428     0.162428
# 7          0.581048     0.795238     0.795238
# 8         -0.518957    -0.524482    -0.518957
# 9         -0.957859    -0.145012    -0.957859
# 10        -0.612002    -0.499770    -0.612002
# 11         0.022102     0.228069     0.228069
# 12         0.035331     0.086088     0.086088
# 13         0.081493     0.217884     0.217884
# 14        -6.236427    -0.328479    -6.236427
# 15         0.570932     0.641636     0.641636
# 16         0.205531     0.467645     0.467645
# 17        -0.320482    -0.180308    -0.320482
# 18         0.125914     0.197507     0.197507
# 19         0.024911    -0.223728    -0.223728
# 20         0.165133     0.287240     0.287240
# 21        -0.653953    -0.732421    -0.653953
# 22         0.064232     1.336051     1.336051
# 23         0.259652     0.282380     0.282380
# 24        -0.720833     0.079660    -0.720833
# 25        -0.341281     0.364370    -0.341281
# 26        -0.575631    -0.713291    -0.575631
# 27        -0.466945    -0.411725    -0.466945
# 28        -0.224496    -0.142115    -0.224496
# 29        -0.381722    -0.495550    -0.381722
# ...             ...          ...          ...
# 123593    -0.353557    -0.349565    -0.353557
# 123594    -1.125640    -1.197009    -1.125640
# 123595    -0.011610    -0.017086    -0.011610
# 123596     0.676648     1.228737     1.228737
# 123597    -0.628723    -0.445517    -0.628723
# 123598    -0.536105    -0.493787    -0.536105
# 123599     0.545200     0.494821     0.494821
# 123600    -0.843765    -0.148289    -0.843765
# 123601    -0.919865    -1.314069    -0.919865
# 123602    -0.341770    -0.196546    -0.341770
# 123603    -0.091656    -0.022268    -0.091656
# 123604     0.222163     0.562407     0.562407
# 123605    -0.464326    -0.409251    -0.464326
# 123606    -0.591141    -0.462911    -0.591141
# 123607     0.612177     0.557933     0.557933
# 123608    -0.365837    -0.405618    -0.365837
# 123609     0.187024    -0.082048    -0.082048
# 123610     0.169724     0.610025     0.610025
# 123611    -1.277167    -0.833651    -1.277167
# 123612    -0.568781    -0.665240    -0.568781
# 123613     0.120650     0.103037     0.103037
# 123614     0.428194     0.837233     0.837233
# 123615    -0.945774    -0.739478    -0.945774
# 123616     0.969598     1.491844     1.491844
# 123617     0.426548     0.604286     0.604286
# 123618     0.893057     1.348708     1.348708
# 123619    -0.481302    -0.535205    -0.481302
# 123620     0.858052     1.167490     1.167490
# 123621    -3.332587    -0.988421    -3.332587
# 123622    -0.033781     0.041315    -0.033781
#
# [123623 rows x 3 columns]

# %%
final_predictions = df_prediction.prediction3.values

# %%
# import optuna

# def objective(trial):
#     train_x, test_x, train_y, test_y = train_test_split(df_train[df_train_columns], target, test_size=0.20, random_state=4590)
    
#     dtrain = lgb.Dataset(train_x, label=train_y)
#     dval = lgb.Dataset(test_x, label=test_y)

#     num_round = trial.suggest_int('num_round', 1, 10000)
#     param = {
#         'objective': 'regression', 
#         'metric': 'rmse',
#         'verbosity': -1,
#         'feature_fraction': trial.suggest_loguniform('feature_fraction', 0.8, 0.95),
#         'bagging_fraction': trial.suggest_loguniform('bagging_fraction', 0.8, 0.95),
#         'bagging_seed': 11,
#         'boosting_type': trial.suggest_categorical('boosting', ['gbdt', 'dart', 'goss']),
#         'num_leaves': trial.suggest_int('num_leaves', 10, 100),
#         'learning_rate': trial.suggest_loguniform('learning_rate', 1e-4, 1.0),
#         'min_child_samples': trial.suggest_int('min_child_samples', 20, 100),
#         'min_data_in_leaf':  trial.suggest_int('min_data_in_leaf', 10, 1000),
#         'lambda_l1':  trial.suggest_loguniform('lambda_l1', 1e-2, 1.0)
#     }

#     if param['boosting_type'] == 'dart':
#         param['drop_rate'] = trial.suggest_loguniform('drop_rate', 1e-4, 1.0)
#         param['skip_drop'] = trial.suggest_loguniform('skip_drop', 1e-4, 1.0)
#     if param['boosting_type'] == 'goss':
#         param['top_rate'] = trial.suggest_uniform('top_rate', 0.0, 1.0)
#         param['other_rate'] = trial.suggest_uniform('other_rate', 0.0, 1.0 - param['top_rate'])

#     gbm = lgb.train(param, dtrain, num_round, valid_sets = [dtrain, dval], verbose_eval=100, early_stopping_rounds=400)
#     preds = gbm.predict(test_x)
#     pred_labels = np.rint(preds)
#     rmse = np.sqrt(mean_squared_error(test_y, pred_labels))
#     return rmse

# study = optuna.create_study()
# study.optimize(objective, n_trials=20)

# print('Number of finished trials: {}'.format(len(study.trials)))

# print('Best trial:')
# trial = study.best_trial

# print('  Value: {}'.format(trial.value))

# print('  Params: ')
# for key, value in trial.params.items():
#     print('    {}: {}'.format(key, value))

# %%
sub_df = pd.DataFrame({"card_id":df_test["card_id"].values})
sub_df["target"] = final_predictions
sub_df.to_csv("../output/submission_model20181231.csv", index=False)
